# %% [markdown]
# # Normalisation - Équilibre du dataset
# ## Objectif
# L'objectif de ce notebook est de tester l'équilibre du jeu de données d'entraînement afin de voir s'il peut y avoir un impact positif. Pour cela nous allons essayer de mettre 3000 images de radio "NORMAL" contre 5000 images de radio "PNEUMONIA" afin de voir si cela peut améliorer les résultats du CNN.
#
# ## Hypothèses
# Les hypothèses quant aux résultats attendus sont les suivants :
# - Une moins bonne précision que celui du CNN
# - Moins de faux négatifs et plus de vrais positifs
#
# ## Etapes de la démarche
# 1. Modifier la condition de chargement des images
# 2. Tester le modèle sur le jeu de données
# 3. Calculer les métriques de performance
# 4. Comparer les résultats avec les résultats du CNN
#
# ## Conclusion
# Les résultats obtenus sont les suivants :
# - Une moins bonne précision que celui du CNN
# - Plus de faux négatifs et moins de vrais positifs
#
# Les résultats ne sont pas en accord avec l'hypothèse de départ. Étonnemment le nombre de faux négatifs est plus élevé que celui du CNN. Cela peut s'expliquer par le fait que le CNN a été entraîné sur un jeu de données plus équilibré que celui-ci.

# %%
# Check that GPU is used
import tensorflow as tf
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
from PIL import Image
import os
import numpy as np

# Define the folders where your data is stored
train_folder = 'train'
test_folder = 'test'
val_folder = 'val'

# Define the subfolders within each folder where the images are stored
subfolders = ['NORMAL', 'PNEUMONIA']

# Define the size of the images you want to resize your images to
img_width, img_height = 128, 128 # Function to load and resize images from a folder

# %%
# Function to load and resize images from a folder
def load_images_from_folder(folder, limit_per_subfolder=None):
    X = []
    y = []
    for subfolder in subfolders:
        folder_path = os.path.join(folder, subfolder)
        if limit_per_subfolder:
            # Get amount of random filenames from the folder
            if subfolder == 'NORMAL':
                limit = min(limit_per_subfolder, len(os.listdir(folder_path)))
            else:
                limit = min(5000, len(os.listdir(folder_path)))
            filenames = np.random.choice(os.listdir(folder_path), limit, replace=False)
        else:
            filenames = os.listdir(folder_path)
        for filename in filenames:
            img_path = os.path.join(folder_path, filename)
            img = Image.open(img_path)

            # Resize the image to the desired size
            img = img.resize((img_width, img_height))

            # Convert RGB image to grayscale
            img = img.convert('L')

            # Convert the image to a NumPy array and append it to X
            img = np.array(img)
            X.append(img)

            # Append the corresponding label to y
            y.append(subfolders.index(subfolder))

    X = np.array(X)
    y = np.array(y)
    return X, y

# %%
# Generate augmented for the training set
from data_augmentation import generate_augmented_images
generate_augmented_images(train_folder, 'NORMAL', image_size=(img_width, img_height))
generate_augmented_images(train_folder, 'PNEUMONIA', image_size=(img_width, img_height))
# Out:
# Found 1341 images belonging to 1 classes.
# Additional count of images to generate: 0
# Given NORMAL count: 1341
# Augmented NORMAL count: 5000
# Found 3875 images belonging to 1 classes.
# Additional count of images to generate: 0
# Given PNEUMONIA count: 3875
# Augmented PNEUMONIA count: 5000

# %%
# Load the training data
# Get min value between the number of normal images and the number of pneumonia images
train_folder = f"{train_folder}_augmented"
min_images = 3000
X_train, y_train = load_images_from_folder(train_folder, min_images)

# Load the test data
X_test, y_test = load_images_from_folder(test_folder)

# Load the validation data
X_val, y_val = load_images_from_folder(val_folder)

# %%
# Make a matplot figure to show how many images are in each subfolder of train
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))
plt.bar(subfolders, [len(os.listdir(os.path.join(train_folder, subfolder))) for subfolder in subfolders])
plt.title('Number of images in each subfolder of train')
plt.show()

# %%
# Make a matplot figure to show how many images if each class in the training set
plt.figure(figsize=(10, 5))
plt.bar(subfolders, [len(y_train[y_train == i]) for i in range(len(subfolders))])
plt.title('Number of images in each class in the training set')
plt.show()

# %%
# Normalize the pixel values to be between 0 and 1
X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255
X_val = X_val.astype('float32') / 255

X_train = X_train.reshape(len(X_train), img_width, img_height, 1)
X_test = X_test.reshape(len(X_test), img_width, img_height, 1)
X_val = X_val.reshape(len(X_val), img_width, img_height, 1)

# %%
single_image = X_train[np.random.randint(len(X_train))]
print(single_image.shape)
plt.imshow(single_image, cmap='Greys')
# Out:
# (128, 128, 1)

# %%
# Define model metrics
from keras.metrics import AUC

metrics = [
    "accuracy",
    AUC(name='auc')
]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# Define the model architecture
def create_model():
    model = Sequential()

    model.add(Conv2D(filters=32, kernel_size=(3,3), input_shape=(img_width, img_height, 1), activation="relu"))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(filters=64, kernel_size=(3,3), activation="relu"))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(filters=128, kernel_size=(3,3), activation="relu"))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(filters=256, kernel_size=(3,3), activation="relu"))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Flatten())

    model.add(Dense(256, activation="relu"))
    model.add(Dropout(0.5))

    model.add(Dense(128, activation="relu"))
    model.add(Dropout(0.5))

    model.add(Dense(1, activation="sigmoid"))

    # compile the model
    model.compile(loss="binary_crossentropy", optimizer="adam", metrics=metrics)

    return model

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='loss', patience=3, restore_best_weights=True)

# %%
# Cross validation
from sklearn.model_selection import KFold
from keras.preprocessing.image import ImageDataGenerator

# Define the number of folds for cross-validation
n_splits = 10
epochs = 7

# Initialize KFold with the number of folds
kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)

# Define lists to store the evaluation scores for each fold
accuracy_scores = []
histories = []
models = []

# Iterate through each fold and train/evaluate the model
for train_idx, val_idx in kf.split(X_train, y_train):
    # Split the data into training and validation sets for this fold
    X_train_fold, y_train_fold = X_train[train_idx], y_train[train_idx]
    X_val_fold, y_val_fold = X_train[val_idx], y_train[val_idx]

    # Create an instance of ImageDataGenerator to generate your image data
    datagen = ImageDataGenerator()

    # Create generators for training and validation data
    train_generator = datagen.flow(x=X_train_fold, y=y_train_fold, batch_size=64)
    valid_generator = datagen.flow(x=X_val_fold, y=y_val_fold, batch_size=64)

    # Create instance of the model for this fold and train it
    model = create_model()

    # Train your model on the training data for this fold
    history = model.fit(train_generator, validation_data=valid_generator, epochs=epochs, verbose=1, callbacks=[early_stop])
    histories.append(history.history)

    models.append(model)
# Out:
# Epoch 1/7
# 113/113 [==============================] - 20s 72ms/step - loss: 0.5343 - accuracy: 0.7192 - auc: 0.7731 - val_loss: 0.2674 - val_accuracy: 0.8988 - val_auc: 0.9641
# Epoch 2/7
# 113/113 [==============================] - 7s 58ms/step - loss: 0.3024 - accuracy: 0.8763 - auc: 0.9402 - val_loss: 0.2231 - val_accuracy: 0.9162 - val_auc: 0.9747
# Epoch 3/7
# 113/113 [==============================] - 7s 58ms/step - loss: 0.2763 - accuracy: 0.8944 - auc: 0.9498 - val_loss: 0.2309 - val_accuracy: 0.9212 - val_auc: 0.9762
# Epoch 4/7
# 113/113 [==============================] - 7s 58ms/step - loss: 0.2430 - accuracy: 0.9064 - auc: 0.9609 - val_loss: 0.1908 - val_accuracy: 0.9262 - val_auc: 0.9785
# Epoch 5/7
# 113/113 [==============================] - 7s 57ms/step - loss: 0.2161 - accuracy: 0.9164 - auc: 0.9688 - val_loss: 0.1892 - val_accuracy: 0.9337 - val_auc: 0.9793
# Epoch 6/7
# 113/113 [==============================] - 6s 57ms/step - loss: 0.1955 - accuracy: 0.9279 - auc: 0.9737 - val_loss: 0.1610 - val_accuracy: 0.9400 - val_auc: 0.9819
# Epoch 7/7
# 113/113 [==============================] - 7s 57ms/step - loss: 0.1686 - accuracy: 0.9375 - auc: 0.9804 - val_loss: 0.1551 - val_accuracy: 0.9413 - val_auc: 0.9846
# Epoch 1/7
# 113/113 [==============================] - 10s 73ms/step - loss: 0.5518 - accuracy: 0.7085 - auc: 0.7880 - val_loss: 0.3195 - val_accuracy: 0.8863 - val_auc: 0.9403
# Epoch 2/7
# 113/113 [==============================] - 7s 58ms/step - loss: 0.3123 - accuracy: 0.8739 - auc: 0.9366 - val_loss: 0.2655 - val_accuracy: 0.8950 - val_auc: 0.9580
# Epoch 3/7
# 113/113 [==============================] - 7s 58ms/step - loss: 0.2748 - accuracy: 0.8882 - auc: 0.9507 - val_loss: 0.2702 - val_accuracy: 0.8838 - val_auc: 0.9683
# Epoch 4/7
# 113/113 [==============================] - 7s 58ms/step - loss: 0.2425 - accuracy: 0.9044 - auc: 0.9609 - val_loss: 0.2041 - val_accuracy: 0.9225 - val_auc: 0.9712
# Epoch 5/7
# 113/113 [==============================] - 7s 58ms/step - loss: 0.2222 - accuracy: 0.9178 - auc: 0.9670 - val_loss: 0.1927 - val_accuracy: 0.9262 - val_auc: 0.9741
# Epoch 6/7
# 113/113 [==============================] - 7s 58ms/step - loss: 0.1976 - accuracy: 0.9260 - auc: 0.9734 - val_loss: 0.1764 - val_accuracy: 0.9400 - val_auc: 0.9769
# Epoch 7/7
# 113/113 [==============================] - 7s 58ms/step - loss: 0.
# Epoch 3/7
# 113/113 [==============================] - 7s 58ms/step - loss: 0.2579 - accuracy: 0.9021 - auc: 0.9565 - val_loss: 0.2409 - val_accuracy: 0.9162 - val_auc: 0.9616
# Epoch 4/7
# 113/113 [==============================] - 7s 58ms/step - loss: 0.2349 - accuracy: 0.9112 - auc: 0.9632 - val_loss: 0.2272 - val_accuracy: 0.9300 - val_auc: 0.9661
# Epoch 5/7
# 113/113 [==============================] - 7s 58ms/step - loss: 0.2177 - accuracy: 0.9197 - auc: 0.9681 - val_loss: 0.2159 - val_accuracy: 0.9200 - val_auc: 0.9666
# Epoch 6/7
# 113/113 [==============================] - 7s 58ms/step - loss: 0.1807 - accuracy: 0.9310 - auc: 0.9780 - val_loss: 0.2194 - val_accuracy: 0.9375 - val_auc: 0.9697
# Epoch 7/7
# 113/113 [==============================] - 7s 58ms/step - loss: 0.1713 - accuracy: 0.9378 - auc: 0.9801 - val_loss: 0.2174 - val_accuracy: 0.9337 - val_auc: 0.9685
# Epoch 1/7
# 113/113 [==============================] - 9s 64ms/step - loss: 0.5973 - accuracy: 0.6806 - auc: 0.7368 - val_loss: 0.3588 - val_accuracy: 0.8288 - val_auc: 0.9250
# Epoch 2/7
# 113/113 [==============================] - 7s 59ms/step - loss: 0.3434 - accuracy: 0.8593 - auc: 0.9242 - val_loss: 0.3002 - val_accuracy: 0.8712 - val_auc: 0.9540
# Epoch 3/7
# 113/113 [==============================] - 7s 58ms/step - loss: 0.2750 - accuracy: 0.8913 - auc: 0.9506 - val_loss: 0.2729 - val_accuracy: 0.8863 - val_auc: 0.9558
# Epoch 4/7
# 113/113 [==============================] - 6s 57ms/step - loss: 0.2421 - accuracy: 0.9076 - auc: 0.9602 - val_loss: 0.2255 - val_accuracy: 0.9112 - val_auc: 0.9696
# Epoch 5/7
# 113/113 [==============================] - 7s 59ms/step - loss: 0.2052 - accuracy: 0.9217 - auc: 0.9718 - val_loss: 0.1970 - val_accuracy: 0.9262 - val_auc: 0.9756
# Epoch 6/7
# 113/113 [==============================] - 7s 59ms/step - loss: 0.2009 - accuracy: 0.9274 - auc: 0.9731 - val_loss: 0.2017 - val_accuracy: 0.9212 - val_auc: 0.9733
# Epoch 7/7
# 113/113 [==============================] - 7s 58ms/step - loss: 0.1631 - accuracy: 0.9396 - auc: 0.9820 - val_loss: 0.1857 - val_accuracy: 0.9237 - val_auc: 0.9792
# Epoch 1/7
# 113/113 [==============================] - 9s 63ms/step - loss: 0.5612 - accuracy: 0.6971 - auc: 0.7727 - val_loss: 0.3523 - val_accuracy: 0.8662 - val_auc: 0.9327
# Epoch 2/7
# 113/113 [==============================] - 7s 58ms/step - loss: 0.3146 - accuracy: 0.8728 - auc: 0.9353 - val_loss: 0.2698 - val_accuracy: 0.9150 - val_auc: 0.9651
# Epoch 3/7
# 113/113 [==============================] - 7s 58ms/step - loss: 0.2728 - accuracy: 0.8958 - auc: 0.9506 - val_loss: 0.2580 - val_accuracy: 0.9087 - val_auc: 0.9664
# Epoch 4/7
# 113/113 [==============================] - 7s 58ms/step - loss: 0.2485 - accuracy: 0.9006 - auc: 0.9592 - val_loss: 0.2169 - val_accuracy: 0.9212 - val_auc: 0.9719
# Epoch 5/7
# 113/113 [==============================] - 7s 58ms/step - loss: 0.2196 - accuracy: 0.9160 - auc: 0.9673 - val_loss: 0.2031 - val_accuracy: 0.9275 - val_auc: 0.9731
# Epoch 6/7
# 113/113 [==============================] - 7s 58ms/step - loss: 0.2110 - accuracy: 0.9226 - auc: 0.9698 - val_loss: 0.2114 - val_accuracy: 0.9250 - val_auc: 0.9698
# Epoch 7/7
# 113/113 [==============================] - 7s 58ms/step - loss: 0.1845 - accuracy: 0.9329 - auc: 0.9763 - val_loss: 0.1950 - val_accuracy: 0.9312 - val_auc: 0.9770
# Epoch 1/7
# 113/113 [==============================] - 8s 61ms/step - loss: 0.5164 - accuracy: 0.7385 - auc: 0.8293 - val_loss: 0.3475 - val_accuracy: 0.8475 - val_auc: 0.9366
# Epoch 2/7
# 113/113 [==============================] - 7s 58ms/step - loss: 0.3011 - accuracy: 0.8829 - auc: 0.9406 - val_loss: 0.2864 - val_accuracy: 0.8737 - val_auc: 0.9552
# Epoch 3/7
# 113/113 [==============================] - 7s 57ms/step - loss: 0.2874 - accuracy: 0.8857 - auc: 0.9467 - val_loss: 0.2374 - val_accuracy: 0.8988 - val_auc: 0.9628
# Epoch 4/7
# 113/113 [==============================] - 6s 57ms/step - loss: 0.2355 - accuracy: 0.9108 - auc: 0.9634 - val_loss: 0.2412 - val_accuracy: 0.8975 - val_auc: 0.9629
# Epoch 5/7
# 113/113 [==============================] - 6s 57ms/step - loss: 0.2062 - accuracy: 0.9243 - auc: 0.9715 - val_loss: 0.2328 - val_accuracy: 0.9100 - val_auc: 0.9727
# Epoch 6/7
# 113/113 [==============================] - 6s 57ms/step - loss: 0.1797 - accuracy: 0.9337 - auc: 0.9776 - val_loss: 0.1916 - val_accuracy: 0.9275 - val_auc: 0.9757
# Epoch 7/7
# 113/113 [==============================] - 7s 58ms/step - loss: 0.1665 - accuracy: 0.9382 - auc: 0.9808 - val_loss: 0.1927 - val_accuracy: 0.9225 - val_auc: 0.9797
# Epoch 1/7
# 113/113 [==============================] - 9s 62ms/step - loss: 0.5340 - accuracy: 0.7068 - auc: 0.8077 - val_loss: 0.3764 - val_accuracy: 0.8263 - val_auc: 0.9445
# Epoch 2/7
# 113/113 [==============================] - 7s 58ms/step - loss: 0.3040 - accuracy: 0.8736 - auc: 0.9384 - val_loss: 0.2517 - val_accuracy: 0.9100 - val_auc: 0.9643
# Epoch 3/7
# 113/113 [==============================] - 7s 58ms/step - loss: 0.2638 - accuracy: 0.8961 - auc: 0.9535 - val_loss: 0.2318 - val_accuracy: 0.9225 - val_auc: 0.9659
# Epoch 4/7
# 113/113 [==============================] - 7s 58ms/step - loss: 0.2392 - accuracy: 0.9072 - auc: 0.9615 - val_loss: 0.2142 - val_accuracy: 0.9225 - val_auc: 0.9713
# Epoch 5/7
# 113/113 [==============================] - 7s 58ms/step - loss: 0.2211 - accuracy: 0.9194 - auc: 0.9679 - val_loss: 0.2008 - val_accuracy: 0.9237 - val_auc: 0.9744
# Epoch 6/7
# 113/113 [==============================] - 7s 58ms/step - loss: 0.1960 - accuracy: 0.9272 - auc: 0.9736 - val_loss: 0.2201 - val_accuracy: 0.9125 - val_auc: 0.9738
# Epoch 7/7
# 113/113 [==============================] - 7s 57ms/step - loss: 0.1583 - accuracy: 0.9426 - auc: 0.9826 - val_loss: 0.1744 - val_accuracy: 0.9362 - val_auc: 0.9776

# %%
# Get accuracy scores for each fold (train and validation)
loss = []
acc = []
val_loss = []
val_acc = []

for history in histories:
    loss.append(np.mean(history["loss"]))
    acc.append(np.mean(history["accuracy"]))
    val_loss.append(np.mean(history["val_loss"]))
    val_acc.append(np.mean(history["val_accuracy"]))

# %%
# Plot loss and validation loss per fold
import matplotlib.pyplot as plt
plt.title('Losses')
plt.plot(range(1, len(loss)+1), loss, label='Loss')
plt.plot(range(1, len(val_loss)+1), val_loss, label='Validation loss')
plt.ylim(0.0, 1.0)
plt.xlabel('Fold')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Plot accuracies and validation accuracies per fold
import matplotlib.pyplot as plt
plt.title('Accuracies')
plt.plot(range(1, len(acc)+1), acc, label='Accuracy')
plt.plot(range(1, len(val_acc)+1), val_acc, label='Validation accuracy')
plt.ylim(0.0, 1.0)
plt.xlabel('Fold')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Train a final model with same parameters and save it
train_generator = datagen.flow(x=X_train, y=y_train, batch_size=64)
valid_generator = datagen.flow(x=X_val, y=y_val, batch_size=64)
model = create_model()
history = model.fit(train_generator, validation_data=valid_generator, epochs=epochs, verbose=1, callbacks=[early_stop])
model.save('cnn.h5')
# Out:
# Epoch 1/7
# 125/125 [==============================] - 10s 65ms/step - loss: 0.5188 - accuracy: 0.7331 - auc: 0.8179 - val_loss: 0.5664 - val_accuracy: 0.7500 - val_auc: 0.8672
# Epoch 2/7
# 125/125 [==============================] - 7s 56ms/step - loss: 0.3013 - accuracy: 0.8801 - auc: 0.9403 - val_loss: 0.3475 - val_accuracy: 0.8750 - val_auc: 0.9688
# Epoch 3/7
# 125/125 [==============================] - 7s 56ms/step - loss: 0.2529 - accuracy: 0.9051 - auc: 0.9573 - val_loss: 0.3518 - val_accuracy: 0.8750 - val_auc: 0.9219
# Epoch 4/7
# 125/125 [==============================] - 7s 56ms/step - loss: 0.2309 - accuracy: 0.9115 - auc: 0.9641 - val_loss: 0.5321 - val_accuracy: 0.7500 - val_auc: 0.8906
# Epoch 5/7
# 125/125 [==============================] - 7s 56ms/step - loss: 0.2163 - accuracy: 0.9234 - auc: 0.9685 - val_loss: 0.6628 - val_accuracy: 0.6875 - val_auc: 0.9219
# Epoch 6/7
# 125/125 [==============================] - 7s 56ms/step - loss: 0.1886 - accuracy: 0.9301 - auc: 0.9754 - val_loss: 0.4226 - val_accuracy: 0.6875 - val_auc: 0.9375
# Epoch 7/7
# 125/125 [==============================] - 7s 56ms/step - loss: 0.1692 - accuracy: 0.9381 - auc: 0.9803 - val_loss: 0.2412 - val_accuracy: 0.9375 - val_auc: 1.0000

# %%
from keras.saving.save import load_model

model = load_model("cnn.h5")

# %%
# Plot val accuracy and val loss of the trained model
import matplotlib.pyplot as plt
plt.title('Accuracy vs Loss per Epoch')
plt.plot(range(1, len(history.history["val_accuracy"])+1), history.history["val_accuracy"], label='Accuracy')
plt.plot(range(1, len(history.history["val_loss"])+1), history.history["val_loss"], label='Loss')
plt.ylim(0.0, 1.0)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Make predictions on the test set
y_pred_test = model.predict(X_test)
y_pred_test = np.where(y_pred_test >= 0.5, 1, 0)
# Out:
# 20/20 [==============================] - 1s 16ms/step

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Compute ROC curve and AUC score for the predictions
fpr, tpr, thresholds = roc_curve(y_test, y_pred_test)
roc_auc = auc(fpr, tpr)

# Plot ROC curve and show AUC score on the plot
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()

# %%
from sklearn.metrics import confusion_matrix
# Compute the confusion matrix for test set
cm = confusion_matrix(y_test, y_pred_test.flatten())
print(cm)
# Out:
# [[189  45]
#  [ 13 377]]

# %%
# Plot the confusion matrix
class_names = subfolders
import seaborn as sns
sns.heatmap(cm, annot=True, fmt='g', cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()

# %%
# Compute the classification report for test set
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred_test, target_names=class_names))
# Out:
#               precision    recall  f1-score   support
#
#       NORMAL       0.94      0.81      0.87       234
#    PNEUMONIA       0.89      0.97      0.93       390
#
#     accuracy                           0.91       624
#    macro avg       0.91      0.89      0.90       624
# weighted avg       0.91      0.91      0.91       624

# %%
# Heatmaps and Grad-CAM
from cam import get_img_array
import cv2
import matplotlib.pyplot as plt 

images = [
    {
        "path": "./val/NORMAL/NORMAL2-IM-1442-0001.jpeg"
    },
    {
        "path": "./val/PNEUMONIA/person1946_bacteria_4874.jpeg"
    }
]

for image in images:
    image_temp = cv2.imread(image["path"])
    image_temp = cv2.cvtColor(image_temp, cv2.COLOR_RGB2GRAY)
    image_temp = cv2.resize(image_temp, (img_width, img_height))

    plt.imshow(image_temp, cmap=plt.cm.gray)
    plt.show()
    
    image["array"] = get_img_array(image["path"], size=(img_width, img_height))
# Out:
# C:\Users\nathp\anaconda3\lib\site-packages\keras\utils\image_utils.py:409: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn(

# %%
# Remove last layer's softmax
model.layers[-1].activation = None

# import os
# os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
# Print model summary to get last max pooling layer name
print(model.summary())
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_40 (Conv2D)          (None, 126, 126, 32)      320
#
#  max_pooling2d_40 (MaxPoolin  (None, 63, 63, 32)       0
#  g2D)
#
#  conv2d_41 (Conv2D)          (None, 61, 61, 64)        18496
#
#  max_pooling2d_41 (MaxPoolin  (None, 30, 30, 64)       0
#  g2D)
#
#  conv2d_42 (Conv2D)          (None, 28, 28, 128)       73856
#
#  max_pooling2d_42 (MaxPoolin  (None, 14, 14, 128)      0
#  g2D)
#
#  conv2d_43 (Conv2D)          (None, 12, 12, 256)       295168
#
#  max_pooling2d_43 (MaxPoolin  (None, 6, 6, 256)        0
#  g2D)
#
#  flatten_10 (Flatten)        (None, 9216)              0
#
#  dense_30 (Dense)            (None, 256)               2359552
#
#  dropout_20 (Dropout)        (None, 256)               0
#
#  dense_31 (Dense)            (None, 128)               32896
#
#  dropout_21 (Dropout)        (None, 128)               0
#
#  dense_32 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 2,780,417
# Trainable params: 2,780,417
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Select last conv layer
last_conv_layer_name = "max_pooling2d_43"

# %%
from cam import make_gradcam_heatmap, display_heatmaps

for image in images:
    heatmaps = []
    for layer in model.layers[:model.layers.index(model.get_layer(last_conv_layer_name)) + 1]:
        heatmap = make_gradcam_heatmap(image["array"], model, layer.name)
        heatmaps.append({
            "layer_name": layer.name,
            "image": heatmap
        })

    # Display heatmaps from all layers until the last max pooling layer
    display_heatmaps(image["path"], heatmaps)

    # Display the chosen image superimposed with heatmaps of each layer until the last max pooling layer
    display_heatmaps(image["path"], heatmaps, True)

# %%
# Predict
for image in images:
    pred = model.predict(image["array"].reshape(1, img_width, img_height, 1))
    print(pred)
    # Display predicted class
    print("Predicted class: {}".format(subfolders[int(pred[0][0])]))
# Out:
# 1/1 [==============================] - 0s 421ms/step
# [[0.]]
# Predicted class: NORMAL
# 1/1 [==============================] - 0s 128ms/step
# [[1.]]
# Predicted class: PNEUMONIA
