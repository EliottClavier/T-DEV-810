# %% [markdown]
# # Hyperparamètres - Validation croisée K-Fold
#
# ## Objectif
# La démarche de recherche avec variation du nombre de folds lors de la validation croisée va nous permettre de réduire la variance de l'évaluation du modèle, et peut-être d'identifier certains paramètres optimaux du modèle.
#
# Nous allons donc comparer le nombre de folds à chaque essais, ici avec 5 folds.
#
# ## Hypothèses
# Les hypothèses sont les suivantes :
#
# - Un nombre de folds trop faible peut engendrer une variance trop importante dans l'évaluation du modèle.
# - On peut s'attendre à l'apparition d'un sous-apprentissage, ou au contraire d'un surapprentissage.
#
# ## Étapes de la démarche
#
# - Définir le nombre de folds (5).
# - Entraîner le modèle avec la validation croisée.
# - Observer les résultats obtenus sur les données de test.
#
# ## Conclusion
#
# En conclusion, nous observons que la précision obtenue est proche de 0,92 , mais aussi que nous observons un nombre très faible de diagnostics faux-négatifs, ce qui paraît être un bon point. Nous voyons donc que la variance est présente à ce niveau avec un nombre faible de folds.
#
# Les valeurs d'accuracy et de loss pour chaque fold sont assez proches, ce qui pourrait signifier que l'évaluation du modèle avec 5 folds est stable et que les données restent représentatives entre ces derniers.

# %%
# Check that GPU is used
import tensorflow as tf
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
from PIL import Image
import os
import numpy as np

# Define the folders where your data is stored
train_folder = 'train'
test_folder = 'test'
val_folder = 'val'

# Define the subfolders within each folder where the images are stored
subfolders = ['NORMAL', 'PNEUMONIA']

# Define the size of the images you want to resize your images to
img_width, img_height = 128, 128

# %%
# Function to load and resize images from a folder
def load_images_from_folder(folder, limit_per_subfolder=None):
    X = []
    y = []
    for subfolder in subfolders:
        folder_path = os.path.join(folder, subfolder)
        if limit_per_subfolder:
            # Get amount of random filenames from the folder
            filenames = np.random.choice(os.listdir(folder_path), limit_per_subfolder, replace=False)
        else:
            filenames = os.listdir(folder_path)
        for filename in filenames:
            img_path = os.path.join(folder_path, filename)
            img = Image.open(img_path)

            # Resize the image to the desired size
            img = img.resize((img_width, img_height))

            # Convert RGB image to grayscale
            img = img.convert('L')

            # Convert the image to a NumPy array and append it to X
            img = np.array(img)
            X.append(img)

            # Append the corresponding label to y
            y.append(subfolders.index(subfolder))

    X = np.array(X)
    y = np.array(y)
    return X, y

# %%
# Generate augmented for the training set
from data_augmentation import generate_augmented_images
generate_augmented_images(train_folder, 'NORMAL', image_size=(img_width, img_height))
generate_augmented_images(train_folder, 'PNEUMONIA', image_size=(img_width, img_height))
# Out:
# Found 1341 images belonging to 1 classes.
# Additional count of images to generate: 0
# Given NORMAL count: 1341
# Augmented NORMAL count: 5000
# Found 2954 images belonging to 1 classes.
# Additional count of images to generate: 0
# Given PNEUMONIA count: 2954
# Augmented PNEUMONIA count: 5000

# %%
# Load the training data
# Get min value between the number of normal images and the number of pneumonia images
train_folder = f"{train_folder}_augmented"
min_images = min(len(os.listdir(os.path.join(train_folder, subfolders[0]))), len(os.listdir(os.path.join(train_folder, subfolders[1]))))
X_train, y_train = load_images_from_folder(train_folder, min_images)

# Load the test data
X_test, y_test = load_images_from_folder(test_folder)

# Load the validation data
X_val, y_val = load_images_from_folder(val_folder)

# %%
# Make a matplot figure to show how many images are in each subfolder of train
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))
plt.bar(subfolders, [len(os.listdir(os.path.join(train_folder, subfolder))) for subfolder in subfolders])
plt.title('Number of images in each subfolder of train')
plt.show()

# %%
# Make a matplot figure to show how many images if each class in the training set
plt.figure(figsize=(10, 5))
plt.bar(subfolders, [len(y_train[y_train == i]) for i in range(len(subfolders))])
plt.title('Number of images in each class in the training set')
plt.show()

# %%
# Normalize the pixel values to be between 0 and 1
X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255
X_val = X_val.astype('float32') / 255

X_train = X_train.reshape(len(X_train), img_width, img_height, 1)
X_test = X_test.reshape(len(X_test), img_width, img_height, 1)
X_val = X_val.reshape(len(X_val), img_width, img_height, 1)

# %%
single_image = X_train[np.random.randint(len(X_train))]
print(single_image.shape)
plt.imshow(single_image, cmap='Greys')
# Out:
# (128, 128, 1)

# %%
# Define model metrics
from keras.metrics import AUC

metrics = [
    "accuracy",
    AUC(name='auc')
]

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# Define the model architecture
def create_model():
    model = Sequential()

    model.add(Conv2D(filters=32, kernel_size=(3,3), input_shape=(img_width, img_height, 1), activation="relu"))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(filters=64, kernel_size=(3,3), activation="relu"))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(filters=128, kernel_size=(3,3), activation="relu"))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(filters=256, kernel_size=(3,3), activation="relu"))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Flatten())

    model.add(Dense(256, activation="relu"))
    model.add(Dropout(0.5))

    model.add(Dense(128, activation="relu"))
    model.add(Dropout(0.5))

    model.add(Dense(1, activation="sigmoid"))

    # compile the model
    model.compile(loss="binary_crossentropy", optimizer="adam", metrics=metrics)

    return model

# %%
from keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='loss', patience=3, restore_best_weights=True)

# %%
# Cross validation
from sklearn.model_selection import KFold
from keras.preprocessing.image import ImageDataGenerator

# Define the number of folds for cross-validation
n_splits = 5
epochs = 7
batch_size = 64

# Initialize KFold with the number of folds
kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)

# Define lists to store the evaluation scores for each fold
accuracy_scores = []
histories = []
models = []

# Iterate through each fold and train/evaluate the model
for train_idx, val_idx in kf.split(X_train, y_train):
    # Split the data into training and validation sets for this fold
    X_train_fold, y_train_fold = X_train[train_idx], y_train[train_idx]
    X_val_fold, y_val_fold = X_train[val_idx], y_train[val_idx]

    # Create an instance of ImageDataGenerator to generate your image data
    datagen = ImageDataGenerator()

    # Create generators for training and validation data
    train_generator = datagen.flow(x=X_train_fold, y=y_train_fold, batch_size=batch_size)
    valid_generator = datagen.flow(x=X_val_fold, y=y_val_fold, batch_size=batch_size)

    # Create instance of the model for this fold and train it
    model = create_model()

    # Train your model on the training data for this fold
    history = model.fit(train_generator, validation_data=valid_generator, epochs=epochs, verbose=1, callbacks=[early_stop])
    histories.append(history.history)

    models.append(model)
# Out:
# Epoch 1/7
# 125/125 [==============================] - 11s 35ms/step - loss: 0.5076 - accuracy: 0.7265 - auc: 0.8223 - val_loss: 0.2471 - val_accuracy: 0.9075 - val_auc: 0.9602
# Epoch 2/7
# 125/125 [==============================] - 4s 32ms/step - loss: 0.2842 - accuracy: 0.8914 - auc: 0.9489 - val_loss: 0.2046 - val_accuracy: 0.9295 - val_auc: 0.9721
# Epoch 3/7
# 125/125 [==============================] - 4s 32ms/step - loss: 0.2187 - accuracy: 0.9196 - auc: 0.9692 - val_loss: 0.2154 - val_accuracy: 0.9160 - val_auc: 0.9789
# Epoch 4/7
# 125/125 [==============================] - 4s 32ms/step - loss: 0.2024 - accuracy: 0.9224 - auc: 0.9742 - val_loss: 0.1897 - val_accuracy: 0.9265 - val_auc: 0.9829
# Epoch 5/7
# 125/125 [==============================] - 4s 32ms/step - loss: 0.1616 - accuracy: 0.9435 - auc: 0.9828 - val_loss: 0.1490 - val_accuracy: 0.9465 - val_auc: 0.9859
# Epoch 6/7
# 125/125 [==============================] - 4s 32ms/step - loss: 0.1499 - accuracy: 0.9460 - auc: 0.9851 - val_loss: 0.1838 - val_accuracy: 0.9365 - val_auc: 0.9810
# Epoch 7/7
# 125/125 [==============================] - 4s 32ms/step - loss: 0.1330 - accuracy: 0.9517 - auc: 0.9879 - val_loss: 0.2149 - val_accuracy: 0.9245 - val_auc: 0.9839
# Epoch 1/7
# 125/125 [==============================] - 5s 34ms/step - loss: 0.6349 - accuracy: 0.6263 - auc: 0.7783 - val_loss: 0.4537 - val_accuracy: 0.8235 - val_auc: 0.8937
# Epoch 2/7
# 125/125 [==============================] - 4s 32ms/step - loss: 0.3795 - accuracy: 0.8413 - auc: 0.9120 - val_loss: 0.2858 - val_accuracy: 0.8890 - val_auc: 0.9567
# Epoch 3/7
# 125/125 [==============================] - 4s 32ms/step - loss: 0.2752 - accuracy: 0.8936 - auc: 0.9535 - val_loss: 0.2379 - val_accuracy: 0.9070 - val_auc: 0.9715
# Epoch 4/7
# 125/125 [==============================] - 4s 32ms/step - loss: 0.2495 - accuracy: 0.9078 - auc: 0.9608 - val_loss: 0.1989 - val_accuracy: 0.9225 - val_auc: 0.9750
# Epoch 5/7
# 125/125 [==============================] - 4s 32ms/step - loss: 0.1988 - accuracy: 0.9256 - auc: 0.9747 - val_loss: 0.1787 - val_accuracy: 0.9340 - val_auc: 0.9808
# Epoch 6/7
# 125/125 [==============================] - 4s 32ms/step - loss: 0.1730 - accuracy: 0.9354 - auc: 0.9811 - val_loss: 0.1963 - val_accuracy: 0.9235 - val_auc: 0.9810
# Epoch 7/7
# 125/125 [==============================] - 4s 32ms/step - loss: 0.1583 - accuracy: 0.9419 - auc: 0.9838 - val_loss: 0.2090 - val_accuracy: 0.9180 - val_auc: 0.9821
# Epoch 1/7
# 125/125 [==============================] - 5s 34ms/step - loss: 0.5791 - accuracy: 0.6740 - auc: 0.8226 - val_loss: 0.3982 - val_accuracy: 0.8145 - val_auc: 0.9302
# Epoch 2/7
# 125/125 [==============================] - 4s 32ms/step - loss: 0.2982 - accuracy: 0.8864 - auc: 0.9448 - val_loss: 0.2446 - val_accuracy: 0.9055 - val_auc: 0.9650
# Epoch 3/7
# 125/125 [==============================] - 4s 32ms/step - loss: 0.2372 - accuracy: 0.9091 - auc: 0.9644 - val_loss: 0.2494 - val_accuracy: 0.9050 - val_auc: 0.9673
# Epoch 4/7
# 125/125 [==============================] - 4s 33ms/step - loss: 0.2059 - accuracy: 0.9261 - auc: 0.9722 - val_loss: 0.2376 - val_accuracy: 0.9090 - val_auc: 0.9769
# Epoch 5/7
# 125/125 [==============================] - 4s 33ms/step - loss: 0.1856 - accuracy: 0.9309 - auc: 0.9773 - val_loss: 0.1879 - val_accuracy: 0.9290 - val_auc: 0.9782
# Epoch 6/7
# 125/125 [==============================] - 4s 33ms/step - loss: 0.1621 - accuracy: 0.9405 - auc: 0.9830 - val_loss: 0.1900 - val_accuracy: 0.9300 - val_auc: 0.9797
# Epoch 7/7
# 125/125 [==============================] - 4s 34ms/step - loss: 0.1406 - accuracy: 0.9495 - auc: 0.9868 - val_loss: 0.1846 - val_accuracy: 0.9315 - val_auc: 0.9813
# Epoch 1/7
# 125/125 [==============================] - 5s 36ms/step - loss: 0.5425 - accuracy: 0.7085 - auc: 0.8535 - val_loss: 0.4980 - val_accuracy: 0.7635 - val_auc: 0.9417
# Epoch 2/7
# 125/125 [==============================] - 4s 34ms/step - loss: 0.3118 - accuracy: 0.8794 - auc: 0.9387 - val_loss: 0.2984 - val_accuracy: 0.8715 - val_auc: 0.9576
# Epoch 3/7
# 125/125 [==============================] - 4s 34ms/step - loss: 0.2535 - accuracy: 0.9041 - auc: 0.9588 - val_loss: 0.2298 - val_accuracy: 0.9150 - val_auc: 0.9679
# Epoch 4/7
# 125/125 [==============================] - 4s 34ms/step - loss: 0.2306 - accuracy: 0.9140 - auc: 0.9664 - val_loss: 0.2383 - val_accuracy: 0.9080 - val_auc: 0.9705
# Epoch 5/7
# 125/125 [==============================] - 4s 34ms/step - loss: 0.1882 - accuracy: 0.9320 - auc: 0.9770 - val_loss: 0.2066 - val_accuracy: 0.9245 - val_auc: 0.9737
# Epoch 6/7
# 125/125 [==============================] - 4s 34ms/step - loss: 0.1671 - accuracy: 0.9364 - auc: 0.9820 - val_loss: 0.2030 - val_accuracy: 0.9285 - val_auc: 0.9769
# Epoch 7/7
# 125/125 [==============================] - 4s 35ms/step - loss: 0.1502 - accuracy: 0.9450 - auc: 0.9847 - val_loss: 0.2261 - val_accuracy: 0.9205 - val_auc: 0.9760
# Epoch 1/7
# 125/125 [==============================] - 5s 36ms/step - loss: 0.5415 - accuracy: 0.6969 - auc: 0.8488 - val_loss: 0.3094 - val_accuracy: 0.8765 - val_auc: 0.9400
# Epoch 2/7
# 125/125 [==============================] - 4s 35ms/step - loss: 0.3173 - accuracy: 0.8758 - auc: 0.9362 - val_loss: 0.2486 - val_accuracy: 0.9080 - val_auc: 0.9644
# Epoch 3/7
# 125/125 [==============================] - 4s 35ms/step - loss: 0.2714 - accuracy: 0.8975 - auc: 0.9526 - val_loss: 0.2412 - val_accuracy: 0.9155 - val_auc: 0.9676
# Epoch 4/7
# 125/125 [==============================] - 4s 35ms/step - loss: 0.2238 - accuracy: 0.9156 - auc: 0.9681 - val_loss: 0.1928 - val_accuracy: 0.9305 - val_auc: 0.9771
# Epoch 5/7
# 125/125 [==============================] - 4s 35ms/step - loss: 0.2046 - accuracy: 0.9241 - auc: 0.9732 - val_loss: 0.1948 - val_accuracy: 0.9300 - val_auc: 0.9779
# Epoch 6/7
# 125/125 [==============================] - 4s 35ms/step - loss: 0.1747 - accuracy: 0.9365 - auc: 0.9798 - val_loss: 0.1976 - val_accuracy: 0.9240 - val_auc: 0.9794
# Epoch 7/7
# 125/125 [==============================] - 4s 35ms/step - loss: 0.1592 - accuracy: 0.9419 - auc: 0.9836 - val_loss: 0.1840 - val_accuracy: 0.9360 - val_auc: 0.9783

# %%
import matplotlib.pyplot as plt

# Define the subplots for the different metrics
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 10))

# Iterate through each fold and plot the accuracy and loss curves
for i, history in enumerate(histories):
    # Get the accuracy and loss data for this fold
    accuracy = history['accuracy']
    loss = history['loss']
    val_accuracy = history['val_accuracy']
    val_loss = history['val_loss']

    # Plot the accuracy curve
    ax1.plot(accuracy, label='Fold {}'.format(i+1))
    ax1.plot(val_accuracy, label='Val Fold {}'.format(i+1), linestyle='--')

    # Plot the loss curve
    ax2.plot(loss, label='Fold {}'.format(i+1))
    ax2.plot(val_loss, label='Val Fold {}'.format(i+1), linestyle='--')

# Add labels and legends to the plots
ax1.set_title('Accuracy')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Accuracy')
ax1.legend()

ax2.set_title('Loss')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Loss')
ax2.legend()

plt.show()

# %%
# Get accuracy scores for each fold (train and validation)
loss = []
acc = []
val_loss = []
val_acc = []

for history in histories:
    loss.append(np.mean(history["loss"]))
    acc.append(np.mean(history["accuracy"]))
    val_loss.append(np.mean(history["val_loss"]))
    val_acc.append(np.mean(history["val_accuracy"]))

# %%
# Plot loss and validation loss per fold
import matplotlib.pyplot as plt
plt.title('Losses')
plt.plot(range(1, len(acc)+1), acc, label='Loss')
plt.plot(range(1, len(val_acc)+1), val_acc, label='Validation loss')
plt.ylim(0.0, 1.0)
plt.xlabel('Fold')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Plot accuracies and validation accuracies per fold
import matplotlib.pyplot as plt
plt.title('Accuracies')
plt.plot(range(1, len(acc)+1), acc, label='Accuracy')
plt.plot(range(1, len(val_acc)+1), val_acc, label='Validation accuracy')
plt.ylim(0.0, 1.0)
plt.xlabel('Fold')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Train a final model with same parameters and save it
train_generator = datagen.flow(x=X_train, y=y_train, batch_size=batch_size)
valid_generator = datagen.flow(x=X_val, y=y_val, batch_size=batch_size)
model = create_model()
history = model.fit(train_generator, validation_data=valid_generator, epochs=epochs, verbose=1, callbacks=[early_stop])
model.save('cnn.h5')
# Out:
# Epoch 1/7
# 157/157 [==============================] - 6s 36ms/step - loss: 0.5097 - accuracy: 0.7257 - auc: 0.8621 - val_loss: 0.4839 - val_accuracy: 0.8125 - val_auc: 0.9219
# Epoch 2/7
# 157/157 [==============================] - 5s 33ms/step - loss: 0.2978 - accuracy: 0.8835 - auc: 0.9441 - val_loss: 0.3259 - val_accuracy: 0.8750 - val_auc: 0.9531
# Epoch 3/7
# 157/157 [==============================] - 5s 34ms/step - loss: 0.2319 - accuracy: 0.9149 - auc: 0.9653 - val_loss: 0.4416 - val_accuracy: 0.8125 - val_auc: 0.8594
# Epoch 4/7
# 157/157 [==============================] - 5s 33ms/step - loss: 0.1951 - accuracy: 0.9289 - auc: 0.9747 - val_loss: 0.7724 - val_accuracy: 0.6250 - val_auc: 0.8438
# Epoch 5/7
# 157/157 [==============================] - 5s 33ms/step - loss: 0.1684 - accuracy: 0.9381 - auc: 0.9812 - val_loss: 0.4456 - val_accuracy: 0.6875 - val_auc: 0.8750
# Epoch 6/7
# 157/157 [==============================] - 5s 33ms/step - loss: 0.1504 - accuracy: 0.9445 - auc: 0.9855 - val_loss: 0.4166 - val_accuracy: 0.8125 - val_auc: 0.8438
# Epoch 7/7
# 157/157 [==============================] - 5s 33ms/step - loss: 0.1320 - accuracy: 0.9515 - auc: 0.9882 - val_loss: 0.5414 - val_accuracy: 0.6875 - val_auc: 0.8438

# %%
# Plot val accuracy and val loss of the trained model
import matplotlib.pyplot as plt
plt.title('Accuracy vs Loss per Epoch')
plt.plot(range(1, len(history.history["val_accuracy"])+1), history.history["val_accuracy"], label='Accuracy')
plt.plot(range(1, len(history.history["val_loss"])+1), history.history["val_loss"], label='Loss')
plt.ylim(0.0, 1.0)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Make predictions on the test set
y_pred_test = model.predict(X_test)
y_pred_test = np.where(y_pred_test >= 0.5, 1, 0)
# Out:
# 20/20 [==============================] - 0s 5ms/step

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Compute ROC curve and AUC score for the predictions
fpr, tpr, thresholds = roc_curve(y_test, y_pred_test)
roc_auc = auc(fpr, tpr)

# Plot ROC curve and show AUC score on the plot
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()

# %%
from sklearn.metrics import confusion_matrix
# Compute the confusion matrix for test set
cm = confusion_matrix(y_test, y_pred_test.flatten())
print(cm)
# Out:
# [[211  23]
#  [ 30 360]]

# %%
# Plot the confusion matrix
class_names = subfolders
import seaborn as sns
sns.heatmap(cm, annot=True, fmt='g', cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()

# %%
# Compute the classification report for test set
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred_test, target_names=class_names))
# Out:
#               precision    recall  f1-score   support
#
#       NORMAL       0.88      0.90      0.89       234
#    PNEUMONIA       0.94      0.92      0.93       390
#
#     accuracy                           0.92       624
#    macro avg       0.91      0.91      0.91       624
# weighted avg       0.92      0.92      0.92       624

# %%
# Heatmaps and Grad-CAM
from cam import get_img_array
import cv2
import matplotlib.pyplot as plt 

images = [
    {
        "path": "./val/NORMAL/NORMAL2-IM-1442-0001.jpeg"
    },
    {
        "path": "./val/PNEUMONIA/person1946_bacteria_4874.jpeg"
    }
]

for image in images:
    image_temp = cv2.imread(image["path"])
    image_temp = cv2.cvtColor(image_temp, cv2.COLOR_RGB2GRAY)
    image_temp = cv2.resize(image_temp, (img_width, img_height))

    plt.imshow(image_temp, cmap=plt.cm.gray)
    plt.show()
    
    image["array"] = get_img_array(image["path"], size=(img_width, img_height))
# Out:
# C:\Users\proma\AppData\Roaming\Python\Python39\site-packages\keras\utils\image_utils.py:409: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn(

# %%
# Remove last layer's softmax
model.layers[-1].activation = None

# import os
# os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
# Print model summary to get last max pooling layer name
print(model.summary())
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_20 (Conv2D)          (None, 126, 126, 32)      320
#
#  max_pooling2d_20 (MaxPoolin  (None, 63, 63, 32)       0
#  g2D)
#
#  conv2d_21 (Conv2D)          (None, 61, 61, 64)        18496
#
#  max_pooling2d_21 (MaxPoolin  (None, 30, 30, 64)       0
#  g2D)
#
#  conv2d_22 (Conv2D)          (None, 28, 28, 128)       73856
#
#  max_pooling2d_22 (MaxPoolin  (None, 14, 14, 128)      0
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 12, 12, 256)       295168
#
#  max_pooling2d_23 (MaxPoolin  (None, 6, 6, 256)        0
#  g2D)
#
#  flatten_5 (Flatten)         (None, 9216)              0
#
#  dense_15 (Dense)            (None, 256)               2359552
#
#  dropout_10 (Dropout)        (None, 256)               0
#
#  dense_16 (Dense)            (None, 128)               32896
#
#  dropout_11 (Dropout)        (None, 128)               0
#
#  dense_17 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 2,780,417
# Trainable params: 2,780,417
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Select last conv layer
last_conv_layer_name = "max_pooling2d_23"

# %%
from cam import make_gradcam_heatmap, display_heatmaps

for image in images:
    heatmaps = []
    for layer in model.layers[:model.layers.index(model.get_layer(last_conv_layer_name)) + 1]:
        heatmap = make_gradcam_heatmap(image["array"], model, layer.name)
        heatmaps.append({
            "layer_name": layer.name,
            "image": heatmap
        })

    # Display heatmaps from all layers until the last max pooling layer
    display_heatmaps(image["path"], heatmaps)

    # Display the chosen image superimposed with heatmaps of each layer until the last max pooling layer
    display_heatmaps(image["path"], heatmaps, True)

# %%
# Predict
for image in images:
    pred = model.predict(image["array"].reshape(1, img_width, img_height, 1))
    print(pred)
    # Display predicted class
    print("Predicted class: {}".format(subfolders[int(pred[0][0])]))
# Out:
# 1/1 [==============================] - 0s 277ms/step
# [[0.]]
# Predicted class: NORMAL
# 1/1 [==============================] - 0s 28ms/step
# [[1.]]
# Predicted class: PNEUMONIA
