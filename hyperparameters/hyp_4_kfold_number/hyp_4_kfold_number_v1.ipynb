# %% [markdown]
# # Hyperparamètres - Validation croisée K-Fold
#
# ## Objectif
# La démarche de recherche avec variation du nombre de folds lors de la validation croisée va nous permettre de réduire la variance de l'évaluation du modèle, et peut-être d'identifier certains paramètres optimaux du modèle.
#
# Nous allons donc comparer le nombre de folds à chaque essais, ici avec 5 folds.
#
# ## Hypothèses
# Les hypothèses sont les suivantes :
#
# - Un nombre de folds trop faible peut engendrer une variance trop importante dans l'évaluation du modèle.
# - On peut s'attendre à l'apparition d'un sous-apprentissage, ou au contraire d'un surapprentissage.
#
# ## Étapes de la démarche
#
# - Définir le nombre de folds (5).
# - Entraîner le modèle avec la validation croisée.
# - Observer les résultats obtenus sur les données de test.
#
# ## Conclusion
#
# En conclusion, nous observons que la précision obtenue est proche de 0,93 , mais aussi que nous observons un nombre très faible de diagnostics faux-négatifs, ce qui paraît être un bon point. Nous voyons donc que la variance est présente à ce niveau avec un nombre faible de folds.

# %%
# Check that GPU is used
import tensorflow as tf
tf.config.list_physical_devices('GPU')

# %%
from PIL import Image
import os
import numpy as np

# Define the folders where your data is stored
train_folder = 'train'
test_folder = 'test'
val_folder = 'val'

# Define the subfolders within each folder where the images are stored
subfolders = ['NORMAL', 'PNEUMONIA']

# Define the size of the images you want to resize your images to
img_width, img_height = 128, 128

# %%
# Function to load and resize images from a folder
def load_images_from_folder(folder, limit_per_subfolder=None):
    X = []
    y = []
    for subfolder in subfolders:
        folder_path = os.path.join(folder, subfolder)
        if limit_per_subfolder:
            # Get amount of random filenames from the folder
            filenames = np.random.choice(os.listdir(folder_path), limit_per_subfolder, replace=False)
        else:
            filenames = os.listdir(folder_path)
        for filename in filenames:
            img_path = os.path.join(folder_path, filename)
            img = Image.open(img_path)

            # Resize the image to the desired size
            img = img.resize((img_width, img_height))

            # Convert RGB image to grayscale
            img = img.convert('L')

            # Convert the image to a NumPy array and append it to X
            img = np.array(img)
            X.append(img)

            # Append the corresponding label to y
            y.append(subfolders.index(subfolder))

    X = np.array(X)
    y = np.array(y)
    return X, y

# %%
# Generate augmented for the training set
from data_augmentation import generate_augmented_images
generate_augmented_images(train_folder, 'NORMAL', image_size=(img_width, img_height))
generate_augmented_images(train_folder, 'PNEUMONIA', image_size=(img_width, img_height))

# %%
# Load the training data
# Get min value between the number of normal images and the number of pneumonia images
train_folder = f"{train_folder}_augmented"
min_images = min(len(os.listdir(os.path.join(train_folder, subfolders[0]))), len(os.listdir(os.path.join(train_folder, subfolders[1]))))
X_train, y_train = load_images_from_folder(train_folder, min_images)

# Load the test data
X_test, y_test = load_images_from_folder(test_folder)

# Load the validation data
X_val, y_val = load_images_from_folder(val_folder)

# %%
# Make a matplot figure to show how many images are in each subfolder of train
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))
plt.bar(subfolders, [len(os.listdir(os.path.join(train_folder, subfolder))) for subfolder in subfolders])
plt.title('Number of images in each subfolder of train')
plt.show()

# %%
# Make a matplot figure to show how many images if each class in the training set
plt.figure(figsize=(10, 5))
plt.bar(subfolders, [len(y_train[y_train == i]) for i in range(len(subfolders))])
plt.title('Number of images in each class in the training set')
plt.show()

# %%
# Normalize the pixel values to be between 0 and 1
X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255
X_val = X_val.astype('float32') / 255

X_train = X_train.reshape(len(X_train), img_width, img_height, 1)
X_test = X_test.reshape(len(X_test), img_width, img_height, 1)
X_val = X_val.reshape(len(X_val), img_width, img_height, 1)

# %%
single_image = X_train[np.random.randint(len(X_train))]
print(single_image.shape)
plt.imshow(single_image, cmap='Greys')

# %%
# Define model metrics
from keras.metrics import AUC

metrics = [
    "accuracy",
    AUC(name='auc')
]

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# Define the model architecture
def create_model():
    model = Sequential()

    model.add(Conv2D(filters=32, kernel_size=(3,3), input_shape=(img_width, img_height, 1), activation="relu"))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(filters=64, kernel_size=(3,3), activation="relu"))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(filters=128, kernel_size=(3,3), activation="relu"))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(filters=256, kernel_size=(3,3), activation="relu"))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Flatten())

    model.add(Dense(256, activation="relu"))
    model.add(Dropout(0.5))

    model.add(Dense(128, activation="relu"))
    model.add(Dropout(0.5))

    model.add(Dense(1, activation="sigmoid"))

    # compile the model
    model.compile(loss="binary_crossentropy", optimizer="adam", metrics=metrics)

    return model

# %%
from keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='loss', patience=3, restore_best_weights=True)

# %%
# Cross validation
from sklearn.model_selection import KFold
from keras.preprocessing.image import ImageDataGenerator

# Define the number of folds for cross-validation
n_splits = 5
epochs = 7
batch_size = 64

# Initialize KFold with the number of folds
kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)

# Define lists to store the evaluation scores for each fold
accuracy_scores = []
histories = []
models = []

# Iterate through each fold and train/evaluate the model
for train_idx, val_idx in kf.split(X_train, y_train):
    # Split the data into training and validation sets for this fold
    X_train_fold, y_train_fold = X_train[train_idx], y_train[train_idx]
    X_val_fold, y_val_fold = X_train[val_idx], y_train[val_idx]

    # Create an instance of ImageDataGenerator to generate your image data
    datagen = ImageDataGenerator()

    # Create generators for training and validation data
    train_generator = datagen.flow(x=X_train_fold, y=y_train_fold, batch_size=batch_size)
    valid_generator = datagen.flow(x=X_val_fold, y=y_val_fold, batch_size=batch_size)

    # Create instance of the model for this fold and train it
    model = create_model()

    # Train your model on the training data for this fold
    history = model.fit(train_generator, validation_data=valid_generator, epochs=epochs, verbose=1, callbacks=[early_stop])
    histories.append(history.history)

    models.append(model)
# Out:
# 125/125 [==============================] - 14s 40ms/step - loss: 0.5670 - accuracy: 0.6720 - auc: 0.7636 - val_loss: 0.2842 - val_accuracy: 0.8910 - val_auc: 0.9529
# Epoch 2/7
# 125/125 [==============================] - 4s 35ms/step - loss: 0.3076 - accuracy: 0.8746 - auc: 0.9414 - val_loss: 0.2412 - val_accuracy: 0.9030 - val_auc: 0.9691
# Epoch 3/7
# 125/125 [==============================] - 5s 37ms/step - loss: 0.2657 - accuracy: 0.9022 - auc: 0.9554 - val_loss: 0.2008 - val_accuracy: 0.9280 - val_auc: 0.9766
# Epoch 4/7
# 125/125 [==============================] - 4s 35ms/step - loss: 0.2156 - accuracy: 0.9230 - auc: 0.9699 - val_loss: 0.1838 - val_accuracy: 0.9330 - val_auc: 0.9797
# Epoch 5/7
# 125/125 [==============================] - 4s 35ms/step - loss: 0.1922 - accuracy: 0.9320 - auc: 0.9762 - val_loss: 0.1765 - val_accuracy: 0.9355 - val_auc: 0.9820
# Epoch 6/7
# 125/125 [==============================] - 4s 35ms/step - loss: 0.1708 - accuracy: 0.9358 - auc: 0.9807 - val_loss: 0.1654 - val_accuracy: 0.9380 - val_auc: 0.9846
# Epoch 7/7
# 125/125 [==============================] - 4s 36ms/step - loss: 0.1518 - accuracy: 0.9436 - auc: 0.9850 - val_loss: 0.1618 - val_accuracy: 0.9410 - val_auc: 0.9848
# Epoch 1/7
# 125/125 [==============================] - 6s 40ms/step - loss: 0.5280 - accuracy: 0.7169 - auc: 0.8607 - val_loss: 0.2760 - val_accuracy: 0.8910 - val_auc: 0.9530
# Epoch 2/7
# 125/125 [==============================] - 5s 37ms/step - loss: 0.2940 - accuracy: 0.8888 - auc: 0.9461 - val_loss: 0.2756 - val_accuracy: 0.8835 - val_auc: 0.9655
# Epoch 3/7
# 125/125 [==============================] - 5s 37ms/step - loss: 0.2391 - accuracy: 0.9131 - auc: 0.9635 - val_loss: 0.2265 - val_accuracy: 0.9250 - val_auc: 0.9686
# Epoch 4/7
# 125/125 [==============================] - 5s 37ms/step - loss: 0.1989 - accuracy: 0.9274 - auc: 0.9747 - val_loss: 0.1864 - val_accuracy: 0.9330 - val_auc: 0.9783
# Epoch 5/7
# 125/125 [==============================] - 5s 37ms/step - loss: 0.1701 - accuracy: 0.9381 - auc: 0.9812 - val_loss: 0.2208 - val_accuracy: 0.9275 - val_auc: 0.9766
# Epoch 6/7
# 125/125 [==============================] - 5s 38ms/step - loss: 0.1557 - accuracy: 0.9427 - auc: 0.9841 - val_loss: 0.1797 - val_accuracy: 0.9295 - val_auc: 0.9810
# Epoch 7/7
# 125/125 [==============================] - 5s 38ms/step - loss: 0.1324 - accuracy: 0.9534 - auc: 0.9880 - val_loss: 0.1715 - val_accuracy: 0.9350 - val_auc: 0.9809
# Epoch 1/7
# 125/125 [==============================] - 6s 42ms/step - loss: 0.5860 - accuracy: 0.6668 - auc: 0.8231 - val_loss: 0.3404 - val_accuracy: 0.8650 - val_auc: 0.9384
# Epoch 2/7
# 125/125 [==============================] - 5s 39ms/step - loss: 0.3040 - accuracy: 0.8856 - auc: 0.9428 - val_loss: 0.2564 - val_accuracy: 0.8950 - val_auc: 0.9678
# Epoch 3/7
# 125/125 [==============================] - 5s 40ms/step - loss: 0.2312 - accuracy: 0.9140 - auc: 0.9661 - val_loss: 0.1993 - val_accuracy: 0.9285 - val_auc: 0.9754
# Epoch 4/7
# 125/125 [==============================] - 5s 41ms/step - loss: 0.1963 - accuracy: 0.9261 - auc: 0.9753 - val_loss: 0.1851 - val_accuracy: 0.9350 - val_auc: 0.9782
# Epoch 5/7
# 125/125 [==============================] - 5s 41ms/step - loss: 0.1685 - accuracy: 0.9390 - auc: 0.9816 - val_loss: 0.1660 - val_accuracy: 0.9440 - val_auc: 0.9823
# Epoch 6/7
# 125/125 [==============================] - 5s 41ms/step - loss: 0.1524 - accuracy: 0.9457 - auc: 0.9845 - val_loss: 0.1710 - val_accuracy: 0.9415 - val_auc: 0.9817
# Epoch 7/7
# 125/125 [==============================] - 5s 41ms/step - loss: 0.1368 - accuracy: 0.9488 - auc: 0.9879 - val_loss: 0.1689 - val_accuracy: 0.9415 - val_auc: 0.9819
# Epoch 1/7
# 125/125 [==============================] - 6s 43ms/step - loss: 0.5523 - accuracy: 0.7001 - auc: 0.8514 - val_loss: 0.3263 - val_accuracy: 0.8675 - val_auc: 0.9403
# Epoch 2/7
# 125/125 [==============================] - 5s 41ms/step - loss: 0.2840 - accuracy: 0.8956 - auc: 0.9491 - val_loss: 0.2206 - val_accuracy: 0.9180 - val_auc: 0.9717
# Epoch 3/7
# 125/125 [==============================] - 5s 41ms/step - loss: 0.2061 - accuracy: 0.9264 - auc: 0.9719 - val_loss: 0.1973 - val_accuracy: 0.9200 - val_auc: 0.9772
# Epoch 4/7
# 125/125 [==============================] - 5s 41ms/step - loss: 0.1964 - accuracy: 0.9312 - auc: 0.9745 - val_loss: 0.1910 - val_accuracy: 0.9265 - val_auc: 0.9790
# Epoch 5/7
# 125/125 [==============================] - 5s 41ms/step - loss: 0.1622 - accuracy: 0.9420 - auc: 0.9830 - val_loss: 0.1643 - val_accuracy: 0.9380 - val_auc: 0.9824
# Epoch 6/7
# 125/125 [==============================] - 5s 41ms/step - loss: 0.1331 - accuracy: 0.9535 - auc: 0.9880 - val_loss: 0.1964 - val_accuracy: 0.9290 - val_auc: 0.9842
# Epoch 7/7
# 125/125 [==============================] - 5s 41ms/step - loss: 0.1193 - accuracy: 0.9572 - auc: 0.9905 - val_loss: 0.1689 - val_accuracy: 0.9390 - val_auc: 0.9840
# Epoch 1/7
# 125/125 [==============================] - 6s 43ms/step - loss: 0.6035 - accuracy: 0.6376 - auc: 0.8038 - val_loss: 0.3180 - val_accuracy: 0.8740 - val_auc: 0.9363
# Epoch 2/7
# 125/125 [==============================] - 5s 41ms/step - loss: 0.3328 - accuracy: 0.8666 - auc: 0.9308 - val_loss: 0.2671 - val_accuracy: 0.8950 - val_auc: 0.9549
# Epoch 3/7
# 125/125 [==============================] - 5s 41ms/step - loss: 0.2483 - accuracy: 0.9086 - auc: 0.9616 - val_loss: 0.2057 - val_accuracy: 0.9270 - val_auc: 0.9725
# Epoch 4/7
# 125/125 [==============================] - 5s 41ms/step - loss: 0.2069 - accuracy: 0.9227 - auc: 0.9723 - val_loss: 0.1898 - val_accuracy: 0.9315 - val_auc: 0.9777
# Epoch 5/7
# 125/125 [==============================] - 5s 41ms/step - loss: 0.1828 - accuracy: 0.9324 - auc: 0.9781 - val_loss: 0.1721 - val_accuracy: 0.9370 - val_auc: 0.9836
# Epoch 6/7
# 125/125 [==============================] - 5s 41ms/step - loss: 0.1572 - accuracy: 0.9439 - auc: 0.9837 - val_loss: 0.1585 - val_accuracy: 0.9430 - val_auc: 0.9845
# Epoch 7/7
# 125/125 [==============================] - 5s 41ms/step - loss: 0.1435 - accuracy: 0.9504 - auc: 0.9861 - val_loss: 0.1640 - val_accuracy: 0.9365 - val_auc: 0.9836

# %%
# Get accuracy scores for each fold (train and validation)
loss = []
acc = []
val_loss = []
val_acc = []

for history in histories:
    loss.append(np.mean(history["loss"]))
    acc.append(np.mean(history["accuracy"]))
    val_loss.append(np.mean(history["val_loss"]))
    val_acc.append(np.mean(history["val_accuracy"]))

# %%
# Plot loss and validation loss per fold
import matplotlib.pyplot as plt
plt.title('Losses')
plt.plot(range(1, len(acc)+1), acc, label='Loss')
plt.plot(range(1, len(val_acc)+1), val_acc, label='Validation loss')
plt.ylim(0.0, 1.0)
plt.xlabel('Fold')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Plot accuracies and validation accuracies per fold
import matplotlib.pyplot as plt
plt.title('Accuracies')
plt.plot(range(1, len(acc)+1), acc, label='Accuracy')
plt.plot(range(1, len(val_acc)+1), val_acc, label='Validation accuracy')
plt.ylim(0.0, 1.0)
plt.xlabel('Fold')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Train a final model with same parameters and save it
train_generator = datagen.flow(x=X_train, y=y_train, batch_size=batch_size)
valid_generator = datagen.flow(x=X_val, y=y_val, batch_size=batch_size)
model = create_model()
history = model.fit(train_generator, validation_data=valid_generator, epochs=epochs, verbose=1, callbacks=[early_stop])
model.save('cnn.h5')
# Out:
# Epoch 1/7
# 157/157 [==============================] - 7s 41ms/step - loss: 0.4966 - accuracy: 0.7474 - auc: 0.8763 - val_loss: 0.4840 - val_accuracy: 0.7500 - val_auc: 0.9531
# Epoch 2/7
# 157/157 [==============================] - 6s 38ms/step - loss: 0.2819 - accuracy: 0.8941 - auc: 0.9507 - val_loss: 0.3235 - val_accuracy: 0.8750 - val_auc: 1.0000
# Epoch 3/7
# 157/157 [==============================] - 6s 38ms/step - loss: 0.2134 - accuracy: 0.9209 - auc: 0.9707 - val_loss: 0.6083 - val_accuracy: 0.6875 - val_auc: 0.8906
# Epoch 4/7
# 157/157 [==============================] - 6s 38ms/step - loss: 0.1812 - accuracy: 0.9323 - auc: 0.9786 - val_loss: 0.6390 - val_accuracy: 0.6875 - val_auc: 0.8594
# Epoch 5/7
# 157/157 [==============================] - 6s 38ms/step - loss: 0.1619 - accuracy: 0.9410 - auc: 0.9826 - val_loss: 0.5941 - val_accuracy: 0.6250 - val_auc: 0.8125
# Epoch 6/7
# 157/157 [==============================] - 6s 38ms/step - loss: 0.1396 - accuracy: 0.9510 - auc: 0.9867 - val_loss: 0.7219 - val_accuracy: 0.7500 - val_auc: 0.8125
# Epoch 7/7
# 157/157 [==============================] - 6s 38ms/step - loss: 0.1226 - accuracy: 0.9568 - auc: 0.9900 - val_loss: 0.8722 - val_accuracy: 0.6250 - val_auc: 0.8594

# %%
# Plot val accuracy and val loss of the trained model
import matplotlib.pyplot as plt
plt.title('Accuracy vs Loss per Epoch')
plt.plot(range(1, len(history.history["val_accuracy"])+1), history.history["val_accuracy"], label='Accuracy')
plt.plot(range(1, len(history.history["val_loss"])+1), history.history["val_loss"], label='Loss')
plt.ylim(0.0, 1.0)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Make predictions on the test set
y_pred_test = model.predict(X_test)
y_pred_test = np.where(y_pred_test >= 0.5, 1, 0)
# Out:
# 20/20 [==============================] - 1s 5ms/step

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Compute ROC curve and AUC score for the predictions
fpr, tpr, thresholds = roc_curve(y_test, y_pred_test)
roc_auc = auc(fpr, tpr)

# Plot ROC curve and show AUC score on the plot
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()

# %%
from sklearn.metrics import confusion_matrix
# Compute the confusion matrix for test set
cm = confusion_matrix(y_test, y_pred_test.flatten())
print(cm)
# Out:
# [[192  42]
#  [  4 386]]

# %%
# Plot the confusion matrix
class_names = subfolders
import seaborn as sns
sns.heatmap(cm, annot=True, fmt='g', cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()

# %%
# Compute the classification report for test set
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred_test, target_names=class_names))
# Out:
#               precision    recall  f1-score   support
#
#       NORMAL       0.98      0.82      0.89       234
#    PNEUMONIA       0.90      0.99      0.94       390
#
#     accuracy                           0.93       624
#    macro avg       0.94      0.91      0.92       624
# weighted avg       0.93      0.93      0.92       624

# %%
# Heatmaps and Grad-CAM
from cam import get_img_array
import cv2
import matplotlib.pyplot as plt 

images = [
    {
        "path": "./val/NORMAL/NORMAL2-IM-1442-0001.jpeg"
    },
    {
        "path": "./val/PNEUMONIA/person1946_bacteria_4874.jpeg"
    }
]

for image in images:
    image_temp = cv2.imread(image["path"])
    image_temp = cv2.cvtColor(image_temp, cv2.COLOR_RGB2GRAY)
    image_temp = cv2.resize(image_temp, (img_width, img_height))

    plt.imshow(image_temp, cmap=plt.cm.gray)
    plt.show()
    
    image["array"] = get_img_array(image["path"], size=(img_width, img_height))
# Out:
# C:\Users\proma\AppData\Roaming\Python\Python39\site-packages\keras\utils\image_utils.py:409: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn(

# %%
# Remove last layer's softmax
model.layers[-1].activation = None

# import os
# os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
# Print model summary to get last max pooling layer name
print(model.summary())
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_20 (Conv2D)          (None, 126, 126, 32)      320
#
#  max_pooling2d_20 (MaxPoolin  (None, 63, 63, 32)       0
#  g2D)
#
#  conv2d_21 (Conv2D)          (None, 61, 61, 64)        18496
#
#  max_pooling2d_21 (MaxPoolin  (None, 30, 30, 64)       0
#  g2D)
#
#  conv2d_22 (Conv2D)          (None, 28, 28, 128)       73856
#
#  max_pooling2d_22 (MaxPoolin  (None, 14, 14, 128)      0
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 12, 12, 256)       295168
#
#  max_pooling2d_23 (MaxPoolin  (None, 6, 6, 256)        0
#  g2D)
#
#  flatten_5 (Flatten)         (None, 9216)              0
#
#  dense_15 (Dense)            (None, 256)               2359552
#
#  dropout_10 (Dropout)        (None, 256)               0
#
#  dense_16 (Dense)            (None, 128)               32896
#
#  dropout_11 (Dropout)        (None, 128)               0
#
#  dense_17 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 2,780,417
# Trainable params: 2,780,417
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Select last conv layer
last_conv_layer_name = "max_pooling2d_23"

# %%
from cam import make_gradcam_heatmap, display_heatmaps

for image in images:
    heatmaps = []
    for layer in model.layers[:model.layers.index(model.get_layer(last_conv_layer_name)) + 1]:
        heatmap = make_gradcam_heatmap(image["array"], model, layer.name)
        heatmaps.append({
            "layer_name": layer.name,
            "image": heatmap
        })

    # Display heatmaps from all layers until the last max pooling layer
    display_heatmaps(image["path"], heatmaps)

    # Display the chosen image superimposed with heatmaps of each layer until the last max pooling layer
    display_heatmaps(image["path"], heatmaps, True)

# %%
# Predict
for image in images:
    pred = model.predict(image["array"].reshape(1, img_width, img_height, 1))
    print(pred)
    # Display predicted class
    print("Predicted class: {}".format(subfolders[int(pred[0][0])]))
# Out:
# 1/1 [==============================] - 0s 339ms/step
# [[0.00058416]]
# Predicted class: NORMAL
# 1/1 [==============================] - 0s 20ms/step
# [[1.]]
# Predicted class: PNEUMONIA
