# %% [markdown]
# # Augmentation d'image - Sheer
# ## Objectif
# L'objectif de ce notebook est d'évaluer l'impact de l'ajout de cisaillement aléatoire jusqu'à de -0.2 à 0.2 sur les images du jeu de données lors de la phase d'entraînement
#
# ## Hypothèses
#
# - Le jeu de donnés ne sera pas suffisament divers pour éviter l'overfitting
# - Le cisaillement aura peu d'impact sur la performance du model meme si il va permettre de diminuer l'overfitting
#
# ## Etapes de la démarche
# 1. Modifier la fonction de formatage des images pour y ajouter du cisaillement via shear_range
# 2. Tester le jeu de données avec l'algo CNN
# 3. Calculer les métriques de performance
# 4. Comparer les résultats avec les résultats du template
#
# ## Interprétation des résultats et Conclusion
# Les résultats obtenus sont les suivants :

# %%
# Check that GPU is used
import tensorflow as tf

tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
from PIL import Image
import os
import numpy as np
from dotenv import load_dotenv

dotenv_path = 'var.env'

# Chargez les variables d'environnement
load_dotenv(dotenv_path)
BASE = os.environ.get('BASE')
ITERATION = '_v2'

TRAIN_FOLDER = BASE + 'train'
TEST_FOLDER = BASE + 'test'
VAL_FOLDER = BASE + 'val'

TRAIN_AUGMENTED_FOLDER = BASE + 'train_augmented'+ ITERATION


# Define the subfolders within each folder where the images are stored
subfolders = ['NORMAL', 'PNEUMONIA']

# Define the size of the images you want to resize your images to
img_width, img_height = 128, 128  # Function to load and resize images from a folder

# %%
# Fonction de chargement des images des dataset et des labels associés
def load_images_from_folder(folder, limit_per_subfolder=None):
    X = []
    y = []
    for subfolder in subfolders:
        folder_path = os.path.join(folder, subfolder)
        if limit_per_subfolder:
            # Get amount of random filenames from the folder
            filenames = np.random.choice(os.listdir(folder_path), limit_per_subfolder, replace=False)
        else:
            filenames = os.listdir(folder_path)
        for filename in filenames:
            img_path = os.path.join(folder_path, filename)
            img = Image.open(img_path)

            # Resize the image to the desired size
            img = img.resize((img_width, img_height))

            # Convert RGB image to grayscale
            img = img.convert('L')

            # Convert the image to a NumPy array and append it to X
            img = np.array(img)
            X.append(img)

            # Append the corresponding label to y
            y.append(subfolders.index(subfolder))

    X = np.array(X)
    y = np.array(y)
    return X, y

# %%
import os
import numpy as np
from PIL import Image, ImageOps
from keras.preprocessing.image import ImageDataGenerator

def generate_augmented_images(folder, to_augment_class, image_size=(128, 128), target_nbr=5000):
    dir = os.path.join(folder, to_augment_class)
    count = len(os.listdir(dir))

    augmented_dir = os.path.join(f"{folder}_augmented"+ITERATION, to_augment_class)

    if not os.path.exists(f"{folder}_augmented"+ITERATION):
        os.mkdir(f"{folder}_augmented"+ITERATION)

    if not os.path.exists(augmented_dir):
        os.mkdir(augmented_dir)

    augmented_count = len(os.listdir(augmented_dir))

    datagen = ImageDataGenerator(
        rotation_range=0,
        width_shift_range=0,
        height_shift_range=0,
        shear_range=0.2,
        zoom_range=0,
        horizontal_flip=True,
        rescale=0,
        fill_mode='nearest',
    )

    generator = datagen.flow_from_directory(

        folder,
        batch_size=1,
        save_to_dir=augmented_dir,
        save_format='jpeg',
        save_prefix='IM_AUGMENTED',
        classes=[to_augment_class],
        keep_aspect_ratio=True,
        target_size=image_size,
    )

    additional_count = target_nbr - len(os.listdir(augmented_dir))

    for i in range(additional_count):
        generator.next()

    new_count = len(os.listdir(augmented_dir))

    print(f'Given {to_augment_class} count: {count}')
    print(f'Augmented {to_augment_class} count: {new_count}')

# %%
generate_augmented_images(TRAIN_FOLDER, 'NORMAL', image_size=(img_width, img_height))
generate_augmented_images(TRAIN_FOLDER, 'PNEUMONIA', image_size=(img_width, img_height))
# Out:
# Found 1341 images belonging to 1 classes.
# Given NORMAL count: 1341
# Augmented NORMAL count: 5000
# Found 3875 images belonging to 1 classes.
# Given PNEUMONIA count: 3876
# Augmented PNEUMONIA count: 5000

# %% [markdown]
# # SHEARING & AUGMENTATION
# ## Comment est ajouté le cisaillement ?
# Pour équilibrer le jeu de données d'entraînement, chaque image est soumise à une fonction d'augmentation qui génère de nouvelles images dans un répertoire distinct. Dans le cadre de cette augmentation, un cisaillement aléatoire est appliqué aux données. Ces variations sont ajoutées aux images pour diversifier le jeu de données d'entraînement.

# %%
# Load the training data
# Get min value between the number of normal images and the number of pneumonia images
TRAIN_FOLDER = f"{TRAIN_AUGMENTED_FOLDER}"

TEST_FOLDER = f"{TEST_FOLDER}"
VAL_FOLDER = f"{VAL_FOLDER}"

min_images = min(len(os.listdir(os.path.join(TRAIN_FOLDER, subfolders[0]))),
                 len(os.listdir(os.path.join(TRAIN_FOLDER, subfolders[1]))))
X_train, y_train = load_images_from_folder(TRAIN_FOLDER, min_images)

# Load the test data
X_test, y_test = load_images_from_folder(TEST_FOLDER)

# Load the validation data
X_val, y_val = load_images_from_folder(VAL_FOLDER)

# %%
# Make a matplot figure to show how many images are in each subfolder of train
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.bar(subfolders, [len(os.listdir(os.path.join(TRAIN_FOLDER, subfolder))) for subfolder in subfolders])
plt.title('Number of images in each subfolder of train')
plt.show()

# %%
# Make a matplot figure to show how many images if each class in the training set
plt.figure(figsize=(10, 5))
plt.bar(subfolders, [len(y_train[y_train == i]) for i in range(len(subfolders))])
plt.title('Number of images in each class in the training set')
plt.show()

# %%
# Normalize the pixel values to be between 0 and 1
num_samples = X_train.shape[0]
print(X_test.shape)
X_train = X_train.reshape(len(X_train), img_width, img_height, 1)
X_test = X_test.reshape(len(X_test), img_width, img_height, 1)
X_val = X_val.reshape(len(X_val), img_width, img_height, 1)

X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255
X_val = X_val.astype('float32') / 255

print('done \n')
# Out:
# (624, 128, 128)
# done

# %%
single_image = X_train[np.random.randint(len(X_train))]
print(single_image.shape)
plt.imshow(single_image, cmap='Greys')
# Out:
# (128, 128, 1)

# %%
# Define model metrics
from keras.metrics import AUC

metrics = [
    "accuracy",
    AUC(name='auc')
]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout


# Define the model architecture
def create_model():
    model = Sequential()

    model.add(Conv2D(filters=32, kernel_size=(3, 3), input_shape=(img_width, img_height, 1), activation="relu"))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(filters=64, kernel_size=(3, 3), activation="relu"))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(filters=128, kernel_size=(3, 3), activation="relu"))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(filters=256, kernel_size=(3, 3), activation="relu"))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Flatten())

    model.add(Dense(256, activation="relu"))
    model.add(Dropout(0.5))

    model.add(Dense(128, activation="relu"))
    model.add(Dropout(0.5))

    model.add(Dense(1, activation="sigmoid"))

    # compile the model
    model.compile(loss="binary_crossentropy", optimizer="adam", metrics=metrics)

    return model

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(monitor='loss', patience=3, restore_best_weights=True)

# %%
# Cross validation
from sklearn.model_selection import KFold
from keras.preprocessing.image import ImageDataGenerator
from h5py import File
# Define the number of folds for cross-validation
n_splits = 10
epochs = 7
batch_size =64

# Initialize KFold with the number of folds
kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)

# Define lists to store the evaluation scores for each fold
accuracy_scores = []
og_val_accuracy_scores = []
histories = []
models = []
fold_no = 1
best_score = float('inf')  # pour une tâche de minimisation
best_model = None
# Iterate through each fold and train/evaluate the model
for train_idx, val_idx in kf.split(X_train, y_train):
    # Split the data into training and validation sets for this fold
    X_train_fold, y_train_fold = X_train[train_idx], y_train[train_idx]
    X_val_fold, y_val_fold = X_train[val_idx], y_train[val_idx]

    # Create an instance of ImageDataGenerator to generate your image data
    datagen = ImageDataGenerator()

    # Create generators for training and validation data
    train_generator = datagen.flow(x=X_train_fold, y=y_train_fold, batch_size=batch_size)
    valid_generator = datagen.flow(x=X_val_fold, y=y_val_fold, batch_size=batch_size)

    # Create instance of the model for this fold and train it
    model = create_model()

    # Train your model on the training data for this fold
    history = model.fit(train_generator, validation_data=valid_generator, epochs=epochs, verbose=1,
                        callbacks=[early_stop])
    # Model Évaluation with original val dataset
    scores = model.evaluate(X_val, y_val, verbose=1)
    og_val_accuracy_scores.append(scores[1])
    print(f'\nScore for fold with orginal val dataset {fold_no}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%\n')

    histories.append(history.history)

    models.append(model)

    # After training, evaluate the model on the validation set for this fold
    accuracy = model.evaluate(X_val_fold, y_val_fold)[1]

    # Store the accuracy score in the list
    accuracy_scores.append(accuracy)

    # Print the accuracy for this fold
    print(f"Accuracy for fold {len(accuracy_scores)}: {accuracy * 100}%")

    # Check if the model is better than the previous
    if scores[0] < best_score:
        best_score = scores[0]
        best_model = model

    fold_no = fold_no + 1

    # Sauvegarde du meilleur modèle
    if best_model is not None:
        best_model.save('cnn_best.h5')

# Calculate and print the average accuracy over all folds
average_accuracy = sum(accuracy_scores) / len(accuracy_scores)
og_val_average_accuracy = sum(og_val_accuracy_scores) / len(og_val_accuracy_scores)
print(f"\nAverage accuracy: {average_accuracy * 100}%")
print(f"\nAverage accuracy with orginal val: {og_val_average_accuracy * 100}%")
# Out:
# Epoch 1/7
# 141/141 [==============================] - 11s 67ms/step - loss: 0.3279 - accuracy: 0.8352 - auc: 0.9306 - val_loss: 0.1104 - val_accuracy: 0.9560 - val_auc: 0.9929
# Epoch 2/7
# 141/141 [==============================] - 9s 65ms/step - loss: 0.1407 - accuracy: 0.9446 - auc: 0.9872 - val_loss: 0.0916 - val_accuracy: 0.9600 - val_auc: 0.9953
# Epoch 3/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.1143 - accuracy: 0.9560 - auc: 0.9912 - val_loss: 0.0790 - val_accuracy: 0.9660 - val_auc: 0.9962
# Epoch 4/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0977 - accuracy: 0.9641 - auc: 0.9932 - val_loss: 0.0748 - val_accuracy: 0.9650 - val_auc: 0.9969
# Epoch 5/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0828 - accuracy: 0.9699 - auc: 0.9950 - val_loss: 0.0550 - val_accuracy: 0.9790 - val_auc: 0.9986
# Epoch 6/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0767 - accuracy: 0.9718 - auc: 0.9957 - val_loss: 0.0598 - val_accuracy: 0.9760 - val_auc: 0.9986
# Epoch 7/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0608 - accuracy: 0.9781 - auc: 0.9972 - val_loss: 0.0608 - val_accuracy: 0.9750 - val_auc: 0.9975
# 1/1 [==============================] - 0s 34ms/step - loss: 0.4778 - accuracy: 0.9375 - auc: 0.9062
#
# Score for fold with orginal val dataset 1: loss of 0.4778476357460022; accuracy of 93.75%
#
# 32/32 [==============================] - 0s 11ms/step - loss: 0.0608 - accuracy: 0.9750 - auc: 0.9975
# Accuracy for fold 1: 97.50000238418579%
# Epoch 1/7
# 141/141 [==============================] - 10s 65ms/step - loss: 0.3226 - accuracy: 0.8472 - auc: 0.9455 - val_loss: 0.1232 - val_accuracy: 0.9580 - val_auc: 0.9903
# Epoch 2/7
# 141/141 [==============================] - 9s 64ms/step - loss: 0.1413 - accuracy: 0.9490 - auc: 0.9869 - val_loss: 0.1205 - val_accuracy: 0.9550 - val_auc: 0.9933
# Epoch 3/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.1301 - accuracy: 0.9498 - auc: 0.9885 - val_loss: 0.0941 - val_accuracy: 0.9600 - val_auc: 0.9949
# Epoch 4/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0982 - accuracy: 0.9590 - auc: 0.9935 - val_loss: 0.1110 - val_accuracy: 0.9560 - val_auc: 0.9941
# Epoch 5/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0823 - accuracy: 0.9694 - auc: 0.9951 - val_loss: 0.1060 - val_accuracy: 0.9680 - val_auc: 0.9941
# Epoch 6/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0708 - accuracy: 0.9740 - auc: 0.9963 - val_loss: 0.0910 - val_accuracy: 0.9650 - val_auc: 0.9936
# Epoch 7/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0621 - accuracy: 0.9786 - auc: 0.9971 - val_loss: 0.0919 - val_accuracy: 0.9690 - val_auc: 0.9932
# 1/1 [==============================] - 0s 30ms/step - loss: 0.4221 - accuracy: 0.8750 - auc: 0.9531
#
# Score for fold with orginal val dataset 2: loss of 0.4221065044403076; accuracy of 87.5%
#
# 32/32 [==============================] - 0s 11ms/step - loss: 0.0919 - accuracy: 0.9690 - auc: 0.9932
# Accuracy for fold 2: 96.8999981880188%
# Epoch 1/7
# 141/141 [==============================] - 10s 65ms/step - loss: 0.3718 - accuracy: 0.7993 - auc: 0.9207 - val_loss: 0.1345 - val_accuracy: 0.9470 - val_auc: 0.9919
# Epoch 2/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.1422 - accuracy: 0.9491 - auc: 0.9864 - val_loss: 0.1038 - val_accuracy: 0.9600 - val_auc: 0.9946
# Epoch 3/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.1146 - accuracy: 0.9591 - auc: 0.9908 - val_loss: 0.0953 - val_accuracy: 0.9590 - val_auc: 0.9965
# Epoch 4/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.1012 - accuracy: 0.9607 - auc: 0.9928 - val_loss: 0.0793 - val_accuracy: 0.9670 - val_auc: 0.9956
# Epoch 5/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0957 - accuracy: 0.9649 - auc: 0.9935 - val_loss: 0.0757 - val_accuracy: 0.9690 - val_auc: 0.9963
# Epoch 6/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0842 - accuracy: 0.9691 - auc: 0.9949 - val_loss: 0.0845 - val_accuracy: 0.9710 - val_auc: 0.9958
# Epoch 7/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0686 - accuracy: 0.9754 - auc: 0.9962 - val_loss: 0.0688 - val_accuracy: 0.9770 - val_auc: 0.9978
# 1/1 [==============================] - 0s 31ms/step - loss: 0.8489 - accuracy: 0.7500 - auc: 0.8438
#
# Score for fold with orginal val dataset 3: loss of 0.8488557934761047; accuracy of 75.0%
#
# 32/32 [==============================] - 0s 11ms/step - loss: 0.0688 - accuracy: 0.9770 - auc: 0.9978
# Accuracy for fold 3: 97.69999980926514%
# Epoch 1/7
# 141/141 [==============================] - 10s 65ms/step - loss: 0.3465 - accuracy: 0.8264 - auc: 0.9353 - val_loss: 0.1447 - val_accuracy: 0.9430 - val_auc: 0.9874
# Epoch 2/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.1395 - accuracy: 0.9504 - auc: 0.9872 - val_loss: 0.1169 - val_accuracy: 0.9540 - val_auc: 0.9933
# Epoch 3/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.1173 - accuracy: 0.9578 - auc: 0.9908 - val_loss: 0.1120 - val_accuracy: 0.9550 - val_auc: 0.9925
# Epoch 4/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0967 - accuracy: 0.9638 - auc: 0.9938 - val_loss: 0.1004 - val_accuracy: 0.9640 - val_auc: 0.9945
# Epoch 5/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0862 - accuracy: 0.9698 - auc: 0.9948 - val_loss: 0.1536 - val_accuracy: 0.9430 - val_auc: 0.9936
# Epoch 6/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0747 - accuracy: 0.9732 - auc: 0.9958 - val_loss: 0.0972 - val_accuracy: 0.9610 - val_auc: 0.9940
# Epoch 7/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0690 - accuracy: 0.9739 - auc: 0.9967 - val_loss: 0.0819 - val_accuracy: 0.9690 - val_auc: 0.9956
# 1/1 [==============================] - 0s 31ms/step - loss: 0.5702 - accuracy: 0.8750 - auc: 0.8750
#
# Score for fold with orginal val dataset 4: loss of 0.5702409744262695; accuracy of 87.5%
#
# 32/32 [==============================] - 0s 11ms/step - loss: 0.0819 - accuracy: 0.9690 - auc: 0.9956
# Accuracy for fold 4: 96.8999981880188%
# Epoch 1/7
# 141/141 [==============================] - 10s 65ms/step - loss: 0.3194 - accuracy: 0.8487 - auc: 0.9464 - val_loss: 0.1705 - val_accuracy: 0.9290 - val_auc: 0.9872
# Epoch 2/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.1409 - accuracy: 0.9480 - auc: 0.9866 - val_loss: 0.1331 - val_accuracy: 0.9490 - val_auc: 0.9927
# Epoch 3/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.1185 - accuracy: 0.9559 - auc: 0.9905 - val_loss: 0.0924 - val_accuracy: 0.9660 - val_auc: 0.9948
# Epoch 4/7
# 141/141 [==============================] - 9s 64ms/step - loss: 0.0944 - accuracy: 0.9656 - auc: 0.9937 - val_loss: 0.0969 - val_accuracy: 0.9620 - val_auc: 0.9947
# Epoch 5/7
# 141/141 [==============================] - 9s 64ms/step - loss: 0.0847 - accuracy: 0.9690 - auc: 0.9947 - val_loss: 0.0779 - val_accuracy: 0.9730 - val_auc: 0.9966
# Epoch 6/7
# 141/141 [==============================] - 9s 64ms/step - loss: 0.0825 - accuracy: 0.9711 - auc: 0.9950 - val_loss: 0.0748 - val_accuracy: 0.9660 - val_auc: 0.9969
# Epoch 7/7
# 141/141 [==============================] - 9s 65ms/step - loss: 0.0716 - accuracy: 0.9738 - auc: 0.9962 - val_loss: 0.0530 - val_accuracy: 0.9800 - val_auc: 0.9982
# 1/1 [==============================] - 0s 31ms/step - loss: 0.4862 - accuracy: 0.7500 - auc: 0.9375
#
# Score for fold with orginal val dataset 5: loss of 0.48623043298721313; accuracy of 75.0%
#
# 32/32 [==============================] - 0s 11ms/step - loss: 0.0530 - accuracy: 0.9800 - auc: 0.9982
# Accuracy for fold 5: 98.00000190734863%
# Epoch 1/7
# 141/141 [==============================] - 10s 67ms/step - loss: 0.3091 - accuracy: 0.8542 - auc: 0.9498 - val_loss: 0.1157 - val_accuracy: 0.9600 - val_auc: 0.9941
# Epoch 2/7
# 141/141 [==============================] - 9s 65ms/step - loss: 0.1406 - accuracy: 0.9460 - auc: 0.9870 - val_loss: 0.0719 - val_accuracy: 0.9780 - val_auc: 0.9957
# Epoch 3/7
# 141/141 [==============================] - 9s 65ms/step - loss: 0.1171 - accuracy: 0.9560 - auc: 0.9912 - val_loss: 0.1297 - val_accuracy: 0.9440 - val_auc: 0.9931
# Epoch 4/7
# 141/141 [==============================] - 9s 65ms/step - loss: 0.1003 - accuracy: 0.9607 - auc: 0.9934 - val_loss: 0.0647 - val_accuracy: 0.9730 - val_auc: 0.9979
# Epoch 5/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0898 - accuracy: 0.9681 - auc: 0.9941 - val_loss: 0.0426 - val_accuracy: 0.9870 - val_auc: 0.9984
# Epoch 6/7
# 141/141 [==============================] - 9s 64ms/step - loss: 0.0771 - accuracy: 0.9708 - auc: 0.9959 - val_loss: 0.0584 - val_accuracy: 0.9830 - val_auc: 0.9969
# Epoch 7/7
# 141/141 [==============================] - 9s 64ms/step - loss: 0.0658 - accuracy: 0.9766 - auc: 0.9966 - val_loss: 0.0426 - val_accuracy: 0.9880 - val_auc: 0.9980
# 1/1 [==============================] - 0s 35ms/step - loss: 0.6448 - accuracy: 0.8125 - auc: 0.8906
#
# Score for fold with orginal val dataset 6: loss of 0.6447935104370117; accuracy of 81.25%
#
# 32/32 [==============================] - 0s 11ms/step - loss: 0.0426 - accuracy: 0.9880 - auc: 0.9980
# Accuracy for fold 6: 98.7999975681305%
# Epoch 1/7
# 141/141 [==============================] - 10s 65ms/step - loss: 0.3913 - accuracy: 0.7908 - auc: 0.9150 - val_loss: 0.1436 - val_accuracy: 0.9430 - val_auc: 0.9890
# Epoch 2/7
# 141/141 [==============================] - 9s 64ms/step - loss: 0.1486 - accuracy: 0.9466 - auc: 0.9856 - val_loss: 0.1089 - val_accuracy: 0.9580 - val_auc: 0.9918
# Epoch 3/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.1161 - accuracy: 0.9552 - auc: 0.9908 - val_loss: 0.1059 - val_accuracy: 0.9580 - val_auc: 0.9917
# Epoch 4/7
# 141/141 [==============================] - 10s 70ms/step - loss: 0.0979 - accuracy: 0.9628 - auc: 0.9936 - val_loss: 0.1891 - val_accuracy: 0.9320 - val_auc: 0.9925
# Epoch 5/7
# 141/141 [==============================] - 11s 74ms/step - loss: 0.0904 - accuracy: 0.9647 - auc: 0.9944 - val_loss: 0.0844 - val_accuracy: 0.9710 - val_auc: 0.9941
# Epoch 6/7
# 141/141 [==============================] - 10s 71ms/step - loss: 0.0801 - accuracy: 0.9709 - auc: 0.9952 - val_loss: 0.0868 - val_accuracy: 0.9670 - val_auc: 0.9950
# Epoch 7/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0706 - accuracy: 0.9740 - auc: 0.9964 - val_loss: 0.0700 - val_accuracy: 0.9780 - val_auc: 0.9960
# 1/1 [==============================] - 0s 30ms/step - loss: 0.6092 - accuracy: 0.7500 - auc: 0.8984
#
# Score for fold with orginal val dataset 7: loss of 0.6091501712799072; accuracy of 75.0%
#
# 32/32 [==============================] - 0s 11ms/step - loss: 0.0700 - accuracy: 0.9780 - auc: 0.9960
# Accuracy for fold 7: 97.79999852180481%
# Epoch 1/7
# 141/141 [==============================] - 11s 65ms/step - loss: 0.3100 - accuracy: 0.8551 - auc: 0.9498 - val_loss: 0.1586 - val_accuracy: 0.9320 - val_auc: 0.9932
# Epoch 2/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.1472 - accuracy: 0.9456 - auc: 0.9858 - val_loss: 0.0800 - val_accuracy: 0.9620 - val_auc: 0.9957
# Epoch 3/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.1100 - accuracy: 0.9603 - auc: 0.9914 - val_loss: 0.0618 - val_accuracy: 0.9730 - val_auc: 0.9981
# Epoch 4/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.1026 - accuracy: 0.9616 - auc: 0.9925 - val_loss: 0.0666 - val_accuracy: 0.9730 - val_auc: 0.9965
# Epoch 5/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0806 - accuracy: 0.9707 - auc: 0.9952 - val_loss: 0.0452 - val_accuracy: 0.9820 - val_auc: 0.9981
# Epoch 6/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0692 - accuracy: 0.9756 - auc: 0.9961 - val_loss: 0.0537 - val_accuracy: 0.9800 - val_auc: 0.9988
# Epoch 7/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0621 - accuracy: 0.9769 - auc: 0.9971 - val_loss: 0.0371 - val_accuracy: 0.9860 - val_auc: 0.9993
# 1/1 [==============================] - 0s 35ms/step - loss: 0.6810 - accuracy: 0.8125 - auc: 0.8828
#
# Score for fold with orginal val dataset 8: loss of 0.6809676885604858; accuracy of 81.25%
#
# 32/32 [==============================] - 0s 11ms/step - loss: 0.0371 - accuracy: 0.9860 - auc: 0.9993
# Accuracy for fold 8: 98.60000014305115%
# Epoch 1/7
# 141/141 [==============================] - 11s 67ms/step - loss: 0.3683 - accuracy: 0.8063 - auc: 0.9235 - val_loss: 0.1296 - val_accuracy: 0.9460 - val_auc: 0.9894
# Epoch 2/7
# 141/141 [==============================] - 9s 64ms/step - loss: 0.1515 - accuracy: 0.9446 - auc: 0.9847 - val_loss: 0.1489 - val_accuracy: 0.9460 - val_auc: 0.9911
# Epoch 3/7
# 141/141 [==============================] - 9s 65ms/step - loss: 0.1180 - accuracy: 0.9561 - auc: 0.9906 - val_loss: 0.1033 - val_accuracy: 0.9640 - val_auc: 0.9945
# Epoch 4/7
# 141/141 [==============================] - 9s 65ms/step - loss: 0.1010 - accuracy: 0.9624 - auc: 0.9930 - val_loss: 0.0823 - val_accuracy: 0.9660 - val_auc: 0.9958
# Epoch 5/7
# 141/141 [==============================] - 9s 64ms/step - loss: 0.0963 - accuracy: 0.9651 - auc: 0.9935 - val_loss: 0.0840 - val_accuracy: 0.9660 - val_auc: 0.9956
# Epoch 6/7
# 141/141 [==============================] - 9s 65ms/step - loss: 0.0744 - accuracy: 0.9726 - auc: 0.9957 - val_loss: 0.0756 - val_accuracy: 0.9680 - val_auc: 0.9969
# Epoch 7/7
# 141/141 [==============================] - 9s 66ms/step - loss: 0.0651 - accuracy: 0.9764 - auc: 0.9970 - val_loss: 0.0895 - val_accuracy: 0.9660 - val_auc: 0.9948
# 1/1 [==============================] - 0s 33ms/step - loss: 0.3572 - accuracy: 0.9375 - auc: 0.9219
#
# Score for fold with orginal val dataset 9: loss of 0.3572385609149933; accuracy of 93.75%
#
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0895 - accuracy: 0.9660 - auc: 0.9948
# Accuracy for fold 9: 96.60000205039978%
# Epoch 1/7
# 141/141 [==============================] - 11s 65ms/step - loss: 0.3223 - accuracy: 0.8503 - auc: 0.9449 - val_loss: 0.1994 - val_accuracy: 0.9180 - val_auc: 0.9834
# Epoch 2/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.1282 - accuracy: 0.9523 - auc: 0.9891 - val_loss: 0.1541 - val_accuracy: 0.9450 - val_auc: 0.9875
# Epoch 3/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.1065 - accuracy: 0.9609 - auc: 0.9920 - val_loss: 0.1310 - val_accuracy: 0.9550 - val_auc: 0.9919
# Epoch 4/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0987 - accuracy: 0.9629 - auc: 0.9935 - val_loss: 0.1191 - val_accuracy: 0.9560 - val_auc: 0.9912
# Epoch 5/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0780 - accuracy: 0.9720 - auc: 0.9955 - val_loss: 0.1149 - val_accuracy: 0.9630 - val_auc: 0.9916
# Epoch 6/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0691 - accuracy: 0.9748 - auc: 0.9966 - val_loss: 0.1078 - val_accuracy: 0.9660 - val_auc: 0.9915
# Epoch 7/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0570 - accuracy: 0.9792 - auc: 0.9972 - val_loss: 0.1249 - val_accuracy: 0.9580 - val_auc: 0.9924
# 1/1 [==============================] - 0s 31ms/step - loss: 0.7255 - accuracy: 0.7500 - auc: 0.8828
#
# Score for fold with orginal val dataset 10: loss of 0.7254794239997864; accuracy of 75.0%
#
# 32/32 [==============================] - 0s 11ms/step - loss: 0.1249 - accuracy: 0.9580 - auc: 0.9924
# Accuracy for fold 10: 95.80000042915344%
#
# Average accuracy: 97.45999991893768%
#
# Average accuracy with orginal val: 82.5%

# %%
# Get accuracy scores for each fold (train and validation)
loss = []
acc = []
val_loss = []
val_acc = []

for history in histories:
    loss.append(np.mean(history["loss"]))
    acc.append(np.mean(history["accuracy"]))
    val_loss.append(np.mean(history["val_loss"]))
    val_acc.append(np.mean(history["val_accuracy"]))

# %%
# Plot loss and validation loss per fold
import matplotlib.pyplot as plt
plt.title('Losses')
plt.plot(range(1, len(loss)+1), loss, label='Loss')
plt.plot(range(1, len(val_loss)+1), val_loss, label='Validation loss')
plt.ylim(0.0, 1.0)
plt.xlabel('Fold')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Plot accuracies and validation accuracies per fold
import matplotlib.pyplot as plt

plt.title('Accuracies')
plt.plot(range(1, len(acc) + 1), acc, label='Accuracy')
plt.plot(range(1, len(val_acc) + 1), val_acc, label='Validation accuracy')
plt.ylim(0.0, 1.0)
plt.xlabel('Fold')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Train a final model with same parameters and save it
# Create an instance of ImageDataGenerator to generate your image data
datagen = ImageDataGenerator()
train_generator = datagen.flow(x=X_train, y=y_train, batch_size=batch_size)
valid_generator = datagen.flow(x=X_val, y=y_val, batch_size=batch_size)
model = create_model()
history = model.fit(train_generator, validation_data=valid_generator, epochs=epochs, verbose=1, callbacks=[early_stop])
model.save('cnn.h5')
# Out:
# Epoch 1/7
# 157/157 [==============================] - 10s 62ms/step - loss: 0.3384 - accuracy: 0.8292 - auc: 0.9347 - val_loss: 1.3323 - val_accuracy: 0.6250 - val_auc: 0.6719
# Epoch 2/7
# 157/157 [==============================] - 10s 61ms/step - loss: 0.1436 - accuracy: 0.9472 - auc: 0.9861 - val_loss: 0.6057 - val_accuracy: 0.8125 - val_auc: 0.8047
# Epoch 3/7
# 157/157 [==============================] - 10s 60ms/step - loss: 0.1158 - accuracy: 0.9561 - auc: 0.9909 - val_loss: 0.6340 - val_accuracy: 0.8125 - val_auc: 0.8516
# Epoch 4/7
# 157/157 [==============================] - 9s 60ms/step - loss: 0.0940 - accuracy: 0.9650 - auc: 0.9937 - val_loss: 0.7425 - val_accuracy: 0.7500 - val_auc: 0.8984
# Epoch 5/7
# 157/157 [==============================] - 10s 62ms/step - loss: 0.0805 - accuracy: 0.9710 - auc: 0.9952 - val_loss: 0.3788 - val_accuracy: 0.8750 - val_auc: 0.9062
# Epoch 6/7
# 157/157 [==============================] - 10s 62ms/step - loss: 0.0785 - accuracy: 0.9711 - auc: 0.9958 - val_loss: 0.4591 - val_accuracy: 0.8750 - val_auc: 0.9688
# Epoch 7/7
# 157/157 [==============================] - 10s 61ms/step - loss: 0.0645 - accuracy: 0.9766 - auc: 0.9969 - val_loss: 0.6059 - val_accuracy: 0.7500 - val_auc: 0.9453

# %%
# Plot val accuracy and val loss of the trained model
import matplotlib.pyplot as plt

plt.title('Accuracy vs Loss per Epoch')
plt.plot(range(1, len(history.history["val_accuracy"]) + 1), history.history["val_accuracy"], label='Accuracy')
plt.plot(range(1, len(history.history["val_loss"]) + 1), history.history["val_loss"], label='Loss')
plt.ylim(0.0, 1.0)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
# Make predictions on the test set
model = load_model('cnn.h5')

# %%
# Make predictions on the test set

y_pred_test = model.predict(X_test)
y_pred_test = np.where(y_pred_test >= 0.5, 1, 0)
# Out:
# 20/20 [==============================] - 0s 9ms/step

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Compute ROC curve and AUC score for the predictions
fpr, tpr, thresholds = roc_curve(y_test, y_pred_test)
roc_auc = auc(fpr, tpr)

# Plot ROC curve and show AUC score on the plot
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()

# %%
from sklearn.metrics import confusion_matrix

# Compute the confusion matrix for test set
cm = confusion_matrix(y_test, y_pred_test.flatten())
print(cm)
# Out:
# [[165  69]
#  [ 11 379]]

# %%
# Plot the confusion matrix
class_names = subfolders
import seaborn as sns

sns.heatmap(cm, annot=True, fmt='g', cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()

# %%
# Compute the classification report for test set
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred_test, target_names=class_names))
# Out:
#               precision    recall  f1-score   support
#
#       NORMAL       0.94      0.71      0.80       234
#    PNEUMONIA       0.85      0.97      0.90       390
#
#     accuracy                           0.87       624
#    macro avg       0.89      0.84      0.85       624
# weighted avg       0.88      0.87      0.87       624

# %%
import tensorflow as tf
import numpy as np
from IPython.display import Image, display
import matplotlib.cm as cm
from keras.utils import load_img, img_to_array, array_to_img


def get_img_array(img_path, size):
    # `img` is a PIL image of size 256x256
    img = load_img(img_path, target_size=size, grayscale=True)
    # `array` is a float32 Numpy array of shape (256, 256, 3)
    array = img_to_array(img)
    # We add a dimension to transform our array into a "batch"
    # of size (1, 299, 299, 3)
    array = np.expand_dims(array, axis=0)
    return array


def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    # First, we create a model that maps the input image to the activations
    # of the last conv layer as well as the output predictions
    grad_model = tf.keras.models.Model(
        [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output]
    )

    # Then, we compute the gradient of the top predicted class for our input image
    # with respect to the activations of the last conv layer
    with tf.GradientTape() as tape:
        last_conv_layer_output, preds = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]

    # This is the gradient of the output neuron (top predicted or chosen)
    # with regard to the output feature map of the last conv layer
    grads = tape.gradient(class_channel, last_conv_layer_output)

    # This is a vector where each entry is the mean intensity of the gradient
    # over a specific feature map channel
    #grads = tf.expand_dims(grads, axis=0)
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # We multiply each channel in the feature map array
    # by "how important this channel is" with regard to the top predicted class
    # then sum all the channels to obtain the heatmap class activation
    last_conv_layer_output = last_conv_layer_output[0]
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)

    # For visualization purpose, we will also normalize the heatmap between 0 & 1
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()


def generate_superimposed_gradcam(img_path, heatmap, alpha=0.4):
    # Load the original image
    img = load_img(img_path)
    img = img_to_array(img)

    # Rescale heatmap to a range 0-255
    heatmap = np.uint8(255 * heatmap)

    # Use jet colormap to colorize heatmap
    jet = cm.get_cmap("jet")

    # Use RGB values of the colormap
    jet_colors = jet(np.arange(256))[:, :3]
    jet_heatmap = jet_colors[heatmap]

    # Create an image with RGB colorized heatmap
    jet_heatmap = array_to_img(jet_heatmap)
    jet_heatmap = jet_heatmap.resize((img.shape[1], img.shape[0]))
    jet_heatmap = img_to_array(jet_heatmap)

    # Superimpose the heatmap on original image
    superimposed_img = jet_heatmap * alpha + img
    superimposed_img = array_to_img(superimposed_img)

    return superimposed_img


def display_heatmaps(img_path, heatmaps, superimposed=False):
    import matplotlib.pyplot as plt

    # Define the number of columns for the subplot grid
    n_cols = min(len(heatmaps), 5)

    # Calculate the number of rows based on the number of columns and total number of images
    n_rows = (len(heatmaps) - 1) // n_cols + 1

    # Create a figure with the desired size
    fig, axes = plt.subplots(n_rows, n_cols, figsize=(20, 4 * n_rows))

    for i, heatmap in enumerate(heatmaps):
        # Calculate the row and column index for this heatmap
        row = i // n_cols
        col = i % n_cols

        # Get the corresponding subplot
        ax = axes[row, col] if n_rows > 1 else axes[col]

        # Set the title of the subplot to the layer name
        ax.set_title(heatmap['layer_name'])

        if superimposed:
            superimposed_img = generate_superimposed_gradcam(img_path, heatmaps[i]["image"])
            # Plot the heatmap
            ax.imshow(superimposed_img)
        else:
            # Plot the heatmap
            ax.imshow(heatmaps[i]["image"], cmap='jet')

    # Hide the remaining subplots that are not used
    for i in range(len(heatmaps), n_rows * n_cols):
        # Calculate the row and column index for this subplot
        row = i // n_cols
        col = i % n_cols

        # Get the corresponding subplot
        ax = axes[row, col] if n_rows > 1 else axes[col]

        # Hide the subplot
        ax.axis('off')

    # Adjust the spacing between subplots
    fig.tight_layout()

    # Show the plot
    plt.show()

# %%
# Remove last layer's softmax
model.layers[-1].activation = None

# import os
# os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
# Print model summary to get last max pooling layer name
print(model.summary())
# Out:
# Model: "sequential_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_84 (Conv2D)          (None, 126, 126, 32)      320
#
#  max_pooling2d_84 (MaxPoolin  (None, 63, 63, 32)       0
#  g2D)
#
#  conv2d_85 (Conv2D)          (None, 61, 61, 64)        18496
#
#  max_pooling2d_85 (MaxPoolin  (None, 30, 30, 64)       0
#  g2D)
#
#  conv2d_86 (Conv2D)          (None, 28, 28, 128)       73856
#
#  max_pooling2d_86 (MaxPoolin  (None, 14, 14, 128)      0
#  g2D)
#
#  conv2d_87 (Conv2D)          (None, 12, 12, 256)       295168
#
#  max_pooling2d_87 (MaxPoolin  (None, 6, 6, 256)        0
#  g2D)
#
#  flatten_21 (Flatten)        (None, 9216)              0
#
#  dense_63 (Dense)            (None, 256)               2359552
#
#  dropout_42 (Dropout)        (None, 256)               0
#
#  dense_64 (Dense)            (None, 128)               32896
#
#  dropout_43 (Dropout)        (None, 128)               0
#
#  dense_65 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 2,780,417
# Trainable params: 2,780,417
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Heatmaps and Grad-CAM


import cv2
import matplotlib.pyplot as plt

images = [
    {
        "path": BASE + "val\\NORMAL\\NORMAL2-IM-1431-0001.jpeg"
    },
    {
        "path": BASE + "val\\PNEUMONIA\\person1946_bacteria_4875.jpeg"
    }
]

for image in images:
    image_temp = cv2.imread(image["path"])
    image_temp = cv2.cvtColor(image_temp, cv2.COLOR_RGB2GRAY)
    image_temp = cv2.resize(image_temp, (img_width, img_height))

    plt.imshow(image_temp, cmap=plt.cm.gray)
    plt.show()

    image["array"] = get_img_array(image["path"], size=(img_width, img_height))
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\keras\utils\image_utils.py:409: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn(

# %%
# Select last conv layer
last_conv_layer_name = "max_pooling2d_87"

# %%
# from cam import make_gradcam_heatmap, display_heatmaps

for image in images:
    heatmaps = []
    for layer in model.layers[:model.layers.index(model.get_layer(last_conv_layer_name)) + 1]:
        heatmap = make_gradcam_heatmap(image["array"], model, layer.name)
        heatmaps.append({
            "layer_name": layer.name,
            "image": heatmap
        })

    # Display heatmaps from all layers until the last max pooling layer
    display_heatmaps(image["path"], heatmaps)

    # Display the chosen image superimposed with heatmaps of each layer until the last max pooling layer
    display_heatmaps(image["path"], heatmaps, True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_5744\2206199731.py:64: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   jet = cm.get_cmap("jet")

# %%
# Predict
for image in images:
    pred = model.predict(image["array"].reshape(1, img_width, img_height, 1))
    print(pred)
    # Display predicted class
    print("Predicted class: {}".format(subfolders[int(pred[0][0])]))
# Out:
# 1/1 [==============================] - 0s 26ms/step
# [[1.]]
# Predicted class: PNEUMONIA
# 1/1 [==============================] - 0s 34ms/step
# [[1.]]
# Predicted class: PNEUMONIA
