# %% [markdown]
# # Augmentation d'image - Sheer
# ## Objectif
# L'objectif de ce notebook est d'évaluer l'impact de l'ajout de cisaillement aléatoire jusqu'à de -0.3 à 0.3 sur les images du jeu de données lors de la phase d'entraînement
#
# ## Hypothèses
#
# - Le jeu de donnés ne sera pas suffisament divers pour éviter l'overfitting
# - Le cisaillement aura peu d'impact sur la performance du model meme si il va permettre de diminuer l'overfitting
#
# ## Etapes de la démarche
# 1. Modifier la fonction de formatage des images pour y ajouter du cisaillement via shear_range
# 2. Tester le jeu de données avec l'algo CNN
# 3. Calculer les métriques de performance
# 4. Comparer les résultats avec les résultats du template
#
# ## Interprétation des résultats et Conclusion
# Les résultats obtenus sont les suivants :

# %%
# Check that GPU is used
import tensorflow as tf

tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
from PIL import Image
import os
import numpy as np
from dotenv import load_dotenv

dotenv_path = 'var.env'

# Chargez les variables d'environnement
load_dotenv(dotenv_path)
BASE = os.environ.get('BASE')
ITERATION = '_v3'

TRAIN_FOLDER = BASE + 'train'
TEST_FOLDER = BASE + 'test'
VAL_FOLDER = BASE + 'val'

TRAIN_AUGMENTED_FOLDER = BASE + 'train_augmented'+ ITERATION


# Define the subfolders within each folder where the images are stored
subfolders = ['NORMAL', 'PNEUMONIA']

# Define the size of the images you want to resize your images to
img_width, img_height = 128, 128  # Function to load and resize images from a folder

# %%
# Fonction de chargement des images des dataset et des labels associés
def load_images_from_folder(folder, limit_per_subfolder=None):
    X = []
    y = []
    for subfolder in subfolders:
        folder_path = os.path.join(folder, subfolder)
        if limit_per_subfolder:
            # Get amount of random filenames from the folder
            filenames = np.random.choice(os.listdir(folder_path), limit_per_subfolder, replace=False)
        else:
            filenames = os.listdir(folder_path)
        for filename in filenames:
            img_path = os.path.join(folder_path, filename)
            img = Image.open(img_path)

            # Resize the image to the desired size
            img = img.resize((img_width, img_height))

            # Convert RGB image to grayscale
            img = img.convert('L')

            # Convert the image to a NumPy array and append it to X
            img = np.array(img)
            X.append(img)

            # Append the corresponding label to y
            y.append(subfolders.index(subfolder))

    X = np.array(X)
    y = np.array(y)
    return X, y

# %%
import os
import numpy as np
from PIL import Image, ImageOps
from keras.preprocessing.image import ImageDataGenerator

def generate_augmented_images(folder, to_augment_class, image_size=(128, 128), target_nbr=5000):
    dir = os.path.join(folder, to_augment_class)
    count = len(os.listdir(dir))

    augmented_dir = os.path.join(f"{folder}_augmented"+ITERATION, to_augment_class)

    if not os.path.exists(f"{folder}_augmented"+ITERATION):
        os.mkdir(f"{folder}_augmented"+ITERATION)

    if not os.path.exists(augmented_dir):
        os.mkdir(augmented_dir)

    augmented_count = len(os.listdir(augmented_dir))

    datagen = ImageDataGenerator(
        rotation_range=0,
        width_shift_range=0,
        height_shift_range=0,
        shear_range=0.3,
        zoom_range=0,
        horizontal_flip=True,
        rescale=0,
        fill_mode='nearest',
    )

    generator = datagen.flow_from_directory(

        folder,
        batch_size=1,
        save_to_dir=augmented_dir,
        save_format='jpeg',
        save_prefix='IM_AUGMENTED',
        classes=[to_augment_class],
        keep_aspect_ratio=True,
        target_size=image_size,
    )

    additional_count = target_nbr - len(os.listdir(augmented_dir))

    for i in range(additional_count):
        generator.next()

    new_count = len(os.listdir(augmented_dir))

    print(f'Given {to_augment_class} count: {count}')
    print(f'Augmented {to_augment_class} count: {new_count}')

# %%
generate_augmented_images(TRAIN_FOLDER, 'NORMAL', image_size=(img_width, img_height))
generate_augmented_images(TRAIN_FOLDER, 'PNEUMONIA', image_size=(img_width, img_height))
# Out:
# Found 1341 images belonging to 1 classes.
# Given NORMAL count: 1341
# Augmented NORMAL count: 5000
# Found 3875 images belonging to 1 classes.
# Given PNEUMONIA count: 3876
# Augmented PNEUMONIA count: 5000

# %% [markdown]
# # SHEARING & AUGMENTATION
# ## Comment est ajouté le cisaillement ?
# Pour équilibrer le jeu de données d'entraînement, chaque image est soumise à une fonction d'augmentation qui génère de nouvelles images dans un répertoire distinct. Dans le cadre de cette augmentation, un cisaillement aléatoire est appliqué aux données. Ces variations sont ajoutées aux images pour diversifier le jeu de données d'entraînement.

# %%
# Load the training data
# Get min value between the number of normal images and the number of pneumonia images
TRAIN_FOLDER = f"{TRAIN_AUGMENTED_FOLDER}"

TEST_FOLDER = f"{TEST_FOLDER}"
VAL_FOLDER = f"{VAL_FOLDER}"

min_images = min(len(os.listdir(os.path.join(TRAIN_FOLDER, subfolders[0]))),
                 len(os.listdir(os.path.join(TRAIN_FOLDER, subfolders[1]))))
X_train, y_train = load_images_from_folder(TRAIN_FOLDER, min_images)

# Load the test data
X_test, y_test = load_images_from_folder(TEST_FOLDER)

# Load the validation data
X_val, y_val = load_images_from_folder(VAL_FOLDER)

# %%
# Make a matplot figure to show how many images are in each subfolder of train
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.bar(subfolders, [len(os.listdir(os.path.join(TRAIN_FOLDER, subfolder))) for subfolder in subfolders])
plt.title('Number of images in each subfolder of train')
plt.show()

# %%
# Make a matplot figure to show how many images if each class in the training set
plt.figure(figsize=(10, 5))
plt.bar(subfolders, [len(y_train[y_train == i]) for i in range(len(subfolders))])
plt.title('Number of images in each class in the training set')
plt.show()

# %%
# Normalize the pixel values to be between 0 and 1
num_samples = X_train.shape[0]
print(X_test.shape)
X_train = X_train.reshape(len(X_train), img_width, img_height, 1)
X_test = X_test.reshape(len(X_test), img_width, img_height, 1)
X_val = X_val.reshape(len(X_val), img_width, img_height, 1)

X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255
X_val = X_val.astype('float32') / 255

print('done \n')
# Out:
# (624, 128, 128)
# done

# %%
single_image = X_train[np.random.randint(len(X_train))]
print(single_image.shape)
plt.imshow(single_image, cmap='Greys')
# Out:
# (128, 128, 1)

# %%
# Define model metrics
from keras.metrics import AUC

metrics = [
    "accuracy",
    AUC(name='auc')
]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout


# Define the model architecture
def create_model():
    model = Sequential()

    model.add(Conv2D(filters=32, kernel_size=(3, 3), input_shape=(img_width, img_height, 1), activation="relu"))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(filters=64, kernel_size=(3, 3), activation="relu"))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(filters=128, kernel_size=(3, 3), activation="relu"))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(filters=256, kernel_size=(3, 3), activation="relu"))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Flatten())

    model.add(Dense(256, activation="relu"))
    model.add(Dropout(0.5))

    model.add(Dense(128, activation="relu"))
    model.add(Dropout(0.5))

    model.add(Dense(1, activation="sigmoid"))

    # compile the model
    model.compile(loss="binary_crossentropy", optimizer="adam", metrics=metrics)

    return model

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(monitor='loss', patience=3, restore_best_weights=True)

# %%
# Cross validation
from sklearn.model_selection import KFold
from keras.preprocessing.image import ImageDataGenerator
from h5py import File
# Define the number of folds for cross-validation
n_splits = 10
epochs = 7
batch_size =64

# Initialize KFold with the number of folds
kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)

# Define lists to store the evaluation scores for each fold
accuracy_scores = []
og_val_accuracy_scores = []
histories = []
models = []
fold_no = 1
best_score = float('inf')  # pour une tâche de minimisation
best_model = None
# Iterate through each fold and train/evaluate the model
for train_idx, val_idx in kf.split(X_train, y_train):
    # Split the data into training and validation sets for this fold
    X_train_fold, y_train_fold = X_train[train_idx], y_train[train_idx]
    X_val_fold, y_val_fold = X_train[val_idx], y_train[val_idx]

    # Create an instance of ImageDataGenerator to generate your image data
    datagen = ImageDataGenerator()

    # Create generators for training and validation data
    train_generator = datagen.flow(x=X_train_fold, y=y_train_fold, batch_size=batch_size)
    valid_generator = datagen.flow(x=X_val_fold, y=y_val_fold, batch_size=batch_size)

    # Create instance of the model for this fold and train it
    model = create_model()

    # Train your model on the training data for this fold
    history = model.fit(train_generator, validation_data=valid_generator, epochs=epochs, verbose=1,
                        callbacks=[early_stop])
    # Model Évaluation with original val dataset
    scores = model.evaluate(X_val, y_val, verbose=1)
    og_val_accuracy_scores.append(scores[1])
    print(f'\nScore for fold with orginal val dataset {fold_no}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%\n')

    histories.append(history.history)

    models.append(model)

    # After training, evaluate the model on the validation set for this fold
    accuracy = model.evaluate(X_val_fold, y_val_fold)[1]

    # Store the accuracy score in the list
    accuracy_scores.append(accuracy)

    # Print the accuracy for this fold
    print(f"Accuracy for fold {len(accuracy_scores)}: {accuracy * 100}%")

    # Check if the model is better than the previous
    if scores[0] < best_score:
        best_score = scores[0]
        best_model = model

    fold_no = fold_no + 1

    # Sauvegarde du meilleur modèle
    if best_model is not None:
        best_model.save('cnn_best.h5')

# Calculate and print the average accuracy over all folds
average_accuracy = sum(accuracy_scores) / len(accuracy_scores)
og_val_average_accuracy = sum(og_val_accuracy_scores) / len(og_val_accuracy_scores)
print(f"\nAverage accuracy: {average_accuracy * 100}%")
print(f"\nAverage accuracy with orginal val: {og_val_average_accuracy * 100}%")
# Out:
# Epoch 1/7
# 141/141 [==============================] - 11s 69ms/step - loss: 0.3262 - accuracy: 0.8438 - auc: 0.9332 - val_loss: 0.1347 - val_accuracy: 0.9510 - val_auc: 0.9898
# Epoch 2/7
# 141/141 [==============================] - 9s 61ms/step - loss: 0.1501 - accuracy: 0.9433 - auc: 0.9852 - val_loss: 0.0862 - val_accuracy: 0.9630 - val_auc: 0.9957
# Epoch 3/7
# 141/141 [==============================] - 9s 61ms/step - loss: 0.1101 - accuracy: 0.9576 - auc: 0.9917 - val_loss: 0.0857 - val_accuracy: 0.9590 - val_auc: 0.9969
# Epoch 4/7
# 141/141 [==============================] - 9s 62ms/step - loss: 0.0923 - accuracy: 0.9669 - auc: 0.9938 - val_loss: 0.0675 - val_accuracy: 0.9630 - val_auc: 0.9974
# Epoch 5/7
# 141/141 [==============================] - 9s 61ms/step - loss: 0.0883 - accuracy: 0.9657 - auc: 0.9946 - val_loss: 0.1111 - val_accuracy: 0.9600 - val_auc: 0.9967
# Epoch 6/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0802 - accuracy: 0.9703 - auc: 0.9952 - val_loss: 0.0689 - val_accuracy: 0.9730 - val_auc: 0.9972
# Epoch 7/7
# 141/141 [==============================] - 10s 68ms/step - loss: 0.0668 - accuracy: 0.9767 - auc: 0.9968 - val_loss: 0.0551 - val_accuracy: 0.9770 - val_auc: 0.9985
# 1/1 [==============================] - 0s 63ms/step - loss: 0.4207 - accuracy: 0.8750 - auc: 0.8906
#
# Score for fold with orginal val dataset 1: loss of 0.4207303524017334; accuracy of 87.5%
#
# 32/32 [==============================] - 1s 14ms/step - loss: 0.0551 - accuracy: 0.9770 - auc: 0.9985
# Accuracy for fold 1: 97.69999980926514%
# Epoch 1/7
# 141/141 [==============================] - 13s 88ms/step - loss: 0.3664 - accuracy: 0.8108 - auc: 0.9271 - val_loss: 0.1554 - val_accuracy: 0.9470 - val_auc: 0.9892
# Epoch 2/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.1518 - accuracy: 0.9423 - auc: 0.9850 - val_loss: 0.0999 - val_accuracy: 0.9680 - val_auc: 0.9931
# Epoch 3/7
# 141/141 [==============================] - 9s 64ms/step - loss: 0.1164 - accuracy: 0.9550 - auc: 0.9910 - val_loss: 0.1074 - val_accuracy: 0.9660 - val_auc: 0.9941
# Epoch 4/7
# 141/141 [==============================] - 9s 61ms/step - loss: 0.1052 - accuracy: 0.9614 - auc: 0.9922 - val_loss: 0.0746 - val_accuracy: 0.9750 - val_auc: 0.9961
# Epoch 5/7
# 141/141 [==============================] - 9s 61ms/step - loss: 0.0912 - accuracy: 0.9668 - auc: 0.9939 - val_loss: 0.0647 - val_accuracy: 0.9760 - val_auc: 0.9969
# Epoch 6/7
# 141/141 [==============================] - 9s 60ms/step - loss: 0.0776 - accuracy: 0.9714 - auc: 0.9956 - val_loss: 0.0753 - val_accuracy: 0.9770 - val_auc: 0.9975
# Epoch 7/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0762 - accuracy: 0.9734 - auc: 0.9957 - val_loss: 0.0571 - val_accuracy: 0.9780 - val_auc: 0.9974
# 1/1 [==============================] - 0s 64ms/step - loss: 0.3222 - accuracy: 0.9375 - auc: 0.9375
#
# Score for fold with orginal val dataset 2: loss of 0.3221738636493683; accuracy of 93.75%
#
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0571 - accuracy: 0.9780 - auc: 0.9974
# Accuracy for fold 2: 97.79999852180481%
# Epoch 1/7
# 141/141 [==============================] - 12s 72ms/step - loss: 0.3466 - accuracy: 0.8231 - auc: 0.9341 - val_loss: 0.1563 - val_accuracy: 0.9430 - val_auc: 0.9858
# Epoch 2/7
# 141/141 [==============================] - 9s 62ms/step - loss: 0.1354 - accuracy: 0.9499 - auc: 0.9878 - val_loss: 0.1174 - val_accuracy: 0.9520 - val_auc: 0.9938
# Epoch 3/7
# 141/141 [==============================] - 9s 61ms/step - loss: 0.1166 - accuracy: 0.9568 - auc: 0.9907 - val_loss: 0.1079 - val_accuracy: 0.9630 - val_auc: 0.9931
# Epoch 4/7
# 141/141 [==============================] - 9s 61ms/step - loss: 0.0906 - accuracy: 0.9659 - auc: 0.9945 - val_loss: 0.0861 - val_accuracy: 0.9660 - val_auc: 0.9941
# Epoch 5/7
# 141/141 [==============================] - 9s 61ms/step - loss: 0.0841 - accuracy: 0.9676 - auc: 0.9952 - val_loss: 0.0764 - val_accuracy: 0.9740 - val_auc: 0.9958
# Epoch 6/7
# 141/141 [==============================] - 9s 61ms/step - loss: 0.0798 - accuracy: 0.9712 - auc: 0.9956 - val_loss: 0.0768 - val_accuracy: 0.9710 - val_auc: 0.9955
# Epoch 7/7
# 141/141 [==============================] - 8s 60ms/step - loss: 0.0738 - accuracy: 0.9712 - auc: 0.9960 - val_loss: 0.0717 - val_accuracy: 0.9630 - val_auc: 0.9969
# 1/1 [==============================] - 0s 32ms/step - loss: 0.9994 - accuracy: 0.6875 - auc: 0.8359
#
# Score for fold with orginal val dataset 3: loss of 0.9994438886642456; accuracy of 68.75%
#
# 32/32 [==============================] - 0s 11ms/step - loss: 0.0717 - accuracy: 0.9630 - auc: 0.9969
# Accuracy for fold 3: 96.29999995231628%
# Epoch 1/7
# 141/141 [==============================] - 10s 65ms/step - loss: 0.3566 - accuracy: 0.8144 - auc: 0.9275 - val_loss: 0.1413 - val_accuracy: 0.9420 - val_auc: 0.9878
# Epoch 2/7
# 141/141 [==============================] - 9s 61ms/step - loss: 0.1426 - accuracy: 0.9476 - auc: 0.9866 - val_loss: 0.1254 - val_accuracy: 0.9450 - val_auc: 0.9921
# Epoch 3/7
# 141/141 [==============================] - 9s 62ms/step - loss: 0.1135 - accuracy: 0.9577 - auc: 0.9915 - val_loss: 0.1023 - val_accuracy: 0.9570 - val_auc: 0.9935
# Epoch 4/7
# 141/141 [==============================] - 9s 60ms/step - loss: 0.0972 - accuracy: 0.9623 - auc: 0.9936 - val_loss: 0.1224 - val_accuracy: 0.9580 - val_auc: 0.9927
# Epoch 5/7
# 141/141 [==============================] - 9s 62ms/step - loss: 0.0857 - accuracy: 0.9684 - auc: 0.9951 - val_loss: 0.0910 - val_accuracy: 0.9690 - val_auc: 0.9927
# Epoch 6/7
# 141/141 [==============================] - 9s 62ms/step - loss: 0.0756 - accuracy: 0.9719 - auc: 0.9959 - val_loss: 0.0740 - val_accuracy: 0.9700 - val_auc: 0.9958
# Epoch 7/7
# 141/141 [==============================] - 9s 61ms/step - loss: 0.0669 - accuracy: 0.9778 - auc: 0.9965 - val_loss: 0.1156 - val_accuracy: 0.9560 - val_auc: 0.9927
# 1/1 [==============================] - 0s 36ms/step - loss: 0.3142 - accuracy: 0.7500 - auc: 0.9219
#
# Score for fold with orginal val dataset 4: loss of 0.3142377734184265; accuracy of 75.0%
#
# 32/32 [==============================] - 0s 11ms/step - loss: 0.1156 - accuracy: 0.9560 - auc: 0.9927
# Accuracy for fold 4: 95.59999704360962%
# Epoch 1/7
# 141/141 [==============================] - 10s 64ms/step - loss: 0.3440 - accuracy: 0.8306 - auc: 0.9354 - val_loss: 0.1539 - val_accuracy: 0.9390 - val_auc: 0.9907
# Epoch 2/7
# 141/141 [==============================] - 9s 60ms/step - loss: 0.1479 - accuracy: 0.9463 - auc: 0.9857 - val_loss: 0.1082 - val_accuracy: 0.9560 - val_auc: 0.9949
# Epoch 3/7
# 141/141 [==============================] - 8s 60ms/step - loss: 0.1192 - accuracy: 0.9549 - auc: 0.9905 - val_loss: 0.0883 - val_accuracy: 0.9600 - val_auc: 0.9954
# Epoch 4/7
# 141/141 [==============================] - 8s 60ms/step - loss: 0.1015 - accuracy: 0.9604 - auc: 0.9931 - val_loss: 0.0677 - val_accuracy: 0.9740 - val_auc: 0.9967
# Epoch 5/7
# 141/141 [==============================] - 8s 60ms/step - loss: 0.0984 - accuracy: 0.9596 - auc: 0.9932 - val_loss: 0.0605 - val_accuracy: 0.9730 - val_auc: 0.9978
# Epoch 6/7
# 141/141 [==============================] - 8s 59ms/step - loss: 0.0790 - accuracy: 0.9702 - auc: 0.9957 - val_loss: 0.0603 - val_accuracy: 0.9760 - val_auc: 0.9979
# Epoch 7/7
# 141/141 [==============================] - 8s 59ms/step - loss: 0.0766 - accuracy: 0.9713 - auc: 0.9960 - val_loss: 0.0540 - val_accuracy: 0.9780 - val_auc: 0.9983
# 1/1 [==============================] - 0s 36ms/step - loss: 0.5930 - accuracy: 0.8125 - auc: 0.8984
#
# Score for fold with orginal val dataset 5: loss of 0.5930454730987549; accuracy of 81.25%
#
# 32/32 [==============================] - 0s 11ms/step - loss: 0.0540 - accuracy: 0.9780 - auc: 0.9983
# Accuracy for fold 5: 97.79999852180481%
# Epoch 1/7
# 141/141 [==============================] - 9s 62ms/step - loss: 0.3817 - accuracy: 0.8086 - auc: 0.9225 - val_loss: 0.1394 - val_accuracy: 0.9460 - val_auc: 0.9895
# Epoch 2/7
# 141/141 [==============================] - 8s 60ms/step - loss: 0.1547 - accuracy: 0.9443 - auc: 0.9844 - val_loss: 0.0988 - val_accuracy: 0.9660 - val_auc: 0.9939
# Epoch 3/7
# 141/141 [==============================] - 8s 60ms/step - loss: 0.1217 - accuracy: 0.9550 - auc: 0.9900 - val_loss: 0.1060 - val_accuracy: 0.9620 - val_auc: 0.9942
# Epoch 4/7
# 141/141 [==============================] - 8s 60ms/step - loss: 0.1056 - accuracy: 0.9609 - auc: 0.9924 - val_loss: 0.0851 - val_accuracy: 0.9730 - val_auc: 0.9951
# Epoch 5/7
# 141/141 [==============================] - 9s 61ms/step - loss: 0.0918 - accuracy: 0.9654 - auc: 0.9940 - val_loss: 0.0700 - val_accuracy: 0.9750 - val_auc: 0.9971
# Epoch 6/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0754 - accuracy: 0.9714 - auc: 0.9959 - val_loss: 0.0701 - val_accuracy: 0.9770 - val_auc: 0.9966
# Epoch 7/7
# 141/141 [==============================] - 9s 62ms/step - loss: 0.0729 - accuracy: 0.9724 - auc: 0.9964 - val_loss: 0.0968 - val_accuracy: 0.9700 - val_auc: 0.9922
# 1/1 [==============================] - 0s 31ms/step - loss: 0.7469 - accuracy: 0.7500 - auc: 0.8672
#
# Score for fold with orginal val dataset 6: loss of 0.7468514442443848; accuracy of 75.0%
#
# 32/32 [==============================] - 0s 13ms/step - loss: 0.0968 - accuracy: 0.9700 - auc: 0.9922
# Accuracy for fold 6: 97.00000286102295%
# Epoch 1/7
# 141/141 [==============================] - 10s 63ms/step - loss: 0.3150 - accuracy: 0.8417 - auc: 0.9447 - val_loss: 0.1653 - val_accuracy: 0.9430 - val_auc: 0.9864
# Epoch 2/7
# 141/141 [==============================] - 9s 61ms/step - loss: 0.1511 - accuracy: 0.9431 - auc: 0.9851 - val_loss: 0.1538 - val_accuracy: 0.9420 - val_auc: 0.9906
# Epoch 3/7
# 141/141 [==============================] - 9s 60ms/step - loss: 0.1202 - accuracy: 0.9539 - auc: 0.9904 - val_loss: 0.1176 - val_accuracy: 0.9520 - val_auc: 0.9935
# Epoch 4/7
# 141/141 [==============================] - 8s 60ms/step - loss: 0.0940 - accuracy: 0.9632 - auc: 0.9941 - val_loss: 0.1200 - val_accuracy: 0.9590 - val_auc: 0.9908
# Epoch 5/7
# 141/141 [==============================] - 8s 60ms/step - loss: 0.0894 - accuracy: 0.9679 - auc: 0.9943 - val_loss: 0.1001 - val_accuracy: 0.9560 - val_auc: 0.9937
# Epoch 6/7
# 141/141 [==============================] - 8s 60ms/step - loss: 0.0809 - accuracy: 0.9706 - auc: 0.9955 - val_loss: 0.1064 - val_accuracy: 0.9630 - val_auc: 0.9922
# Epoch 7/7
# 141/141 [==============================] - 8s 60ms/step - loss: 0.0738 - accuracy: 0.9734 - auc: 0.9960 - val_loss: 0.0908 - val_accuracy: 0.9690 - val_auc: 0.9946
# 1/1 [==============================] - 0s 30ms/step - loss: 0.5242 - accuracy: 0.8750 - auc: 0.8828
#
# Score for fold with orginal val dataset 7: loss of 0.5241876840591431; accuracy of 87.5%
#
# 32/32 [==============================] - 0s 10ms/step - loss: 0.0908 - accuracy: 0.9690 - auc: 0.9946
# Accuracy for fold 7: 96.8999981880188%
# Epoch 1/7
# 141/141 [==============================] - 10s 62ms/step - loss: 0.3550 - accuracy: 0.8239 - auc: 0.9319 - val_loss: 0.1189 - val_accuracy: 0.9550 - val_auc: 0.9915
# Epoch 2/7
# 141/141 [==============================] - 8s 60ms/step - loss: 0.1514 - accuracy: 0.9420 - auc: 0.9852 - val_loss: 0.1811 - val_accuracy: 0.9340 - val_auc: 0.9937
# Epoch 3/7
# 141/141 [==============================] - 8s 60ms/step - loss: 0.1205 - accuracy: 0.9554 - auc: 0.9902 - val_loss: 0.0793 - val_accuracy: 0.9650 - val_auc: 0.9963
# Epoch 4/7
# 141/141 [==============================] - 9s 64ms/step - loss: 0.1004 - accuracy: 0.9637 - auc: 0.9931 - val_loss: 0.0711 - val_accuracy: 0.9640 - val_auc: 0.9964
# Epoch 5/7
# 141/141 [==============================] - 9s 66ms/step - loss: 0.0863 - accuracy: 0.9673 - auc: 0.9951 - val_loss: 0.0751 - val_accuracy: 0.9680 - val_auc: 0.9970
# Epoch 6/7
# 141/141 [==============================] - 10s 69ms/step - loss: 0.0758 - accuracy: 0.9707 - auc: 0.9958 - val_loss: 0.0508 - val_accuracy: 0.9810 - val_auc: 0.9987
# Epoch 7/7
# 141/141 [==============================] - 9s 62ms/step - loss: 0.0665 - accuracy: 0.9758 - auc: 0.9969 - val_loss: 0.0439 - val_accuracy: 0.9820 - val_auc: 0.9990
# 1/1 [==============================] - 0s 39ms/step - loss: 0.5507 - accuracy: 0.8125 - auc: 0.8516
#
# Score for fold with orginal val dataset 8: loss of 0.5507043600082397; accuracy of 81.25%
#
# 32/32 [==============================] - 1s 23ms/step - loss: 0.0439 - accuracy: 0.9820 - auc: 0.9990
# Accuracy for fold 8: 98.19999933242798%
# Epoch 1/7
# 141/141 [==============================] - 10s 62ms/step - loss: 0.3271 - accuracy: 0.8426 - auc: 0.9439 - val_loss: 0.2592 - val_accuracy: 0.9170 - val_auc: 0.9840
# Epoch 2/7
# 141/141 [==============================] - 8s 59ms/step - loss: 0.1531 - accuracy: 0.9410 - auc: 0.9848 - val_loss: 0.1520 - val_accuracy: 0.9450 - val_auc: 0.9900
# Epoch 3/7
# 141/141 [==============================] - 8s 60ms/step - loss: 0.1137 - accuracy: 0.9601 - auc: 0.9912 - val_loss: 0.1093 - val_accuracy: 0.9530 - val_auc: 0.9930
# Epoch 4/7
# 141/141 [==============================] - 8s 60ms/step - loss: 0.0979 - accuracy: 0.9618 - auc: 0.9937 - val_loss: 0.1026 - val_accuracy: 0.9600 - val_auc: 0.9933
# Epoch 5/7
# 141/141 [==============================] - 8s 59ms/step - loss: 0.0840 - accuracy: 0.9680 - auc: 0.9950 - val_loss: 0.0820 - val_accuracy: 0.9690 - val_auc: 0.9957
# Epoch 6/7
# 141/141 [==============================] - 8s 60ms/step - loss: 0.0744 - accuracy: 0.9736 - auc: 0.9960 - val_loss: 0.0707 - val_accuracy: 0.9730 - val_auc: 0.9967
# Epoch 7/7
# 141/141 [==============================] - 8s 60ms/step - loss: 0.0605 - accuracy: 0.9783 - auc: 0.9971 - val_loss: 0.1214 - val_accuracy: 0.9670 - val_auc: 0.9915
# 1/1 [==============================] - 0s 39ms/step - loss: 0.6740 - accuracy: 0.8125 - auc: 0.9609
#
# Score for fold with orginal val dataset 9: loss of 0.6739534735679626; accuracy of 81.25%
#
# 32/32 [==============================] - 0s 12ms/step - loss: 0.1214 - accuracy: 0.9670 - auc: 0.9915
# Accuracy for fold 9: 96.70000076293945%
# Epoch 1/7
# 141/141 [==============================] - 10s 66ms/step - loss: 0.3355 - accuracy: 0.8456 - auc: 0.9394 - val_loss: 0.1293 - val_accuracy: 0.9610 - val_auc: 0.9892
# Epoch 2/7
# 141/141 [==============================] - 11s 75ms/step - loss: 0.1565 - accuracy: 0.9402 - auc: 0.9841 - val_loss: 0.1079 - val_accuracy: 0.9560 - val_auc: 0.9926
# Epoch 3/7
# 141/141 [==============================] - 10s 71ms/step - loss: 0.1222 - accuracy: 0.9548 - auc: 0.9899 - val_loss: 0.1489 - val_accuracy: 0.9450 - val_auc: 0.9912
# Epoch 4/7
# 141/141 [==============================] - 8s 59ms/step - loss: 0.1025 - accuracy: 0.9609 - auc: 0.9931 - val_loss: 0.0937 - val_accuracy: 0.9620 - val_auc: 0.9943
# Epoch 5/7
# 141/141 [==============================] - 8s 60ms/step - loss: 0.0886 - accuracy: 0.9661 - auc: 0.9946 - val_loss: 0.0974 - val_accuracy: 0.9610 - val_auc: 0.9947
# Epoch 6/7
# 141/141 [==============================] - 8s 59ms/step - loss: 0.0836 - accuracy: 0.9683 - auc: 0.9956 - val_loss: 0.0746 - val_accuracy: 0.9760 - val_auc: 0.9949
# Epoch 7/7
# 141/141 [==============================] - 8s 59ms/step - loss: 0.0667 - accuracy: 0.9760 - auc: 0.9966 - val_loss: 0.0813 - val_accuracy: 0.9660 - val_auc: 0.9953
# 1/1 [==============================] - 0s 36ms/step - loss: 0.7702 - accuracy: 0.7500 - auc: 0.8984
#
# Score for fold with orginal val dataset 10: loss of 0.7701600790023804; accuracy of 75.0%
#
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0813 - accuracy: 0.9660 - auc: 0.9953
# Accuracy for fold 10: 96.60000205039978%
#
# Average accuracy: 97.05999970436096%
#
# Average accuracy with orginal val: 80.625%

# %%
# Get accuracy scores for each fold (train and validation)
loss = []
acc = []
val_loss = []
val_acc = []

for history in histories:
    loss.append(np.mean(history["loss"]))
    acc.append(np.mean(history["accuracy"]))
    val_loss.append(np.mean(history["val_loss"]))
    val_acc.append(np.mean(history["val_accuracy"]))

# %%
# Plot loss and validation loss per fold
import matplotlib.pyplot as plt
plt.title('Losses')
plt.plot(range(1, len(loss)+1), loss, label='Loss')
plt.plot(range(1, len(val_loss)+1), val_loss, label='Validation loss')
plt.ylim(0.0, 1.0)
plt.xlabel('Fold')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Plot accuracies and validation accuracies per fold
import matplotlib.pyplot as plt

plt.title('Accuracies')
plt.plot(range(1, len(acc) + 1), acc, label='Accuracy')
plt.plot(range(1, len(val_acc) + 1), val_acc, label='Validation accuracy')
plt.ylim(0.0, 1.0)
plt.xlabel('Fold')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Train a final model with same parameters and save it
# Create an instance of ImageDataGenerator to generate your image data
datagen = ImageDataGenerator()
train_generator = datagen.flow(x=X_train, y=y_train, batch_size=batch_size)
valid_generator = datagen.flow(x=X_val, y=y_val, batch_size=batch_size)
model = create_model()
history = model.fit(train_generator, validation_data=valid_generator, epochs=epochs, verbose=1, callbacks=[early_stop])
model.save('cnn.h5')
# Out:
# Epoch 1/7
# 157/157 [==============================] - 10s 59ms/step - loss: 0.3170 - accuracy: 0.8474 - auc: 0.9456 - val_loss: 0.6176 - val_accuracy: 0.8125 - val_auc: 0.8125
# Epoch 2/7
# 157/157 [==============================] - 9s 57ms/step - loss: 0.1387 - accuracy: 0.9505 - auc: 0.9872 - val_loss: 1.4852 - val_accuracy: 0.6250 - val_auc: 0.7500
# Epoch 3/7
# 157/157 [==============================] - 9s 57ms/step - loss: 0.1368 - accuracy: 0.9486 - auc: 0.9878 - val_loss: 0.8970 - val_accuracy: 0.6875 - val_auc: 0.8516
# Epoch 4/7
# 157/157 [==============================] - 9s 57ms/step - loss: 0.0980 - accuracy: 0.9651 - auc: 0.9936 - val_loss: 0.5193 - val_accuracy: 0.7500 - val_auc: 0.8281
# Epoch 5/7
# 157/157 [==============================] - 9s 57ms/step - loss: 0.0871 - accuracy: 0.9680 - auc: 0.9949 - val_loss: 0.5044 - val_accuracy: 0.8125 - val_auc: 0.8906
# Epoch 6/7
# 157/157 [==============================] - 9s 58ms/step - loss: 0.0796 - accuracy: 0.9732 - auc: 0.9952 - val_loss: 0.4314 - val_accuracy: 0.8750 - val_auc: 0.9219
# Epoch 7/7
# 157/157 [==============================] - 9s 58ms/step - loss: 0.0662 - accuracy: 0.9770 - auc: 0.9968 - val_loss: 1.2571 - val_accuracy: 0.6875 - val_auc: 0.9297

# %%
# Plot val accuracy and val loss of the trained model
import matplotlib.pyplot as plt

plt.title('Accuracy vs Loss per Epoch')
plt.plot(range(1, len(history.history["val_accuracy"]) + 1), history.history["val_accuracy"], label='Accuracy')
plt.plot(range(1, len(history.history["val_loss"]) + 1), history.history["val_loss"], label='Loss')
plt.ylim(0.0, 1.0)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
# Make predictions on the test set
model = load_model('cnn.h5')

# %%
# Make predictions on the test set

y_pred_test = model.predict(X_test)
y_pred_test = np.where(y_pred_test >= 0.5, 1, 0)
# Out:
# 20/20 [==============================] - 0s 8ms/step

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Compute ROC curve and AUC score for the predictions
fpr, tpr, thresholds = roc_curve(y_test, y_pred_test)
roc_auc = auc(fpr, tpr)

# Plot ROC curve and show AUC score on the plot
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()

# %%
from sklearn.metrics import confusion_matrix

# Compute the confusion matrix for test set
cm = confusion_matrix(y_test, y_pred_test.flatten())
print(cm)
# Out:
# [[158  76]
#  [  7 383]]

# %%
# Plot the confusion matrix
class_names = subfolders
import seaborn as sns

sns.heatmap(cm, annot=True, fmt='g', cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()

# %%
# Compute the classification report for test set
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred_test, target_names=class_names))
# Out:
#               precision    recall  f1-score   support
#
#       NORMAL       0.96      0.68      0.79       234
#    PNEUMONIA       0.83      0.98      0.90       390
#
#     accuracy                           0.87       624
#    macro avg       0.90      0.83      0.85       624
# weighted avg       0.88      0.87      0.86       624

# %%
import tensorflow as tf
import numpy as np
from IPython.display import Image, display
import matplotlib.cm as cm
from keras.utils import load_img, img_to_array, array_to_img


def get_img_array(img_path, size):
    # `img` is a PIL image of size 256x256
    img = load_img(img_path, target_size=size, grayscale=True)
    # `array` is a float32 Numpy array of shape (256, 256, 3)
    array = img_to_array(img)
    # We add a dimension to transform our array into a "batch"
    # of size (1, 299, 299, 3)
    array = np.expand_dims(array, axis=0)
    return array


def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    # First, we create a model that maps the input image to the activations
    # of the last conv layer as well as the output predictions
    grad_model = tf.keras.models.Model(
        [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output]
    )

    # Then, we compute the gradient of the top predicted class for our input image
    # with respect to the activations of the last conv layer
    with tf.GradientTape() as tape:
        last_conv_layer_output, preds = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]

    # This is the gradient of the output neuron (top predicted or chosen)
    # with regard to the output feature map of the last conv layer
    grads = tape.gradient(class_channel, last_conv_layer_output)

    # This is a vector where each entry is the mean intensity of the gradient
    # over a specific feature map channel
    #grads = tf.expand_dims(grads, axis=0)
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # We multiply each channel in the feature map array
    # by "how important this channel is" with regard to the top predicted class
    # then sum all the channels to obtain the heatmap class activation
    last_conv_layer_output = last_conv_layer_output[0]
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)

    # For visualization purpose, we will also normalize the heatmap between 0 & 1
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()


def generate_superimposed_gradcam(img_path, heatmap, alpha=0.4):
    # Load the original image
    img = load_img(img_path)
    img = img_to_array(img)

    # Rescale heatmap to a range 0-255
    heatmap = np.uint8(255 * heatmap)

    # Use jet colormap to colorize heatmap
    jet = cm.get_cmap("jet")

    # Use RGB values of the colormap
    jet_colors = jet(np.arange(256))[:, :3]
    jet_heatmap = jet_colors[heatmap]

    # Create an image with RGB colorized heatmap
    jet_heatmap = array_to_img(jet_heatmap)
    jet_heatmap = jet_heatmap.resize((img.shape[1], img.shape[0]))
    jet_heatmap = img_to_array(jet_heatmap)

    # Superimpose the heatmap on original image
    superimposed_img = jet_heatmap * alpha + img
    superimposed_img = array_to_img(superimposed_img)

    return superimposed_img


def display_heatmaps(img_path, heatmaps, superimposed=False):
    import matplotlib.pyplot as plt

    # Define the number of columns for the subplot grid
    n_cols = min(len(heatmaps), 5)

    # Calculate the number of rows based on the number of columns and total number of images
    n_rows = (len(heatmaps) - 1) // n_cols + 1

    # Create a figure with the desired size
    fig, axes = plt.subplots(n_rows, n_cols, figsize=(20, 4 * n_rows))

    for i, heatmap in enumerate(heatmaps):
        # Calculate the row and column index for this heatmap
        row = i // n_cols
        col = i % n_cols

        # Get the corresponding subplot
        ax = axes[row, col] if n_rows > 1 else axes[col]

        # Set the title of the subplot to the layer name
        ax.set_title(heatmap['layer_name'])

        if superimposed:
            superimposed_img = generate_superimposed_gradcam(img_path, heatmaps[i]["image"])
            # Plot the heatmap
            ax.imshow(superimposed_img)
        else:
            # Plot the heatmap
            ax.imshow(heatmaps[i]["image"], cmap='jet')

    # Hide the remaining subplots that are not used
    for i in range(len(heatmaps), n_rows * n_cols):
        # Calculate the row and column index for this subplot
        row = i // n_cols
        col = i % n_cols

        # Get the corresponding subplot
        ax = axes[row, col] if n_rows > 1 else axes[col]

        # Hide the subplot
        ax.axis('off')

    # Adjust the spacing between subplots
    fig.tight_layout()

    # Show the plot
    plt.show()

# %%
# Remove last layer's softmax
model.layers[-1].activation = None

# import os
# os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
# Print model summary to get last max pooling layer name
print(model.summary())
# Out:
# Model: "sequential_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_84 (Conv2D)          (None, 126, 126, 32)      320
#
#  max_pooling2d_84 (MaxPoolin  (None, 63, 63, 32)       0
#  g2D)
#
#  conv2d_85 (Conv2D)          (None, 61, 61, 64)        18496
#
#  max_pooling2d_85 (MaxPoolin  (None, 30, 30, 64)       0
#  g2D)
#
#  conv2d_86 (Conv2D)          (None, 28, 28, 128)       73856
#
#  max_pooling2d_86 (MaxPoolin  (None, 14, 14, 128)      0
#  g2D)
#
#  conv2d_87 (Conv2D)          (None, 12, 12, 256)       295168
#
#  max_pooling2d_87 (MaxPoolin  (None, 6, 6, 256)        0
#  g2D)
#
#  flatten_21 (Flatten)        (None, 9216)              0
#
#  dense_63 (Dense)            (None, 256)               2359552
#
#  dropout_42 (Dropout)        (None, 256)               0
#
#  dense_64 (Dense)            (None, 128)               32896
#
#  dropout_43 (Dropout)        (None, 128)               0
#
#  dense_65 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 2,780,417
# Trainable params: 2,780,417
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Heatmaps and Grad-CAM


import cv2
import matplotlib.pyplot as plt

images = [
    {
        "path": BASE + "val\\NORMAL\\NORMAL2-IM-1431-0001.jpeg"
    },
    {
        "path": BASE + "val\\PNEUMONIA\\person1946_bacteria_4875.jpeg"
    }
]

for image in images:
    image_temp = cv2.imread(image["path"])
    image_temp = cv2.cvtColor(image_temp, cv2.COLOR_RGB2GRAY)
    image_temp = cv2.resize(image_temp, (img_width, img_height))

    plt.imshow(image_temp, cmap=plt.cm.gray)
    plt.show()

    image["array"] = get_img_array(image["path"], size=(img_width, img_height))
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\keras\utils\image_utils.py:409: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn(

# %%
# Select last conv layer
last_conv_layer_name = "max_pooling2d_87"

# %%
# from cam import make_gradcam_heatmap, display_heatmaps

for image in images:
    heatmaps = []
    for layer in model.layers[:model.layers.index(model.get_layer(last_conv_layer_name)) + 1]:
        heatmap = make_gradcam_heatmap(image["array"], model, layer.name)
        heatmaps.append({
            "layer_name": layer.name,
            "image": heatmap
        })

    # Display heatmaps from all layers until the last max pooling layer
    display_heatmaps(image["path"], heatmaps)

    # Display the chosen image superimposed with heatmaps of each layer until the last max pooling layer
    display_heatmaps(image["path"], heatmaps, True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_27380\2206199731.py:64: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   jet = cm.get_cmap("jet")

# %%
# Predict
for image in images:
    pred = model.predict(image["array"].reshape(1, img_width, img_height, 1))
    print(pred)
    # Display predicted class
    print("Predicted class: {}".format(subfolders[int(pred[0][0])]))
# Out:
# 1/1 [==============================] - 0s 27ms/step
# [[1.]]
# Predicted class: PNEUMONIA
# 1/1 [==============================] - 0s 22ms/step
# [[1.]]
# Predicted class: PNEUMONIA
