# %% [markdown]
# # Augmentation d'image - Sheer
# ## Objectif
# L'objectif de ce notebook est d'évaluer l'impact de l'ajout de cisaillement aléatoire jusqu'à de -0.1 à 0.1 sur les images du jeu de données lors de la phase d'entraînement
#
# ## Hypothèses
#
# - Le jeu de donnés ne sera pas suffisament divers pour éviter l'overfitting
# - Le cisaillement aura peu d'impact sur la performance du model meme si il va permettre de diminuer l'overfitting
#
# ## Etapes de la démarche
# 1. Modifier la fonction de formatage des images pour y ajouter du cisaillement via shear_range
# 2. Tester le jeu de données avec l'algo CNN
# 3. Calculer les métriques de performance
# 4. Comparer les résultats avec les résultats du template
#
# ## Interprétation des résultats et Conclusion
# Les résultats obtenus sont les suivants :

# %%
# Check that GPU is used
import tensorflow as tf

tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
from PIL import Image
import os
import numpy as np
from dotenv import load_dotenv

dotenv_path = 'var.env'

# Chargez les variables d'environnement
load_dotenv(dotenv_path)
BASE = os.environ.get('BASE')
ITERATION = '_v1'

TRAIN_FOLDER = BASE + 'train'
TEST_FOLDER = BASE + 'test'
VAL_FOLDER = BASE + 'val'

TRAIN_AUGMENTED_FOLDER = BASE + 'train_augmented'+ ITERATION


# Define the subfolders within each folder where the images are stored
subfolders = ['NORMAL', 'PNEUMONIA']

# Define the size of the images you want to resize your images to
img_width, img_height = 128, 128  # Function to load and resize images from a folder

# %%
# Fonction de chargement des images des dataset et des labels associés
def load_images_from_folder(folder, limit_per_subfolder=None):
    X = []
    y = []
    for subfolder in subfolders:
        folder_path = os.path.join(folder, subfolder)
        if limit_per_subfolder:
            # Get amount of random filenames from the folder
            filenames = np.random.choice(os.listdir(folder_path), limit_per_subfolder, replace=False)
        else:
            filenames = os.listdir(folder_path)
        for filename in filenames:
            img_path = os.path.join(folder_path, filename)
            img = Image.open(img_path)

            # Resize the image to the desired size
            img = img.resize((img_width, img_height))

            # Convert RGB image to grayscale
            img = img.convert('L')

            # Convert the image to a NumPy array and append it to X
            img = np.array(img)
            X.append(img)

            # Append the corresponding label to y
            y.append(subfolders.index(subfolder))

    X = np.array(X)
    y = np.array(y)
    return X, y

# %%
import os
import numpy as np
from PIL import Image, ImageOps
from keras.preprocessing.image import ImageDataGenerator

def generate_augmented_images(folder, to_augment_class, image_size=(128, 128), target_nbr=5000):
    dir = os.path.join(folder, to_augment_class)
    count = len(os.listdir(dir))

    augmented_dir = os.path.join(f"{folder}_augmented"+ITERATION, to_augment_class)

    if not os.path.exists(f"{folder}_augmented"+ITERATION):
        os.mkdir(f"{folder}_augmented"+ITERATION)

    if not os.path.exists(augmented_dir):
        os.mkdir(augmented_dir)

    augmented_count = len(os.listdir(augmented_dir))

    datagen = ImageDataGenerator(
        rotation_range=0,
        width_shift_range=0,
        height_shift_range=0,
        shear_range=0.1,
        zoom_range=0,
        horizontal_flip=True,
        rescale=0,
        fill_mode='nearest',
    )

    generator = datagen.flow_from_directory(

        folder,
        batch_size=1,
        save_to_dir=augmented_dir,
        save_format='jpeg',
        save_prefix='IM_AUGMENTED',
        classes=[to_augment_class],
        keep_aspect_ratio=True,
        target_size=image_size,
    )

    additional_count = target_nbr - len(os.listdir(augmented_dir))

    for i in range(additional_count):
        generator.next()

    new_count = len(os.listdir(augmented_dir))

    print(f'Given {to_augment_class} count: {count}')
    print(f'Augmented {to_augment_class} count: {new_count}')

# %%
generate_augmented_images(TRAIN_FOLDER, 'NORMAL', image_size=(img_width, img_height))
generate_augmented_images(TRAIN_FOLDER, 'PNEUMONIA', image_size=(img_width, img_height))
# Out:
# Found 1341 images belonging to 1 classes.
# Given NORMAL count: 1341
# Augmented NORMAL count: 5000
# Found 3875 images belonging to 1 classes.
# Given PNEUMONIA count: 3876
# Augmented PNEUMONIA count: 5000

# %% [markdown]
# # SHEARING & AUGMENTATION
# ## Comment est ajouté le cisaillement ?
# Pour équilibrer le jeu de données d'entraînement, chaque image est soumise à une fonction d'augmentation qui génère de nouvelles images dans un répertoire distinct. Dans le cadre de cette augmentation, un cisaillement aléatoire est appliqué aux données. Ces variations sont ajoutées aux images pour diversifier le jeu de données d'entraînement.

# %%
# Load the training data
# Get min value between the number of normal images and the number of pneumonia images
TRAIN_FOLDER = f"{TRAIN_AUGMENTED_FOLDER}"

TEST_FOLDER = f"{TEST_FOLDER}"
VAL_FOLDER = f"{VAL_FOLDER}"

min_images = min(len(os.listdir(os.path.join(TRAIN_FOLDER, subfolders[0]))),
                 len(os.listdir(os.path.join(TRAIN_FOLDER, subfolders[1]))))
X_train, y_train = load_images_from_folder(TRAIN_FOLDER, min_images)

# Load the test data
X_test, y_test = load_images_from_folder(TEST_FOLDER)

# Load the validation data
X_val, y_val = load_images_from_folder(VAL_FOLDER)

# %%
# Make a matplot figure to show how many images are in each subfolder of train
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.bar(subfolders, [len(os.listdir(os.path.join(TRAIN_FOLDER, subfolder))) for subfolder in subfolders])
plt.title('Number of images in each subfolder of train')
plt.show()

# %%
# Make a matplot figure to show how many images if each class in the training set
plt.figure(figsize=(10, 5))
plt.bar(subfolders, [len(y_train[y_train == i]) for i in range(len(subfolders))])
plt.title('Number of images in each class in the training set')
plt.show()

# %%
# Normalize the pixel values to be between 0 and 1
num_samples = X_train.shape[0]
print(X_test.shape)
X_train = X_train.reshape(len(X_train), img_width, img_height, 1)
X_test = X_test.reshape(len(X_test), img_width, img_height, 1)
X_val = X_val.reshape(len(X_val), img_width, img_height, 1)

X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255
X_val = X_val.astype('float32') / 255

print('done \n')
# Out:
# (624, 128, 128)
# done

# %%
single_image = X_train[np.random.randint(len(X_train))]
print(single_image.shape)
plt.imshow(single_image, cmap='Greys')
# Out:
# (128, 128, 1)

# %%
# Define model metrics
from keras.metrics import AUC

metrics = [
    "accuracy",
    AUC(name='auc')
]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout


# Define the model architecture
def create_model():
    model = Sequential()

    model.add(Conv2D(filters=32, kernel_size=(3, 3), input_shape=(img_width, img_height, 1), activation="relu"))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(filters=64, kernel_size=(3, 3), activation="relu"))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(filters=128, kernel_size=(3, 3), activation="relu"))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(filters=256, kernel_size=(3, 3), activation="relu"))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Flatten())

    model.add(Dense(256, activation="relu"))
    model.add(Dropout(0.5))

    model.add(Dense(128, activation="relu"))
    model.add(Dropout(0.5))

    model.add(Dense(1, activation="sigmoid"))

    # compile the model
    model.compile(loss="binary_crossentropy", optimizer="adam", metrics=metrics)

    return model

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(monitor='loss', patience=3, restore_best_weights=True)

# %%
# Cross validation
from sklearn.model_selection import KFold
from keras.preprocessing.image import ImageDataGenerator
from h5py import File
# Define the number of folds for cross-validation
n_splits = 10
epochs = 7
batch_size =64

# Initialize KFold with the number of folds
kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)

# Define lists to store the evaluation scores for each fold
accuracy_scores = []
og_val_accuracy_scores = []
histories = []
models = []
fold_no = 1
best_score = float('inf')  # pour une tâche de minimisation
best_model = None
# Iterate through each fold and train/evaluate the model
for train_idx, val_idx in kf.split(X_train, y_train):
    # Split the data into training and validation sets for this fold
    X_train_fold, y_train_fold = X_train[train_idx], y_train[train_idx]
    X_val_fold, y_val_fold = X_train[val_idx], y_train[val_idx]

    # Create an instance of ImageDataGenerator to generate your image data
    datagen = ImageDataGenerator()

    # Create generators for training and validation data
    train_generator = datagen.flow(x=X_train_fold, y=y_train_fold, batch_size=batch_size)
    valid_generator = datagen.flow(x=X_val_fold, y=y_val_fold, batch_size=batch_size)

    # Create instance of the model for this fold and train it
    model = create_model()

    # Train your model on the training data for this fold
    history = model.fit(train_generator, validation_data=valid_generator, epochs=epochs, verbose=1,
                        callbacks=[early_stop])
    # Model Évaluation with original val dataset
    scores = model.evaluate(X_val, y_val, verbose=1)
    og_val_accuracy_scores.append(scores[1])
    print(f'\nScore for fold with orginal val dataset {fold_no}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%\n')

    histories.append(history.history)

    models.append(model)

    # After training, evaluate the model on the validation set for this fold
    accuracy = model.evaluate(X_val_fold, y_val_fold)[1]

    # Store the accuracy score in the list
    accuracy_scores.append(accuracy)

    # Print the accuracy for this fold
    print(f"Accuracy for fold {len(accuracy_scores)}: {accuracy * 100}%")

    # Check if the model is better than the previous
    if scores[0] < best_score:
        best_score = scores[0]
        best_model = model

    fold_no = fold_no + 1

    # Sauvegarde du meilleur modèle
    if best_model is not None:
        best_model.save('cnn_best.h5')

# Calculate and print the average accuracy over all folds
average_accuracy = sum(accuracy_scores) / len(accuracy_scores)
og_val_average_accuracy = sum(og_val_accuracy_scores) / len(og_val_accuracy_scores)
print(f"\nAverage accuracy: {average_accuracy * 100}%")
print(f"\nAverage accuracy with orginal val: {og_val_average_accuracy * 100}%")
# Out:
# Epoch 1/7
# 141/141 [==============================] - 11s 66ms/step - loss: 0.3583 - accuracy: 0.8182 - auc: 0.9161 - val_loss: 0.1147 - val_accuracy: 0.9570 - val_auc: 0.9928
# Epoch 2/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.1427 - accuracy: 0.9482 - auc: 0.9863 - val_loss: 0.1042 - val_accuracy: 0.9660 - val_auc: 0.9953
# Epoch 3/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.1378 - accuracy: 0.9484 - auc: 0.9877 - val_loss: 0.0837 - val_accuracy: 0.9730 - val_auc: 0.9960
# Epoch 4/7
# 141/141 [==============================] - 9s 62ms/step - loss: 0.1029 - accuracy: 0.9623 - auc: 0.9924 - val_loss: 0.0634 - val_accuracy: 0.9730 - val_auc: 0.9975
# Epoch 5/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0885 - accuracy: 0.9679 - auc: 0.9942 - val_loss: 0.0986 - val_accuracy: 0.9690 - val_auc: 0.9956
# Epoch 6/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0881 - accuracy: 0.9690 - auc: 0.9947 - val_loss: 0.0581 - val_accuracy: 0.9740 - val_auc: 0.9981
# Epoch 7/7
# 141/141 [==============================] - 9s 62ms/step - loss: 0.0712 - accuracy: 0.9742 - auc: 0.9960 - val_loss: 0.0615 - val_accuracy: 0.9760 - val_auc: 0.9982
# 1/1 [==============================] - 0s 33ms/step - loss: 0.4597 - accuracy: 0.8750 - auc: 0.8984
#
# Score for fold with orginal val dataset 1: loss of 0.4597470760345459; accuracy of 87.5%
#
# 32/32 [==============================] - 0s 11ms/step - loss: 0.0615 - accuracy: 0.9760 - auc: 0.9982
# Accuracy for fold 1: 97.60000109672546%
# Epoch 1/7
# 141/141 [==============================] - 10s 65ms/step - loss: 0.3556 - accuracy: 0.8191 - auc: 0.9308 - val_loss: 0.1336 - val_accuracy: 0.9520 - val_auc: 0.9920
# Epoch 2/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.1460 - accuracy: 0.9460 - auc: 0.9858 - val_loss: 0.0893 - val_accuracy: 0.9670 - val_auc: 0.9962
# Epoch 3/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.1208 - accuracy: 0.9546 - auc: 0.9901 - val_loss: 0.1394 - val_accuracy: 0.9390 - val_auc: 0.9958
# Epoch 4/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.1035 - accuracy: 0.9604 - auc: 0.9923 - val_loss: 0.0659 - val_accuracy: 0.9800 - val_auc: 0.9966
# Epoch 5/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0885 - accuracy: 0.9670 - auc: 0.9942 - val_loss: 0.0730 - val_accuracy: 0.9760 - val_auc: 0.9971
# Epoch 6/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0750 - accuracy: 0.9729 - auc: 0.9959 - val_loss: 0.0529 - val_accuracy: 0.9840 - val_auc: 0.9984
# Epoch 7/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0641 - accuracy: 0.9769 - auc: 0.9968 - val_loss: 0.0594 - val_accuracy: 0.9790 - val_auc: 0.9961
# 1/1 [==============================] - 0s 30ms/step - loss: 0.5769 - accuracy: 0.7500 - auc: 0.9141
#
# Score for fold with orginal val dataset 2: loss of 0.5769373774528503; accuracy of 75.0%
#
# 32/32 [==============================] - 0s 11ms/step - loss: 0.0594 - accuracy: 0.9790 - auc: 0.9961
# Accuracy for fold 2: 97.89999723434448%
# Epoch 1/7
# 141/141 [==============================] - 12s 80ms/step - loss: 0.3327 - accuracy: 0.8284 - auc: 0.9397 - val_loss: 0.1411 - val_accuracy: 0.9420 - val_auc: 0.9868
# Epoch 2/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.1364 - accuracy: 0.9476 - auc: 0.9879 - val_loss: 0.1416 - val_accuracy: 0.9490 - val_auc: 0.9911
# Epoch 3/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.1119 - accuracy: 0.9578 - auc: 0.9916 - val_loss: 0.0987 - val_accuracy: 0.9590 - val_auc: 0.9933
# Epoch 4/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0973 - accuracy: 0.9641 - auc: 0.9935 - val_loss: 0.1030 - val_accuracy: 0.9560 - val_auc: 0.9943
# Epoch 5/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0802 - accuracy: 0.9700 - auc: 0.9952 - val_loss: 0.0795 - val_accuracy: 0.9700 - val_auc: 0.9952
# Epoch 6/7
# 141/141 [==============================] - 10s 69ms/step - loss: 0.0758 - accuracy: 0.9718 - auc: 0.9957 - val_loss: 0.0747 - val_accuracy: 0.9700 - val_auc: 0.9964
# Epoch 7/7
# 141/141 [==============================] - 9s 64ms/step - loss: 0.0643 - accuracy: 0.9781 - auc: 0.9970 - val_loss: 0.0986 - val_accuracy: 0.9680 - val_auc: 0.9927
# 1/1 [==============================] - 0s 45ms/step - loss: 0.3759 - accuracy: 0.8125 - auc: 0.9297
#
# Score for fold with orginal val dataset 3: loss of 0.37592899799346924; accuracy of 81.25%
#
# 32/32 [==============================] - 0s 13ms/step - loss: 0.0986 - accuracy: 0.9680 - auc: 0.9927
# Accuracy for fold 3: 96.79999947547913%
# Epoch 1/7
# 141/141 [==============================] - 12s 70ms/step - loss: 0.3613 - accuracy: 0.8100 - auc: 0.9259 - val_loss: 0.2455 - val_accuracy: 0.9010 - val_auc: 0.9875
# Epoch 2/7
# 141/141 [==============================] - 9s 64ms/step - loss: 0.1585 - accuracy: 0.9414 - auc: 0.9836 - val_loss: 0.1209 - val_accuracy: 0.9520 - val_auc: 0.9925
# Epoch 3/7
# 141/141 [==============================] - 9s 64ms/step - loss: 0.1196 - accuracy: 0.9570 - auc: 0.9904 - val_loss: 0.1143 - val_accuracy: 0.9520 - val_auc: 0.9920
# Epoch 4/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0951 - accuracy: 0.9654 - auc: 0.9936 - val_loss: 0.0815 - val_accuracy: 0.9720 - val_auc: 0.9954
# Epoch 5/7
# 141/141 [==============================] - 9s 62ms/step - loss: 0.0822 - accuracy: 0.9720 - auc: 0.9947 - val_loss: 0.0715 - val_accuracy: 0.9720 - val_auc: 0.9967
# Epoch 6/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0696 - accuracy: 0.9749 - auc: 0.9964 - val_loss: 0.0751 - val_accuracy: 0.9740 - val_auc: 0.9955
# Epoch 7/7
# 141/141 [==============================] - 9s 62ms/step - loss: 0.0731 - accuracy: 0.9748 - auc: 0.9959 - val_loss: 0.0818 - val_accuracy: 0.9710 - val_auc: 0.9956
# 1/1 [==============================] - 0s 31ms/step - loss: 0.4573 - accuracy: 0.8750 - auc: 0.9219
#
# Score for fold with orginal val dataset 4: loss of 0.45728829503059387; accuracy of 87.5%
#
# 32/32 [==============================] - 0s 10ms/step - loss: 0.0818 - accuracy: 0.9710 - auc: 0.9956
# Accuracy for fold 4: 97.10000157356262%
# Epoch 1/7
# 141/141 [==============================] - 10s 64ms/step - loss: 0.3592 - accuracy: 0.8198 - auc: 0.9309 - val_loss: 0.1424 - val_accuracy: 0.9490 - val_auc: 0.9878
# Epoch 2/7
# 141/141 [==============================] - 9s 62ms/step - loss: 0.1393 - accuracy: 0.9490 - auc: 0.9870 - val_loss: 0.1486 - val_accuracy: 0.9500 - val_auc: 0.9916
# Epoch 3/7
# 141/141 [==============================] - 9s 62ms/step - loss: 0.1143 - accuracy: 0.9597 - auc: 0.9911 - val_loss: 0.1025 - val_accuracy: 0.9600 - val_auc: 0.9937
# Epoch 4/7
# 141/141 [==============================] - 9s 62ms/step - loss: 0.0929 - accuracy: 0.9656 - auc: 0.9941 - val_loss: 0.0946 - val_accuracy: 0.9650 - val_auc: 0.9949
# Epoch 5/7
# 141/141 [==============================] - 9s 62ms/step - loss: 0.0782 - accuracy: 0.9724 - auc: 0.9955 - val_loss: 0.1069 - val_accuracy: 0.9630 - val_auc: 0.9952
# Epoch 6/7
# 141/141 [==============================] - 9s 62ms/step - loss: 0.0658 - accuracy: 0.9763 - auc: 0.9966 - val_loss: 0.0679 - val_accuracy: 0.9730 - val_auc: 0.9964
# Epoch 7/7
# 141/141 [==============================] - 9s 62ms/step - loss: 0.0627 - accuracy: 0.9774 - auc: 0.9968 - val_loss: 0.0823 - val_accuracy: 0.9740 - val_auc: 0.9941
# 1/1 [==============================] - 0s 30ms/step - loss: 0.4877 - accuracy: 0.8750 - auc: 0.8906
#
# Score for fold with orginal val dataset 5: loss of 0.48769283294677734; accuracy of 87.5%
#
# 32/32 [==============================] - 0s 11ms/step - loss: 0.0823 - accuracy: 0.9740 - auc: 0.9941
# Accuracy for fold 5: 97.39999771118164%
# Epoch 1/7
# 141/141 [==============================] - 10s 64ms/step - loss: 0.3669 - accuracy: 0.8080 - auc: 0.9249 - val_loss: 0.1292 - val_accuracy: 0.9520 - val_auc: 0.9901
# Epoch 2/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.1396 - accuracy: 0.9496 - auc: 0.9870 - val_loss: 0.0952 - val_accuracy: 0.9630 - val_auc: 0.9949
# Epoch 3/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.1166 - accuracy: 0.9581 - auc: 0.9908 - val_loss: 0.0908 - val_accuracy: 0.9580 - val_auc: 0.9952
# Epoch 4/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.1090 - accuracy: 0.9607 - auc: 0.9919 - val_loss: 0.0976 - val_accuracy: 0.9600 - val_auc: 0.9959
# Epoch 5/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0977 - accuracy: 0.9640 - auc: 0.9931 - val_loss: 0.0752 - val_accuracy: 0.9690 - val_auc: 0.9967
# Epoch 6/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0818 - accuracy: 0.9709 - auc: 0.9953 - val_loss: 0.0882 - val_accuracy: 0.9630 - val_auc: 0.9962
# Epoch 7/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0680 - accuracy: 0.9749 - auc: 0.9963 - val_loss: 0.0890 - val_accuracy: 0.9630 - val_auc: 0.9966
# 1/1 [==============================] - 0s 30ms/step - loss: 0.9238 - accuracy: 0.7500 - auc: 0.8828
#
# Score for fold with orginal val dataset 6: loss of 0.923809826374054; accuracy of 75.0%
#
# 32/32 [==============================] - 0s 11ms/step - loss: 0.0890 - accuracy: 0.9630 - auc: 0.9966
# Accuracy for fold 6: 96.29999995231628%
# Epoch 1/7
# 141/141 [==============================] - 10s 65ms/step - loss: 0.3751 - accuracy: 0.8047 - auc: 0.9204 - val_loss: 0.1832 - val_accuracy: 0.9270 - val_auc: 0.9811
# Epoch 2/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.1410 - accuracy: 0.9474 - auc: 0.9864 - val_loss: 0.1309 - val_accuracy: 0.9440 - val_auc: 0.9891
# Epoch 3/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.1153 - accuracy: 0.9573 - auc: 0.9908 - val_loss: 0.1545 - val_accuracy: 0.9390 - val_auc: 0.9894
# Epoch 4/7
# 141/141 [==============================] - 9s 64ms/step - loss: 0.0986 - accuracy: 0.9630 - auc: 0.9934 - val_loss: 0.1533 - val_accuracy: 0.9440 - val_auc: 0.9872
# Epoch 5/7
# 141/141 [==============================] - 9s 64ms/step - loss: 0.0909 - accuracy: 0.9672 - auc: 0.9939 - val_loss: 0.1498 - val_accuracy: 0.9500 - val_auc: 0.9876
# Epoch 6/7
# 141/141 [==============================] - 9s 64ms/step - loss: 0.0753 - accuracy: 0.9748 - auc: 0.9957 - val_loss: 0.0956 - val_accuracy: 0.9590 - val_auc: 0.9942
# Epoch 7/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0713 - accuracy: 0.9750 - auc: 0.9957 - val_loss: 0.1012 - val_accuracy: 0.9590 - val_auc: 0.9957
# 1/1 [==============================] - 0s 30ms/step - loss: 0.8207 - accuracy: 0.7500 - auc: 0.8906
#
# Score for fold with orginal val dataset 7: loss of 0.8207134008407593; accuracy of 75.0%
#
# 32/32 [==============================] - 0s 11ms/step - loss: 0.1012 - accuracy: 0.9590 - auc: 0.9957
# Accuracy for fold 7: 95.89999914169312%
# Epoch 1/7
# 141/141 [==============================] - 10s 66ms/step - loss: 0.3571 - accuracy: 0.8312 - auc: 0.9320 - val_loss: 0.1204 - val_accuracy: 0.9610 - val_auc: 0.9908
# Epoch 2/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.1361 - accuracy: 0.9486 - auc: 0.9879 - val_loss: 0.0933 - val_accuracy: 0.9640 - val_auc: 0.9943
# Epoch 3/7
# 141/141 [==============================] - 9s 62ms/step - loss: 0.1150 - accuracy: 0.9568 - auc: 0.9912 - val_loss: 0.0785 - val_accuracy: 0.9710 - val_auc: 0.9956
# Epoch 4/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0897 - accuracy: 0.9668 - auc: 0.9940 - val_loss: 0.0695 - val_accuracy: 0.9740 - val_auc: 0.9964
# Epoch 5/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0846 - accuracy: 0.9677 - auc: 0.9945 - val_loss: 0.0591 - val_accuracy: 0.9780 - val_auc: 0.9971
# Epoch 6/7
# 141/141 [==============================] - 10s 69ms/step - loss: 0.0704 - accuracy: 0.9732 - auc: 0.9962 - val_loss: 0.0613 - val_accuracy: 0.9770 - val_auc: 0.9968
# Epoch 7/7
# 141/141 [==============================] - 9s 65ms/step - loss: 0.0650 - accuracy: 0.9772 - auc: 0.9967 - val_loss: 0.0438 - val_accuracy: 0.9830 - val_auc: 0.9980
# 1/1 [==============================] - 0s 36ms/step - loss: 0.4644 - accuracy: 0.8750 - auc: 0.8984
#
# Score for fold with orginal val dataset 8: loss of 0.46440446376800537; accuracy of 87.5%
#
# 32/32 [==============================] - 0s 11ms/step - loss: 0.0438 - accuracy: 0.9830 - auc: 0.9980
# Accuracy for fold 8: 98.29999804496765%
# Epoch 1/7
# 141/141 [==============================] - 11s 66ms/step - loss: 0.3629 - accuracy: 0.8078 - auc: 0.9293 - val_loss: 0.2076 - val_accuracy: 0.9150 - val_auc: 0.9911
# Epoch 2/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.1347 - accuracy: 0.9506 - auc: 0.9878 - val_loss: 0.0881 - val_accuracy: 0.9600 - val_auc: 0.9954
# Epoch 3/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.1109 - accuracy: 0.9627 - auc: 0.9911 - val_loss: 0.0930 - val_accuracy: 0.9650 - val_auc: 0.9952
# Epoch 4/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0871 - accuracy: 0.9684 - auc: 0.9946 - val_loss: 0.0831 - val_accuracy: 0.9680 - val_auc: 0.9955
# Epoch 5/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0856 - accuracy: 0.9694 - auc: 0.9948 - val_loss: 0.0948 - val_accuracy: 0.9720 - val_auc: 0.9937
# Epoch 6/7
# 141/141 [==============================] - 9s 62ms/step - loss: 0.0643 - accuracy: 0.9766 - auc: 0.9967 - val_loss: 0.0692 - val_accuracy: 0.9760 - val_auc: 0.9968
# Epoch 7/7
# 141/141 [==============================] - 9s 62ms/step - loss: 0.0553 - accuracy: 0.9807 - auc: 0.9973 - val_loss: 0.0953 - val_accuracy: 0.9710 - val_auc: 0.9928
# 1/1 [==============================] - 0s 30ms/step - loss: 0.5289 - accuracy: 0.8125 - auc: 0.9141
#
# Score for fold with orginal val dataset 9: loss of 0.5289466977119446; accuracy of 81.25%
#
# 32/32 [==============================] - 0s 11ms/step - loss: 0.0953 - accuracy: 0.9710 - auc: 0.9928
# Accuracy for fold 9: 97.10000157356262%
# Epoch 1/7
# 141/141 [==============================] - 10s 64ms/step - loss: 0.3479 - accuracy: 0.8237 - auc: 0.9336 - val_loss: 0.1574 - val_accuracy: 0.9320 - val_auc: 0.9883
# Epoch 2/7
# 141/141 [==============================] - 9s 62ms/step - loss: 0.1365 - accuracy: 0.9489 - auc: 0.9876 - val_loss: 0.1022 - val_accuracy: 0.9580 - val_auc: 0.9930
# Epoch 3/7
# 141/141 [==============================] - 9s 62ms/step - loss: 0.1127 - accuracy: 0.9591 - auc: 0.9911 - val_loss: 0.0968 - val_accuracy: 0.9630 - val_auc: 0.9940
# Epoch 4/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0923 - accuracy: 0.9654 - auc: 0.9942 - val_loss: 0.0853 - val_accuracy: 0.9730 - val_auc: 0.9943
# Epoch 5/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0786 - accuracy: 0.9729 - auc: 0.9955 - val_loss: 0.0929 - val_accuracy: 0.9710 - val_auc: 0.9953
# Epoch 6/7
# 141/141 [==============================] - 9s 62ms/step - loss: 0.0705 - accuracy: 0.9740 - auc: 0.9964 - val_loss: 0.1047 - val_accuracy: 0.9640 - val_auc: 0.9946
# Epoch 7/7
# 141/141 [==============================] - 9s 64ms/step - loss: 0.0621 - accuracy: 0.9754 - auc: 0.9973 - val_loss: 0.1816 - val_accuracy: 0.9390 - val_auc: 0.9939
# 1/1 [==============================] - 0s 57ms/step - loss: 0.7269 - accuracy: 0.8125 - auc: 0.8359
#
# Score for fold with orginal val dataset 10: loss of 0.7269445657730103; accuracy of 81.25%
#
# 32/32 [==============================] - 0s 12ms/step - loss: 0.1816 - accuracy: 0.9390 - auc: 0.9939
# Accuracy for fold 10: 93.90000104904175%
#
# Average accuracy: 96.82999968528748%
#
# Average accuracy with orginal val: 81.875%

# %%
# Get accuracy scores for each fold (train and validation)
loss = []
acc = []
val_loss = []
val_acc = []

for history in histories:
    loss.append(np.mean(history["loss"]))
    acc.append(np.mean(history["accuracy"]))
    val_loss.append(np.mean(history["val_loss"]))
    val_acc.append(np.mean(history["val_accuracy"]))

# %%
# Plot loss and validation loss per fold
import matplotlib.pyplot as plt
plt.title('Losses')
plt.plot(range(1, len(loss)+1), loss, label='Loss')
plt.plot(range(1, len(val_loss)+1), val_loss, label='Validation loss')
plt.ylim(0.0, 1.0)
plt.xlabel('Fold')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Plot accuracies and validation accuracies per fold
import matplotlib.pyplot as plt

plt.title('Accuracies')
plt.plot(range(1, len(acc) + 1), acc, label='Accuracy')
plt.plot(range(1, len(val_acc) + 1), val_acc, label='Validation accuracy')
plt.ylim(0.0, 1.0)
plt.xlabel('Fold')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Train a final model with same parameters and save it
# Create an instance of ImageDataGenerator to generate your image data
datagen = ImageDataGenerator()
train_generator = datagen.flow(x=X_train, y=y_train, batch_size=batch_size)
valid_generator = datagen.flow(x=X_val, y=y_val, batch_size=batch_size)
model = create_model()
history = model.fit(train_generator, validation_data=valid_generator, epochs=epochs, verbose=1, callbacks=[early_stop])
model.save('cnn.h5')
# Out:
# Epoch 1/7
# 157/157 [==============================] - 11s 63ms/step - loss: 0.3043 - accuracy: 0.8535 - auc: 0.9466 - val_loss: 0.6067 - val_accuracy: 0.7500 - val_auc: 0.7812
# Epoch 2/7
# 157/157 [==============================] - 10s 61ms/step - loss: 0.1386 - accuracy: 0.9486 - auc: 0.9866 - val_loss: 0.8238 - val_accuracy: 0.7500 - val_auc: 0.7969
# Epoch 3/7
# 157/157 [==============================] - 9s 60ms/step - loss: 0.1071 - accuracy: 0.9583 - auc: 0.9924 - val_loss: 0.4841 - val_accuracy: 0.8125 - val_auc: 0.8672
# Epoch 4/7
# 157/157 [==============================] - 9s 60ms/step - loss: 0.0881 - accuracy: 0.9671 - auc: 0.9948 - val_loss: 0.5558 - val_accuracy: 0.7500 - val_auc: 0.8750
# Epoch 5/7
# 157/157 [==============================] - 10s 61ms/step - loss: 0.0747 - accuracy: 0.9701 - auc: 0.9961 - val_loss: 0.4695 - val_accuracy: 0.9375 - val_auc: 0.8828
# Epoch 6/7
# 157/157 [==============================] - 10s 62ms/step - loss: 0.0594 - accuracy: 0.9778 - auc: 0.9974 - val_loss: 0.4603 - val_accuracy: 0.8750 - val_auc: 0.8906
# Epoch 7/7
# 157/157 [==============================] - 10s 61ms/step - loss: 0.0551 - accuracy: 0.9775 - auc: 0.9979 - val_loss: 0.6525 - val_accuracy: 0.6250 - val_auc: 0.9219

# %%
# Plot val accuracy and val loss of the trained model
import matplotlib.pyplot as plt

plt.title('Accuracy vs Loss per Epoch')
plt.plot(range(1, len(history.history["val_accuracy"]) + 1), history.history["val_accuracy"], label='Accuracy')
plt.plot(range(1, len(history.history["val_loss"]) + 1), history.history["val_loss"], label='Loss')
plt.ylim(0.0, 1.0)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
# Make predictions on the test set
model = load_model('cnn.h5')

# %%
# Make predictions on the test set

y_pred_test = model.predict(X_test)
y_pred_test = np.where(y_pred_test >= 0.5, 1, 0)
# Out:
# 20/20 [==============================] - 0s 9ms/step

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Compute ROC curve and AUC score for the predictions
fpr, tpr, thresholds = roc_curve(y_test, y_pred_test)
roc_auc = auc(fpr, tpr)

# Plot ROC curve and show AUC score on the plot
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()

# %%
from sklearn.metrics import confusion_matrix

# Compute the confusion matrix for test set
cm = confusion_matrix(y_test, y_pred_test.flatten())
print(cm)
# Out:
# [[231   3]
#  [134 256]]

# %%
# Plot the confusion matrix
class_names = subfolders
import seaborn as sns

sns.heatmap(cm, annot=True, fmt='g', cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()

# %%
# Compute the classification report for test set
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred_test, target_names=class_names))
# Out:
#               precision    recall  f1-score   support
#
#       NORMAL       0.63      0.99      0.77       234
#    PNEUMONIA       0.99      0.66      0.79       390
#
#     accuracy                           0.78       624
#    macro avg       0.81      0.82      0.78       624
# weighted avg       0.86      0.78      0.78       624

# %%
import tensorflow as tf
import numpy as np
from IPython.display import Image, display
import matplotlib.cm as cm
from keras.utils import load_img, img_to_array, array_to_img


def get_img_array(img_path, size):
    # `img` is a PIL image of size 256x256
    img = load_img(img_path, target_size=size, grayscale=True)
    # `array` is a float32 Numpy array of shape (256, 256, 3)
    array = img_to_array(img)
    # We add a dimension to transform our array into a "batch"
    # of size (1, 299, 299, 3)
    array = np.expand_dims(array, axis=0)
    return array


def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    # First, we create a model that maps the input image to the activations
    # of the last conv layer as well as the output predictions
    grad_model = tf.keras.models.Model(
        [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output]
    )

    # Then, we compute the gradient of the top predicted class for our input image
    # with respect to the activations of the last conv layer
    with tf.GradientTape() as tape:
        last_conv_layer_output, preds = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]

    # This is the gradient of the output neuron (top predicted or chosen)
    # with regard to the output feature map of the last conv layer
    grads = tape.gradient(class_channel, last_conv_layer_output)

    # This is a vector where each entry is the mean intensity of the gradient
    # over a specific feature map channel
    #grads = tf.expand_dims(grads, axis=0)
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # We multiply each channel in the feature map array
    # by "how important this channel is" with regard to the top predicted class
    # then sum all the channels to obtain the heatmap class activation
    last_conv_layer_output = last_conv_layer_output[0]
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)

    # For visualization purpose, we will also normalize the heatmap between 0 & 1
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()


def generate_superimposed_gradcam(img_path, heatmap, alpha=0.4):
    # Load the original image
    img = load_img(img_path)
    img = img_to_array(img)

    # Rescale heatmap to a range 0-255
    heatmap = np.uint8(255 * heatmap)

    # Use jet colormap to colorize heatmap
    jet = cm.get_cmap("jet")

    # Use RGB values of the colormap
    jet_colors = jet(np.arange(256))[:, :3]
    jet_heatmap = jet_colors[heatmap]

    # Create an image with RGB colorized heatmap
    jet_heatmap = array_to_img(jet_heatmap)
    jet_heatmap = jet_heatmap.resize((img.shape[1], img.shape[0]))
    jet_heatmap = img_to_array(jet_heatmap)

    # Superimpose the heatmap on original image
    superimposed_img = jet_heatmap * alpha + img
    superimposed_img = array_to_img(superimposed_img)

    return superimposed_img


def display_heatmaps(img_path, heatmaps, superimposed=False):
    import matplotlib.pyplot as plt

    # Define the number of columns for the subplot grid
    n_cols = min(len(heatmaps), 5)

    # Calculate the number of rows based on the number of columns and total number of images
    n_rows = (len(heatmaps) - 1) // n_cols + 1

    # Create a figure with the desired size
    fig, axes = plt.subplots(n_rows, n_cols, figsize=(20, 4 * n_rows))

    for i, heatmap in enumerate(heatmaps):
        # Calculate the row and column index for this heatmap
        row = i // n_cols
        col = i % n_cols

        # Get the corresponding subplot
        ax = axes[row, col] if n_rows > 1 else axes[col]

        # Set the title of the subplot to the layer name
        ax.set_title(heatmap['layer_name'])

        if superimposed:
            superimposed_img = generate_superimposed_gradcam(img_path, heatmaps[i]["image"])
            # Plot the heatmap
            ax.imshow(superimposed_img)
        else:
            # Plot the heatmap
            ax.imshow(heatmaps[i]["image"], cmap='jet')

    # Hide the remaining subplots that are not used
    for i in range(len(heatmaps), n_rows * n_cols):
        # Calculate the row and column index for this subplot
        row = i // n_cols
        col = i % n_cols

        # Get the corresponding subplot
        ax = axes[row, col] if n_rows > 1 else axes[col]

        # Hide the subplot
        ax.axis('off')

    # Adjust the spacing between subplots
    fig.tight_layout()

    # Show the plot
    plt.show()

# %%
# Remove last layer's softmax
model.layers[-1].activation = None

# import os
# os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
# Print model summary to get last max pooling layer name
print(model.summary())
# Out:
# Model: "sequential_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_84 (Conv2D)          (None, 126, 126, 32)      320
#
#  max_pooling2d_84 (MaxPoolin  (None, 63, 63, 32)       0
#  g2D)
#
#  conv2d_85 (Conv2D)          (None, 61, 61, 64)        18496
#
#  max_pooling2d_85 (MaxPoolin  (None, 30, 30, 64)       0
#  g2D)
#
#  conv2d_86 (Conv2D)          (None, 28, 28, 128)       73856
#
#  max_pooling2d_86 (MaxPoolin  (None, 14, 14, 128)      0
#  g2D)
#
#  conv2d_87 (Conv2D)          (None, 12, 12, 256)       295168
#
#  max_pooling2d_87 (MaxPoolin  (None, 6, 6, 256)        0
#  g2D)
#
#  flatten_21 (Flatten)        (None, 9216)              0
#
#  dense_63 (Dense)            (None, 256)               2359552
#
#  dropout_42 (Dropout)        (None, 256)               0
#
#  dense_64 (Dense)            (None, 128)               32896
#
#  dropout_43 (Dropout)        (None, 128)               0
#
#  dense_65 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 2,780,417
# Trainable params: 2,780,417
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Heatmaps and Grad-CAM


import cv2
import matplotlib.pyplot as plt

images = [
    {
        "path": BASE + "val\\NORMAL\\NORMAL2-IM-1431-0001.jpeg"
    },
    {
        "path": BASE + "val\\PNEUMONIA\\person1946_bacteria_4875.jpeg"
    }
]

for image in images:
    image_temp = cv2.imread(image["path"])
    image_temp = cv2.cvtColor(image_temp, cv2.COLOR_RGB2GRAY)
    image_temp = cv2.resize(image_temp, (img_width, img_height))

    plt.imshow(image_temp, cmap=plt.cm.gray)
    plt.show()

    image["array"] = get_img_array(image["path"], size=(img_width, img_height))
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\keras\utils\image_utils.py:409: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn(

# %%
# Select last conv layer
last_conv_layer_name = "max_pooling2d_87"

# %%
# from cam import make_gradcam_heatmap, display_heatmaps

for image in images:
    heatmaps = []
    for layer in model.layers[:model.layers.index(model.get_layer(last_conv_layer_name)) + 1]:
        heatmap = make_gradcam_heatmap(image["array"], model, layer.name)
        heatmaps.append({
            "layer_name": layer.name,
            "image": heatmap
        })

    # Display heatmaps from all layers until the last max pooling layer
    display_heatmaps(image["path"], heatmaps)

    # Display the chosen image superimposed with heatmaps of each layer until the last max pooling layer
    display_heatmaps(image["path"], heatmaps, True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_19772\2206199731.py:64: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   jet = cm.get_cmap("jet")

# %%
# Predict
for image in images:
    pred = model.predict(image["array"].reshape(1, img_width, img_height, 1))
    print(pred)
    # Display predicted class
    print("Predicted class: {}".format(subfolders[int(pred[0][0])]))
# Out:
# 1/1 [==============================] - 0s 29ms/step
# [[1.]]
# Predicted class: PNEUMONIA
# 1/1 [==============================] - 0s 28ms/step
# [[1.]]
# Predicted class: PNEUMONIA
