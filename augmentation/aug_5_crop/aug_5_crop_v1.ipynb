# %% [markdown]
# # Template - Détection de la pneumonie à partir d'images radiologiques
# Le but de ce notebook est de servir de référence pour créer un terrain propice aux différentes expérimentations que nous allons faire. Dans ce notebook, nous avons une trame principale permettant de récupérer les données, les normaliser puis les augmenter, construire le modèle et entrainer ce dernier. A la suite de cet entrainement, plusieurs métriques permettent de déterminer l'efficacité et la fiabilité du modèle selon les données fournies.
#
# **Chacun des notebooks derivant de celui-ci se doivent d'expliciter en introduction l'intérêt de l'expérimentation, de décrire les différentes étapes de l'expérimentation et les résultats attendus. Les résultats obtenus doivent être présentés et commentés dans une conclusion qui accompagne les métriques.**
#
# ## Version 2
# Des modifications ont été apportés aux templates pour ajouter de la souplesse aux entrainements sur GPU :
# - Modification de la taille des images : de 256x256 à 128x128
# - Modification du batch size : de 100 à 64
# - Correction du graph de la métrique loss

# %%
# Check that GPU is used
import tensorflow as tf
tf.config.list_physical_devices('GPU')

# %%
from PIL import Image
import os
import numpy as np

# Define the folders where your data is stored
TRAIN_FOLDER = 'train'
TEST_FOLDER = 'test'
VAL_FOLDER = 'val'
ITERATION = 'v1_'

# Define the subfolders within each folder where the images are stored
subfolders = ['NORMAL', 'PNEUMONIA']

# Define the size of the images you want to resize your images to
img_width, img_height = 128, 128

# %%
# Function to load and resize images from a folder
def load_images_from_folder(folder, limit_per_subfolder=None):
    X = []
    y = []
    for subfolder in subfolders:
        folder_path = os.path.join(folder, subfolder)
        if limit_per_subfolder:
            # Get amount of random filenames from the folder
            filenames = np.random.choice(os.listdir(folder_path), limit_per_subfolder, replace=False)
        else:
            filenames = os.listdir(folder_path)
        for filename in filenames:
            img_path = os.path.join(folder_path, filename)
            img = Image.open(img_path)

            # Resize the image to the desired size
            img = img.resize((img_width, img_height))

            # Convert RGB image to grayscale
            img = img.convert('L')

            # Convert the image to a NumPy array and append it to X
            img = np.array(img)
            X.append(img)

            # Append the corresponding label to y
            y.append(subfolders.index(subfolder))

    X = np.array(X)
    y = np.array(y)
    return X, y

# %%
import os
import numpy as np
from PIL import Image, ImageOps
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator

def make_square(folder, target_folder, target_size=(224, 224)):
    for filename in os.listdir(folder):
        image_path = os.path.join(folder, filename)
        image = Image.open(image_path)

        # Obtenez les dimensions de l'image
        width, height = image.size  # Utilisez la méthode size de PIL Image

        # Calculez le côté le plus petit
        size = min(height, width)

        # Créez une image carrée en rognant les parties centrales
        left = (width - size) / 2
        top = (height - size) / 2
        right = (width + size) / 2
        bottom = (height + size) / 2

        image = image.crop((left, top, right, bottom))

        # Redimensionnez l'image pour la taille cible
        image = image.resize(target_size, Image.LANCZOS)

        # Sauvegardez l'image
        image.save(os.path.join(target_folder, filename))


def generate_cropped_image(folder, to_augment_class):
    padded_folder = f"{folder}_cropped"

    padded_dir = os.path.join(f"{folder}_cropped", to_augment_class)

    if not os.path.exists(padded_folder):
        os.mkdir(padded_folder)

    if not os.path.exists(padded_dir):
        os.mkdir(padded_dir)

    make_square(os.path.join(folder, to_augment_class), padded_dir)

    return padded_folder


def generate_augmented_images(folder, to_augment_class, image_size=(128, 128), target_nbr=5000):
    dir = os.path.join(folder, to_augment_class)
    count = len(os.listdir(dir))

    augmented_dir = os.path.join(f"{folder}_augmented", to_augment_class)

    if not os.path.exists(f"{folder}_augmented"):
        os.mkdir(f"{folder}_augmented")

    if not os.path.exists(augmented_dir):
        os.mkdir(augmented_dir)

    augmented_count = len(os.listdir(augmented_dir))

    datagen = ImageDataGenerator(
        rotation_range=0,
        width_shift_range=0,
        height_shift_range=0,
        shear_range=0,
        zoom_range=0,
        horizontal_flip=True,
        fill_mode='nearest',
    )

    generator = datagen.flow_from_directory(

        folder,
        batch_size=1,
        save_to_dir=augmented_dir,
        save_format='jpeg',
        save_prefix='IM_AUGMENTED',
        classes=[to_augment_class],
        keep_aspect_ratio=True,
        target_size=image_size,
    )

    additional_count = target_nbr - len(os.listdir(augmented_dir))

    for i in range(additional_count):
        generator.next()

    new_count = len(os.listdir(augmented_dir))

    print(f'Given {to_augment_class} count: {count}')
    print(f'Augmented {to_augment_class} count: {new_count}')

# %%
# Generate augmented for the training set
path_train_n = generate_cropped_image(TRAIN_FOLDER, 'NORMAL')
path_train_p = generate_cropped_image(TRAIN_FOLDER, 'PNEUMONIA')

generate_augmented_images(path_train_n, 'NORMAL', image_size=(img_width, img_height))
generate_augmented_images(path_train_p, 'PNEUMONIA', image_size=(img_width, img_height))
# Out:
# Found 1341 images belonging to 1 classes.
# Given NORMAL count: 1341
# Augmented NORMAL count: 5000
# Found 3875 images belonging to 1 classes.
# Given PNEUMONIA count: 3875
# Augmented PNEUMONIA count: 5000

# %%
# Load the training data
# Get min value between the number of normal images and the number of pneumonia images
TRAIN_FOLDER = f"train_cropped_augmented"
min_images = min(len(os.listdir(os.path.join(TRAIN_FOLDER, subfolders[0]))), len(os.listdir(os.path.join(TRAIN_FOLDER, subfolders[1]))))
X_train, y_train = load_images_from_folder(TRAIN_FOLDER, min_images)

# Load the test data
X_test, y_test = load_images_from_folder(TEST_FOLDER)

# Load the validation data
X_val, y_val = load_images_from_folder(VAL_FOLDER)

# %%
# Make a matplot figure to show how many images are in each subfolder of train
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))
plt.bar(subfolders, [len(os.listdir(os.path.join(TRAIN_FOLDER, subfolder))) for subfolder in subfolders])
plt.title('Number of images in each subfolder of train')
plt.show()

# %%
# Make a matplot figure to show how many images if each class in the training set
plt.figure(figsize=(10, 5))
plt.bar(subfolders, [len(y_train[y_train == i]) for i in range(len(subfolders))])
plt.title('Number of images in each class in the training set')
plt.show()

# %%
# Normalize the pixel values to be between 0 and 1
X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255
X_val = X_val.astype('float32') / 255

X_train = X_train.reshape(len(X_train), img_width, img_height, 1)
X_test = X_test.reshape(len(X_test), img_width, img_height, 1)
X_val = X_val.reshape(len(X_val), img_width, img_height, 1)

# %%
single_image = X_train[np.random.randint(len(X_train))]
print(single_image.shape)
plt.imshow(single_image, cmap='Greys')
# Out:
# (128, 128, 1)

# %%
# Define model metrics
from keras.metrics import AUC

metrics = [
    "accuracy",
    AUC(name='auc')
]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# Define the model architecture
def create_model():
    model = Sequential()

    model.add(Conv2D(filters=32, kernel_size=(3,3), input_shape=(img_width, img_height, 1), activation="relu"))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(filters=64, kernel_size=(3,3), activation="relu"))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(filters=128, kernel_size=(3,3), activation="relu"))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(filters=256, kernel_size=(3,3), activation="relu"))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Flatten())

    model.add(Dense(256, activation="relu"))
    model.add(Dropout(0.5))

    model.add(Dense(128, activation="relu"))
    model.add(Dropout(0.5))

    model.add(Dense(1, activation="sigmoid"))

    # compile the model
    model.compile(loss="binary_crossentropy", optimizer="adam", metrics=metrics)

    return model

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='loss', patience=3, restore_best_weights=True)

# %%
# Cross validation
from sklearn.model_selection import KFold
from keras.preprocessing.image import ImageDataGenerator

# Define the number of folds for cross-validation
n_splits = 10
epochs = 7
batch_size = 64

# Initialize KFold with the number of folds
kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)

# Define lists to store the evaluation scores for each fold
accuracy_scores = []
histories = []
models = []

# Iterate through each fold and train/evaluate the model
for train_idx, val_idx in kf.split(X_train, y_train):
    # Split the data into training and validation sets for this fold
    X_train_fold, y_train_fold = X_train[train_idx], y_train[train_idx]
    X_val_fold, y_val_fold = X_train[val_idx], y_train[val_idx]

    # Create an instance of ImageDataGenerator to generate your image data
    datagen = ImageDataGenerator()

    # Create generators for training and validation data
    train_generator = datagen.flow(x=X_train_fold, y=y_train_fold, batch_size=batch_size)
    valid_generator = datagen.flow(x=X_val_fold, y=y_val_fold, batch_size=batch_size)

    # Create instance of the model for this fold and train it
    model = create_model()

    # Train your model on the training data for this fold
    history = model.fit(train_generator, validation_data=valid_generator, epochs=epochs, verbose=1, callbacks=[early_stop])
    histories.append(history.history)

    models.append(model)
# Out:
# Epoch 1/7
# 141/141 [==============================] - 15s 70ms/step - loss: 0.3431 - accuracy: 0.8258 - auc: 0.9242 - val_loss: 0.1539 - val_accuracy: 0.9400 - val_auc: 0.9877
# Epoch 2/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.1464 - accuracy: 0.9484 - auc: 0.9853 - val_loss: 0.1391 - val_accuracy: 0.9410 - val_auc: 0.9933
# Epoch 3/7
# 141/141 [==============================] - 9s 64ms/step - loss: 0.1204 - accuracy: 0.9551 - auc: 0.9904 - val_loss: 0.0954 - val_accuracy: 0.9560 - val_auc: 0.9953
# Epoch 4/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.1030 - accuracy: 0.9621 - auc: 0.9928 - val_loss: 0.0777 - val_accuracy: 0.9700 - val_auc: 0.9963
# Epoch 5/7
# 141/141 [==============================] - 9s 62ms/step - loss: 0.0916 - accuracy: 0.9652 - auc: 0.9944 - val_loss: 0.0938 - val_accuracy: 0.9740 - val_auc: 0.9938
# Epoch 6/7
# 141/141 [==============================] - 9s 62ms/step - loss: 0.0802 - accuracy: 0.9710 - auc: 0.9953 - val_loss: 0.0760 - val_accuracy: 0.9730 - val_auc: 0.9961
# Epoch 7/7
# 141/141 [==============================] - 9s 62ms/step - loss: 0.0693 - accuracy: 0.9739 - auc: 0.9968 - val_loss: 0.0625 - val_accuracy: 0.9720 - val_auc: 0.9976
# Epoch 1/7
# 141/141 [==============================] - 10s 63ms/step - loss: 0.3581 - accuracy: 0.8280 - auc: 0.9330 - val_loss: 0.1121 - val_accuracy: 0.9570 - val_auc: 0.9935
# Epoch 2/7
# 141/141 [==============================] - 9s 62ms/step - loss: 0.1428 - accuracy: 0.9507 - auc: 0.9861 - val_loss: 0.0902 - val_accuracy: 0.9620 - val_auc: 0.9952
# Epoch 3/7
# 141/141 [==============================] - 9s 62ms/step - loss: 0.1065 - accuracy: 0.9598 - auc: 0.9925 - val_loss: 0.0736 - val_accuracy: 0.9670 - val_auc: 0.9970
# Epoch 4/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0928 - accuracy: 0.9667 - auc: 0.9939 - val_loss: 0.0913 - val_accuracy: 0.9600 - val_auc: 0.9977
# Epoch 5/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0725 - accuracy: 0.9734 - auc: 0.9961 - val_loss: 0.0525 - val_accuracy: 0.9800 - val_auc: 0.9975
# Epoch 6/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0746 - accuracy: 0.9737 - auc: 0.9956 - val_loss: 0.0516 - val_accuracy: 0.9790 - val_auc: 0.9989
# Epoch 7/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0612 - accuracy: 0.9777 - auc: 0.9973 - val_loss: 0.0485 - val_accuracy: 0.9810 - val_auc: 0.9985
# Epoch 1/7
# 141/141 [==============================] - 10s 65ms/step - loss: 0.3568 - accuracy: 0.8153 - auc: 0.9307 - val_loss: 0.1834 - val_accuracy: 0.9360 - val_auc: 0.9926
# Epoch 2/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.1521 - accuracy: 0.9476 - auc: 0.9843 - val_loss: 0.0784 - val_accuracy: 0.9690 - val_auc: 0.9969
# Epoch 3/7
# 141/141 [==============================] - 9s 62ms/step - loss: 0.1178 - accuracy: 0.9568 - auc: 0.9902 - val_loss: 0.0775 - val_accuracy: 0.9720 - val_auc: 0.9972
# Epoch 4/7
# 141/141 [==============================] - 9s 61ms/step - loss: 0.1009 - accuracy: 0.9642 - auc: 0.9926 - val_loss: 0.0891 - val_accuracy: 0.9680 - val_auc: 0.9969
# Epoch 5/7
# 141/141 [==============================] - 9s 61ms/step - loss: 0.0817 - accuracy: 0.9708 - auc: 0.9949 - val_loss: 0.0601 - val_accuracy: 0.9740 - val_auc: 0.9980
# Epoch 6/7
# 141/141 [==============================] - 9s 61ms/step - loss: 0.0795 - accuracy: 0.9718 - auc: 0.9950 - val_loss: 0.0596 - val_accuracy: 0.9760 - val_auc: 0.9983
# Epoch 7/7
# 141/141 [==============================] - 9s 61ms/step - loss: 0.0658 - accuracy: 0.9769 - auc: 0.9964 - val_loss: 0.0582 - val_accuracy: 0.9750 - val_auc: 0.9982
# Epoch 1/7
# 141/141 [==============================] - 11s 73ms/step - loss: 0.3538 - accuracy: 0.8217 - auc: 0.9330 - val_loss: 0.1567 - val_accuracy: 0.9360 - val_auc: 0.9885
# Epoch 2/7
# 141/141 [==============================] - 10s 67ms/step - loss: 0.1472 - accuracy: 0.9474 - auc: 0.9855 - val_loss: 0.0986 - val_accuracy: 0.9600 - val_auc: 0.9947
# Epoch 3/7
# 141/141 [==============================] - 9s 65ms/step - loss: 0.1102 - accuracy: 0.9612 - auc: 0.9918 - val_loss: 0.0806 - val_accuracy: 0.9610 - val_auc: 0.9964
# Epoch 4/7
# 141/141 [==============================] - 9s 64ms/step - loss: 0.0989 - accuracy: 0.9659 - auc: 0.9931 - val_loss: 0.0938 - val_accuracy: 0.9590 - val_auc: 0.9959
# Epoch 5/7
# 141/141 [==============================] - 9s 64ms/step - loss: 0.0919 - accuracy: 0.9666 - auc: 0.9939 - val_loss: 0.0889 - val_accuracy: 0.9650 - val_auc: 0.9951
# Epoch 6/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0744 - accuracy: 0.9704 - auc: 0.9961 - val_loss: 0.0921 - val_accuracy: 0.9680 - val_auc: 0.9941
# Epoch 7/7
# 141/141 [==============================] - 9s 62ms/step - loss: 0.0644 - accuracy: 0.9763 - auc: 0.9972 - val_loss: 0.0667 - val_accuracy: 0.9830 - val_auc: 0.9960
# Epoch 1/7
# 141/141 [==============================] - 11s 65ms/step - loss: 0.3715 - accuracy: 0.8140 - auc: 0.9262 - val_loss: 0.1475 - val_accuracy: 0.9420 - val_auc: 0.9888
# Epoch 2/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.1558 - accuracy: 0.9421 - auc: 0.9843 - val_loss: 0.1072 - val_accuracy: 0.9510 - val_auc: 0.9938
# Epoch 3/7
# 141/141 [==============================] - 9s 65ms/step - loss: 0.1122 - accuracy: 0.9572 - auc: 0.9916 - val_loss: 0.0904 - val_accuracy: 0.9630 - val_auc: 0.9955
# Epoch 4/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0993 - accuracy: 0.9631 - auc: 0.9932 - val_loss: 0.0815 - val_accuracy: 0.9670 - val_auc: 0.9961
# Epoch 5/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0828 - accuracy: 0.9708 - auc: 0.9947 - val_loss: 0.0854 - val_accuracy: 0.9650 - val_auc: 0.9960
# Epoch 6/7
# 141/141 [==============================] - 9s 62ms/step - loss: 0.0739 - accuracy: 0.9719 - auc: 0.9960 - val_loss: 0.0751 - val_accuracy: 0.9710 - val_auc: 0.9967
# Epoch 7/7
# 141/141 [==============================] - 9s 62ms/step - loss: 0.0724 - accuracy: 0.9733 - auc: 0.9962 - val_loss: 0.0743 - val_accuracy: 0.9720 - val_auc: 0.9969
# Epoch 1/7
# 141/141 [==============================] - 11s 68ms/step - loss: 0.3630 - accuracy: 0.8219 - auc: 0.9306 - val_loss: 0.1395 - val_accuracy: 0.9520 - val_auc: 0.9867
# Epoch 2/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.1439 - accuracy: 0.9470 - auc: 0.9865 - val_loss: 0.0931 - val_accuracy: 0.9680 - val_auc: 0.9921
# Epoch 3/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.1220 - accuracy: 0.9537 - auc: 0.9898 - val_loss: 0.0892 - val_accuracy: 0.9740 - val_auc: 0.9949
# Epoch 4/7
# 141/141 [==============================] - 9s 62ms/step - loss: 0.0962 - accuracy: 0.9676 - auc: 0.9935 - val_loss: 0.0816 - val_accuracy: 0.9680 - val_auc: 0.9938
# Epoch 5/7
# 141/141 [==============================] - 9s 62ms/step - loss: 0.0790 - accuracy: 0.9707 - auc: 0.9954 - val_loss: 0.0780 - val_accuracy: 0.9730 - val_auc: 0.9958
# Epoch 6/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0780 - accuracy: 0.9714 - auc: 0.9955 - val_loss: 0.0776 - val_accuracy: 0.9740 - val_auc: 0.9950
# Epoch 7/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0607 - accuracy: 0.9777 - auc: 0.9974 - val_loss: 0.0532 - val_accuracy: 0.9830 - val_auc: 0.9972
# Epoch 1/7
# 141/141 [==============================] - 11s 68ms/step - loss: 0.3506 - accuracy: 0.8187 - auc: 0.9335 - val_loss: 0.2159 - val_accuracy: 0.9160 - val_auc: 0.9824
# Epoch 2/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.1439 - accuracy: 0.9482 - auc: 0.9864 - val_loss: 0.1710 - val_accuracy: 0.9360 - val_auc: 0.9834
# Epoch 3/7
# 141/141 [==============================] - 9s 64ms/step - loss: 0.1188 - accuracy: 0.9578 - auc: 0.9901 - val_loss: 0.1555 - val_accuracy: 0.9390 - val_auc: 0.9869
# Epoch 4/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0989 - accuracy: 0.9637 - auc: 0.9931 - val_loss: 0.1232 - val_accuracy: 0.9480 - val_auc: 0.9927
# Epoch 5/7
# 141/141 [==============================] - 9s 62ms/step - loss: 0.0872 - accuracy: 0.9686 - auc: 0.9946 - val_loss: 0.1110 - val_accuracy: 0.9560 - val_auc: 0.9925
# Epoch 6/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0771 - accuracy: 0.9728 - auc: 0.9957 - val_loss: 0.1514 - val_accuracy: 0.9440 - val_auc: 0.9886
# Epoch 7/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0769 - accuracy: 0.9756 - auc: 0.9953 - val_loss: 0.1230 - val_accuracy: 0.9520 - val_auc: 0.9925
# Epoch 1/7
# 141/141 [==============================] - 11s 67ms/step - loss: 0.4006 - accuracy: 0.7848 - auc: 0.9077 - val_loss: 0.1789 - val_accuracy: 0.9340 - val_auc: 0.9872
# Epoch 2/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.1487 - accuracy: 0.9424 - auc: 0.9860 - val_loss: 0.1042 - val_accuracy: 0.9650 - val_auc: 0.9927
# Epoch 3/7
# 141/141 [==============================] - 9s 64ms/step - loss: 0.1125 - accuracy: 0.9577 - auc: 0.9913 - val_loss: 0.0877 - val_accuracy: 0.9670 - val_auc: 0.9942
# Epoch 4/7
# 141/141 [==============================] - 9s 64ms/step - loss: 0.0976 - accuracy: 0.9633 - auc: 0.9936 - val_loss: 0.0935 - val_accuracy: 0.9620 - val_auc: 0.9958
# Epoch 5/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0883 - accuracy: 0.9681 - auc: 0.9946 - val_loss: 0.0751 - val_accuracy: 0.9730 - val_auc: 0.9959
# Epoch 6/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0825 - accuracy: 0.9698 - auc: 0.9954 - val_loss: 0.0649 - val_accuracy: 0.9760 - val_auc: 0.9970
# Epoch 7/7
# 141/141 [==============================] - 9s 64ms/step - loss: 0.0659 - accuracy: 0.9763 - auc: 0.9965 - val_loss: 0.0790 - val_accuracy: 0.9710 - val_auc: 0.9960
# Epoch 1/7
# 141/141 [==============================] - 11s 65ms/step - loss: 0.3629 - accuracy: 0.8173 - auc: 0.9285 - val_loss: 0.1500 - val_accuracy: 0.9400 - val_auc: 0.9864
# Epoch 2/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.1483 - accuracy: 0.9470 - auc: 0.9852 - val_loss: 0.1239 - val_accuracy: 0.9540 - val_auc: 0.9905
# Epoch 3/7
# 141/141 [==============================] - 9s 62ms/step - loss: 0.1215 - accuracy: 0.9564 - auc: 0.9900 - val_loss: 0.1042 - val_accuracy: 0.9630 - val_auc: 0.9927
# Epoch 4/7
# 141/141 [==============================] - 9s 62ms/step - loss: 0.0936 - accuracy: 0.9646 - auc: 0.9941 - val_loss: 0.1176 - val_accuracy: 0.9600 - val_auc: 0.9916
# Epoch 5/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0889 - accuracy: 0.9698 - auc: 0.9942 - val_loss: 0.0822 - val_accuracy: 0.9720 - val_auc: 0.9950
# Epoch 6/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0788 - accuracy: 0.9710 - auc: 0.9957 - val_loss: 0.0775 - val_accuracy: 0.9720 - val_auc: 0.9961
# Epoch 7/7
# 141/141 [==============================] - 9s 62ms/step - loss: 0.0630 - accuracy: 0.9776 - auc: 0.9970 - val_loss: 0.1052 - val_accuracy: 0.9640 - val_auc: 0.9938
# Epoch 1/7
# 141/141 [==============================] - 11s 64ms/step - loss: 0.3535 - accuracy: 0.8293 - auc: 0.9325 - val_loss: 0.2470 - val_accuracy: 0.8970 - val_auc: 0.9839
# Epoch 2/7
# 141/141 [==============================] - 9s 62ms/step - loss: 0.1516 - accuracy: 0.9442 - auc: 0.9850 - val_loss: 0.1391 - val_accuracy: 0.9500 - val_auc: 0.9893
# Epoch 3/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.1292 - accuracy: 0.9527 - auc: 0.9888 - val_loss: 0.1247 - val_accuracy: 0.9510 - val_auc: 0.9940
# Epoch 4/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.1093 - accuracy: 0.9587 - auc: 0.9922 - val_loss: 0.0988 - val_accuracy: 0.9590 - val_auc: 0.9936
# Epoch 5/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0920 - accuracy: 0.9676 - auc: 0.9938 - val_loss: 0.0943 - val_accuracy: 0.9670 - val_auc: 0.9963
# Epoch 6/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0773 - accuracy: 0.9723 - auc: 0.9959 - val_loss: 0.0669 - val_accuracy: 0.9760 - val_auc: 0.9978
# Epoch 7/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.0663 - accuracy: 0.9761 - auc: 0.9968 - val_loss: 0.0600 - val_accuracy: 0.9770 - val_auc: 0.9980

# %%
# Get accuracy scores for each fold (train and validation)
loss = []
acc = []
val_loss = []
val_acc = []

for history in histories:
    loss.append(np.mean(history["loss"]))
    acc.append(np.mean(history["accuracy"]))
    val_loss.append(np.mean(history["val_loss"]))
    val_acc.append(np.mean(history["val_accuracy"]))

# %%
# Plot loss and validation loss per fold
import matplotlib.pyplot as plt
plt.title('Losses')
plt.plot(range(1, len(loss)+1), loss, label='Loss')
plt.plot(range(1, len(val_loss)+1), val_loss, label='Validation loss')
plt.ylim(0.0, 1.0)
plt.xlabel('Fold')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Plot accuracies and validation accuracies per fold
import matplotlib.pyplot as plt
plt.title('Accuracies')
plt.plot(range(1, len(acc)+1), acc, label='Accuracy')
plt.plot(range(1, len(val_acc)+1), val_acc, label='Validation accuracy')
plt.ylim(0.0, 1.0)
plt.xlabel('Fold')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Train a final model with same parameters and save it
train_generator = datagen.flow(x=X_train, y=y_train, batch_size=batch_size)
valid_generator = datagen.flow(x=X_val, y=y_val, batch_size=batch_size)
model = create_model()
history = model.fit(train_generator, validation_data=valid_generator, epochs=epochs, verbose=1, callbacks=[early_stop])
model.save('cnn.h5')
# Out:
# Epoch 1/7
# 157/157 [==============================] - 10s 62ms/step - loss: 0.3186 - accuracy: 0.8500 - auc: 0.9470 - val_loss: 0.4263 - val_accuracy: 0.8125 - val_auc: 0.8906
# Epoch 2/7
# 157/157 [==============================] - 9s 57ms/step - loss: 0.1196 - accuracy: 0.9570 - auc: 0.9902 - val_loss: 0.4809 - val_accuracy: 0.6875 - val_auc: 0.8281
# Epoch 3/7
# 157/157 [==============================] - 9s 57ms/step - loss: 0.0950 - accuracy: 0.9640 - auc: 0.9936 - val_loss: 0.3968 - val_accuracy: 0.8125 - val_auc: 0.9375
# Epoch 4/7
# 157/157 [==============================] - 9s 58ms/step - loss: 0.0685 - accuracy: 0.9753 - auc: 0.9965 - val_loss: 0.2296 - val_accuracy: 0.9375 - val_auc: 0.9844
# Epoch 5/7
# 157/157 [==============================] - 9s 57ms/step - loss: 0.0630 - accuracy: 0.9769 - auc: 0.9969 - val_loss: 0.4955 - val_accuracy: 0.7500 - val_auc: 0.8672
# Epoch 6/7
# 157/157 [==============================] - 9s 57ms/step - loss: 0.0485 - accuracy: 0.9829 - auc: 0.9979 - val_loss: 0.5677 - val_accuracy: 0.7500 - val_auc: 0.9453
# Epoch 7/7
# 157/157 [==============================] - 9s 57ms/step - loss: 0.0451 - accuracy: 0.9835 - auc: 0.9986 - val_loss: 0.1663 - val_accuracy: 0.9375 - val_auc: 1.0000

# %%
# Plot val accuracy and val loss of the trained model
import matplotlib.pyplot as plt
plt.title('Accuracy vs Loss per Epoch')
plt.plot(range(1, len(history.history["val_accuracy"])+1), history.history["val_accuracy"], label='Accuracy')
plt.plot(range(1, len(history.history["val_loss"])+1), history.history["val_loss"], label='Loss')
plt.ylim(0.0, 1.0)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Make predictions on the test set
y_pred_test = model.predict(X_test)
y_pred_test = np.where(y_pred_test >= 0.5, 1, 0)
# Out:
# 20/20 [==============================] - 1s 8ms/step

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Compute ROC curve and AUC score for the predictions
fpr, tpr, thresholds = roc_curve(y_test, y_pred_test)
roc_auc = auc(fpr, tpr)

# Plot ROC curve and show AUC score on the plot
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()

# %%
from sklearn.metrics import confusion_matrix
# Compute the confusion matrix for test set
cm = confusion_matrix(y_test, y_pred_test.flatten())
print(cm)
# Out:
# [[170  64]
#  [ 25 365]]

# %%
# Plot the confusion matrix
class_names = subfolders
import seaborn as sns
sns.heatmap(cm, annot=True, fmt='g', cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()

# %%
# Compute the classification report for test set
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred_test, target_names=class_names))
# Out:
#               precision    recall  f1-score   support
#
#       NORMAL       0.87      0.73      0.79       234
#    PNEUMONIA       0.85      0.94      0.89       390
#
#     accuracy                           0.86       624
#    macro avg       0.86      0.83      0.84       624
# weighted avg       0.86      0.86      0.85       624

# %%
# Heatmaps and Grad-CAM
from common.cam import get_img_array
import cv2
import matplotlib.pyplot as plt 

images = [
    {
        "path": "./val/NORMAL/NORMAL2-IM-1442-0001.jpeg"
    },
    {
        "path": "./val/PNEUMONIA/person1946_bacteria_4874.jpeg"
    }
]

for image in images:
    image_temp = cv2.imread(image["path"])
    image_temp = cv2.cvtColor(image_temp, cv2.COLOR_RGB2GRAY)
    image_temp = cv2.resize(image_temp, (img_width, img_height))

    plt.imshow(image_temp, cmap=plt.cm.gray)
    plt.show()
    
    image["array"] = get_img_array(image["path"], size=(img_width, img_height))
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\keras\utils\image_utils.py:409: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn(

# %%
# Remove last layer's softmax
model.layers[-1].activation = None

# import os
# os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
# Print model summary to get last max pooling layer name
print(model.summary())
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_40 (Conv2D)          (None, 126, 126, 32)      320
#
#  max_pooling2d_40 (MaxPoolin  (None, 63, 63, 32)       0
#  g2D)
#
#  conv2d_41 (Conv2D)          (None, 61, 61, 64)        18496
#
#  max_pooling2d_41 (MaxPoolin  (None, 30, 30, 64)       0
#  g2D)
#
#  conv2d_42 (Conv2D)          (None, 28, 28, 128)       73856
#
#  max_pooling2d_42 (MaxPoolin  (None, 14, 14, 128)      0
#  g2D)
#
#  conv2d_43 (Conv2D)          (None, 12, 12, 256)       295168
#
#  max_pooling2d_43 (MaxPoolin  (None, 6, 6, 256)        0
#  g2D)
#
#  flatten_10 (Flatten)        (None, 9216)              0
#
#  dense_30 (Dense)            (None, 256)               2359552
#
#  dropout_20 (Dropout)        (None, 256)               0
#
#  dense_31 (Dense)            (None, 128)               32896
#
#  dropout_21 (Dropout)        (None, 128)               0
#
#  dense_32 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 2,780,417
# Trainable params: 2,780,417
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Select last conv layer
last_conv_layer_name = "max_pooling2d_43"

# %%
from common.cam import make_gradcam_heatmap, display_heatmaps

for image in images:
    heatmaps = []
    for layer in model.layers[:model.layers.index(model.get_layer(last_conv_layer_name)) + 1]:
        heatmap = make_gradcam_heatmap(image["array"], model, layer.name)
        heatmaps.append({
            "layer_name": layer.name,
            "image": heatmap
        })

    # Display heatmaps from all layers until the last max pooling layer
    display_heatmaps(image["path"], heatmaps)

    # Display the chosen image superimposed with heatmaps of each layer until the last max pooling layer
    display_heatmaps(image["path"], heatmaps, True)

# %%
# Predict
for image in images:
    pred = model.predict(image["array"].reshape(1, img_width, img_height, 1))
    print(pred)
    # Display predicted class
    print("Predicted class: {}".format(subfolders[int(pred[0][0])]))
# Out:
# 1/1 [==============================] - 0s 340ms/step
# [[0.]]
# Predicted class: NORMAL
# 1/1 [==============================] - 0s 16ms/step
# [[1.]]
# Predicted class: PNEUMONIA
