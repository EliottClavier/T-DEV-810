# %% [markdown]
# # Augmentation d'image - Crop - 2/2
# ## Objectif
# L'objectif de ce notebook est de tester l'ajout de crop aux images lors du formatage sur le jeu de données de l'étude avec les autres parametres.
#
# ## Hypothèses
#
# - Le crop va permettre de supprimer des infos non pertinentes en péripherie et d'ameliorer les performances
#
# ## Etapes de la démarche
# 1. Modifier la fonction de formatage des images pour y ajouter du crop
# 2. Tester le jeu de données avec l'algo CNN
# 3. Calculer les métriques de performance
# 4. Comparer les résultats avec les résultats du template aug_control_v1
#
# ## Interprétation des résultats et Conclusion
# Les résultats obtenus sont les suivants :
#
# - La cross validation ne montre pas d’inconsistence
# - l'AUC a diminué, passant de 90 à 83 points. La matrice de confusion montre une augmentation générale des erreurs, en particulier des faux négatifs. De plus, la heatmap révèle un modèle moins sensible aux zones pertinentes de l'image.

# %%
# Check that GPU is used
import tensorflow as tf

tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Chargez les variables d'environnement

TRAIN_FOLDER = 'train'
TEST_FOLDER = 'test'
VAL_FOLDER = 'val'

TRAIN_AUGMENTED_FOLDER = 'train_augmented'
ITERATION = 'v1.0'
# Define the subfolders within each folder where the images are stored
subfolders = ['NORMAL', 'PNEUMONIA']

# Define the size of the images you want to resize your images to
img_width, img_height = 128, 128  # Function to load and resize images from a folder

# %%
# Fonction de chargement des images des dataset et des labels associés
def load_images_from_folder(folder, limit_per_subfolder=None):
    X = []
    y = []
    for subfolder in subfolders:
        folder_path = os.path.join(folder, subfolder)
        if limit_per_subfolder:
            # Get amount of random filenames from the folder
            filenames = np.random.choice(os.listdir(folder_path), limit_per_subfolder, replace=False)
        else:
            filenames = os.listdir(folder_path)
        for filename in filenames:
            img_path = os.path.join(folder_path, filename)
            img = Image.open(img_path)

            # Resize the image to the desired size
            img = img.resize((img_width, img_height))

            # Convert RGB image to grayscale
            img = img.convert('L')

            # Convert the image to a NumPy array and append it to X
            img = np.array(img)
            X.append(img)

            # Append the corresponding label to y
            y.append(subfolders.index(subfolder))

    X = np.array(X)
    y = np.array(y)
    return X, y

# %%
import os
import numpy as np
from PIL import Image, ImageOps
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator

def make_square(folder, target_folder, target_size=(224, 224)):
    for filename in os.listdir(folder):
        image_path = os.path.join(folder, filename)
        image = Image.open(image_path)

        # Obtenez les dimensions de l'image
        width, height = image.size  # Utilisez la méthode size de PIL Image

        # Calculez le côté le plus petit
        size = min(height, width)

        # Créez une image carrée en rognant les parties centrales
        left = (width - size) / 2
        top = (height - size) / 2
        right = (width + size) / 2
        bottom = (height + size) / 2

        image = image.crop((left, top, right, bottom))

        # Redimensionnez l'image pour la taille cible
        image = image.resize(target_size, Image.LANCZOS)

        # Sauvegardez l'image
        image.save(os.path.join(target_folder, filename))


def generate_cropped_image(folder, to_augment_class):
    padded_folder = f"{folder}_cropped_{ITERATION}"

    padded_dir = os.path.join(f"{folder}_cropped_{ITERATION}", to_augment_class)

    if not os.path.exists(padded_folder):
        os.mkdir(padded_folder)

    if not os.path.exists(padded_dir):
        os.mkdir(padded_dir)

    make_square(os.path.join(folder, to_augment_class), padded_dir)

    return padded_folder


def generate_augmented_images(folder, to_augment_class, image_size=(128, 128), target_nbr=5000):
    dir = os.path.join(folder, to_augment_class)
    count = len(os.listdir(dir))

    augmented_dir = os.path.join(f"{folder}_augmented", to_augment_class)

    if not os.path.exists(f"{folder}_augmented"):
        os.mkdir(f"{folder}_augmented")

    if not os.path.exists(augmented_dir):
        os.mkdir(augmented_dir)

    augmented_count = len(os.listdir(augmented_dir))

    datagen = ImageDataGenerator(
        rotation_range=20,
        width_shift_range=0.1,
        height_shift_range=0.1,
        shear_range=0,
        zoom_range=0.2,
        horizontal_flip=True,
        fill_mode='nearest',
    )

    generator = datagen.flow_from_directory(

        folder,
        batch_size=1,
        save_to_dir=augmented_dir,
        save_format='jpeg',
        save_prefix='IM_AUGMENTED',
        classes=[to_augment_class],
        # keep_aspect_ratio=True,
        # target_size=image_size,
    )

    additional_count = target_nbr - len(os.listdir(augmented_dir))

    for i in range(additional_count):
        generator.next()

    new_count = len(os.listdir(augmented_dir))

    print(f'Given {to_augment_class} count: {count}')
    print(f'Augmented {to_augment_class} count: {new_count}')

# %%
# Generate augmented for the training set
path_train_n = generate_cropped_image(TRAIN_FOLDER, 'NORMAL')
path_train_p = generate_cropped_image(TRAIN_FOLDER, 'PNEUMONIA')

generate_augmented_images(path_train_n, 'NORMAL', image_size=(img_width, img_height))
generate_augmented_images(path_train_p, 'PNEUMONIA', image_size=(img_width, img_height))
# Out:
# Found 1341 images belonging to 1 classes.
# Given NORMAL count: 1341
# Augmented NORMAL count: 5000
# Found 3875 images belonging to 1 classes.
# Given PNEUMONIA count: 3875
# Augmented PNEUMONIA count: 5000

# %%
# Load the training data
# Get min value between the number of normal images and the number of pneumonia images
TRAIN_FOLDER = f"train_cropped_{ITERATION}_augmented"

TEST_FOLDER = f"{TEST_FOLDER}"
VAL_FOLDER = f"{VAL_FOLDER}"

min_images = min(len(os.listdir(os.path.join(TRAIN_FOLDER, subfolders[0]))),
                 len(os.listdir(os.path.join(TRAIN_FOLDER, subfolders[1]))))
X_train, y_train = load_images_from_folder(TRAIN_FOLDER, min_images)

# Load the test data
X_test, y_test = load_images_from_folder(TEST_FOLDER)

# Load the validation data
X_val, y_val = load_images_from_folder(VAL_FOLDER)

# %%
# Make a matplot figure to show how many images are in each subfolder of train
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.bar(subfolders, [len(os.listdir(os.path.join(TRAIN_FOLDER, subfolder))) for subfolder in subfolders])
plt.title('Number of images in each subfolder of train')
plt.show()

# %%
# Make a matplot figure to show how many images if each class in the training set
plt.figure(figsize=(10, 5))
plt.bar(subfolders, [len(y_train[y_train == i]) for i in range(len(subfolders))])
plt.title('Number of images in each class in the training set')
plt.show()

# %%
# Normalize the pixel values to be between 0 and 1
num_samples = X_train.shape[0]
print(X_test.shape)
X_train = X_train.reshape(len(X_train), img_width, img_height, 1)
X_test = X_test.reshape(len(X_test), img_width, img_height, 1)
X_val = X_val.reshape(len(X_val), img_width, img_height, 1)

# X_train = X_train.astype('float32') / 255
# X_test = X_test.astype('float32') / 255
# X_val = X_val.astype('float32') / 255

print('done \n')
# Out:
# (624, 128, 128)
# done

# %%
single_image = X_train[np.random.randint(len(X_train))]
print(single_image.shape)
plt.imshow(single_image, cmap='Greys')
# Out:
# (128, 128, 1)

# %%
# Define model metrics
from keras.metrics import AUC

metrics = [
    "accuracy",
    AUC(name='auc')
]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout


# Define the model architecture
def create_model():
    model = Sequential()

    model.add(Conv2D(filters=32, kernel_size=(3, 3), input_shape=(img_width, img_height, 1), activation="relu"))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(filters=64, kernel_size=(3, 3), activation="relu"))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(filters=128, kernel_size=(3, 3), activation="relu"))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(filters=256, kernel_size=(3, 3), activation="relu"))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Flatten())

    model.add(Dense(256, activation="relu"))
    model.add(Dropout(0.5))

    model.add(Dense(128, activation="relu"))
    model.add(Dropout(0.5))

    model.add(Dense(1, activation="sigmoid"))

    # compile the model
    model.compile(loss="binary_crossentropy", optimizer="adam", metrics=metrics)

    return model

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(monitor='loss', patience=3, restore_best_weights=True)

# %%
# Cross validation
from sklearn.model_selection import KFold
from keras.preprocessing.image import ImageDataGenerator
from h5py import File
# Define the number of folds for cross-validation
n_splits = 10
epochs = 7
batch_size =64

# Initialize KFold with the number of folds
kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)

# Define lists to store the evaluation scores for each fold
accuracy_scores = []
og_val_accuracy_scores = []
histories = []
models = []
fold_no = 1
best_score = float('inf')  # pour une tâche de minimisation
best_model = None
# Iterate through each fold and train/evaluate the model
for train_idx, val_idx in kf.split(X_train, y_train):
    # Split the data into training and validation sets for this fold
    X_train_fold, y_train_fold = X_train[train_idx], y_train[train_idx]
    X_val_fold, y_val_fold = X_train[val_idx], y_train[val_idx]

    # Create an instance of ImageDataGenerator to generate your image data
    datagen = ImageDataGenerator()

    # Create generators for training and validation data
    train_generator = datagen.flow(x=X_train_fold, y=y_train_fold, batch_size=batch_size)
    valid_generator = datagen.flow(x=X_val_fold, y=y_val_fold, batch_size=batch_size)

    # Create instance of the model for this fold and train it
    model = create_model()

    # Train your model on the training data for this fold
    history = model.fit(train_generator, validation_data=valid_generator, epochs=epochs, verbose=1,
                        callbacks=[early_stop])
    # Model Évaluation with original val dataset
    scores = model.evaluate(X_val, y_val, verbose=1)
    og_val_accuracy_scores.append(scores[1])
    print(f'\nScore for fold with orginal val dataset {fold_no}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%\n')

    histories.append(history.history)

    models.append(model)

    # After training, evaluate the model on the validation set for this fold
    accuracy = model.evaluate(X_val_fold, y_val_fold)[1]

    # Store the accuracy score in the list
    accuracy_scores.append(accuracy)

    # Print the accuracy for this fold
    print(f"Accuracy for fold {len(accuracy_scores)}: {accuracy * 100}%")

    # Check if the model is better than the previous
    if scores[0] < best_score:
        best_score = scores[0]
        best_model = model

    fold_no = fold_no + 1

    # Sauvegarde du meilleur modèle
    if best_model is not None:
        best_model.save(f'cnn_best_{ITERATION}.h5')

# Calculate and print the average accuracy over all folds
average_accuracy = sum(accuracy_scores) / len(accuracy_scores)
og_val_average_accuracy = sum(og_val_accuracy_scores) / len(og_val_accuracy_scores)
print(f"\nAverage accuracy: {average_accuracy * 100}%")
print(f"\nAverage accuracy with orginal val: {og_val_average_accuracy * 100}%")
# Out:
# Epoch 1/7
# 141/141 [==============================] - 8s 37ms/step - loss: 0.5437 - accuracy: 0.8291 - auc: 0.9068 - val_loss: 0.1436 - val_accuracy: 0.9410 - val_auc: 0.9890
# Epoch 2/7
# 141/141 [==============================] - 5s 33ms/step - loss: 0.1510 - accuracy: 0.9452 - auc: 0.9853 - val_loss: 0.1033 - val_accuracy: 0.9530 - val_auc: 0.9929
# Epoch 3/7
# 141/141 [==============================] - 5s 33ms/step - loss: 0.1256 - accuracy: 0.9567 - auc: 0.9897 - val_loss: 0.1792 - val_accuracy: 0.9290 - val_auc: 0.9932
# Epoch 4/7
# 141/141 [==============================] - 5s 33ms/step - loss: 0.1162 - accuracy: 0.9570 - auc: 0.9907 - val_loss: 0.0999 - val_accuracy: 0.9600 - val_auc: 0.9939
# Epoch 5/7
# 141/141 [==============================] - 5s 33ms/step - loss: 0.1022 - accuracy: 0.9647 - auc: 0.9926 - val_loss: 0.0737 - val_accuracy: 0.9730 - val_auc: 0.9974
# Epoch 6/7
# 141/141 [==============================] - 5s 33ms/step - loss: 0.1062 - accuracy: 0.9621 - auc: 0.9923 - val_loss: 0.1146 - val_accuracy: 0.9630 - val_auc: 0.9919
# Epoch 7/7
# 141/141 [==============================] - 5s 33ms/step - loss: 0.0866 - accuracy: 0.9697 - auc: 0.9944 - val_loss: 0.0719 - val_accuracy: 0.9810 - val_auc: 0.9975
# 1/1 [==============================] - 0s 341ms/step - loss: 0.5439 - accuracy: 0.8750 - auc: 0.8984
#
# Score for fold with orginal val dataset 1: loss of 0.5438950061798096; accuracy of 87.5%
#
# 32/32 [==============================] - 0s 8ms/step - loss: 0.0719 - accuracy: 0.9810 - auc: 0.9975
# Accuracy for fold 1: 98.1000006198883%
# Epoch 1/7
# 141/141 [==============================] - 6s 34ms/step - loss: 0.6678 - accuracy: 0.8211 - auc: 0.9114 - val_loss: 0.2022 - val_accuracy: 0.9090 - val_auc: 0.9865
# Epoch 2/7
# 141/141 [==============================] - 5s 33ms/step - loss: 0.1861 - accuracy: 0.9334 - auc: 0.9780 - val_loss: 0.1160 - val_accuracy: 0.9620 - val_auc: 0.9926
# Epoch 3/7
# 141/141 [==============================] - 5s 33ms/step - loss: 0.1502 - accuracy: 0.9474 - auc: 0.9853 - val_loss: 0.1588 - val_accuracy: 0.9370 - val_auc: 0.9916
# Epoch 4/7
# 141/141 [==============================] - 5s 32ms/step - loss: 0.1259 - accuracy: 0.9560 - auc: 0.9893 - val_loss: 0.0959 - val_accuracy: 0.9640 - val_auc: 0.9943
# Epoch 5/7
# 141/141 [==============================] - 5s 32ms/step - loss: 0.1286 - accuracy: 0.9538 - auc: 0.9890 - val_loss: 0.0874 - val_accuracy: 0.9730 - val_auc: 0.9939
# Epoch 6/7
# 141/141 [==============================] - 5s 33ms/step - loss: 0.1039 - accuracy: 0.9606 - auc: 0.9929 - val_loss: 0.0744 - val_accuracy: 0.9750 - val_auc: 0.9969
# Epoch 7/7
# 141/141 [==============================] - 5s 32ms/step - loss: 0.0884 - accuracy: 0.9694 - auc: 0.9943 - val_loss: 0.0709 - val_accuracy: 0.9710 - val_auc: 0.9968
# 1/1 [==============================] - 0s 258ms/step - loss: 0.9384 - accuracy: 0.6875 - auc: 0.7969
#
# Score for fold with orginal val dataset 2: loss of 0.9383912682533264; accuracy of 68.75%
#
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0709 - accuracy: 0.9710 - auc: 0.9968
# Accuracy for fold 2: 97.10000157356262%
# Epoch 1/7
# 141/141 [==============================] - 6s 35ms/step - loss: 0.6010 - accuracy: 0.8270 - auc: 0.9158 - val_loss: 0.1472 - val_accuracy: 0.9430 - val_auc: 0.9885
# Epoch 2/7
# 141/141 [==============================] - 5s 33ms/step - loss: 0.1613 - accuracy: 0.9398 - auc: 0.9831 - val_loss: 0.1137 - val_accuracy: 0.9530 - val_auc: 0.9932
# Epoch 3/7
# 141/141 [==============================] - 5s 33ms/step - loss: 0.1433 - accuracy: 0.9507 - auc: 0.9870 - val_loss: 0.1020 - val_accuracy: 0.9570 - val_auc: 0.9942
# Epoch 4/7
# 141/141 [==============================] - 5s 33ms/step - loss: 0.1290 - accuracy: 0.9568 - auc: 0.9887 - val_loss: 0.1153 - val_accuracy: 0.9490 - val_auc: 0.9936
# Epoch 5/7
# 141/141 [==============================] - 5s 32ms/step - loss: 0.1085 - accuracy: 0.9603 - auc: 0.9918 - val_loss: 0.1021 - val_accuracy: 0.9630 - val_auc: 0.9931
# Epoch 6/7
# 141/141 [==============================] - 5s 32ms/step - loss: 0.0937 - accuracy: 0.9664 - auc: 0.9933 - val_loss: 0.0809 - val_accuracy: 0.9600 - val_auc: 0.9956
# Epoch 7/7
# 141/141 [==============================] - 4s 32ms/step - loss: 0.0825 - accuracy: 0.9697 - auc: 0.9955 - val_loss: 0.0976 - val_accuracy: 0.9600 - val_auc: 0.9941
# 1/1 [==============================] - 0s 272ms/step - loss: 1.4109 - accuracy: 0.6250 - auc: 0.8750
#
# Score for fold with orginal val dataset 3: loss of 1.4108829498291016; accuracy of 62.5%
#
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0976 - accuracy: 0.9600 - auc: 0.9941
# Accuracy for fold 3: 95.99999785423279%
# Epoch 1/7
# 141/141 [==============================] - 6s 36ms/step - loss: 0.7509 - accuracy: 0.8308 - auc: 0.9153 - val_loss: 0.1932 - val_accuracy: 0.9250 - val_auc: 0.9870
# Epoch 2/7
# 141/141 [==============================] - 5s 33ms/step - loss: 0.1777 - accuracy: 0.9359 - auc: 0.9801 - val_loss: 0.1189 - val_accuracy: 0.9520 - val_auc: 0.9915
# Epoch 3/7
# 141/141 [==============================] - 5s 32ms/step - loss: 0.1379 - accuracy: 0.9490 - auc: 0.9876 - val_loss: 0.1446 - val_accuracy: 0.9490 - val_auc: 0.9936
# Epoch 4/7
# 141/141 [==============================] - 5s 33ms/step - loss: 0.1123 - accuracy: 0.9581 - auc: 0.9915 - val_loss: 0.1017 - val_accuracy: 0.9590 - val_auc: 0.9943
# Epoch 5/7
# 141/141 [==============================] - 5s 33ms/step - loss: 0.1161 - accuracy: 0.9602 - auc: 0.9908 - val_loss: 0.0906 - val_accuracy: 0.9670 - val_auc: 0.9951
# Epoch 6/7
# 141/141 [==============================] - 5s 32ms/step - loss: 0.0906 - accuracy: 0.9670 - auc: 0.9942 - val_loss: 0.0839 - val_accuracy: 0.9770 - val_auc: 0.9960
# Epoch 7/7
# 141/141 [==============================] - 5s 32ms/step - loss: 0.0939 - accuracy: 0.9663 - auc: 0.9938 - val_loss: 0.0941 - val_accuracy: 0.9670 - val_auc: 0.9923
# 1/1 [==============================] - 0s 265ms/step - loss: 0.2129 - accuracy: 0.9375 - auc: 0.9688
#
# Score for fold with orginal val dataset 4: loss of 0.2128886878490448; accuracy of 93.75%
#
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0941 - accuracy: 0.9670 - auc: 0.9923
# Accuracy for fold 4: 96.70000076293945%
# Epoch 1/7
# 141/141 [==============================] - 6s 35ms/step - loss: 0.5859 - accuracy: 0.8141 - auc: 0.9085 - val_loss: 0.1237 - val_accuracy: 0.9490 - val_auc: 0.9903
# Epoch 2/7
# 141/141 [==============================] - 5s 32ms/step - loss: 0.1613 - accuracy: 0.9424 - auc: 0.9832 - val_loss: 0.1261 - val_accuracy: 0.9530 - val_auc: 0.9930
# Epoch 3/7
# 141/141 [==============================] - 5s 32ms/step - loss: 0.1416 - accuracy: 0.9498 - auc: 0.9868 - val_loss: 0.1217 - val_accuracy: 0.9530 - val_auc: 0.9939
# Epoch 4/7
# 141/141 [==============================] - 5s 33ms/step - loss: 0.1165 - accuracy: 0.9573 - auc: 0.9908 - val_loss: 0.2044 - val_accuracy: 0.9300 - val_auc: 0.9898
# Epoch 5/7
# 141/141 [==============================] - 5s 32ms/step - loss: 0.1122 - accuracy: 0.9627 - auc: 0.9911 - val_loss: 0.0933 - val_accuracy: 0.9670 - val_auc: 0.9949
# Epoch 6/7
# 141/141 [==============================] - 5s 32ms/step - loss: 0.0963 - accuracy: 0.9657 - auc: 0.9935 - val_loss: 0.0804 - val_accuracy: 0.9670 - val_auc: 0.9966
# Epoch 7/7
# 141/141 [==============================] - 5s 33ms/step - loss: 0.1064 - accuracy: 0.9611 - auc: 0.9923 - val_loss: 0.1631 - val_accuracy: 0.9420 - val_auc: 0.9913
# 1/1 [==============================] - 0s 301ms/step - loss: 0.9053 - accuracy: 0.6875 - auc: 0.8359
#
# Score for fold with orginal val dataset 5: loss of 0.9052895903587341; accuracy of 68.75%
#
# 32/32 [==============================] - 0s 7ms/step - loss: 0.1631 - accuracy: 0.9420 - auc: 0.9913
# Accuracy for fold 5: 94.19999718666077%
# Epoch 1/7
# 141/141 [==============================] - 6s 35ms/step - loss: 0.6708 - accuracy: 0.8221 - auc: 0.9033 - val_loss: 0.1377 - val_accuracy: 0.9530 - val_auc: 0.9882
# Epoch 2/7
# 141/141 [==============================] - 5s 33ms/step - loss: 0.1951 - accuracy: 0.9266 - auc: 0.9763 - val_loss: 0.1155 - val_accuracy: 0.9690 - val_auc: 0.9948
# Epoch 3/7
# 141/141 [==============================] - 5s 33ms/step - loss: 0.1534 - accuracy: 0.9437 - auc: 0.9847 - val_loss: 0.1020 - val_accuracy: 0.9600 - val_auc: 0.9946
# Epoch 4/7
# 141/141 [==============================] - 5s 33ms/step - loss: 0.1247 - accuracy: 0.9579 - auc: 0.9895 - val_loss: 0.0750 - val_accuracy: 0.9670 - val_auc: 0.9966
# Epoch 5/7
# 141/141 [==============================] - 5s 32ms/step - loss: 0.1177 - accuracy: 0.9562 - auc: 0.9905 - val_loss: 0.0650 - val_accuracy: 0.9760 - val_auc: 0.9982
# Epoch 6/7
# 141/141 [==============================] - 5s 33ms/step - loss: 0.0955 - accuracy: 0.9646 - auc: 0.9936 - val_loss: 0.0666 - val_accuracy: 0.9770 - val_auc: 0.9974
# Epoch 7/7
# 141/141 [==============================] - 5s 33ms/step - loss: 0.0983 - accuracy: 0.9664 - auc: 0.9930 - val_loss: 0.0605 - val_accuracy: 0.9760 - val_auc: 0.9981
# 1/1 [==============================] - 0s 325ms/step - loss: 0.8787 - accuracy: 0.6875 - auc: 0.9219
#
# Score for fold with orginal val dataset 6: loss of 0.8787270784378052; accuracy of 68.75%
#
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0605 - accuracy: 0.9760 - auc: 0.9981
# Accuracy for fold 6: 97.60000109672546%
# Epoch 1/7
# 141/141 [==============================] - 6s 35ms/step - loss: 0.8803 - accuracy: 0.8097 - auc: 0.9041 - val_loss: 0.2017 - val_accuracy: 0.9320 - val_auc: 0.9843
# Epoch 2/7
# 141/141 [==============================] - 5s 33ms/step - loss: 0.2030 - accuracy: 0.9252 - auc: 0.9743 - val_loss: 0.1780 - val_accuracy: 0.9440 - val_auc: 0.9854
# Epoch 3/7
# 141/141 [==============================] - 5s 33ms/step - loss: 0.1390 - accuracy: 0.9507 - auc: 0.9873 - val_loss: 0.1792 - val_accuracy: 0.9490 - val_auc: 0.9854
# Epoch 4/7
# 141/141 [==============================] - 5s 32ms/step - loss: 0.1325 - accuracy: 0.9509 - auc: 0.9884 - val_loss: 0.1414 - val_accuracy: 0.9540 - val_auc: 0.9859
# Epoch 5/7
# 141/141 [==============================] - 5s 32ms/step - loss: 0.1082 - accuracy: 0.9632 - auc: 0.9918 - val_loss: 0.1198 - val_accuracy: 0.9650 - val_auc: 0.9878
# Epoch 6/7
# 141/141 [==============================] - 5s 33ms/step - loss: 0.0956 - accuracy: 0.9652 - auc: 0.9938 - val_loss: 0.1033 - val_accuracy: 0.9710 - val_auc: 0.9918
# Epoch 7/7
# 141/141 [==============================] - 5s 32ms/step - loss: 0.0891 - accuracy: 0.9678 - auc: 0.9946 - val_loss: 0.1571 - val_accuracy: 0.9600 - val_auc: 0.9870
# 1/1 [==============================] - 0s 333ms/step - loss: 0.7170 - accuracy: 0.8125 - auc: 0.8516
#
# Score for fold with orginal val dataset 7: loss of 0.7169817686080933; accuracy of 81.25%
#
# 32/32 [==============================] - 0s 6ms/step - loss: 0.1571 - accuracy: 0.9600 - auc: 0.9870
# Accuracy for fold 7: 95.99999785423279%
# Epoch 1/7
# 141/141 [==============================] - 6s 35ms/step - loss: 0.7971 - accuracy: 0.8281 - auc: 0.9087 - val_loss: 0.1549 - val_accuracy: 0.9390 - val_auc: 0.9862
# Epoch 2/7
# 141/141 [==============================] - 5s 33ms/step - loss: 0.1967 - accuracy: 0.9266 - auc: 0.9761 - val_loss: 0.1151 - val_accuracy: 0.9570 - val_auc: 0.9932
# Epoch 3/7
# 141/141 [==============================] - 5s 33ms/step - loss: 0.1468 - accuracy: 0.9489 - auc: 0.9860 - val_loss: 0.1351 - val_accuracy: 0.9470 - val_auc: 0.9937
# Epoch 4/7
# 141/141 [==============================] - 5s 32ms/step - loss: 0.1264 - accuracy: 0.9546 - auc: 0.9892 - val_loss: 0.0886 - val_accuracy: 0.9650 - val_auc: 0.9968
# Epoch 5/7
# 141/141 [==============================] - 5s 33ms/step - loss: 0.1255 - accuracy: 0.9528 - auc: 0.9897 - val_loss: 0.1726 - val_accuracy: 0.9330 - val_auc: 0.9941
# Epoch 6/7
# 141/141 [==============================] - 5s 33ms/step - loss: 0.1058 - accuracy: 0.9623 - auc: 0.9922 - val_loss: 0.0795 - val_accuracy: 0.9700 - val_auc: 0.9964
# Epoch 7/7
# 141/141 [==============================] - 5s 33ms/step - loss: 0.0849 - accuracy: 0.9712 - auc: 0.9945 - val_loss: 0.0720 - val_accuracy: 0.9760 - val_auc: 0.9973
# 1/1 [==============================] - 0s 324ms/step - loss: 0.3504 - accuracy: 0.8125 - auc: 0.9375
#
# Score for fold with orginal val dataset 8: loss of 0.3503873348236084; accuracy of 81.25%
#
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0720 - accuracy: 0.9760 - auc: 0.9973
# Accuracy for fold 8: 97.60000109672546%
# Epoch 1/7
# 141/141 [==============================] - 6s 35ms/step - loss: 0.6997 - accuracy: 0.8354 - auc: 0.9209 - val_loss: 0.1319 - val_accuracy: 0.9560 - val_auc: 0.9902
# Epoch 2/7
# 141/141 [==============================] - 5s 33ms/step - loss: 0.1609 - accuracy: 0.9398 - auc: 0.9834 - val_loss: 0.1111 - val_accuracy: 0.9610 - val_auc: 0.9936
# Epoch 3/7
# 141/141 [==============================] - 5s 33ms/step - loss: 0.1410 - accuracy: 0.9498 - auc: 0.9867 - val_loss: 0.1422 - val_accuracy: 0.9490 - val_auc: 0.9896
# Epoch 4/7
# 141/141 [==============================] - 5s 33ms/step - loss: 0.1423 - accuracy: 0.9460 - auc: 0.9867 - val_loss: 0.1230 - val_accuracy: 0.9500 - val_auc: 0.9939
# Epoch 5/7
# 141/141 [==============================] - 5s 33ms/step - loss: 0.1015 - accuracy: 0.9628 - auc: 0.9926 - val_loss: 0.0893 - val_accuracy: 0.9670 - val_auc: 0.9949
# Epoch 6/7
# 141/141 [==============================] - 5s 32ms/step - loss: 0.1169 - accuracy: 0.9579 - auc: 0.9909 - val_loss: 0.1089 - val_accuracy: 0.9620 - val_auc: 0.9922
# Epoch 7/7
# 141/141 [==============================] - 5s 32ms/step - loss: 0.1037 - accuracy: 0.9632 - auc: 0.9926 - val_loss: 0.0858 - val_accuracy: 0.9690 - val_auc: 0.9942
# 1/1 [==============================] - 0s 269ms/step - loss: 0.9145 - accuracy: 0.7500 - auc: 0.9297
#
# Score for fold with orginal val dataset 9: loss of 0.9145274758338928; accuracy of 75.0%
#
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0858 - accuracy: 0.9690 - auc: 0.9942
# Accuracy for fold 9: 96.8999981880188%
# Epoch 1/7
# 141/141 [==============================] - 6s 35ms/step - loss: 0.6384 - accuracy: 0.8177 - auc: 0.9099 - val_loss: 0.1500 - val_accuracy: 0.9390 - val_auc: 0.9890
# Epoch 2/7
# 141/141 [==============================] - 5s 33ms/step - loss: 0.1689 - accuracy: 0.9390 - auc: 0.9814 - val_loss: 0.1189 - val_accuracy: 0.9560 - val_auc: 0.9926
# Epoch 3/7
# 141/141 [==============================] - 5s 33ms/step - loss: 0.1549 - accuracy: 0.9429 - auc: 0.9846 - val_loss: 0.0947 - val_accuracy: 0.9650 - val_auc: 0.9946
# Epoch 4/7
# 141/141 [==============================] - 5s 33ms/step - loss: 0.1169 - accuracy: 0.9599 - auc: 0.9908 - val_loss: 0.0862 - val_accuracy: 0.9670 - val_auc: 0.9962
# Epoch 5/7
# 141/141 [==============================] - 5s 33ms/step - loss: 0.1057 - accuracy: 0.9614 - auc: 0.9922 - val_loss: 0.0984 - val_accuracy: 0.9630 - val_auc: 0.9935
# Epoch 6/7
# 141/141 [==============================] - 5s 32ms/step - loss: 0.1097 - accuracy: 0.9599 - auc: 0.9918 - val_loss: 0.1023 - val_accuracy: 0.9600 - val_auc: 0.9948
# Epoch 7/7
# 141/141 [==============================] - 5s 33ms/step - loss: 0.0953 - accuracy: 0.9674 - auc: 0.9936 - val_loss: 0.0679 - val_accuracy: 0.9740 - val_auc: 0.9975
# 1/1 [==============================] - 0s 269ms/step - loss: 0.2687 - accuracy: 0.8750 - auc: 0.9375
#
# Score for fold with orginal val dataset 10: loss of 0.268736869096756; accuracy of 87.5%
#
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0679 - accuracy: 0.9740 - auc: 0.9975
# Accuracy for fold 10: 97.39999771118164%
#
# Average accuracy: 96.75999939441681%
#
# Average accuracy with orginal val: 77.5%

# %%
# Get accuracy scores for each fold (train and validation)
loss = []
acc = []
val_loss = []
val_acc = []

for history in histories:
    loss.append(np.mean(history["loss"]))
    acc.append(np.mean(history["accuracy"]))
    val_loss.append(np.mean(history["val_loss"]))
    val_acc.append(np.mean(history["val_accuracy"]))

# %%
# Plot loss and validation loss per fold
import matplotlib.pyplot as plt
plt.title('Losses')
plt.plot(range(1, len(loss)+1), loss, label='Loss')
plt.plot(range(1, len(val_loss)+1), val_loss, label='Validation loss')
plt.ylim(0.0, 1.0)
plt.xlabel('Fold')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Plot accuracies and validation accuracies per fold
import matplotlib.pyplot as plt

plt.title('Accuracies')
plt.plot(range(1, len(acc) + 1), acc, label='Accuracy')
plt.plot(range(1, len(val_acc) + 1), val_acc, label='Validation accuracy')
plt.ylim(0.0, 1.0)
plt.xlabel('Fold')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Train a final model with same parameters and save it
# Create an instance of ImageDataGenerator to generate your image data
datagen = ImageDataGenerator()
train_generator = datagen.flow(x=X_train, y=y_train, batch_size=batch_size)
valid_generator = datagen.flow(x=X_val, y=y_val, batch_size=batch_size)
model = create_model()
history = model.fit(train_generator, validation_data=valid_generator, epochs=epochs, verbose=1, callbacks=[early_stop])
model.save(f'cnn_{ITERATION}.h5')
# Out:
# Epoch 1/7
# 157/157 [==============================] - 7s 34ms/step - loss: 0.7441 - accuracy: 0.8343 - auc: 0.9030 - val_loss: 0.8120 - val_accuracy: 0.7500 - val_auc: 0.7578
# Epoch 2/7
# 157/157 [==============================] - 5s 31ms/step - loss: 0.1639 - accuracy: 0.9427 - auc: 0.9831 - val_loss: 0.6474 - val_accuracy: 0.8125 - val_auc: 0.8594
# Epoch 3/7
# 157/157 [==============================] - 5s 32ms/step - loss: 0.1329 - accuracy: 0.9519 - auc: 0.9881 - val_loss: 0.3875 - val_accuracy: 0.7500 - val_auc: 0.9062
# Epoch 4/7
# 157/157 [==============================] - 5s 32ms/step - loss: 0.1201 - accuracy: 0.9577 - auc: 0.9903 - val_loss: 0.8368 - val_accuracy: 0.7500 - val_auc: 0.8125
# Epoch 5/7
# 157/157 [==============================] - 5s 31ms/step - loss: 0.1118 - accuracy: 0.9614 - auc: 0.9914 - val_loss: 1.0538 - val_accuracy: 0.6875 - val_auc: 0.8203
# Epoch 6/7
# 157/157 [==============================] - 5s 31ms/step - loss: 0.1128 - accuracy: 0.9596 - auc: 0.9912 - val_loss: 0.3631 - val_accuracy: 0.8125 - val_auc: 0.9062
# Epoch 7/7
# 157/157 [==============================] - 5s 32ms/step - loss: 0.0960 - accuracy: 0.9662 - auc: 0.9934 - val_loss: 0.7047 - val_accuracy: 0.7500 - val_auc: 0.8984

# %%
# Plot val accuracy and val loss of the trained model
import matplotlib.pyplot as plt

plt.title('Accuracy vs Loss per Epoch')
plt.plot(range(1, len(history.history["val_accuracy"]) + 1), history.history["val_accuracy"], label='Accuracy')
plt.plot(range(1, len(history.history["val_loss"]) + 1), history.history["val_loss"], label='Loss')
plt.ylim(0.0, 1.0)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Import the model from the results folder

from tensorflow.keras.models import load_model
model = load_model(f'cnn_{ITERATION}.h5')

# %%
# Make predictions on the test set

y_pred_test = model.predict(X_test)
y_pred_test = np.where(y_pred_test >= 0.5, 1, 0)
# Out:
# 20/20 [==============================] - 0s 13ms/step

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Compute ROC curve and AUC score for the predictions
fpr, tpr, thresholds = roc_curve(y_test, y_pred_test)
roc_auc = auc(fpr, tpr)

# Plot ROC curve and show AUC score on the plot
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()

# %%
from sklearn.metrics import confusion_matrix

# Compute the confusion matrix for test set
cm = confusion_matrix(y_test, y_pred_test.flatten())
print(cm)
# Out:
# [[172  62]
#  [ 27 363]]

# %%
# Plot the confusion matrix
class_names = subfolders
import seaborn as sns

sns.heatmap(cm, annot=True, fmt='g', cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()

# %%
# Compute the classification report for test set
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred_test, target_names=class_names))
# Out:
#               precision    recall  f1-score   support
#
#       NORMAL       0.86      0.74      0.79       234
#    PNEUMONIA       0.85      0.93      0.89       390
#
#     accuracy                           0.86       624
#    macro avg       0.86      0.83      0.84       624
# weighted avg       0.86      0.86      0.85       624

# %%
# Remove last layer's softmax
model.layers[-1].activation = None

# import os
# os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
# Print model summary to get last max pooling layer name
print(model.summary())
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_44 (Conv2D)          (None, 126, 126, 32)      320
#
#  max_pooling2d_44 (MaxPoolin  (None, 63, 63, 32)       0
#  g2D)
#
#  conv2d_45 (Conv2D)          (None, 61, 61, 64)        18496
#
#  max_pooling2d_45 (MaxPoolin  (None, 30, 30, 64)       0
#  g2D)
#
#  conv2d_46 (Conv2D)          (None, 28, 28, 128)       73856
#
#  max_pooling2d_46 (MaxPoolin  (None, 14, 14, 128)      0
#  g2D)
#
#  conv2d_47 (Conv2D)          (None, 12, 12, 256)       295168
#
#  max_pooling2d_47 (MaxPoolin  (None, 6, 6, 256)        0
#  g2D)
#
#  flatten_11 (Flatten)        (None, 9216)              0
#
#  dense_33 (Dense)            (None, 256)               2359552
#
#  dropout_22 (Dropout)        (None, 256)               0
#
#  dense_34 (Dense)            (None, 128)               32896
#
#  dropout_23 (Dropout)        (None, 128)               0
#
#  dense_35 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 2,780,417
# Trainable params: 2,780,417
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Heatmaps and Grad-CAM
from common.cam import get_img_array
import cv2
import matplotlib.pyplot as plt

images = [
    {
        "path": "./val/NORMAL/NORMAL2-IM-1442-0001.jpeg"
    },
    {
        "path": "./val/PNEUMONIA/person1946_bacteria_4874.jpeg"
    }

]

for image in images:
    image_temp = cv2.imread(image["path"])
    image_temp = cv2.cvtColor(image_temp, cv2.COLOR_RGB2GRAY)
    image_temp = cv2.resize(image_temp, (img_width, img_height))

    plt.imshow(image_temp, cmap=plt.cm.gray)
    plt.show()

    image["array"] = get_img_array(image["path"], size=(img_width, img_height))
# Out:
# C:\Users\Clement\anaconda3\envs\env\envs\env\lib\site-packages\keras\utils\image_utils.py:409: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn(

# %%
# Select last conv layer
last_conv_layer_name = "max_pooling2d_47"

# %%
# from cam import make_gradcam_heatmap, display_heatmaps
from common.cam import make_gradcam_heatmap, display_heatmaps
for image in images:
    heatmaps = []
    for layer in model.layers[:model.layers.index(model.get_layer(last_conv_layer_name)) + 1]:
        heatmap = make_gradcam_heatmap(image["array"], model, layer.name)
        heatmaps.append({
            "layer_name": layer.name,
            "image": heatmap
        })

    # Display heatmaps from all layers until the last max pooling layer
    display_heatmaps(image["path"], heatmaps)

    # Display the chosen image superimposed with heatmaps of each layer until the last max pooling layer
    display_heatmaps(image["path"], heatmaps, True)

# %%
# Predict
for image in images:
    pred = model.predict(image["array"].reshape(1, img_width, img_height, 1))
    print(pred)
    # Display predicted class
    print("Predicted class: {}".format(subfolders[int(pred[0][0])]))
# Out:
# 1/1 [==============================] - 0s 102ms/step
# [[-17.515148]]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[52], line 6
#       4 print(pred)
#       5 # Display predicted class
# ----> 6 print("Predicted class: {}".format(subfolders[int(pred[0][0])]))
#
# IndexError: list index out of range
