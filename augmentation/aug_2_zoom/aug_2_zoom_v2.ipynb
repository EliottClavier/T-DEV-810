# %% [markdown]
# # Augmentation d'image - Zoom
# ## Objectif
# L'objectif de ce notebook est d'évaluer l'impact de l'ajout de zoom aléatoire jusqu'à 0.3 sur les images du jeu de données lors de la phase d'entraînement
#
# ## Hypothèses
#
# - Bien que les informations en périphérie des images puissent être perdues, cela ne devrait pas avoir un impact significatif.
# - Certains éléments distinctifs tels que des lettres et des chiffres présents en périphérie des photos devraient disparaître, évitant ainsi un apprentissage basé sur des performances élevées mais pour de mauvaises raisons.
#
# ## Etapes de la démarche
# 1. Modifier la fonction de formatage des images pour y ajouter du zoom
# 2. Tester le jeu de données avec l'algo CNN
# 3. Calculer les métriques de performance
# 4. Comparer les résultats avec les résultats du template
#
# ## Interprétation des résultats et Conclusion
# Les résultats obtenus sont les suivants :

# %%
# Check that GPU is used
import tensorflow as tf

tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
from PIL import Image
import os
import numpy as np
from dotenv import load_dotenv

dotenv_path = 'var.env'

# Chargez les variables d'environnement
load_dotenv(dotenv_path)
BASE = os.environ.get('BASE')
ITERATION = '_v2'

TRAIN_FOLDER = BASE + 'train'
TEST_FOLDER = BASE + 'test'
VAL_FOLDER = BASE + 'val'

TRAIN_AUGMENTED_FOLDER = BASE + 'train_augmented'+ ITERATION


# Define the subfolders within each folder where the images are stored
subfolders = ['NORMAL', 'PNEUMONIA']

# Define the size of the images you want to resize your images to
img_width, img_height = 128, 128  # Function to load and resize images from a folder

# %%
# Fonction de chargement des images des dataset et des labels associés
def load_images_from_folder(folder, limit_per_subfolder=None):
    X = []
    y = []
    for subfolder in subfolders:
        folder_path = os.path.join(folder, subfolder)
        if limit_per_subfolder:
            # Get amount of random filenames from the folder
            filenames = np.random.choice(os.listdir(folder_path), limit_per_subfolder, replace=False)
        else:
            filenames = os.listdir(folder_path)
        for filename in filenames:
            img_path = os.path.join(folder_path, filename)
            img = Image.open(img_path)

            # Resize the image to the desired size
            img = img.resize((img_width, img_height))

            # Convert RGB image to grayscale
            img = img.convert('L')

            # Convert the image to a NumPy array and append it to X
            img = np.array(img)
            X.append(img)

            # Append the corresponding label to y
            y.append(subfolders.index(subfolder))

    X = np.array(X)
    y = np.array(y)
    return X, y

# %%
import os
import numpy as np
from PIL import Image, ImageOps
from keras.preprocessing.image import ImageDataGenerator

def generate_augmented_images(folder, to_augment_class, image_size=(128, 128), target_nbr=5000):
    dir = os.path.join(folder, to_augment_class)
    count = len(os.listdir(dir))

    augmented_dir = os.path.join(f"{folder}_augmented"+ITERATION, to_augment_class)

    if not os.path.exists(f"{folder}_augmented"+ITERATION):
        os.mkdir(f"{folder}_augmented"+ITERATION)

    if not os.path.exists(augmented_dir):
        os.mkdir(augmented_dir)

    augmented_count = len(os.listdir(augmented_dir))

    datagen = ImageDataGenerator(
        rotation_range=0,
        width_shift_range=0,
        height_shift_range=0,
        shear_range=0,
        zoom_range=0.3,
        horizontal_flip=True,
        fill_mode='nearest',
    )

    generator = datagen.flow_from_directory(

        folder,
        batch_size=1,
        save_to_dir=augmented_dir,
        save_format='jpeg',
        save_prefix='IM_AUGMENTED',
        classes=[to_augment_class],
        keep_aspect_ratio=True,
        target_size=image_size,
    )

    additional_count = target_nbr - len(os.listdir(augmented_dir))

    for i in range(additional_count):
        generator.next()

    new_count = len(os.listdir(augmented_dir))

    print(f'Given {to_augment_class} count: {count}')
    print(f'Augmented {to_augment_class} count: {new_count}')

# %%
generate_augmented_images(TRAIN_FOLDER, 'NORMAL', image_size=(img_width, img_height))
generate_augmented_images(TRAIN_FOLDER, 'PNEUMONIA', image_size=(img_width, img_height))
# Out:
# Found 1341 images belonging to 1 classes.
# Given NORMAL count: 1341
# Augmented NORMAL count: 5000
# Found 3875 images belonging to 1 classes.
# Given PNEUMONIA count: 3876
# Augmented PNEUMONIA count: 5000

# %% [markdown]
# # ZOOM & AUGMENTATION
# ## Comment est ajouté le zoom ?
# Pour équilibrer le jeu de données d'entraînement, chaque image est soumise à une fonction d'augmentation qui génère de nouvelles images dans un répertoire distinct. Dans le cadre de cette augmentation, un zoom aléatoire pouvant atteindre 0.3 est appliqué aux données. Ainsi, des variations de zoom aléatoires sont ajoutées aux images pour diversifier le jeu de données d'entraînement.

# %%
# Load the training data
# Get min value between the number of normal images and the number of pneumonia images
TRAIN_FOLDER = f"{TRAIN_AUGMENTED_FOLDER}"

TEST_FOLDER = f"{TEST_FOLDER}"
VAL_FOLDER = f"{VAL_FOLDER}"

min_images = min(len(os.listdir(os.path.join(TRAIN_FOLDER, subfolders[0]))),
                 len(os.listdir(os.path.join(TRAIN_FOLDER, subfolders[1]))))
X_train, y_train = load_images_from_folder(TRAIN_FOLDER, min_images)

# Load the test data
X_test, y_test = load_images_from_folder(TEST_FOLDER)

# Load the validation data
X_val, y_val = load_images_from_folder(VAL_FOLDER)

# %%
# Make a matplot figure to show how many images are in each subfolder of train
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.bar(subfolders, [len(os.listdir(os.path.join(TRAIN_FOLDER, subfolder))) for subfolder in subfolders])
plt.title('Number of images in each subfolder of train')
plt.show()

# %%
# Make a matplot figure to show how many images if each class in the training set
plt.figure(figsize=(10, 5))
plt.bar(subfolders, [len(y_train[y_train == i]) for i in range(len(subfolders))])
plt.title('Number of images in each class in the training set')
plt.show()

# %%
# Normalize the pixel values to be between 0 and 1
num_samples = X_train.shape[0]
print(X_test.shape)
X_train = X_train.reshape(len(X_train), img_width, img_height, 1)
X_test = X_test.reshape(len(X_test), img_width, img_height, 1)
X_val = X_val.reshape(len(X_val), img_width, img_height, 1)

X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255
X_val = X_val.astype('float32') / 255

print('done \n')
# Out:
# (624, 128, 128)
# done

# %%
single_image = X_train[np.random.randint(len(X_train))]
print(single_image.shape)
plt.imshow(single_image, cmap='Greys')
# Out:
# (128, 128, 1)

# %%
# Define model metrics
from keras.metrics import AUC

metrics = [
    "accuracy",
    AUC(name='auc')
]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout


# Define the model architecture
def create_model():
    model = Sequential()

    model.add(Conv2D(filters=32, kernel_size=(3, 3), input_shape=(img_width, img_height, 1), activation="relu"))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(filters=64, kernel_size=(3, 3), activation="relu"))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(filters=128, kernel_size=(3, 3), activation="relu"))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(filters=256, kernel_size=(3, 3), activation="relu"))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Flatten())

    model.add(Dense(256, activation="relu"))
    model.add(Dropout(0.5))

    model.add(Dense(128, activation="relu"))
    model.add(Dropout(0.5))

    model.add(Dense(1, activation="sigmoid"))

    # compile the model
    model.compile(loss="binary_crossentropy", optimizer="adam", metrics=metrics)

    return model

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(monitor='loss', patience=3, restore_best_weights=True)

# %%
# Cross validation
from sklearn.model_selection import KFold
from keras.preprocessing.image import ImageDataGenerator
from h5py import File
# Define the number of folds for cross-validation
n_splits = 10
epochs = 7
batch_size =64

# Initialize KFold with the number of folds
kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)

# Define lists to store the evaluation scores for each fold
accuracy_scores = []
og_val_accuracy_scores = []
histories = []
models = []
fold_no = 1
best_score = float('inf')  # pour une tâche de minimisation
best_model = None
# Iterate through each fold and train/evaluate the model
for train_idx, val_idx in kf.split(X_train, y_train):
    # Split the data into training and validation sets for this fold
    X_train_fold, y_train_fold = X_train[train_idx], y_train[train_idx]
    X_val_fold, y_val_fold = X_train[val_idx], y_train[val_idx]

    # Create an instance of ImageDataGenerator to generate your image data
    datagen = ImageDataGenerator()

    # Create generators for training and validation data
    train_generator = datagen.flow(x=X_train_fold, y=y_train_fold, batch_size=batch_size)
    valid_generator = datagen.flow(x=X_val_fold, y=y_val_fold, batch_size=batch_size)

    # Create instance of the model for this fold and train it
    model = create_model()

    # Train your model on the training data for this fold
    history = model.fit(train_generator, validation_data=valid_generator, epochs=epochs, verbose=1,
                        callbacks=[early_stop])
    # Model Évaluation with original val dataset
    scores = model.evaluate(X_val, y_val, verbose=1)
    og_val_accuracy_scores.append(scores[1])
    print(f'\nScore for fold with orginal val dataset {fold_no}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%\n')

    histories.append(history.history)

    models.append(model)

    # After training, evaluate the model on the validation set for this fold
    accuracy = model.evaluate(X_val_fold, y_val_fold)[1]

    # Store the accuracy score in the list
    accuracy_scores.append(accuracy)

    # Print the accuracy for this fold
    print(f"Accuracy for fold {len(accuracy_scores)}: {accuracy * 100}%")

    # Check if the model is better than the previous
    if scores[0] < best_score:
        best_score = scores[0]
        best_model = model

    fold_no = fold_no + 1

    # Sauvegarde du meilleur modèle
    if best_model is not None:
        best_model.save('cnn_best.h5')

# Calculate and print the average accuracy over all folds
average_accuracy = sum(accuracy_scores) / len(accuracy_scores)
og_val_average_accuracy = sum(og_val_accuracy_scores) / len(og_val_accuracy_scores)
print(f"\nAverage accuracy: {average_accuracy * 100}%")
print(f"\nAverage accuracy with orginal val: {og_val_average_accuracy * 100}%")
# Out:
# Epoch 1/7
# 141/141 [==============================] - 10s 61ms/step - loss: 0.4916 - accuracy: 0.7442 - auc: 0.8396 - val_loss: 0.3042 - val_accuracy: 0.8740 - val_auc: 0.9523
# Epoch 2/7
# 141/141 [==============================] - 8s 60ms/step - loss: 0.3176 - accuracy: 0.8720 - auc: 0.9382 - val_loss: 0.2888 - val_accuracy: 0.8950 - val_auc: 0.9583
# Epoch 3/7
# 141/141 [==============================] - 9s 61ms/step - loss: 0.2578 - accuracy: 0.8980 - auc: 0.9588 - val_loss: 0.2406 - val_accuracy: 0.8980 - val_auc: 0.9695
# Epoch 4/7
# 141/141 [==============================] - 9s 61ms/step - loss: 0.2140 - accuracy: 0.9191 - auc: 0.9713 - val_loss: 0.1935 - val_accuracy: 0.9260 - val_auc: 0.9778
# Epoch 5/7
# 141/141 [==============================] - 9s 60ms/step - loss: 0.1852 - accuracy: 0.9309 - auc: 0.9782 - val_loss: 0.1782 - val_accuracy: 0.9390 - val_auc: 0.9785
# Epoch 6/7
# 141/141 [==============================] - 8s 60ms/step - loss: 0.1664 - accuracy: 0.9377 - auc: 0.9823 - val_loss: 0.2234 - val_accuracy: 0.9230 - val_auc: 0.9747
# Epoch 7/7
# 141/141 [==============================] - 8s 60ms/step - loss: 0.1646 - accuracy: 0.9383 - auc: 0.9827 - val_loss: 0.1929 - val_accuracy: 0.9350 - val_auc: 0.9804
# 1/1 [==============================] - 0s 30ms/step - loss: 1.2370 - accuracy: 0.5000 - auc: 0.9141
#
# Score for fold with orginal val dataset 1: loss of 1.2370328903198242; accuracy of 50.0%
#
# 32/32 [==============================] - 0s 12ms/step - loss: 0.1929 - accuracy: 0.9350 - auc: 0.9804
# Accuracy for fold 1: 93.50000023841858%
# Epoch 1/7
# 141/141 [==============================] - 10s 62ms/step - loss: 0.5094 - accuracy: 0.7294 - auc: 0.8493 - val_loss: 0.3164 - val_accuracy: 0.8790 - val_auc: 0.9387
# Epoch 2/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.2913 - accuracy: 0.8856 - auc: 0.9479 - val_loss: 0.2579 - val_accuracy: 0.9060 - val_auc: 0.9616
# Epoch 3/7
# 141/141 [==============================] - 9s 60ms/step - loss: 0.2519 - accuracy: 0.9022 - auc: 0.9604 - val_loss: 0.2299 - val_accuracy: 0.9100 - val_auc: 0.9669
# Epoch 4/7
# 141/141 [==============================] - 8s 59ms/step - loss: 0.2071 - accuracy: 0.9216 - auc: 0.9730 - val_loss: 0.2271 - val_accuracy: 0.9080 - val_auc: 0.9691
# Epoch 5/7
# 141/141 [==============================] - 9s 61ms/step - loss: 0.1942 - accuracy: 0.9249 - auc: 0.9765 - val_loss: 0.2387 - val_accuracy: 0.9300 - val_auc: 0.9668
# Epoch 6/7
# 141/141 [==============================] - 8s 60ms/step - loss: 0.1762 - accuracy: 0.9330 - auc: 0.9804 - val_loss: 0.1659 - val_accuracy: 0.9380 - val_auc: 0.9817
# Epoch 7/7
# 141/141 [==============================] - 8s 60ms/step - loss: 0.1449 - accuracy: 0.9463 - auc: 0.9865 - val_loss: 0.1550 - val_accuracy: 0.9440 - val_auc: 0.9845
# 1/1 [==============================] - 0s 30ms/step - loss: 1.0443 - accuracy: 0.5625 - auc: 0.8438
#
# Score for fold with orginal val dataset 2: loss of 1.04425048828125; accuracy of 56.25%
#
# 32/32 [==============================] - 0s 10ms/step - loss: 0.1550 - accuracy: 0.9440 - auc: 0.9845
# Accuracy for fold 2: 94.40000057220459%
# Epoch 1/7
# 141/141 [==============================] - 9s 61ms/step - loss: 0.4984 - accuracy: 0.7400 - auc: 0.8576 - val_loss: 0.3694 - val_accuracy: 0.8480 - val_auc: 0.9598
# Epoch 2/7
# 141/141 [==============================] - 9s 60ms/step - loss: 0.3025 - accuracy: 0.8803 - auc: 0.9442 - val_loss: 0.2611 - val_accuracy: 0.8940 - val_auc: 0.9608
# Epoch 3/7
# 141/141 [==============================] - 8s 59ms/step - loss: 0.2506 - accuracy: 0.9043 - auc: 0.9614 - val_loss: 0.1929 - val_accuracy: 0.9200 - val_auc: 0.9833
# Epoch 4/7
# 141/141 [==============================] - 8s 59ms/step - loss: 0.2154 - accuracy: 0.9160 - auc: 0.9709 - val_loss: 0.1674 - val_accuracy: 0.9320 - val_auc: 0.9838
# Epoch 5/7
# 141/141 [==============================] - 8s 59ms/step - loss: 0.1929 - accuracy: 0.9274 - auc: 0.9767 - val_loss: 0.1313 - val_accuracy: 0.9490 - val_auc: 0.9898
# Epoch 6/7
# 141/141 [==============================] - 8s 59ms/step - loss: 0.1751 - accuracy: 0.9360 - auc: 0.9805 - val_loss: 0.1832 - val_accuracy: 0.9300 - val_auc: 0.9884
# Epoch 7/7
# 141/141 [==============================] - 8s 59ms/step - loss: 0.1531 - accuracy: 0.9432 - auc: 0.9847 - val_loss: 0.1428 - val_accuracy: 0.9460 - val_auc: 0.9897
# 1/1 [==============================] - 0s 29ms/step - loss: 0.7137 - accuracy: 0.6875 - auc: 0.7188
#
# Score for fold with orginal val dataset 3: loss of 0.7137062549591064; accuracy of 68.75%
#
# 32/32 [==============================] - 0s 10ms/step - loss: 0.1428 - accuracy: 0.9460 - auc: 0.9897
# Accuracy for fold 3: 94.59999799728394%
# Epoch 1/7
# 141/141 [==============================] - 9s 61ms/step - loss: 0.4942 - accuracy: 0.7391 - auc: 0.8588 - val_loss: 0.2962 - val_accuracy: 0.8710 - val_auc: 0.9484
# Epoch 2/7
# 141/141 [==============================] - 8s 59ms/step - loss: 0.3025 - accuracy: 0.8814 - auc: 0.9437 - val_loss: 0.2407 - val_accuracy: 0.9120 - val_auc: 0.9651
# Epoch 3/7
# 141/141 [==============================] - 8s 59ms/step - loss: 0.2369 - accuracy: 0.9094 - auc: 0.9651 - val_loss: 0.1976 - val_accuracy: 0.9150 - val_auc: 0.9767
# Epoch 4/7
# 141/141 [==============================] - 8s 59ms/step - loss: 0.2053 - accuracy: 0.9236 - auc: 0.9733 - val_loss: 0.1657 - val_accuracy: 0.9370 - val_auc: 0.9829
# Epoch 5/7
# 141/141 [==============================] - 8s 60ms/step - loss: 0.1713 - accuracy: 0.9380 - auc: 0.9810 - val_loss: 0.1686 - val_accuracy: 0.9360 - val_auc: 0.9831
# Epoch 6/7
# 141/141 [==============================] - 8s 60ms/step - loss: 0.1528 - accuracy: 0.9418 - auc: 0.9851 - val_loss: 0.1900 - val_accuracy: 0.9210 - val_auc: 0.9806
# Epoch 7/7
# 141/141 [==============================] - 8s 59ms/step - loss: 0.1413 - accuracy: 0.9459 - auc: 0.9873 - val_loss: 0.1856 - val_accuracy: 0.9280 - val_auc: 0.9851
# 1/1 [==============================] - 0s 30ms/step - loss: 1.1103 - accuracy: 0.6250 - auc: 0.8984
#
# Score for fold with orginal val dataset 4: loss of 1.1102757453918457; accuracy of 62.5%
#
# 32/32 [==============================] - 0s 11ms/step - loss: 0.1856 - accuracy: 0.9280 - auc: 0.9851
# Accuracy for fold 4: 92.79999732971191%
# Epoch 1/7
# 141/141 [==============================] - 9s 62ms/step - loss: 0.4917 - accuracy: 0.7447 - auc: 0.8596 - val_loss: 0.2646 - val_accuracy: 0.8970 - val_auc: 0.9618
# Epoch 2/7
# 141/141 [==============================] - 9s 60ms/step - loss: 0.2812 - accuracy: 0.8909 - auc: 0.9510 - val_loss: 0.2108 - val_accuracy: 0.9250 - val_auc: 0.9717
# Epoch 3/7
# 141/141 [==============================] - 8s 60ms/step - loss: 0.2466 - accuracy: 0.9037 - auc: 0.9620 - val_loss: 0.1985 - val_accuracy: 0.9250 - val_auc: 0.9769
# Epoch 4/7
# 141/141 [==============================] - 9s 60ms/step - loss: 0.2042 - accuracy: 0.9242 - auc: 0.9738 - val_loss: 0.1470 - val_accuracy: 0.9380 - val_auc: 0.9876
# Epoch 5/7
# 141/141 [==============================] - 9s 61ms/step - loss: 0.1750 - accuracy: 0.9327 - auc: 0.9806 - val_loss: 0.1422 - val_accuracy: 0.9480 - val_auc: 0.9901
# Epoch 6/7
# 141/141 [==============================] - 8s 60ms/step - loss: 0.1576 - accuracy: 0.9399 - auc: 0.9842 - val_loss: 0.1676 - val_accuracy: 0.9380 - val_auc: 0.9837
# Epoch 7/7
# 141/141 [==============================] - 8s 60ms/step - loss: 0.1421 - accuracy: 0.9473 - auc: 0.9872 - val_loss: 0.1583 - val_accuracy: 0.9360 - val_auc: 0.9845
# 1/1 [==============================] - 0s 29ms/step - loss: 0.9648 - accuracy: 0.6250 - auc: 0.7109
#
# Score for fold with orginal val dataset 5: loss of 0.9648282527923584; accuracy of 62.5%
#
# 32/32 [==============================] - 0s 11ms/step - loss: 0.1583 - accuracy: 0.9360 - auc: 0.9845
# Accuracy for fold 5: 93.59999895095825%
# Epoch 1/7
# 141/141 [==============================] - 9s 62ms/step - loss: 0.5075 - accuracy: 0.7307 - auc: 0.8494 - val_loss: 0.3747 - val_accuracy: 0.8530 - val_auc: 0.9358
# Epoch 2/7
# 141/141 [==============================] - 8s 60ms/step - loss: 0.2890 - accuracy: 0.8876 - auc: 0.9480 - val_loss: 0.2465 - val_accuracy: 0.8930 - val_auc: 0.9627
# Epoch 3/7
# 141/141 [==============================] - 8s 60ms/step - loss: 0.2283 - accuracy: 0.9131 - auc: 0.9673 - val_loss: 0.2165 - val_accuracy: 0.9180 - val_auc: 0.9735
# Epoch 4/7
# 141/141 [==============================] - 8s 60ms/step - loss: 0.1983 - accuracy: 0.9252 - auc: 0.9753 - val_loss: 0.1907 - val_accuracy: 0.9210 - val_auc: 0.9793
# Epoch 5/7
# 141/141 [==============================] - 8s 59ms/step - loss: 0.1697 - accuracy: 0.9362 - auc: 0.9814 - val_loss: 0.1808 - val_accuracy: 0.9300 - val_auc: 0.9816
# Epoch 6/7
# 141/141 [==============================] - 8s 60ms/step - loss: 0.1589 - accuracy: 0.9390 - auc: 0.9839 - val_loss: 0.1839 - val_accuracy: 0.9280 - val_auc: 0.9805
# Epoch 7/7
# 141/141 [==============================] - 8s 60ms/step - loss: 0.1463 - accuracy: 0.9474 - auc: 0.9858 - val_loss: 0.1543 - val_accuracy: 0.9470 - val_auc: 0.9865
# 1/1 [==============================] - 0s 30ms/step - loss: 0.6013 - accuracy: 0.5625 - auc: 0.9219
#
# Score for fold with orginal val dataset 6: loss of 0.6012777090072632; accuracy of 56.25%
#
# 32/32 [==============================] - 0s 11ms/step - loss: 0.1543 - accuracy: 0.9470 - auc: 0.9865
# Accuracy for fold 6: 94.70000267028809%
# Epoch 1/7
# 141/141 [==============================] - 10s 67ms/step - loss: 0.4948 - accuracy: 0.7417 - auc: 0.8582 - val_loss: 0.3209 - val_accuracy: 0.8670 - val_auc: 0.9608
# Epoch 2/7
# 141/141 [==============================] - 9s 65ms/step - loss: 0.2673 - accuracy: 0.8957 - auc: 0.9558 - val_loss: 0.1801 - val_accuracy: 0.9320 - val_auc: 0.9806
# Epoch 3/7
# 141/141 [==============================] - 9s 65ms/step - loss: 0.2055 - accuracy: 0.9220 - auc: 0.9732 - val_loss: 0.1770 - val_accuracy: 0.9280 - val_auc: 0.9807
# Epoch 4/7
# 141/141 [==============================] - 9s 65ms/step - loss: 0.1823 - accuracy: 0.9297 - auc: 0.9787 - val_loss: 0.1771 - val_accuracy: 0.9270 - val_auc: 0.9806
# Epoch 5/7
# 141/141 [==============================] - 9s 65ms/step - loss: 0.1596 - accuracy: 0.9406 - auc: 0.9838 - val_loss: 0.1782 - val_accuracy: 0.9320 - val_auc: 0.9850
# Epoch 6/7
# 141/141 [==============================] - 9s 65ms/step - loss: 0.1346 - accuracy: 0.9503 - auc: 0.9881 - val_loss: 0.1476 - val_accuracy: 0.9400 - val_auc: 0.9881
# Epoch 7/7
# 141/141 [==============================] - 9s 65ms/step - loss: 0.1246 - accuracy: 0.9538 - auc: 0.9899 - val_loss: 0.1784 - val_accuracy: 0.9330 - val_auc: 0.9840
# 1/1 [==============================] - 0s 30ms/step - loss: 0.6806 - accuracy: 0.5625 - auc: 0.7812
#
# Score for fold with orginal val dataset 7: loss of 0.6805530786514282; accuracy of 56.25%
#
# 32/32 [==============================] - 0s 11ms/step - loss: 0.1784 - accuracy: 0.9330 - auc: 0.9840
# Accuracy for fold 7: 93.30000281333923%
# Epoch 1/7
# 141/141 [==============================] - 10s 68ms/step - loss: 0.4840 - accuracy: 0.7434 - auc: 0.8625 - val_loss: 0.2663 - val_accuracy: 0.8920 - val_auc: 0.9551
# Epoch 2/7
# 141/141 [==============================] - 9s 64ms/step - loss: 0.2735 - accuracy: 0.8897 - auc: 0.9544 - val_loss: 0.2434 - val_accuracy: 0.9050 - val_auc: 0.9715
# Epoch 3/7
# 141/141 [==============================] - 9s 64ms/step - loss: 0.2205 - accuracy: 0.9178 - auc: 0.9694 - val_loss: 0.1868 - val_accuracy: 0.9230 - val_auc: 0.9793
# Epoch 4/7
# 141/141 [==============================] - 9s 65ms/step - loss: 0.1792 - accuracy: 0.9331 - auc: 0.9795 - val_loss: 0.1712 - val_accuracy: 0.9340 - val_auc: 0.9829
# Epoch 5/7
# 141/141 [==============================] - 9s 64ms/step - loss: 0.1668 - accuracy: 0.9352 - auc: 0.9826 - val_loss: 0.1488 - val_accuracy: 0.9440 - val_auc: 0.9866
# Epoch 6/7
# 141/141 [==============================] - 9s 64ms/step - loss: 0.1458 - accuracy: 0.9456 - auc: 0.9862 - val_loss: 0.1361 - val_accuracy: 0.9470 - val_auc: 0.9888
# Epoch 7/7
# 141/141 [==============================] - 9s 64ms/step - loss: 0.1298 - accuracy: 0.9523 - auc: 0.9887 - val_loss: 0.1204 - val_accuracy: 0.9570 - val_auc: 0.9908
# 1/1 [==============================] - 0s 30ms/step - loss: 1.0637 - accuracy: 0.6250 - auc: 0.8125
#
# Score for fold with orginal val dataset 8: loss of 1.063731074333191; accuracy of 62.5%
#
# 32/32 [==============================] - 0s 11ms/step - loss: 0.1204 - accuracy: 0.9570 - auc: 0.9908
# Accuracy for fold 8: 95.70000171661377%
# Epoch 1/7
# 141/141 [==============================] - 11s 62ms/step - loss: 0.5206 - accuracy: 0.7260 - auc: 0.8461 - val_loss: 0.3428 - val_accuracy: 0.8520 - val_auc: 0.9307
# Epoch 2/7
# 141/141 [==============================] - 9s 61ms/step - loss: 0.2897 - accuracy: 0.8867 - auc: 0.9478 - val_loss: 0.2434 - val_accuracy: 0.9060 - val_auc: 0.9629
# Epoch 3/7
# 141/141 [==============================] - 8s 60ms/step - loss: 0.2256 - accuracy: 0.9128 - auc: 0.9682 - val_loss: 0.2381 - val_accuracy: 0.9050 - val_auc: 0.9659
# Epoch 4/7
# 141/141 [==============================] - 8s 59ms/step - loss: 0.1893 - accuracy: 0.9277 - auc: 0.9770 - val_loss: 0.1771 - val_accuracy: 0.9270 - val_auc: 0.9798
# Epoch 5/7
# 141/141 [==============================] - 8s 60ms/step - loss: 0.1678 - accuracy: 0.9391 - auc: 0.9820 - val_loss: 0.1743 - val_accuracy: 0.9280 - val_auc: 0.9822
# Epoch 6/7
# 141/141 [==============================] - 8s 60ms/step - loss: 0.1597 - accuracy: 0.9391 - auc: 0.9838 - val_loss: 0.1548 - val_accuracy: 0.9410 - val_auc: 0.9865
# Epoch 7/7
# 141/141 [==============================] - 9s 61ms/step - loss: 0.1328 - accuracy: 0.9496 - auc: 0.9887 - val_loss: 0.1558 - val_accuracy: 0.9450 - val_auc: 0.9836
# 1/1 [==============================] - 0s 29ms/step - loss: 0.5967 - accuracy: 0.7500 - auc: 0.8438
#
# Score for fold with orginal val dataset 9: loss of 0.5967328548431396; accuracy of 75.0%
#
# 32/32 [==============================] - 0s 11ms/step - loss: 0.1558 - accuracy: 0.9450 - auc: 0.9836
# Accuracy for fold 9: 94.49999928474426%
# Epoch 1/7
# 141/141 [==============================] - 9s 61ms/step - loss: 0.5106 - accuracy: 0.7279 - auc: 0.8483 - val_loss: 0.2766 - val_accuracy: 0.8820 - val_auc: 0.9544
# Epoch 2/7
# 141/141 [==============================] - 9s 60ms/step - loss: 0.3070 - accuracy: 0.8766 - auc: 0.9417 - val_loss: 0.2043 - val_accuracy: 0.9210 - val_auc: 0.9758
# Epoch 3/7
# 141/141 [==============================] - 9s 61ms/step - loss: 0.2480 - accuracy: 0.9030 - auc: 0.9617 - val_loss: 0.2028 - val_accuracy: 0.9170 - val_auc: 0.9779
# Epoch 4/7
# 141/141 [==============================] - 8s 60ms/step - loss: 0.2053 - accuracy: 0.9193 - auc: 0.9735 - val_loss: 0.1440 - val_accuracy: 0.9470 - val_auc: 0.9866
# Epoch 5/7
# 141/141 [==============================] - 8s 59ms/step - loss: 0.1722 - accuracy: 0.9329 - auc: 0.9810 - val_loss: 0.1667 - val_accuracy: 0.9320 - val_auc: 0.9861
# Epoch 6/7
# 141/141 [==============================] - 8s 59ms/step - loss: 0.1539 - accuracy: 0.9416 - auc: 0.9847 - val_loss: 0.1352 - val_accuracy: 0.9510 - val_auc: 0.9888
# Epoch 7/7
# 141/141 [==============================] - 8s 59ms/step - loss: 0.1421 - accuracy: 0.9450 - auc: 0.9872 - val_loss: 0.1422 - val_accuracy: 0.9490 - val_auc: 0.9885
# 1/1 [==============================] - 0s 30ms/step - loss: 0.9743 - accuracy: 0.6250 - auc: 0.8203
#
# Score for fold with orginal val dataset 10: loss of 0.9743265509605408; accuracy of 62.5%
#
# 32/32 [==============================] - 0s 10ms/step - loss: 0.1422 - accuracy: 0.9490 - auc: 0.9885
# Accuracy for fold 10: 94.90000009536743%
#
# Average accuracy: 94.200000166893%
#
# Average accuracy with orginal val: 61.25000000000001%

# %%
# Get accuracy scores for each fold (train and validation)
loss = []
acc = []
val_loss = []
val_acc = []

for history in histories:
    loss.append(np.mean(history["loss"]))
    acc.append(np.mean(history["accuracy"]))
    val_loss.append(np.mean(history["val_loss"]))
    val_acc.append(np.mean(history["val_accuracy"]))

# %%
# Plot loss and validation loss per fold
import matplotlib.pyplot as plt
plt.title('Losses')
plt.plot(range(1, len(loss)+1), loss, label='Loss')
plt.plot(range(1, len(val_loss)+1), val_loss, label='Validation loss')
plt.ylim(0.0, 1.0)
plt.xlabel('Fold')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Plot accuracies and validation accuracies per fold
import matplotlib.pyplot as plt

plt.title('Accuracies')
plt.plot(range(1, len(acc) + 1), acc, label='Accuracy')
plt.plot(range(1, len(val_acc) + 1), val_acc, label='Validation accuracy')
plt.ylim(0.0, 1.0)
plt.xlabel('Fold')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Train a final model with same parameters and save it
# Create an instance of ImageDataGenerator to generate your image data
datagen = ImageDataGenerator()
train_generator = datagen.flow(x=X_train, y=y_train, batch_size=batch_size)
valid_generator = datagen.flow(x=X_val, y=y_val, batch_size=batch_size)
model = create_model()
history = model.fit(train_generator, validation_data=valid_generator, epochs=epochs, verbose=1, callbacks=[early_stop])
model.save('cnn.h5')
# Out:
# Epoch 1/7
# 157/157 [==============================] - 10s 59ms/step - loss: 0.4397 - accuracy: 0.7789 - auc: 0.8912 - val_loss: 0.7649 - val_accuracy: 0.5625 - val_auc: 0.7188
# Epoch 2/7
# 157/157 [==============================] - 9s 57ms/step - loss: 0.2512 - accuracy: 0.9048 - auc: 0.9608 - val_loss: 0.5907 - val_accuracy: 0.8125 - val_auc: 0.8125
# Epoch 3/7
# 157/157 [==============================] - 9s 57ms/step - loss: 0.2032 - accuracy: 0.9214 - auc: 0.9742 - val_loss: 0.8840 - val_accuracy: 0.5625 - val_auc: 0.8750
# Epoch 4/7
# 157/157 [==============================] - 9s 57ms/step - loss: 0.1779 - accuracy: 0.9317 - auc: 0.9800 - val_loss: 0.4896 - val_accuracy: 0.6875 - val_auc: 0.8594
# Epoch 5/7
# 157/157 [==============================] - 9s 57ms/step - loss: 0.1603 - accuracy: 0.9408 - auc: 0.9838 - val_loss: 0.5871 - val_accuracy: 0.6875 - val_auc: 0.7969
# Epoch 6/7
# 157/157 [==============================] - 9s 57ms/step - loss: 0.1339 - accuracy: 0.9515 - auc: 0.9886 - val_loss: 0.5602 - val_accuracy: 0.5625 - val_auc: 0.7812
# Epoch 7/7
# 157/157 [==============================] - 9s 58ms/step - loss: 0.1283 - accuracy: 0.9518 - auc: 0.9892 - val_loss: 0.4813 - val_accuracy: 0.8125 - val_auc: 0.8906

# %%
# Plot val accuracy and val loss of the trained model
import matplotlib.pyplot as plt

plt.title('Accuracy vs Loss per Epoch')
plt.plot(range(1, len(history.history["val_accuracy"]) + 1), history.history["val_accuracy"], label='Accuracy')
plt.plot(range(1, len(history.history["val_loss"]) + 1), history.history["val_loss"], label='Loss')
plt.ylim(0.0, 1.0)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
# Make predictions on the test set
model = load_model('cnn.h5')

# %%
# Make predictions on the test set

y_pred_test = model.predict(X_test)
y_pred_test = np.where(y_pred_test >= 0.5, 1, 0)
# Out:
# 20/20 [==============================] - 0s 9ms/step

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Compute ROC curve and AUC score for the predictions
fpr, tpr, thresholds = roc_curve(y_test, y_pred_test)
roc_auc = auc(fpr, tpr)

# Plot ROC curve and show AUC score on the plot
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()

# %%
from sklearn.metrics import confusion_matrix

# Compute the confusion matrix for test set
cm = confusion_matrix(y_test, y_pred_test.flatten())
print(cm)
# Out:
# [[218  16]
#  [ 65 325]]

# %%
# Plot the confusion matrix
class_names = subfolders
import seaborn as sns

sns.heatmap(cm, annot=True, fmt='g', cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()

# %%
# Compute the classification report for test set
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred_test, target_names=class_names))
# Out:
#               precision    recall  f1-score   support
#
#       NORMAL       0.77      0.93      0.84       234
#    PNEUMONIA       0.95      0.83      0.89       390
#
#     accuracy                           0.87       624
#    macro avg       0.86      0.88      0.87       624
# weighted avg       0.88      0.87      0.87       624

# %%
import tensorflow as tf
import numpy as np
from IPython.display import Image, display
import matplotlib.cm as cm
from keras.utils import load_img, img_to_array, array_to_img


def get_img_array(img_path, size):
    # `img` is a PIL image of size 256x256
    img = load_img(img_path, target_size=size, grayscale=True)
    # `array` is a float32 Numpy array of shape (256, 256, 3)
    array = img_to_array(img)
    # We add a dimension to transform our array into a "batch"
    # of size (1, 299, 299, 3)
    array = np.expand_dims(array, axis=0)
    return array


def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    # First, we create a model that maps the input image to the activations
    # of the last conv layer as well as the output predictions
    grad_model = tf.keras.models.Model(
        [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output]
    )

    # Then, we compute the gradient of the top predicted class for our input image
    # with respect to the activations of the last conv layer
    with tf.GradientTape() as tape:
        last_conv_layer_output, preds = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]

    # This is the gradient of the output neuron (top predicted or chosen)
    # with regard to the output feature map of the last conv layer
    grads = tape.gradient(class_channel, last_conv_layer_output)

    # This is a vector where each entry is the mean intensity of the gradient
    # over a specific feature map channel
    #grads = tf.expand_dims(grads, axis=0)
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # We multiply each channel in the feature map array
    # by "how important this channel is" with regard to the top predicted class
    # then sum all the channels to obtain the heatmap class activation
    last_conv_layer_output = last_conv_layer_output[0]
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)

    # For visualization purpose, we will also normalize the heatmap between 0 & 1
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()


def generate_superimposed_gradcam(img_path, heatmap, alpha=0.4):
    # Load the original image
    img = load_img(img_path)
    img = img_to_array(img)

    # Rescale heatmap to a range 0-255
    heatmap = np.uint8(255 * heatmap)

    # Use jet colormap to colorize heatmap
    jet = cm.get_cmap("jet")

    # Use RGB values of the colormap
    jet_colors = jet(np.arange(256))[:, :3]
    jet_heatmap = jet_colors[heatmap]

    # Create an image with RGB colorized heatmap
    jet_heatmap = array_to_img(jet_heatmap)
    jet_heatmap = jet_heatmap.resize((img.shape[1], img.shape[0]))
    jet_heatmap = img_to_array(jet_heatmap)

    # Superimpose the heatmap on original image
    superimposed_img = jet_heatmap * alpha + img
    superimposed_img = array_to_img(superimposed_img)

    return superimposed_img


def display_heatmaps(img_path, heatmaps, superimposed=False):
    import matplotlib.pyplot as plt

    # Define the number of columns for the subplot grid
    n_cols = min(len(heatmaps), 5)

    # Calculate the number of rows based on the number of columns and total number of images
    n_rows = (len(heatmaps) - 1) // n_cols + 1

    # Create a figure with the desired size
    fig, axes = plt.subplots(n_rows, n_cols, figsize=(20, 4 * n_rows))

    for i, heatmap in enumerate(heatmaps):
        # Calculate the row and column index for this heatmap
        row = i // n_cols
        col = i % n_cols

        # Get the corresponding subplot
        ax = axes[row, col] if n_rows > 1 else axes[col]

        # Set the title of the subplot to the layer name
        ax.set_title(heatmap['layer_name'])

        if superimposed:
            superimposed_img = generate_superimposed_gradcam(img_path, heatmaps[i]["image"])
            # Plot the heatmap
            ax.imshow(superimposed_img)
        else:
            # Plot the heatmap
            ax.imshow(heatmaps[i]["image"], cmap='jet')

    # Hide the remaining subplots that are not used
    for i in range(len(heatmaps), n_rows * n_cols):
        # Calculate the row and column index for this subplot
        row = i // n_cols
        col = i % n_cols

        # Get the corresponding subplot
        ax = axes[row, col] if n_rows > 1 else axes[col]

        # Hide the subplot
        ax.axis('off')

    # Adjust the spacing between subplots
    fig.tight_layout()

    # Show the plot
    plt.show()

# %%
# Remove last layer's softmax
model.layers[-1].activation = None

# import os
# os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
# Print model summary to get last max pooling layer name
print(model.summary())
# Out:
# Model: "sequential_22"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_88 (Conv2D)          (None, 126, 126, 32)      320
#
#  max_pooling2d_88 (MaxPoolin  (None, 63, 63, 32)       0
#  g2D)
#
#  conv2d_89 (Conv2D)          (None, 61, 61, 64)        18496
#
#  max_pooling2d_89 (MaxPoolin  (None, 30, 30, 64)       0
#  g2D)
#
#  conv2d_90 (Conv2D)          (None, 28, 28, 128)       73856
#
#  max_pooling2d_90 (MaxPoolin  (None, 14, 14, 128)      0
#  g2D)
#
#  conv2d_91 (Conv2D)          (None, 12, 12, 256)       295168
#
#  max_pooling2d_91 (MaxPoolin  (None, 6, 6, 256)        0
#  g2D)
#
#  flatten_22 (Flatten)        (None, 9216)              0
#
#  dense_66 (Dense)            (None, 256)               2359552
#
#  dropout_44 (Dropout)        (None, 256)               0
#
#  dense_67 (Dense)            (None, 128)               32896
#
#  dropout_45 (Dropout)        (None, 128)               0
#
#  dense_68 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 2,780,417
# Trainable params: 2,780,417
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Select last conv layer
last_conv_layer_name = "max_pooling2d_91"

# %%
# Heatmaps and Grad-CAM


import cv2
import matplotlib.pyplot as plt

images = [
    {
        "path": BASE + "val\\NORMAL\\NORMAL2-IM-1431-0001.jpeg"
    },
    {
        "path": BASE + "val\\PNEUMONIA\\person1946_bacteria_4875.jpeg"
    }
]

for image in images:
    image_temp = cv2.imread(image["path"])
    image_temp = cv2.cvtColor(image_temp, cv2.COLOR_RGB2GRAY)
    image_temp = cv2.resize(image_temp, (img_width, img_height))

    plt.imshow(image_temp, cmap=plt.cm.gray)
    plt.show()

    image["array"] = get_img_array(image["path"], size=(img_width, img_height))

# %%
# from cam import make_gradcam_heatmap, display_heatmaps

for image in images:
    heatmaps = []
    for layer in model.layers[:model.layers.index(model.get_layer(last_conv_layer_name)) + 1]:
        heatmap = make_gradcam_heatmap(image["array"], model, layer.name)
        heatmaps.append({
            "layer_name": layer.name,
            "image": heatmap
        })

    # Display heatmaps from all layers until the last max pooling layer
    display_heatmaps(image["path"], heatmaps)

    # Display the chosen image superimposed with heatmaps of each layer until the last max pooling layer
    display_heatmaps(image["path"], heatmaps, True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_16080\2206199731.py:64: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   jet = cm.get_cmap("jet")

# %%
# Predict
for image in images:
    pred = model.predict(image["array"].reshape(1, img_width, img_height, 1))
    print(pred)
    # Display predicted class
    print("Predicted class: {}".format(subfolders[int(pred[0][0])]))
# Out:
# 1/1 [==============================] - 0s 453ms/step
# [[1.]]
# Predicted class: PNEUMONIA
# 1/1 [==============================] - 0s 29ms/step
# [[1.]]
# Predicted class: PNEUMONIA
