# %% [markdown]
# # Augmentation d'image - Zoom
# ## Objectif
# L'objectif de ce notebook est d'évaluer l'impact de l'ajout de zoom aléatoire jusqu'à 0.4 sur les images du jeu de données lors de la phase d'entraînement
#
# ## Hypothèses
#
# - Bien que les informations en périphérie des images puissent être perdues, cela ne devrait pas avoir un impact significatif.
# - Certains éléments distinctifs tels que des lettres et des chiffres présents en périphérie des photos devraient disparaître, évitant ainsi un apprentissage basé sur des performances élevées mais pour de mauvaises raisons.
#
# ## Etapes de la démarche
# 1. Modifier la fonction de formatage des images pour y ajouter du zoom
# 2. Tester le jeu de données avec l'algo CNN
# 3. Calculer les métriques de performance
# 4. Comparer les résultats avec les résultats du template
#
# ## Interprétation des résultats et Conclusion
# Les résultats obtenus sont les suivants :

# %%
# Check that GPU is used
import tensorflow as tf

tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
from PIL import Image
import os
import numpy as np
from dotenv import load_dotenv

dotenv_path = 'var.env'

# Chargez les variables d'environnement
load_dotenv(dotenv_path)
BASE = os.environ.get('BASE')
ITERATION = '_v3'

TRAIN_FOLDER = BASE + 'train'
TEST_FOLDER = BASE + 'test'
VAL_FOLDER = BASE + 'val'

TRAIN_AUGMENTED_FOLDER = BASE + 'train_augmented'+ ITERATION


# Define the subfolders within each folder where the images are stored
subfolders = ['NORMAL', 'PNEUMONIA']

# Define the size of the images you want to resize your images to
img_width, img_height = 128, 128  # Function to load and resize images from a folder

# %%
# Fonction de chargement des images des dataset et des labels associés
def load_images_from_folder(folder, limit_per_subfolder=None):
    X = []
    y = []
    for subfolder in subfolders:
        folder_path = os.path.join(folder, subfolder)
        if limit_per_subfolder:
            # Get amount of random filenames from the folder
            filenames = np.random.choice(os.listdir(folder_path), limit_per_subfolder, replace=False)
        else:
            filenames = os.listdir(folder_path)
        for filename in filenames:
            img_path = os.path.join(folder_path, filename)
            img = Image.open(img_path)

            # Resize the image to the desired size
            img = img.resize((img_width, img_height))

            # Convert RGB image to grayscale
            img = img.convert('L')

            # Convert the image to a NumPy array and append it to X
            img = np.array(img)
            X.append(img)

            # Append the corresponding label to y
            y.append(subfolders.index(subfolder))

    X = np.array(X)
    y = np.array(y)
    return X, y

# %%
import os
import numpy as np
from PIL import Image, ImageOps
from keras.preprocessing.image import ImageDataGenerator

def generate_augmented_images(folder, to_augment_class, image_size=(128, 128), target_nbr=5000):
    dir = os.path.join(folder, to_augment_class)
    count = len(os.listdir(dir))

    augmented_dir = os.path.join(f"{folder}_augmented"+ITERATION, to_augment_class)

    if not os.path.exists(f"{folder}_augmented"+ITERATION):
        os.mkdir(f"{folder}_augmented"+ITERATION)

    if not os.path.exists(augmented_dir):
        os.mkdir(augmented_dir)

    augmented_count = len(os.listdir(augmented_dir))

    datagen = ImageDataGenerator(
        rotation_range=0,
        width_shift_range=0,
        height_shift_range=0,
        shear_range=0,
        zoom_range=0.4,
        horizontal_flip=True,
        fill_mode='nearest',
    )

    generator = datagen.flow_from_directory(

        folder,
        batch_size=1,
        save_to_dir=augmented_dir,
        save_format='jpeg',
        save_prefix='IM_AUGMENTED',
        classes=[to_augment_class],
        keep_aspect_ratio=True,
        target_size=image_size,
    )

    additional_count = target_nbr - len(os.listdir(augmented_dir))

    for i in range(additional_count):
        generator.next()

    new_count = len(os.listdir(augmented_dir))

    print(f'Given {to_augment_class} count: {count}')
    print(f'Augmented {to_augment_class} count: {new_count}')

# %%
generate_augmented_images(TRAIN_FOLDER, 'NORMAL', image_size=(img_width, img_height))
generate_augmented_images(TRAIN_FOLDER, 'PNEUMONIA', image_size=(img_width, img_height))
# Out:
# Found 1341 images belonging to 1 classes.
# Given NORMAL count: 1341
# Augmented NORMAL count: 5000
# Found 3875 images belonging to 1 classes.
# Given PNEUMONIA count: 3876
# Augmented PNEUMONIA count: 5000

# %% [markdown]
# # ZOOM & AUGMENTATION
# ## Comment est ajouté le zoom ?
# Pour équilibrer le jeu de données d'entraînement, chaque image est soumise à une fonction d'augmentation qui génère de nouvelles images dans un répertoire distinct. Dans le cadre de cette augmentation, un zoom aléatoire pouvant atteindre 0.3 est appliqué aux données. Ainsi, des variations de zoom aléatoires sont ajoutées aux images pour diversifier le jeu de données d'entraînement.

# %%
# Load the training data
# Get min value between the number of normal images and the number of pneumonia images
TRAIN_FOLDER = f"{TRAIN_AUGMENTED_FOLDER}"

TEST_FOLDER = f"{TEST_FOLDER}"
VAL_FOLDER = f"{VAL_FOLDER}"

min_images = min(len(os.listdir(os.path.join(TRAIN_FOLDER, subfolders[0]))),
                 len(os.listdir(os.path.join(TRAIN_FOLDER, subfolders[1]))))
X_train, y_train = load_images_from_folder(TRAIN_FOLDER, min_images)

# Load the test data
X_test, y_test = load_images_from_folder(TEST_FOLDER)

# Load the validation data
X_val, y_val = load_images_from_folder(VAL_FOLDER)

# %%
# Make a matplot figure to show how many images are in each subfolder of train
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.bar(subfolders, [len(os.listdir(os.path.join(TRAIN_FOLDER, subfolder))) for subfolder in subfolders])
plt.title('Number of images in each subfolder of train')
plt.show()

# %%
# Make a matplot figure to show how many images if each class in the training set
plt.figure(figsize=(10, 5))
plt.bar(subfolders, [len(y_train[y_train == i]) for i in range(len(subfolders))])
plt.title('Number of images in each class in the training set')
plt.show()

# %%
# Normalize the pixel values to be between 0 and 1
num_samples = X_train.shape[0]
print(X_test.shape)
X_train = X_train.reshape(len(X_train), img_width, img_height, 1)
X_test = X_test.reshape(len(X_test), img_width, img_height, 1)
X_val = X_val.reshape(len(X_val), img_width, img_height, 1)

X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255
X_val = X_val.astype('float32') / 255

print('done \n')
# Out:
# (624, 128, 128)
# done

# %%
single_image = X_train[np.random.randint(len(X_train))]
print(single_image.shape)
plt.imshow(single_image, cmap='Greys')
# Out:
# (128, 128, 1)

# %%
# Define model metrics
from keras.metrics import AUC

metrics = [
    "accuracy",
    AUC(name='auc')
]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout


# Define the model architecture
def create_model():
    model = Sequential()

    model.add(Conv2D(filters=32, kernel_size=(3, 3), input_shape=(img_width, img_height, 1), activation="relu"))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(filters=64, kernel_size=(3, 3), activation="relu"))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(filters=128, kernel_size=(3, 3), activation="relu"))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(filters=256, kernel_size=(3, 3), activation="relu"))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Flatten())

    model.add(Dense(256, activation="relu"))
    model.add(Dropout(0.5))

    model.add(Dense(128, activation="relu"))
    model.add(Dropout(0.5))

    model.add(Dense(1, activation="sigmoid"))

    # compile the model
    model.compile(loss="binary_crossentropy", optimizer="adam", metrics=metrics)

    return model

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(monitor='loss', patience=3, restore_best_weights=True)

# %%
# Cross validation
from sklearn.model_selection import KFold
from keras.preprocessing.image import ImageDataGenerator
from h5py import File
# Define the number of folds for cross-validation
n_splits = 10
epochs = 7
batch_size =64

# Initialize KFold with the number of folds
kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)

# Define lists to store the evaluation scores for each fold
accuracy_scores = []
og_val_accuracy_scores = []
histories = []
models = []
fold_no = 1
best_score = float('inf')  # pour une tâche de minimisation
best_model = None
# Iterate through each fold and train/evaluate the model
for train_idx, val_idx in kf.split(X_train, y_train):
    # Split the data into training and validation sets for this fold
    X_train_fold, y_train_fold = X_train[train_idx], y_train[train_idx]
    X_val_fold, y_val_fold = X_train[val_idx], y_train[val_idx]

    # Create an instance of ImageDataGenerator to generate your image data
    datagen = ImageDataGenerator()

    # Create generators for training and validation data
    train_generator = datagen.flow(x=X_train_fold, y=y_train_fold, batch_size=batch_size)
    valid_generator = datagen.flow(x=X_val_fold, y=y_val_fold, batch_size=batch_size)

    # Create instance of the model for this fold and train it
    model = create_model()

    # Train your model on the training data for this fold
    history = model.fit(train_generator, validation_data=valid_generator, epochs=epochs, verbose=1,
                        callbacks=[early_stop])
    # Model Évaluation with original val dataset
    scores = model.evaluate(X_val, y_val, verbose=1)
    og_val_accuracy_scores.append(scores[1])
    print(f'\nScore for fold with orginal val dataset {fold_no}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%\n')

    histories.append(history.history)

    models.append(model)

    # After training, evaluate the model on the validation set for this fold
    accuracy = model.evaluate(X_val_fold, y_val_fold)[1]

    # Store the accuracy score in the list
    accuracy_scores.append(accuracy)

    # Print the accuracy for this fold
    print(f"Accuracy for fold {len(accuracy_scores)}: {accuracy * 100}%")

    # Check if the model is better than the previous
    if scores[0] < best_score:
        best_score = scores[0]
        best_model = model

    fold_no = fold_no + 1

    # Sauvegarde du meilleur modèle
    if best_model is not None:
        best_model.save('cnn_best.h5')

# Calculate and print the average accuracy over all folds
average_accuracy = sum(accuracy_scores) / len(accuracy_scores)
og_val_average_accuracy = sum(og_val_accuracy_scores) / len(og_val_accuracy_scores)
print(f"\nAverage accuracy: {average_accuracy * 100}%")
print(f"\nAverage accuracy with orginal val: {og_val_average_accuracy * 100}%")
# Out:
# Epoch 1/7
# 141/141 [==============================] - 19s 80ms/step - loss: 0.5800 - accuracy: 0.6598 - auc: 0.7490 - val_loss: 0.3461 - val_accuracy: 0.8420 - val_auc: 0.9298
# Epoch 2/7
# 141/141 [==============================] - 10s 68ms/step - loss: 0.3198 - accuracy: 0.8706 - auc: 0.9373 - val_loss: 0.2903 - val_accuracy: 0.8810 - val_auc: 0.9565
# Epoch 3/7
# 141/141 [==============================] - 10s 68ms/step - loss: 0.2792 - accuracy: 0.8922 - auc: 0.9527 - val_loss: 0.2161 - val_accuracy: 0.9050 - val_auc: 0.9751
# Epoch 4/7
# 141/141 [==============================] - 10s 68ms/step - loss: 0.2282 - accuracy: 0.9110 - auc: 0.9682 - val_loss: 0.2038 - val_accuracy: 0.9090 - val_auc: 0.9771
# Epoch 5/7
# 141/141 [==============================] - 10s 68ms/step - loss: 0.1895 - accuracy: 0.9307 - auc: 0.9775 - val_loss: 0.1640 - val_accuracy: 0.9380 - val_auc: 0.9843
# Epoch 6/7
# 141/141 [==============================] - 9s 64ms/step - loss: 0.1665 - accuracy: 0.9388 - auc: 0.9823 - val_loss: 0.1608 - val_accuracy: 0.9370 - val_auc: 0.9874
# Epoch 7/7
# 141/141 [==============================] - 9s 63ms/step - loss: 0.1454 - accuracy: 0.9464 - auc: 0.9862 - val_loss: 0.1652 - val_accuracy: 0.9310 - val_auc: 0.9862
# 1/1 [==============================] - 0s 292ms/step - loss: 0.7734 - accuracy: 0.6250 - auc: 0.8281
#
# Score for fold with orginal val dataset 1: loss of 0.7733830213546753; accuracy of 62.5%
#
# 32/32 [==============================] - 1s 18ms/step - loss: 0.1652 - accuracy: 0.9310 - auc: 0.9862
# Accuracy for fold 1: 93.09999942779541%
# Epoch 1/7
# 141/141 [==============================] - 12s 78ms/step - loss: 0.5234 - accuracy: 0.7163 - auc: 0.8374 - val_loss: 0.3751 - val_accuracy: 0.8490 - val_auc: 0.9413
# Epoch 2/7
# 141/141 [==============================] - 20s 144ms/step - loss: 0.3266 - accuracy: 0.8687 - auc: 0.9355 - val_loss: 0.2419 - val_accuracy: 0.9050 - val_auc: 0.9638
# Epoch 3/7
# 141/141 [==============================] - 27s 195ms/step - loss: 0.2656 - accuracy: 0.8956 - auc: 0.9569 - val_loss: 0.2174 - val_accuracy: 0.9130 - val_auc: 0.9724
# Epoch 4/7
# 141/141 [==============================] - 23s 165ms/step - loss: 0.2161 - accuracy: 0.9190 - auc: 0.9712 - val_loss: 0.1731 - val_accuracy: 0.9310 - val_auc: 0.9817
# Epoch 5/7
# 141/141 [==============================] - 23s 166ms/step - loss: 0.1988 - accuracy: 0.9228 - auc: 0.9755 - val_loss: 0.1479 - val_accuracy: 0.9400 - val_auc: 0.9869
# Epoch 6/7
# 141/141 [==============================] - 23s 164ms/step - loss: 0.1664 - accuracy: 0.9387 - auc: 0.9823 - val_loss: 0.1758 - val_accuracy: 0.9290 - val_auc: 0.9812
# Epoch 7/7
# 141/141 [==============================] - 23s 167ms/step - loss: 0.1528 - accuracy: 0.9436 - auc: 0.9847 - val_loss: 0.1533 - val_accuracy: 0.9400 - val_auc: 0.9860
# 1/1 [==============================] - 0s 32ms/step - loss: 0.5238 - accuracy: 0.6875 - auc: 0.7969
#
# Score for fold with orginal val dataset 2: loss of 0.5237946510314941; accuracy of 68.75%
#
# 32/32 [==============================] - 0s 10ms/step - loss: 0.1533 - accuracy: 0.9400 - auc: 0.9860
# Accuracy for fold 2: 93.99999976158142%
# Epoch 1/7
# 141/141 [==============================] - 26s 178ms/step - loss: 0.5622 - accuracy: 0.6951 - auc: 0.8132 - val_loss: 0.4630 - val_accuracy: 0.7850 - val_auc: 0.9129
# Epoch 2/7
# 141/141 [==============================] - 23s 165ms/step - loss: 0.3728 - accuracy: 0.8429 - auc: 0.9154 - val_loss: 0.2671 - val_accuracy: 0.9000 - val_auc: 0.9579
# Epoch 3/7
# 141/141 [==============================] - 25s 177ms/step - loss: 0.2993 - accuracy: 0.8829 - auc: 0.9453 - val_loss: 0.2568 - val_accuracy: 0.8980 - val_auc: 0.9693
# Epoch 4/7
# 141/141 [==============================] - 26s 172ms/step - loss: 0.2546 - accuracy: 0.9029 - auc: 0.9601 - val_loss: 0.2003 - val_accuracy: 0.9230 - val_auc: 0.9751
# Epoch 5/7
# 141/141 [==============================] - 24s 168ms/step - loss: 0.2371 - accuracy: 0.9079 - auc: 0.9656 - val_loss: 0.1852 - val_accuracy: 0.9350 - val_auc: 0.9770
# Epoch 6/7
# 141/141 [==============================] - 23s 166ms/step - loss: 0.1989 - accuracy: 0.9259 - auc: 0.9754 - val_loss: 0.2156 - val_accuracy: 0.9190 - val_auc: 0.9800
# Epoch 7/7
# 141/141 [==============================] - 23s 164ms/step - loss: 0.1719 - accuracy: 0.9361 - auc: 0.9814 - val_loss: 0.1795 - val_accuracy: 0.9360 - val_auc: 0.9834
# 1/1 [==============================] - 0s 32ms/step - loss: 0.5546 - accuracy: 0.7500 - auc: 0.9062
#
# Score for fold with orginal val dataset 3: loss of 0.5546085834503174; accuracy of 75.0%
#
# 32/32 [==============================] - 2s 14ms/step - loss: 0.1795 - accuracy: 0.9360 - auc: 0.9834
# Accuracy for fold 3: 93.59999895095825%
# Epoch 1/7
# 141/141 [==============================] - 25s 166ms/step - loss: 0.5502 - accuracy: 0.7059 - auc: 0.8221 - val_loss: 0.3702 - val_accuracy: 0.8470 - val_auc: 0.9186
# Epoch 2/7
# 141/141 [==============================] - 24s 169ms/step - loss: 0.3400 - accuracy: 0.8601 - auc: 0.9305 - val_loss: 0.2706 - val_accuracy: 0.8880 - val_auc: 0.9555
# Epoch 3/7
# 141/141 [==============================] - 24s 173ms/step - loss: 0.2756 - accuracy: 0.8946 - auc: 0.9537 - val_loss: 0.3069 - val_accuracy: 0.8820 - val_auc: 0.9635
# Epoch 4/7
# 141/141 [==============================] - 23s 160ms/step - loss: 0.2394 - accuracy: 0.9083 - auc: 0.9647 - val_loss: 0.2377 - val_accuracy: 0.9070 - val_auc: 0.9723
# Epoch 5/7
# 141/141 [==============================] - 25s 175ms/step - loss: 0.2092 - accuracy: 0.9207 - auc: 0.9729 - val_loss: 0.2226 - val_accuracy: 0.9110 - val_auc: 0.9727
# Epoch 6/7
# 141/141 [==============================] - 23s 161ms/step - loss: 0.1772 - accuracy: 0.9327 - auc: 0.9799 - val_loss: 0.2333 - val_accuracy: 0.9130 - val_auc: 0.9752
# Epoch 7/7
# 141/141 [==============================] - 23s 162ms/step - loss: 0.1679 - accuracy: 0.9391 - auc: 0.9823 - val_loss: 0.2263 - val_accuracy: 0.9190 - val_auc: 0.9784
# 1/1 [==============================] - 0s 16ms/step - loss: 0.7285 - accuracy: 0.6250 - auc: 0.9062
#
# Score for fold with orginal val dataset 4: loss of 0.7285425662994385; accuracy of 62.5%
#
# 32/32 [==============================] - 0s 11ms/step - loss: 0.2263 - accuracy: 0.9190 - auc: 0.9784
# Accuracy for fold 4: 91.90000295639038%
# Epoch 1/7
# 141/141 [==============================] - 26s 176ms/step - loss: 0.5101 - accuracy: 0.7360 - auc: 0.8458 - val_loss: 0.3174 - val_accuracy: 0.8730 - val_auc: 0.9399
# Epoch 2/7
# 141/141 [==============================] - 23s 165ms/step - loss: 0.3272 - accuracy: 0.8684 - auc: 0.9349 - val_loss: 0.2617 - val_accuracy: 0.8960 - val_auc: 0.9585
# Epoch 3/7
# 141/141 [==============================] - 25s 180ms/step - loss: 0.2652 - accuracy: 0.8971 - auc: 0.9572 - val_loss: 0.2560 - val_accuracy: 0.8980 - val_auc: 0.9674
# Epoch 4/7
# 141/141 [==============================] - 24s 169ms/step - loss: 0.2322 - accuracy: 0.9093 - auc: 0.9669 - val_loss: 0.2126 - val_accuracy: 0.9160 - val_auc: 0.9750
# Epoch 5/7
# 141/141 [==============================] - 25s 176ms/step - loss: 0.1996 - accuracy: 0.9260 - auc: 0.9751 - val_loss: 0.2189 - val_accuracy: 0.9130 - val_auc: 0.9759
# Epoch 6/7
# 141/141 [==============================] - 23s 166ms/step - loss: 0.1720 - accuracy: 0.9366 - auc: 0.9810 - val_loss: 0.1859 - val_accuracy: 0.9360 - val_auc: 0.9800
# Epoch 7/7
# 141/141 [==============================] - 25s 179ms/step - loss: 0.1514 - accuracy: 0.9446 - auc: 0.9854 - val_loss: 0.2095 - val_accuracy: 0.9070 - val_auc: 0.9784
# 1/1 [==============================] - 0s 31ms/step - loss: 0.9854 - accuracy: 0.6250 - auc: 0.6641
#
# Score for fold with orginal val dataset 5: loss of 0.9853959083557129; accuracy of 62.5%
#
# 32/32 [==============================] - 0s 13ms/step - loss: 0.2095 - accuracy: 0.9070 - auc: 0.9784
# Accuracy for fold 5: 90.70000052452087%
# Epoch 1/7
# 141/141 [==============================] - 24s 162ms/step - loss: 0.5414 - accuracy: 0.7089 - auc: 0.8229 - val_loss: 0.3530 - val_accuracy: 0.8450 - val_auc: 0.9396
# Epoch 2/7
# 141/141 [==============================] - 24s 168ms/step - loss: 0.3301 - accuracy: 0.8623 - auc: 0.9337 - val_loss: 0.2346 - val_accuracy: 0.9090 - val_auc: 0.9654
# Epoch 3/7
# 141/141 [==============================] - 24s 165ms/step - loss: 0.2707 - accuracy: 0.8929 - auc: 0.9551 - val_loss: 0.2346 - val_accuracy: 0.9150 - val_auc: 0.9691
# Epoch 4/7
# 141/141 [==============================] - 24s 174ms/step - loss: 0.2281 - accuracy: 0.9119 - auc: 0.9680 - val_loss: 0.2368 - val_accuracy: 0.9010 - val_auc: 0.9788
# Epoch 5/7
# 141/141 [==============================] - 26s 182ms/step - loss: 0.2007 - accuracy: 0.9233 - auc: 0.9754 - val_loss: 0.1629 - val_accuracy: 0.9310 - val_auc: 0.9828
# Epoch 6/7
# 141/141 [==============================] - 23s 166ms/step - loss: 0.1642 - accuracy: 0.9381 - auc: 0.9830 - val_loss: 0.1639 - val_accuracy: 0.9370 - val_auc: 0.9833
# Epoch 7/7
# 141/141 [==============================] - 24s 171ms/step - loss: 0.1483 - accuracy: 0.9486 - auc: 0.9853 - val_loss: 0.1898 - val_accuracy: 0.9230 - val_auc: 0.9839
# 1/1 [==============================] - 0s 30ms/step - loss: 0.5703 - accuracy: 0.6875 - auc: 0.7812
#
# Score for fold with orginal val dataset 6: loss of 0.5702724456787109; accuracy of 68.75%
#
# 32/32 [==============================] - 2s 56ms/step - loss: 0.1898 - accuracy: 0.9230 - auc: 0.9839
# Accuracy for fold 6: 92.29999780654907%
# Epoch 1/7
# 141/141 [==============================] - 25s 163ms/step - loss: 0.5338 - accuracy: 0.7178 - auc: 0.8325 - val_loss: 0.3979 - val_accuracy: 0.8230 - val_auc: 0.9246
# Epoch 2/7
# 141/141 [==============================] - 23s 166ms/step - loss: 0.3437 - accuracy: 0.8600 - auc: 0.9286 - val_loss: 0.2462 - val_accuracy: 0.8990 - val_auc: 0.9639
# Epoch 3/7
# 141/141 [==============================] - 23s 164ms/step - loss: 0.2587 - accuracy: 0.9018 - auc: 0.9590 - val_loss: 0.2421 - val_accuracy: 0.9110 - val_auc: 0.9709
# Epoch 4/7
# 141/141 [==============================] - 24s 169ms/step - loss: 0.2122 - accuracy: 0.9201 - auc: 0.9718 - val_loss: 0.1930 - val_accuracy: 0.9240 - val_auc: 0.9809
# Epoch 5/7
# 141/141 [==============================] - 25s 178ms/step - loss: 0.1867 - accuracy: 0.9304 - auc: 0.9782 - val_loss: 0.1564 - val_accuracy: 0.9460 - val_auc: 0.9839
# Epoch 6/7
# 141/141 [==============================] - 23s 163ms/step - loss: 0.1701 - accuracy: 0.9367 - auc: 0.9812 - val_loss: 0.1757 - val_accuracy: 0.9300 - val_auc: 0.9833
# Epoch 7/7
# 141/141 [==============================] - 23s 161ms/step - loss: 0.1432 - accuracy: 0.9502 - auc: 0.9863 - val_loss: 0.1467 - val_accuracy: 0.9470 - val_auc: 0.9875
# 1/1 [==============================] - 0s 35ms/step - loss: 0.8184 - accuracy: 0.5000 - auc: 0.7891
#
# Score for fold with orginal val dataset 7: loss of 0.8184439539909363; accuracy of 50.0%
#
# 32/32 [==============================] - 0s 10ms/step - loss: 0.1467 - accuracy: 0.9470 - auc: 0.9875
# Accuracy for fold 7: 94.70000267028809%
# Epoch 1/7
# 141/141 [==============================] - 25s 175ms/step - loss: 0.5393 - accuracy: 0.7116 - auc: 0.8296 - val_loss: 0.3404 - val_accuracy: 0.8580 - val_auc: 0.9323
# Epoch 2/7
# 141/141 [==============================] - 23s 162ms/step - loss: 0.3360 - accuracy: 0.8614 - auc: 0.9316 - val_loss: 0.2934 - val_accuracy: 0.8770 - val_auc: 0.9582
# Epoch 3/7
# 141/141 [==============================] - 23s 163ms/step - loss: 0.2634 - accuracy: 0.8956 - auc: 0.9577 - val_loss: 0.2201 - val_accuracy: 0.9200 - val_auc: 0.9715
# Epoch 4/7
# 141/141 [==============================] - 22s 160ms/step - loss: 0.2050 - accuracy: 0.9212 - auc: 0.9741 - val_loss: 0.2112 - val_accuracy: 0.9200 - val_auc: 0.9792
# Epoch 5/7
# 141/141 [==============================] - 24s 174ms/step - loss: 0.1770 - accuracy: 0.9336 - auc: 0.9803 - val_loss: 0.2119 - val_accuracy: 0.9270 - val_auc: 0.9774
# Epoch 6/7
# 141/141 [==============================] - 23s 160ms/step - loss: 0.1542 - accuracy: 0.9418 - auc: 0.9849 - val_loss: 0.1947 - val_accuracy: 0.9330 - val_auc: 0.9774
# Epoch 7/7
# 141/141 [==============================] - 22s 155ms/step - loss: 0.1414 - accuracy: 0.9466 - auc: 0.9873 - val_loss: 0.1649 - val_accuracy: 0.9400 - val_auc: 0.9848
# 1/1 [==============================] - 0s 31ms/step - loss: 1.0014 - accuracy: 0.5000 - auc: 0.7734
#
# Score for fold with orginal val dataset 8: loss of 1.0014280080795288; accuracy of 50.0%
#
# 32/32 [==============================] - 2s 49ms/step - loss: 0.1649 - accuracy: 0.9400 - auc: 0.9848
# Accuracy for fold 8: 93.99999976158142%
# Epoch 1/7
# 141/141 [==============================] - 24s 158ms/step - loss: 0.5112 - accuracy: 0.7340 - auc: 0.8483 - val_loss: 0.3138 - val_accuracy: 0.8660 - val_auc: 0.9452
# Epoch 2/7
# 141/141 [==============================] - 22s 158ms/step - loss: 0.3438 - accuracy: 0.8608 - auc: 0.9284 - val_loss: 0.2631 - val_accuracy: 0.8990 - val_auc: 0.9613
# Epoch 3/7
# 141/141 [==============================] - 24s 170ms/step - loss: 0.2483 - accuracy: 0.9058 - auc: 0.9619 - val_loss: 0.2015 - val_accuracy: 0.9210 - val_auc: 0.9771
# Epoch 4/7
# 141/141 [==============================] - 22s 158ms/step - loss: 0.2081 - accuracy: 0.9226 - auc: 0.9730 - val_loss: 0.1959 - val_accuracy: 0.9250 - val_auc: 0.9800
# Epoch 5/7
# 141/141 [==============================] - 23s 166ms/step - loss: 0.1777 - accuracy: 0.9356 - auc: 0.9799 - val_loss: 0.1757 - val_accuracy: 0.9300 - val_auc: 0.9838
# Epoch 6/7
# 141/141 [==============================] - 23s 161ms/step - loss: 0.1588 - accuracy: 0.9408 - auc: 0.9839 - val_loss: 0.1946 - val_accuracy: 0.9230 - val_auc: 0.9806
# Epoch 7/7
# 141/141 [==============================] - 24s 168ms/step - loss: 0.1426 - accuracy: 0.9463 - auc: 0.9869 - val_loss: 0.1454 - val_accuracy: 0.9480 - val_auc: 0.9865
# 1/1 [==============================] - 0s 38ms/step - loss: 0.6530 - accuracy: 0.6250 - auc: 0.6641
#
# Score for fold with orginal val dataset 9: loss of 0.6529867649078369; accuracy of 62.5%
#
# 32/32 [==============================] - 0s 11ms/step - loss: 0.1454 - accuracy: 0.9480 - auc: 0.9865
# Accuracy for fold 9: 94.80000138282776%
# Epoch 1/7
# 141/141 [==============================] - 23s 153ms/step - loss: 0.5661 - accuracy: 0.6687 - auc: 0.7958 - val_loss: 0.4873 - val_accuracy: 0.7800 - val_auc: 0.9173
# Epoch 2/7
# 141/141 [==============================] - 22s 159ms/step - loss: 0.3502 - accuracy: 0.8562 - auc: 0.9252 - val_loss: 0.2886 - val_accuracy: 0.8850 - val_auc: 0.9551
# Epoch 3/7
# 141/141 [==============================] - 24s 173ms/step - loss: 0.2906 - accuracy: 0.8867 - auc: 0.9488 - val_loss: 0.2668 - val_accuracy: 0.8980 - val_auc: 0.9591
# Epoch 4/7
# 141/141 [==============================] - 25s 174ms/step - loss: 0.2600 - accuracy: 0.9017 - auc: 0.9587 - val_loss: 0.2111 - val_accuracy: 0.9220 - val_auc: 0.9733
# Epoch 5/7
# 141/141 [==============================] - 23s 167ms/step - loss: 0.2112 - accuracy: 0.9209 - auc: 0.9721 - val_loss: 0.2056 - val_accuracy: 0.9190 - val_auc: 0.9734
# Epoch 6/7
# 141/141 [==============================] - 22s 158ms/step - loss: 0.1956 - accuracy: 0.9250 - auc: 0.9765 - val_loss: 0.1695 - val_accuracy: 0.9410 - val_auc: 0.9815
# Epoch 7/7
# 141/141 [==============================] - 22s 155ms/step - loss: 0.1713 - accuracy: 0.9380 - auc: 0.9815 - val_loss: 0.1646 - val_accuracy: 0.9430 - val_auc: 0.9822
# 1/1 [==============================] - 0s 47ms/step - loss: 1.1264 - accuracy: 0.6250 - auc: 0.6406
#
# Score for fold with orginal val dataset 10: loss of 1.12639582157135; accuracy of 62.5%
#
# 32/32 [==============================] - 2s 54ms/step - loss: 0.1646 - accuracy: 0.9430 - auc: 0.9822
# Accuracy for fold 10: 94.30000185966492%
#
# Average accuracy: 93.34000051021576%
#
# Average accuracy with orginal val: 62.5%

# %%
# Get accuracy scores for each fold (train and validation)
loss = []
acc = []
val_loss = []
val_acc = []

for history in histories:
    loss.append(np.mean(history["loss"]))
    acc.append(np.mean(history["accuracy"]))
    val_loss.append(np.mean(history["val_loss"]))
    val_acc.append(np.mean(history["val_accuracy"]))

# %%
# Plot loss and validation loss per fold
import matplotlib.pyplot as plt
plt.title('Losses')
plt.plot(range(1, len(loss)+1), loss, label='Loss')
plt.plot(range(1, len(val_loss)+1), val_loss, label='Validation loss')
plt.ylim(0.0, 1.0)
plt.xlabel('Fold')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Plot accuracies and validation accuracies per fold
import matplotlib.pyplot as plt

plt.title('Accuracies')
plt.plot(range(1, len(acc) + 1), acc, label='Accuracy')
plt.plot(range(1, len(val_acc) + 1), val_acc, label='Validation accuracy')
plt.ylim(0.0, 1.0)
plt.xlabel('Fold')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Train a final model with same parameters and save it
# Create an instance of ImageDataGenerator to generate your image data
datagen = ImageDataGenerator()
train_generator = datagen.flow(x=X_train, y=y_train, batch_size=batch_size)
valid_generator = datagen.flow(x=X_val, y=y_val, batch_size=batch_size)
model = create_model()
history = model.fit(train_generator, validation_data=valid_generator, epochs=epochs, verbose=1, callbacks=[early_stop])
model.save('cnn.h5')
# Out:
# Epoch 1/7
# 157/157 [==============================] - 26s 155ms/step - loss: 0.5064 - accuracy: 0.7403 - auc: 0.8510 - val_loss: 0.7270 - val_accuracy: 0.5000 - val_auc: 0.5781
# Epoch 2/7
# 157/157 [==============================] - 24s 155ms/step - loss: 0.3200 - accuracy: 0.8750 - auc: 0.9381 - val_loss: 0.7662 - val_accuracy: 0.5000 - val_auc: 0.6016
# Epoch 3/7
# 157/157 [==============================] - 23s 146ms/step - loss: 0.2655 - accuracy: 0.8926 - auc: 0.9570 - val_loss: 0.7020 - val_accuracy: 0.6250 - val_auc: 0.6250
# Epoch 4/7
# 157/157 [==============================] - 24s 155ms/step - loss: 0.2222 - accuracy: 0.9150 - auc: 0.9695 - val_loss: 0.6964 - val_accuracy: 0.6250 - val_auc: 0.7969
# Epoch 5/7
# 157/157 [==============================] - 25s 161ms/step - loss: 0.1896 - accuracy: 0.9301 - auc: 0.9772 - val_loss: 0.8247 - val_accuracy: 0.5000 - val_auc: 0.6406
# Epoch 6/7
# 157/157 [==============================] - 26s 169ms/step - loss: 0.1677 - accuracy: 0.9344 - auc: 0.9824 - val_loss: 0.5908 - val_accuracy: 0.7500 - val_auc: 0.7891
# Epoch 7/7
# 157/157 [==============================] - 32s 207ms/step - loss: 0.1597 - accuracy: 0.9393 - auc: 0.9837 - val_loss: 0.8584 - val_accuracy: 0.5625 - val_auc: 0.6406

# %%
# Plot val accuracy and val loss of the trained model
import matplotlib.pyplot as plt

plt.title('Accuracy vs Loss per Epoch')
plt.plot(range(1, len(history.history["val_accuracy"]) + 1), history.history["val_accuracy"], label='Accuracy')
plt.plot(range(1, len(history.history["val_loss"]) + 1), history.history["val_loss"], label='Loss')
plt.ylim(0.0, 1.0)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
# Make predictions on the test set
model = load_model('cnn.h5')

# %%
# Make predictions on the test set

y_pred_test = model.predict(X_test)
y_pred_test = np.where(y_pred_test >= 0.5, 1, 0)
# Out:
# 20/20 [==============================] - 2s 12ms/step

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Compute ROC curve and AUC score for the predictions
fpr, tpr, thresholds = roc_curve(y_test, y_pred_test)
roc_auc = auc(fpr, tpr)

# Plot ROC curve and show AUC score on the plot
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()

# %%
from sklearn.metrics import confusion_matrix

# Compute the confusion matrix for test set
cm = confusion_matrix(y_test, y_pred_test.flatten())
print(cm)
# Out:
# [[218  16]
#  [140 250]]

# %%
# Plot the confusion matrix
class_names = subfolders
import seaborn as sns

sns.heatmap(cm, annot=True, fmt='g', cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()

# %%
# Compute the classification report for test set
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred_test, target_names=class_names))
# Out:
#               precision    recall  f1-score   support
#
#       NORMAL       0.61      0.93      0.74       234
#    PNEUMONIA       0.94      0.64      0.76       390
#
#     accuracy                           0.75       624
#    macro avg       0.77      0.79      0.75       624
# weighted avg       0.82      0.75      0.75       624

# %%
import tensorflow as tf
import numpy as np
from IPython.display import Image, display
import matplotlib.cm as cm
from keras.utils import load_img, img_to_array, array_to_img


def get_img_array(img_path, size):
    # `img` is a PIL image of size 256x256
    img = load_img(img_path, target_size=size, grayscale=True)
    # `array` is a float32 Numpy array of shape (256, 256, 3)
    array = img_to_array(img)
    # We add a dimension to transform our array into a "batch"
    # of size (1, 299, 299, 3)
    array = np.expand_dims(array, axis=0)
    return array


def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    # First, we create a model that maps the input image to the activations
    # of the last conv layer as well as the output predictions
    grad_model = tf.keras.models.Model(
        [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output]
    )

    # Then, we compute the gradient of the top predicted class for our input image
    # with respect to the activations of the last conv layer
    with tf.GradientTape() as tape:
        last_conv_layer_output, preds = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]

    # This is the gradient of the output neuron (top predicted or chosen)
    # with regard to the output feature map of the last conv layer
    grads = tape.gradient(class_channel, last_conv_layer_output)

    # This is a vector where each entry is the mean intensity of the gradient
    # over a specific feature map channel
    #grads = tf.expand_dims(grads, axis=0)
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # We multiply each channel in the feature map array
    # by "how important this channel is" with regard to the top predicted class
    # then sum all the channels to obtain the heatmap class activation
    last_conv_layer_output = last_conv_layer_output[0]
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)

    # For visualization purpose, we will also normalize the heatmap between 0 & 1
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()


def generate_superimposed_gradcam(img_path, heatmap, alpha=0.4):
    # Load the original image
    img = load_img(img_path)
    img = img_to_array(img)

    # Rescale heatmap to a range 0-255
    heatmap = np.uint8(255 * heatmap)

    # Use jet colormap to colorize heatmap
    jet = cm.get_cmap("jet")

    # Use RGB values of the colormap
    jet_colors = jet(np.arange(256))[:, :3]
    jet_heatmap = jet_colors[heatmap]

    # Create an image with RGB colorized heatmap
    jet_heatmap = array_to_img(jet_heatmap)
    jet_heatmap = jet_heatmap.resize((img.shape[1], img.shape[0]))
    jet_heatmap = img_to_array(jet_heatmap)

    # Superimpose the heatmap on original image
    superimposed_img = jet_heatmap * alpha + img
    superimposed_img = array_to_img(superimposed_img)

    return superimposed_img


def display_heatmaps(img_path, heatmaps, superimposed=False):
    import matplotlib.pyplot as plt

    # Define the number of columns for the subplot grid
    n_cols = min(len(heatmaps), 5)

    # Calculate the number of rows based on the number of columns and total number of images
    n_rows = (len(heatmaps) - 1) // n_cols + 1

    # Create a figure with the desired size
    fig, axes = plt.subplots(n_rows, n_cols, figsize=(20, 4 * n_rows))

    for i, heatmap in enumerate(heatmaps):
        # Calculate the row and column index for this heatmap
        row = i // n_cols
        col = i % n_cols

        # Get the corresponding subplot
        ax = axes[row, col] if n_rows > 1 else axes[col]

        # Set the title of the subplot to the layer name
        ax.set_title(heatmap['layer_name'])

        if superimposed:
            superimposed_img = generate_superimposed_gradcam(img_path, heatmaps[i]["image"])
            # Plot the heatmap
            ax.imshow(superimposed_img)
        else:
            # Plot the heatmap
            ax.imshow(heatmaps[i]["image"], cmap='jet')

    # Hide the remaining subplots that are not used
    for i in range(len(heatmaps), n_rows * n_cols):
        # Calculate the row and column index for this subplot
        row = i // n_cols
        col = i % n_cols

        # Get the corresponding subplot
        ax = axes[row, col] if n_rows > 1 else axes[col]

        # Hide the subplot
        ax.axis('off')

    # Adjust the spacing between subplots
    fig.tight_layout()

    # Show the plot
    plt.show()

# %%
# Remove last layer's softmax
model.layers[-1].activation = None

# import os
# os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
# Print model summary to get last max pooling layer name
print(model.summary())
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_40 (Conv2D)          (None, 126, 126, 32)      320
#
#  max_pooling2d_40 (MaxPoolin  (None, 63, 63, 32)       0
#  g2D)
#
#  conv2d_41 (Conv2D)          (None, 61, 61, 64)        18496
#
#  max_pooling2d_41 (MaxPoolin  (None, 30, 30, 64)       0
#  g2D)
#
#  conv2d_42 (Conv2D)          (None, 28, 28, 128)       73856
#
#  max_pooling2d_42 (MaxPoolin  (None, 14, 14, 128)      0
#  g2D)
#
#  conv2d_43 (Conv2D)          (None, 12, 12, 256)       295168
#
#  max_pooling2d_43 (MaxPoolin  (None, 6, 6, 256)        0
#  g2D)
#
#  flatten_10 (Flatten)        (None, 9216)              0
#
#  dense_30 (Dense)            (None, 256)               2359552
#
#  dropout_20 (Dropout)        (None, 256)               0
#
#  dense_31 (Dense)            (None, 128)               32896
#
#  dropout_21 (Dropout)        (None, 128)               0
#
#  dense_32 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 2,780,417
# Trainable params: 2,780,417
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Heatmaps and Grad-CAM


import cv2
import matplotlib.pyplot as plt

images = [
    {
        "path": BASE + "val\\NORMAL\\NORMAL2-IM-1431-0001.jpeg"
    },
    {
        "path": BASE + "val\\PNEUMONIA\\person1946_bacteria_4875.jpeg"
    }
]

for image in images:
    image_temp = cv2.imread(image["path"])
    image_temp = cv2.cvtColor(image_temp, cv2.COLOR_RGB2GRAY)
    image_temp = cv2.resize(image_temp, (img_width, img_height))

    plt.imshow(image_temp, cmap=plt.cm.gray)
    plt.show()

    image["array"] = get_img_array(image["path"], size=(img_width, img_height))
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\keras\utils\image_utils.py:409: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn(

# %%
# Select last conv layer
last_conv_layer_name = "max_pooling2d_43"

# %%
# from cam import make_gradcam_heatmap, display_heatmaps

for image in images:
    heatmaps = []
    for layer in model.layers[:model.layers.index(model.get_layer(last_conv_layer_name)) + 1]:
        heatmap = make_gradcam_heatmap(image["array"], model, layer.name)
        heatmaps.append({
            "layer_name": layer.name,
            "image": heatmap
        })

    # Display heatmaps from all layers until the last max pooling layer
    display_heatmaps(image["path"], heatmaps)

    # Display the chosen image superimposed with heatmaps of each layer until the last max pooling layer
    display_heatmaps(image["path"], heatmaps, True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_17808\2206199731.py:64: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   jet = cm.get_cmap("jet")

# %%
# Predict
for image in images:
    pred = model.predict(image["array"].reshape(1, img_width, img_height, 1))
    print(pred)
    # Display predicted class
    print("Predicted class: {}".format(subfolders[int(pred[0][0])]))
# Out:
# 1/1 [==============================] - 0s 173ms/step
# [[1.]]
# Predicted class: PNEUMONIA
# 1/1 [==============================] - 0s 32ms/step
# [[1.]]
# Predicted class: PNEUMONIA
