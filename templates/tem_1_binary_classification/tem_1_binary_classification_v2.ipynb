# %% [markdown]
# # Template - Détection de la pneumonie à partir d'images radiologiques
# Le but de ce notebook est de servir de référence pour créer un terrain propice aux différentes expérimentations que nous allons faire. Dans ce notebook, nous avons une trame principale permettant de récupérer les données, les normaliser puis les augmenter, construire le modèle et entrainer ce dernier. A la suite de cet entrainement, plusieurs métriques permettent de déterminer l'efficacité et la fiabilité du modèle selon les données fournies.
#
# **Chacun des notebooks derivant de celui-ci se doivent d'expliciter en introduction l'intérêt de l'expérimentation, de décrire les différentes étapes de l'expérimentation et les résultats attendus. Les résultats obtenus doivent être présentés et commentés dans une conclusion qui accompagne les métriques.**
#
# ## Version 2
# Des modifications ont été apportés aux templates pour ajouter de la souplesse aux entrainements sur GPU :
# - Modification de la taille des images : de 256x256 à 128x128
# - Modification du batch size : de 100 à 64

# %%
# Check that GPU is used
import tensorflow as tf
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
from PIL import Image
import os
import numpy as np

# Define the folders where your data is stored
train_folder = 'train'
test_folder = 'test'
val_folder = 'val'

# Define the subfolders within each folder where the images are stored
subfolders = ['NORMAL', 'PNEUMONIA']

# Define the size of the images you want to resize your images to
img_width, img_height = 128, 128

# %%
# Function to load and resize images from a folder
def load_images_from_folder(folder, limit_per_subfolder=None):
    X = []
    y = []
    for subfolder in subfolders:
        folder_path = os.path.join(folder, subfolder)
        if limit_per_subfolder:
            # Get amount of random filenames from the folder
            filenames = np.random.choice(os.listdir(folder_path), limit_per_subfolder, replace=False)
        else:
            filenames = os.listdir(folder_path)
        for filename in filenames:
            img_path = os.path.join(folder_path, filename)
            img = Image.open(img_path)

            # Resize the image to the desired size
            img = img.resize((img_width, img_height))

            # Convert RGB image to grayscale
            img = img.convert('L')

            # Convert the image to a NumPy array and append it to X
            img = np.array(img)
            X.append(img)

            # Append the corresponding label to y
            y.append(subfolders.index(subfolder))

    X = np.array(X)
    y = np.array(y)
    return X, y

# %%
# Generate augmented for the training set
from common.data_augmentation import generate_augmented_images
generate_augmented_images(train_folder, 'NORMAL', image_size=(img_width, img_height))
generate_augmented_images(train_folder, 'PNEUMONIA', image_size=(img_width, img_height))
# Out:
# Found 1341 images belonging to 1 classes.
# Additional count of images to generate: 0
# Given NORMAL count: 1341
# Augmented NORMAL count: 5000
# Found 3874 images belonging to 1 classes.
# Additional count of images to generate: 0
# Given PNEUMONIA count: 3874
# Augmented PNEUMONIA count: 5000

# %%
# Load the training data
# Get min value between the number of normal images and the number of pneumonia images
train_folder = f"{train_folder}_augmented"
min_images = min(len(os.listdir(os.path.join(train_folder, subfolders[0]))), len(os.listdir(os.path.join(train_folder, subfolders[1]))))
X_train, y_train = load_images_from_folder(train_folder, min_images)

# Load the test data
X_test, y_test = load_images_from_folder(test_folder)

# Load the validation data
X_val, y_val = load_images_from_folder(val_folder)

# %%
# Make a matplot figure to show how many images are in each subfolder of train
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))
plt.bar(subfolders, [len(os.listdir(os.path.join(train_folder, subfolder))) for subfolder in subfolders])
plt.title('Number of images in each subfolder of train')
plt.show()

# %%
# Make a matplot figure to show how many images if each class in the training set
plt.figure(figsize=(10, 5))
plt.bar(subfolders, [len(y_train[y_train == i]) for i in range(len(subfolders))])
plt.title('Number of images in each class in the training set')
plt.show()

# %%
# Normalize the pixel values to be between 0 and 1
X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255
X_val = X_val.astype('float32') / 255

X_train = X_train.reshape(len(X_train), img_width, img_height, 1)
X_test = X_test.reshape(len(X_test), img_width, img_height, 1)
X_val = X_val.reshape(len(X_val), img_width, img_height, 1)

# %%
single_image = X_train[np.random.randint(len(X_train))]
print(single_image.shape)
plt.imshow(single_image, cmap='Greys')
# Out:
# (128, 128, 1)

# %%
# Define model metrics
from keras.metrics import AUC

metrics = [
    "accuracy",
    AUC(name='auc')
]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# Define the model architecture
def create_model():
    model = Sequential()

    model.add(Conv2D(filters=32, kernel_size=(3,3), input_shape=(img_width, img_height, 1), activation="relu"))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(filters=64, kernel_size=(3,3), activation="relu"))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(filters=128, kernel_size=(3,3), activation="relu"))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(filters=256, kernel_size=(3,3), activation="relu"))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Flatten())

    model.add(Dense(256, activation="relu"))
    model.add(Dropout(0.5))

    model.add(Dense(128, activation="relu"))
    model.add(Dropout(0.5))

    model.add(Dense(1, activation="sigmoid"))

    # compile the model
    model.compile(loss="binary_crossentropy", optimizer="adam", metrics=metrics)

    return model

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='loss', patience=3, restore_best_weights=True)

# %%
# Cross validation
from sklearn.model_selection import KFold
from keras.preprocessing.image import ImageDataGenerator

# Define the number of folds for cross-validation
n_splits = 10
epochs = 7
batch_size = 64

# Initialize KFold with the number of folds
kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)

# Define lists to store the evaluation scores for each fold
accuracy_scores = []
histories = []
models = []

# Iterate through each fold and train/evaluate the model
for train_idx, val_idx in kf.split(X_train, y_train):
    # Split the data into training and validation sets for this fold
    X_train_fold, y_train_fold = X_train[train_idx], y_train[train_idx]
    X_val_fold, y_val_fold = X_train[val_idx], y_train[val_idx]

    # Create an instance of ImageDataGenerator to generate your image data
    datagen = ImageDataGenerator()

    # Create generators for training and validation data
    train_generator = datagen.flow(x=X_train_fold, y=y_train_fold, batch_size=batch_size)
    valid_generator = datagen.flow(x=X_val_fold, y=y_val_fold, batch_size=batch_size)

    # Create instance of the model for this fold and train it
    model = create_model()

    # Train your model on the training data for this fold
    history = model.fit(train_generator, validation_data=valid_generator, epochs=epochs, verbose=1, callbacks=[early_stop])
    histories.append(history.history)

    models.append(model)
# Out:
# Epoch 1/7
# 141/141 [==============================] - 7s 25ms/step - loss: 0.6282 - accuracy: 0.6217 - auc: 0.6940 - val_loss: 0.4357 - val_accuracy: 0.8350 - val_auc: 0.9080
# Epoch 2/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.3653 - accuracy: 0.8461 - auc: 0.9148 - val_loss: 0.2680 - val_accuracy: 0.8950 - val_auc: 0.9549
# Epoch 3/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.2549 - accuracy: 0.9020 - auc: 0.9579 - val_loss: 0.2423 - val_accuracy: 0.9000 - val_auc: 0.9699
# Epoch 4/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.2129 - accuracy: 0.9207 - auc: 0.9711 - val_loss: 0.2000 - val_accuracy: 0.9220 - val_auc: 0.9784
# Epoch 5/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.1868 - accuracy: 0.9310 - auc: 0.9779 - val_loss: 0.1762 - val_accuracy: 0.9370 - val_auc: 0.9807
# Epoch 6/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.1611 - accuracy: 0.9420 - auc: 0.9826 - val_loss: 0.1646 - val_accuracy: 0.9350 - val_auc: 0.9824
# Epoch 7/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.1522 - accuracy: 0.9459 - auc: 0.9845 - val_loss: 0.1630 - val_accuracy: 0.9410 - val_auc: 0.9841
# Epoch 1/7
# 141/141 [==============================] - 4s 22ms/step - loss: 0.6377 - accuracy: 0.6081 - auc: 0.7252 - val_loss: 0.5489 - val_accuracy: 0.7210 - val_auc: 0.8722
# Epoch 2/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.3979 - accuracy: 0.8244 - auc: 0.9021 - val_loss: 0.3229 - val_accuracy: 0.8660 - val_auc: 0.9384
# Epoch 3/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.3025 - accuracy: 0.8779 - auc: 0.9430 - val_loss: 0.3005 - val_accuracy: 0.8750 - val_auc: 0.9579
# Epoch 4/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.2483 - accuracy: 0.9047 - auc: 0.9611 - val_loss: 0.2444 - val_accuracy: 0.9050 - val_auc: 0.9633
# Epoch 5/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.2166 - accuracy: 0.9190 - auc: 0.9697 - val_loss: 0.2580 - val_accuracy: 0.8910 - val_auc: 0.9660
# Epoch 6/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.2114 - accuracy: 0.9211 - auc: 0.9713 - val_loss: 0.2328 - val_accuracy: 0.9130 - val_auc: 0.9720
# Epoch 7/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.1816 - accuracy: 0.9310 - auc: 0.9785 - val_loss: 0.2935 - val_accuracy: 0.8860 - val_auc: 0.9655
# Epoch 1/7
# 141/141 [==============================] - 4s 22ms/step - loss: 0.5684 - accuracy: 0.6703 - auc: 0.7845 - val_loss: 0.5199 - val_accuracy: 0.8200 - val_auc: 0.9171
# Epoch 2/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.3247 - accuracy: 0.8699 - auc: 0.9340 - val_loss: 0.2762 - val_accuracy: 0.8900 - val_auc: 0.9518
# Epoch 3/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.2516 - accuracy: 0.9062 - auc: 0.9592 - val_loss: 0.2258 - val_accuracy: 0.9160 - val_auc: 0.9675
# Epoch 4/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.2131 - accuracy: 0.9234 - auc: 0.9702 - val_loss: 0.2278 - val_accuracy: 0.9200 - val_auc: 0.9693
# Epoch 5/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.1808 - accuracy: 0.9352 - auc: 0.9784 - val_loss: 0.2258 - val_accuracy: 0.9180 - val_auc: 0.9737
# Epoch 6/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.1582 - accuracy: 0.9434 - auc: 0.9835 - val_loss: 0.2005 - val_accuracy: 0.9300 - val_auc: 0.9773
# Epoch 7/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.1398 - accuracy: 0.9477 - auc: 0.9872 - val_loss: 0.2064 - val_accuracy: 0.9280 - val_auc: 0.9781
# Epoch 1/7
# 141/141 [==============================] - 3s 22ms/step - loss: 0.5417 - accuracy: 0.6968 - auc: 0.8217 - val_loss: 0.4107 - val_accuracy: 0.8270 - val_auc: 0.9183
# Epoch 2/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.3123 - accuracy: 0.8777 - auc: 0.9372 - val_loss: 0.2724 - val_accuracy: 0.8980 - val_auc: 0.9541
# Epoch 3/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.2392 - accuracy: 0.9073 - auc: 0.9635 - val_loss: 0.2898 - val_accuracy: 0.8930 - val_auc: 0.9549
# Epoch 4/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.2010 - accuracy: 0.9243 - auc: 0.9741 - val_loss: 0.2194 - val_accuracy: 0.9200 - val_auc: 0.9708
# Epoch 5/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.1678 - accuracy: 0.9409 - auc: 0.9814 - val_loss: 0.2083 - val_accuracy: 0.9310 - val_auc: 0.9739
# Epoch 6/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.1480 - accuracy: 0.9459 - auc: 0.9854 - val_loss: 0.1999 - val_accuracy: 0.9220 - val_auc: 0.9754
# Epoch 7/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.1310 - accuracy: 0.9544 - auc: 0.9883 - val_loss: 0.1865 - val_accuracy: 0.9350 - val_auc: 0.9791
# Epoch 1/7
# 141/141 [==============================] - 3s 22ms/step - loss: 0.5509 - accuracy: 0.6857 - auc: 0.8124 - val_loss: 0.3328 - val_accuracy: 0.8530 - val_auc: 0.9429
# Epoch 2/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.3267 - accuracy: 0.8658 - auc: 0.9327 - val_loss: 0.2993 - val_accuracy: 0.8700 - val_auc: 0.9641
# Epoch 3/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.2803 - accuracy: 0.8897 - auc: 0.9513 - val_loss: 0.2260 - val_accuracy: 0.9160 - val_auc: 0.9681
# Epoch 4/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.2396 - accuracy: 0.9076 - auc: 0.9635 - val_loss: 0.1836 - val_accuracy: 0.9320 - val_auc: 0.9780
# Epoch 5/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.2021 - accuracy: 0.9267 - auc: 0.9737 - val_loss: 0.1784 - val_accuracy: 0.9420 - val_auc: 0.9788
# Epoch 6/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.1836 - accuracy: 0.9296 - auc: 0.9783 - val_loss: 0.1731 - val_accuracy: 0.9360 - val_auc: 0.9821
# Epoch 7/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.1545 - accuracy: 0.9430 - auc: 0.9843 - val_loss: 0.1731 - val_accuracy: 0.9360 - val_auc: 0.9812
# Epoch 1/7
# 141/141 [==============================] - 3s 22ms/step - loss: 0.6329 - accuracy: 0.6268 - auc: 0.7403 - val_loss: 0.3994 - val_accuracy: 0.8420 - val_auc: 0.9231
# Epoch 2/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.3781 - accuracy: 0.8387 - auc: 0.9113 - val_loss: 0.1910 - val_accuracy: 0.9300 - val_auc: 0.9770
# Epoch 3/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.2763 - accuracy: 0.8929 - auc: 0.9525 - val_loss: 0.1712 - val_accuracy: 0.9460 - val_auc: 0.9824
# Epoch 4/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.2325 - accuracy: 0.9137 - auc: 0.9655 - val_loss: 0.1507 - val_accuracy: 0.9420 - val_auc: 0.9862
# Epoch 5/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.2021 - accuracy: 0.9252 - auc: 0.9734 - val_loss: 0.1709 - val_accuracy: 0.9370 - val_auc: 0.9889
# Epoch 6/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.1786 - accuracy: 0.9352 - auc: 0.9789 - val_loss: 0.1160 - val_accuracy: 0.9580 - val_auc: 0.9918
# Epoch 7/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.1591 - accuracy: 0.9414 - auc: 0.9834 - val_loss: 0.1210 - val_accuracy: 0.9540 - val_auc: 0.9907
# Epoch 1/7
# 141/141 [==============================] - 4s 22ms/step - loss: 0.5341 - accuracy: 0.7152 - auc: 0.8295 - val_loss: 0.3153 - val_accuracy: 0.8720 - val_auc: 0.9503
# Epoch 2/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.3088 - accuracy: 0.8738 - auc: 0.9395 - val_loss: 0.2346 - val_accuracy: 0.9090 - val_auc: 0.9704
# Epoch 3/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.2502 - accuracy: 0.9059 - auc: 0.9603 - val_loss: 0.2074 - val_accuracy: 0.9250 - val_auc: 0.9734
# Epoch 4/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.2221 - accuracy: 0.9183 - auc: 0.9688 - val_loss: 0.1997 - val_accuracy: 0.9300 - val_auc: 0.9760
# Epoch 5/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.1895 - accuracy: 0.9307 - auc: 0.9765 - val_loss: 0.1818 - val_accuracy: 0.9340 - val_auc: 0.9792
# Epoch 6/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.1638 - accuracy: 0.9421 - auc: 0.9820 - val_loss: 0.1615 - val_accuracy: 0.9390 - val_auc: 0.9841
# Epoch 7/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.1474 - accuracy: 0.9466 - auc: 0.9855 - val_loss: 0.1488 - val_accuracy: 0.9510 - val_auc: 0.9854
# Epoch 1/7
# 141/141 [==============================] - 4s 23ms/step - loss: 0.5417 - accuracy: 0.6951 - auc: 0.8217 - val_loss: 0.3910 - val_accuracy: 0.8240 - val_auc: 0.9295
# Epoch 2/7
# 141/141 [==============================] - 3s 22ms/step - loss: 0.2853 - accuracy: 0.8863 - auc: 0.9474 - val_loss: 0.2907 - val_accuracy: 0.8740 - val_auc: 0.9610
# Epoch 3/7
# 141/141 [==============================] - 3s 22ms/step - loss: 0.2398 - accuracy: 0.9098 - auc: 0.9624 - val_loss: 0.1942 - val_accuracy: 0.9340 - val_auc: 0.9754
# Epoch 4/7
# 141/141 [==============================] - 3s 22ms/step - loss: 0.2072 - accuracy: 0.9207 - auc: 0.9719 - val_loss: 0.2164 - val_accuracy: 0.9210 - val_auc: 0.9714
# Epoch 5/7
# 141/141 [==============================] - 3s 22ms/step - loss: 0.1772 - accuracy: 0.9348 - auc: 0.9789 - val_loss: 0.1929 - val_accuracy: 0.9340 - val_auc: 0.9751
# Epoch 6/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.1580 - accuracy: 0.9422 - auc: 0.9833 - val_loss: 0.1857 - val_accuracy: 0.9340 - val_auc: 0.9819
# Epoch 7/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.1394 - accuracy: 0.9510 - auc: 0.9867 - val_loss: 0.1890 - val_accuracy: 0.9350 - val_auc: 0.9800
# Epoch 1/7
# 141/141 [==============================] - 4s 22ms/step - loss: 0.5703 - accuracy: 0.6880 - auc: 0.8030 - val_loss: 0.3202 - val_accuracy: 0.8660 - val_auc: 0.9377
# Epoch 2/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.3442 - accuracy: 0.8608 - auc: 0.9261 - val_loss: 0.2352 - val_accuracy: 0.9020 - val_auc: 0.9650
# Epoch 3/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.2702 - accuracy: 0.8921 - auc: 0.9538 - val_loss: 0.2048 - val_accuracy: 0.9220 - val_auc: 0.9756
# Epoch 4/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.2212 - accuracy: 0.9147 - auc: 0.9691 - val_loss: 0.1985 - val_accuracy: 0.9280 - val_auc: 0.9761
# Epoch 5/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.1909 - accuracy: 0.9292 - auc: 0.9766 - val_loss: 0.1710 - val_accuracy: 0.9280 - val_auc: 0.9808
# Epoch 6/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.1685 - accuracy: 0.9377 - auc: 0.9815 - val_loss: 0.1597 - val_accuracy: 0.9360 - val_auc: 0.9842
# Epoch 7/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.1525 - accuracy: 0.9410 - auc: 0.9851 - val_loss: 0.1835 - val_accuracy: 0.9390 - val_auc: 0.9805
# Epoch 1/7
# 141/141 [==============================] - 3s 22ms/step - loss: 0.6323 - accuracy: 0.6362 - auc: 0.7421 - val_loss: 0.4822 - val_accuracy: 0.7680 - val_auc: 0.8716
# Epoch 2/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.3542 - accuracy: 0.8452 - auc: 0.9225 - val_loss: 0.2560 - val_accuracy: 0.9010 - val_auc: 0.9599
# Epoch 3/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.2428 - accuracy: 0.9077 - auc: 0.9630 - val_loss: 0.2708 - val_accuracy: 0.9000 - val_auc: 0.9657
# Epoch 4/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.2070 - accuracy: 0.9222 - auc: 0.9730 - val_loss: 0.2313 - val_accuracy: 0.9170 - val_auc: 0.9698
# Epoch 5/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.1837 - accuracy: 0.9342 - auc: 0.9776 - val_loss: 0.1810 - val_accuracy: 0.9440 - val_auc: 0.9778
# Epoch 6/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.1642 - accuracy: 0.9423 - auc: 0.9822 - val_loss: 0.1861 - val_accuracy: 0.9340 - val_auc: 0.9778
# Epoch 7/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.1421 - accuracy: 0.9481 - auc: 0.9866 - val_loss: 0.1864 - val_accuracy: 0.9340 - val_auc: 0.9805

# %%
# Get accuracy scores for each fold (train and validation)
loss = []
acc = []
val_loss = []
val_acc = []

for history in histories:
    loss.append(np.mean(history["loss"]))
    acc.append(np.mean(history["accuracy"]))
    val_loss.append(np.mean(history["val_loss"]))
    val_acc.append(np.mean(history["val_accuracy"]))

# %%
# Plot loss and validation loss per fold
import matplotlib.pyplot as plt
plt.title('Losses')
plt.plot(range(1, len(acc)+1), acc, label='Loss')
plt.plot(range(1, len(val_acc)+1), val_acc, label='Validation loss')
plt.ylim(0.0, 1.0)
plt.xlabel('Fold')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Plot accuracies and validation accuracies per fold
import matplotlib.pyplot as plt
plt.title('Accuracies')
plt.plot(range(1, len(acc)+1), acc, label='Accuracy')
plt.plot(range(1, len(val_acc)+1), val_acc, label='Validation accuracy')
plt.ylim(0.0, 1.0)
plt.xlabel('Fold')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Train a final model with same parameters and save it
train_generator = datagen.flow(x=X_train, y=y_train, batch_size=batch_size)
valid_generator = datagen.flow(x=X_val, y=y_val, batch_size=batch_size)
model = create_model()
history = model.fit(train_generator, validation_data=valid_generator, epochs=epochs, verbose=1, callbacks=[early_stop])
model.save('cnn.h5')
# Out:
# Epoch 1/7
# 157/157 [==============================] - 4s 22ms/step - loss: 0.6066 - accuracy: 0.6288 - auc: 0.7468 - val_loss: 0.3672 - val_accuracy: 0.8125 - val_auc: 0.9688
# Epoch 2/7
# 157/157 [==============================] - 3s 21ms/step - loss: 0.3465 - accuracy: 0.8544 - auc: 0.9257 - val_loss: 0.3516 - val_accuracy: 0.9375 - val_auc: 0.9688
# Epoch 3/7
# 157/157 [==============================] - 3s 21ms/step - loss: 0.2680 - accuracy: 0.8941 - auc: 0.9546 - val_loss: 0.2707 - val_accuracy: 0.8750 - val_auc: 0.9844
# Epoch 4/7
# 157/157 [==============================] - 3s 21ms/step - loss: 0.2337 - accuracy: 0.9117 - auc: 0.9653 - val_loss: 0.2488 - val_accuracy: 0.8750 - val_auc: 0.9844
# Epoch 5/7
# 157/157 [==============================] - 3s 21ms/step - loss: 0.1964 - accuracy: 0.9299 - auc: 0.9750 - val_loss: 0.2658 - val_accuracy: 0.9375 - val_auc: 0.9844
# Epoch 6/7
# 157/157 [==============================] - 3s 20ms/step - loss: 0.1692 - accuracy: 0.9404 - auc: 0.9809 - val_loss: 0.2052 - val_accuracy: 0.9375 - val_auc: 0.9922
# Epoch 7/7
# 157/157 [==============================] - 3s 20ms/step - loss: 0.1652 - accuracy: 0.9416 - auc: 0.9819 - val_loss: 0.2217 - val_accuracy: 0.9375 - val_auc: 0.9844

# %%
# Plot val accuracy and val loss of the trained model
import matplotlib.pyplot as plt
plt.title('Accuracy vs Loss per Epoch')
plt.plot(range(1, len(history.history["val_accuracy"])+1), history.history["val_accuracy"], label='Accuracy')
plt.plot(range(1, len(history.history["val_loss"])+1), history.history["val_loss"], label='Loss')
plt.ylim(0.0, 1.0)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Make predictions on the test set
y_pred_test = model.predict(X_test)
y_pred_test = np.where(y_pred_test >= 0.5, 1, 0)
# Out:
# 20/20 [==============================] - 0s 3ms/step

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Compute ROC curve and AUC score for the predictions
fpr, tpr, thresholds = roc_curve(y_test, y_pred_test)
roc_auc = auc(fpr, tpr)

# Plot ROC curve and show AUC score on the plot
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()

# %%
from sklearn.metrics import confusion_matrix
# Compute the confusion matrix for test set
cm = confusion_matrix(y_test, y_pred_test.flatten())
print(cm)
# Out:
# [[204  30]
#  [ 21 369]]

# %%
# Plot the confusion matrix
class_names = subfolders
import seaborn as sns
sns.heatmap(cm, annot=True, fmt='g', cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()

# %%
# Compute the classification report for test set
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred_test, target_names=class_names))
# Out:
#               precision    recall  f1-score   support
#
#       NORMAL       0.91      0.87      0.89       234
#    PNEUMONIA       0.92      0.95      0.94       390
#
#     accuracy                           0.92       624
#    macro avg       0.92      0.91      0.91       624
# weighted avg       0.92      0.92      0.92       624

# %%
# Heatmaps and Grad-CAM
from common.cam import get_img_array
import cv2
import matplotlib.pyplot as plt 

images = [
    {
        "path": "./val/NORMAL/NORMAL2-IM-1442-0001.jpeg"
    },
    {
        "path": "./val/PNEUMONIA/person1946_bacteria_4874.jpeg"
    }
]

for image in images:
    image_temp = cv2.imread(image["path"])
    image_temp = cv2.cvtColor(image_temp, cv2.COLOR_RGB2GRAY)
    image_temp = cv2.resize(image_temp, (img_width, img_height))

    plt.imshow(image_temp, cmap=plt.cm.gray)
    plt.show()
    
    image["array"] = get_img_array(image["path"], size=(img_width, img_height))
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\keras\utils\image_utils.py:409: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn(

# %%
# Remove last layer's softmax
model.layers[-1].activation = None

# import os
# os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
# Print model summary to get last max pooling layer name
print(model.summary())
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_40 (Conv2D)          (None, 126, 126, 32)      320
#
#  max_pooling2d_40 (MaxPoolin  (None, 63, 63, 32)       0
#  g2D)
#
#  conv2d_41 (Conv2D)          (None, 61, 61, 64)        18496
#
#  max_pooling2d_41 (MaxPoolin  (None, 30, 30, 64)       0
#  g2D)
#
#  conv2d_42 (Conv2D)          (None, 28, 28, 128)       73856
#
#  max_pooling2d_42 (MaxPoolin  (None, 14, 14, 128)      0
#  g2D)
#
#  conv2d_43 (Conv2D)          (None, 12, 12, 256)       295168
#
#  max_pooling2d_43 (MaxPoolin  (None, 6, 6, 256)        0
#  g2D)
#
#  flatten_10 (Flatten)        (None, 9216)              0
#
#  dense_30 (Dense)            (None, 256)               2359552
#
#  dropout_20 (Dropout)        (None, 256)               0
#
#  dense_31 (Dense)            (None, 128)               32896
#
#  dropout_21 (Dropout)        (None, 128)               0
#
#  dense_32 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 2,780,417
# Trainable params: 2,780,417
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Select last conv layer
last_conv_layer_name = "max_pooling2d_43"

# %%
from common.cam import make_gradcam_heatmap, display_heatmaps

for image in images:
    heatmaps = []
    for layer in model.layers[:model.layers.index(model.get_layer(last_conv_layer_name)) + 1]:
        heatmap = make_gradcam_heatmap(image["array"], model, layer.name)
        heatmaps.append({
            "layer_name": layer.name,
            "image": heatmap
        })

    # Display heatmaps from all layers until the last max pooling layer
    display_heatmaps(image["path"], heatmaps)

    # Display the chosen image superimposed with heatmaps of each layer until the last max pooling layer
    display_heatmaps(image["path"], heatmaps, True)

# %%
# Predict
for image in images:
    pred = model.predict(image["array"].reshape(1, img_width, img_height, 1))
    print(pred)
    # Display predicted class
    print("Predicted class: {}".format(subfolders[int(pred[0][0])]))
# Out:
# 1/1 [==============================] - 0s 310ms/step
# [[3.0443117e-35]]
# Predicted class: NORMAL
# 1/1 [==============================] - 0s 11ms/step
# [[1.]]
# Predicted class: PNEUMONIA
