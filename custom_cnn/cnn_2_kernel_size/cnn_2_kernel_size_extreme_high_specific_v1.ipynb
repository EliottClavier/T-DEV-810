# %% [markdown]
# # CNN Tuning - Taille du kernel - Extrême haut sur une couche spécifique
#
# ## Objectif
# L'objectif de ce notebook est de tester notre CNN en modifiant la taille des kernel par couches de convolutions avec des valeurs très hautes comparées à la référence.
#
# ## Hypothèses
# Les hypothèses quant aux résultats attendus sont les suivantes :
# - Une précision beaucoup plus faible que celle du CNN car les choix faits sont aléatoires
#
# ## Etapes de la démarche
# 1. Dans la méthode create_model(), changer la taille du kernel par couches de convolution
# 2. Tester le modèle sur le jeu de données
# 3. Calculer les métriques de performance
# 4. Comparer les résultats avec les résultats du CNN
#
# ## Conclusion
# Les résultats obtenus sont les suivants :
# - Une précision extremement faible de 0.73
# - Les heatmaps montrent que les choix du CNN ne sont pas pertinents par rapport à la référence
#
# On peut en conclure que la cohérence du kernel_size est importante pour la performance du CNN. Prendre une valeur trop haute d'entrée ne permet pas aux couches de convolutions de prendre de bonnes décisions dans les couches suivantes, même si le kernel size reste standard ou plus faible.

# %%
# Check that GPU is used
import tensorflow as tf
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
from PIL import Image
import os
import numpy as np

# Define the folders where your data is stored
train_folder = 'train'
test_folder = 'test'
val_folder = 'val'

# Define the subfolders within each folder where the images are stored
subfolders = ['NORMAL', 'PNEUMONIA']

# Define the size of the images you want to resize your images to
img_width, img_height = 128, 128

# %%
# Function to load and resize images from a folder
def load_images_from_folder(folder, limit_per_subfolder=None):
    X = []
    y = []
    for subfolder in subfolders:
        folder_path = os.path.join(folder, subfolder)
        if limit_per_subfolder:
            # Get amount of random filenames from the folder
            filenames = np.random.choice(os.listdir(folder_path), limit_per_subfolder, replace=False)
        else:
            filenames = os.listdir(folder_path)
        for filename in filenames:
            img_path = os.path.join(folder_path, filename)
            img = Image.open(img_path)

            # Resize the image to the desired size
            img = img.resize((img_width, img_height))

            # Convert RGB image to grayscale
            img = img.convert('L')

            # Convert the image to a NumPy array and append it to X
            img = np.array(img)
            X.append(img)

            # Append the corresponding label to y
            y.append(subfolders.index(subfolder))

    X = np.array(X)
    y = np.array(y)
    return X, y

# %%
# Generate augmented for the training set
from common.data_augmentation import generate_augmented_images
generate_augmented_images(train_folder, 'NORMAL', image_size=(img_width, img_height))
generate_augmented_images(train_folder, 'PNEUMONIA', image_size=(img_width, img_height))
# Out:
# Found 1341 images belonging to 1 classes.
# Additional count of images to generate: 0
# Given NORMAL count: 1341
# Augmented NORMAL count: 5000
# Found 3874 images belonging to 1 classes.
# Additional count of images to generate: 0
# Given PNEUMONIA count: 3874
# Augmented PNEUMONIA count: 5000

# %%
# Load the training data
# Get min value between the number of normal images and the number of pneumonia images
train_folder = f"{train_folder}_augmented"
min_images = min(len(os.listdir(os.path.join(train_folder, subfolders[0]))), len(os.listdir(os.path.join(train_folder, subfolders[1]))))
X_train, y_train = load_images_from_folder(train_folder, min_images)

# Load the test data
X_test, y_test = load_images_from_folder(test_folder)

# Load the validation data
X_val, y_val = load_images_from_folder(val_folder)

# %%
# Make a matplot figure to show how many images are in each subfolder of train
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))
plt.bar(subfolders, [len(os.listdir(os.path.join(train_folder, subfolder))) for subfolder in subfolders])
plt.title('Number of images in each subfolder of train')
plt.show()

# %%
# Make a matplot figure to show how many images if each class in the training set
plt.figure(figsize=(10, 5))
plt.bar(subfolders, [len(y_train[y_train == i]) for i in range(len(subfolders))])
plt.title('Number of images in each class in the training set')
plt.show()

# %%
# Normalize the pixel values to be between 0 and 1
X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255
X_val = X_val.astype('float32') / 255

X_train = X_train.reshape(len(X_train), img_width, img_height, 1)
X_test = X_test.reshape(len(X_test), img_width, img_height, 1)
X_val = X_val.reshape(len(X_val), img_width, img_height, 1)

# %%
single_image = X_train[np.random.randint(len(X_train))]
print(single_image.shape)
plt.imshow(single_image, cmap='Greys')
# Out:
# (128, 128, 1)

# %%
# Define model metrics
from keras.metrics import AUC

metrics = [
    "accuracy",
    AUC(name='auc')
]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# Define the model architecture
def create_model():
    model = Sequential()

    model.add(Conv2D(filters=32, kernel_size=(32,32), input_shape=(img_width, img_height, 1), activation="relu"))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(filters=64, kernel_size=(2,2), activation="relu"))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(filters=128, kernel_size=(2,2), activation="relu"))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(filters=256, kernel_size=(2,2), activation="relu"))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Flatten())

    model.add(Dense(256, activation="relu"))
    model.add(Dropout(0.5))

    model.add(Dense(128, activation="relu"))
    model.add(Dropout(0.5))

    model.add(Dense(1, activation="sigmoid"))

    # compile the model
    model.compile(loss="binary_crossentropy", optimizer="adam", metrics=metrics)

    return model

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='loss', patience=3, restore_best_weights=True)

# %%
# Cross validation
from sklearn.model_selection import KFold
from keras.preprocessing.image import ImageDataGenerator

# Define the number of folds for cross-validation
n_splits = 10
epochs = 7
batch_size = 64

# Initialize KFold with the number of folds
kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)

# Define lists to store the evaluation scores for each fold
accuracy_scores = []
histories = []
models = []

# Iterate through each fold and train/evaluate the model
for train_idx, val_idx in kf.split(X_train, y_train):
    # Split the data into training and validation sets for this fold
    X_train_fold, y_train_fold = X_train[train_idx], y_train[train_idx]
    X_val_fold, y_val_fold = X_train[val_idx], y_train[val_idx]

    # Create an instance of ImageDataGenerator to generate your image data
    datagen = ImageDataGenerator()

    # Create generators for training and validation data
    train_generator = datagen.flow(x=X_train_fold, y=y_train_fold, batch_size=batch_size)
    valid_generator = datagen.flow(x=X_val_fold, y=y_val_fold, batch_size=batch_size)

    # Create instance of the model for this fold and train it
    model = create_model()

    # Train your model on the training data for this fold
    history = model.fit(train_generator, validation_data=valid_generator, epochs=epochs, verbose=1, callbacks=[early_stop])
    histories.append(history.history)

    models.append(model)
# Out:
# Epoch 1/7
# 141/141 [==============================] - 9s 31ms/step - loss: 0.6949 - accuracy: 0.5006 - auc: 0.4974 - val_loss: 0.6933 - val_accuracy: 0.4920 - val_auc: 0.5000
# Epoch 2/7
# 141/141 [==============================] - 3s 20ms/step - loss: 0.6935 - accuracy: 0.4951 - auc: 0.4971 - val_loss: 0.6934 - val_accuracy: 0.4920 - val_auc: 0.5000
# Epoch 3/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.6935 - accuracy: 0.4923 - auc: 0.4868 - val_loss: 0.6931 - val_accuracy: 0.5080 - val_auc: 0.5000
# Epoch 4/7
# 141/141 [==============================] - 3s 20ms/step - loss: 0.6934 - accuracy: 0.4949 - auc: 0.4889 - val_loss: 0.6930 - val_accuracy: 0.5080 - val_auc: 0.5000
# Epoch 5/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.6932 - accuracy: 0.5027 - auc: 0.4999 - val_loss: 0.6930 - val_accuracy: 0.5080 - val_auc: 0.5000
# Epoch 6/7
# 141/141 [==============================] - 3s 20ms/step - loss: 0.6933 - accuracy: 0.4969 - auc: 0.4954 - val_loss: 0.6931 - val_accuracy: 0.5080 - val_auc: 0.5000
# Epoch 7/7
# 141/141 [==============================] - 3s 20ms/step - loss: 0.6934 - accuracy: 0.4897 - auc: 0.4830 - val_loss: 0.6932 - val_accuracy: 0.4920 - val_auc: 0.5000
# Epoch 1/7
# 141/141 [==============================] - 4s 24ms/step - loss: 0.6957 - accuracy: 0.5019 - auc: 0.5058 - val_loss: 0.6914 - val_accuracy: 0.5140 - val_auc: 0.5292
# Epoch 2/7
# 141/141 [==============================] - 3s 20ms/step - loss: 0.6759 - accuracy: 0.6002 - auc: 0.6211 - val_loss: 0.6645 - val_accuracy: 0.6170 - val_auc: 0.6456
# Epoch 3/7
# 141/141 [==============================] - 3s 20ms/step - loss: 0.6472 - accuracy: 0.6522 - auc: 0.6714 - val_loss: 0.6311 - val_accuracy: 0.6580 - val_auc: 0.6876
# Epoch 4/7
# 141/141 [==============================] - 3s 20ms/step - loss: 0.6223 - accuracy: 0.6724 - auc: 0.6967 - val_loss: 0.6226 - val_accuracy: 0.6630 - val_auc: 0.7057
# Epoch 5/7
# 141/141 [==============================] - 3s 20ms/step - loss: 0.6078 - accuracy: 0.6827 - auc: 0.7156 - val_loss: 0.6279 - val_accuracy: 0.6620 - val_auc: 0.7050
# Epoch 6/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.5926 - accuracy: 0.7017 - auc: 0.7343 - val_loss: 0.6075 - val_accuracy: 0.6800 - val_auc: 0.7306
# Epoch 7/7
# 141/141 [==============================] - 3s 20ms/step - loss: 0.5798 - accuracy: 0.7099 - auc: 0.7438 - val_loss: 0.5991 - val_accuracy: 0.6840 - val_auc: 0.7414
# Epoch 1/7
# 141/141 [==============================] - 4s 21ms/step - loss: 0.6939 - accuracy: 0.4953 - auc: 0.5289 - val_loss: 0.6934 - val_accuracy: 0.4750 - val_auc: 0.5000
# Epoch 2/7
# 141/141 [==============================] - 3s 20ms/step - loss: 0.6933 - accuracy: 0.5031 - auc: 0.4889 - val_loss: 0.6939 - val_accuracy: 0.4750 - val_auc: 0.5000
# Epoch 3/7
# 141/141 [==============================] - 3s 20ms/step - loss: 0.6933 - accuracy: 0.4928 - auc: 0.4874 - val_loss: 0.6933 - val_accuracy: 0.4750 - val_auc: 0.5000
# Epoch 4/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.6932 - accuracy: 0.4989 - auc: 0.4972 - val_loss: 0.6938 - val_accuracy: 0.4750 - val_auc: 0.5000
# Epoch 5/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.6931 - accuracy: 0.5001 - auc: 0.5037 - val_loss: 0.6939 - val_accuracy: 0.4750 - val_auc: 0.5000
# Epoch 6/7
# 141/141 [==============================] - 3s 19ms/step - loss: 0.6933 - accuracy: 0.4944 - auc: 0.4985 - val_loss: 0.6942 - val_accuracy: 0.4750 - val_auc: 0.5000
# Epoch 7/7
# 141/141 [==============================] - 3s 18ms/step - loss: 0.6933 - accuracy: 0.4977 - auc: 0.4965 - val_loss: 0.6938 - val_accuracy: 0.4750 - val_auc: 0.5000
# Epoch 1/7
# 141/141 [==============================] - 3s 18ms/step - loss: 0.6939 - accuracy: 0.5163 - auc: 0.5161 - val_loss: 0.6865 - val_accuracy: 0.5210 - val_auc: 0.5990
# Epoch 2/7
# 141/141 [==============================] - 2s 18ms/step - loss: 0.6685 - accuracy: 0.5846 - auc: 0.6215 - val_loss: 0.5546 - val_accuracy: 0.7530 - val_auc: 0.8361
# Epoch 3/7
# 141/141 [==============================] - 2s 17ms/step - loss: 0.4929 - accuracy: 0.7677 - auc: 0.8416 - val_loss: 0.4007 - val_accuracy: 0.8150 - val_auc: 0.9231
# Epoch 4/7
# 141/141 [==============================] - 3s 20ms/step - loss: 0.3914 - accuracy: 0.8304 - auc: 0.9042 - val_loss: 0.4073 - val_accuracy: 0.8060 - val_auc: 0.9291
# Epoch 5/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.3438 - accuracy: 0.8554 - auc: 0.9264 - val_loss: 0.3161 - val_accuracy: 0.8550 - val_auc: 0.9426
# Epoch 6/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.3131 - accuracy: 0.8699 - auc: 0.9390 - val_loss: 0.2977 - val_accuracy: 0.8690 - val_auc: 0.9511
# Epoch 7/7
# 141/141 [==============================] - 3s 20ms/step - loss: 0.2956 - accuracy: 0.8782 - auc: 0.9453 - val_loss: 0.2740 - val_accuracy: 0.8800 - val_auc: 0.9559
# Epoch 1/7
# 141/141 [==============================] - 4s 23ms/step - loss: 0.6946 - accuracy: 0.4924 - auc: 0.5712 - val_loss: 0.6932 - val_accuracy: 0.4940 - val_auc: 0.5000
# Epoch 2/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.6933 - accuracy: 0.5030 - auc: 0.4998 - val_loss: 0.6934 - val_accuracy: 0.4940 - val_auc: 0.5000
# Epoch 3/7
# 141/141 [==============================] - 3s 20ms/step - loss: 0.6934 - accuracy: 0.4933 - auc: 0.4856 - val_loss: 0.6933 - val_accuracy: 0.4940 - val_auc: 0.5000
# Epoch 4/7
# 141/141 [==============================] - 3s 20ms/step - loss: 0.6932 - accuracy: 0.4986 - auc: 0.5027 - val_loss: 0.6933 - val_accuracy: 0.4940 - val_auc: 0.5000
# Epoch 5/7
# 141/141 [==============================] - 3s 20ms/step - loss: 0.6933 - accuracy: 0.4993 - auc: 0.4984 - val_loss: 0.6931 - val_accuracy: 0.5060 - val_auc: 0.5000
# Epoch 6/7
# 141/141 [==============================] - 3s 20ms/step - loss: 0.6932 - accuracy: 0.5004 - auc: 0.4986 - val_loss: 0.6931 - val_accuracy: 0.5060 - val_auc: 0.5000
# Epoch 7/7
# 141/141 [==============================] - 3s 20ms/step - loss: 0.6932 - accuracy: 0.4957 - auc: 0.5027 - val_loss: 0.6931 - val_accuracy: 0.5060 - val_auc: 0.5000
# Epoch 1/7
# 141/141 [==============================] - 4s 22ms/step - loss: 0.6941 - accuracy: 0.5059 - auc: 0.5084 - val_loss: 0.6937 - val_accuracy: 0.4980 - val_auc: 0.5000
# Epoch 2/7
# 141/141 [==============================] - 3s 20ms/step - loss: 0.6935 - accuracy: 0.4950 - auc: 0.4935 - val_loss: 0.6932 - val_accuracy: 0.4980 - val_auc: 0.5000
# Epoch 3/7
# 141/141 [==============================] - 3s 20ms/step - loss: 0.6924 - accuracy: 0.5017 - auc: 0.5086 - val_loss: 0.6898 - val_accuracy: 0.5220 - val_auc: 0.5203
# Epoch 4/7
# 141/141 [==============================] - 3s 22ms/step - loss: 0.6933 - accuracy: 0.4923 - auc: 0.4886 - val_loss: 0.6932 - val_accuracy: 0.5020 - val_auc: 0.5000
# Epoch 5/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.6934 - accuracy: 0.4924 - auc: 0.4862 - val_loss: 0.6932 - val_accuracy: 0.4980 - val_auc: 0.5000
# Epoch 6/7
# 141/141 [==============================] - 3s 20ms/step - loss: 0.6932 - accuracy: 0.5001 - auc: 0.5067 - val_loss: 0.6931 - val_accuracy: 0.5020 - val_auc: 0.5000
# Epoch 1/7
# 141/141 [==============================] - 4s 21ms/step - loss: 0.6940 - accuracy: 0.4991 - auc: 0.5001 - val_loss: 0.6933 - val_accuracy: 0.4920 - val_auc: 0.5000
# Epoch 2/7
# 141/141 [==============================] - 3s 20ms/step - loss: 0.6933 - accuracy: 0.4981 - auc: 0.5025 - val_loss: 0.6931 - val_accuracy: 0.5080 - val_auc: 0.5000
# Epoch 3/7
# 141/141 [==============================] - 3s 20ms/step - loss: 0.6934 - accuracy: 0.4841 - auc: 0.4913 - val_loss: 0.6931 - val_accuracy: 0.5080 - val_auc: 0.5000
# Epoch 4/7
# 141/141 [==============================] - 3s 20ms/step - loss: 0.6933 - accuracy: 0.5027 - auc: 0.5016 - val_loss: 0.6931 - val_accuracy: 0.5080 - val_auc: 0.5000
# Epoch 5/7
# 141/141 [==============================] - 3s 20ms/step - loss: 0.6932 - accuracy: 0.5054 - auc: 0.5032 - val_loss: 0.6936 - val_accuracy: 0.4920 - val_auc: 0.5000
# Epoch 6/7
# 141/141 [==============================] - 3s 20ms/step - loss: 0.6934 - accuracy: 0.4968 - auc: 0.4902 - val_loss: 0.6932 - val_accuracy: 0.4920 - val_auc: 0.5000
# Epoch 7/7
# 141/141 [==============================] - 3s 19ms/step - loss: 0.6934 - accuracy: 0.4972 - auc: 0.4974 - val_loss: 0.6931 - val_accuracy: 0.5080 - val_auc: 0.5000
# Epoch 1/7
# 141/141 [==============================] - 4s 23ms/step - loss: 0.6904 - accuracy: 0.5172 - auc: 0.5296 - val_loss: 0.6432 - val_accuracy: 0.6900 - val_auc: 0.8107
# Epoch 2/7
# 141/141 [==============================] - 3s 20ms/step - loss: 0.5536 - accuracy: 0.7332 - auc: 0.7957 - val_loss: 0.4794 - val_accuracy: 0.7620 - val_auc: 0.8786
# Epoch 3/7
# 141/141 [==============================] - 3s 20ms/step - loss: 0.4218 - accuracy: 0.8100 - auc: 0.8887 - val_loss: 0.3448 - val_accuracy: 0.8470 - val_auc: 0.9295
# Epoch 4/7
# 141/141 [==============================] - 3s 20ms/step - loss: 0.3337 - accuracy: 0.8541 - auc: 0.9300 - val_loss: 0.2753 - val_accuracy: 0.8980 - val_auc: 0.9530
# Epoch 5/7
# 141/141 [==============================] - 3s 20ms/step - loss: 0.3243 - accuracy: 0.8616 - auc: 0.9350 - val_loss: 0.2826 - val_accuracy: 0.8750 - val_auc: 0.9624
# Epoch 6/7
# 141/141 [==============================] - 3s 20ms/step - loss: 0.2589 - accuracy: 0.8961 - auc: 0.9577 - val_loss: 0.2227 - val_accuracy: 0.9070 - val_auc: 0.9679
# Epoch 7/7
# 141/141 [==============================] - 3s 20ms/step - loss: 0.2266 - accuracy: 0.9123 - auc: 0.9678 - val_loss: 0.2299 - val_accuracy: 0.9080 - val_auc: 0.9706
# Epoch 1/7
# 141/141 [==============================] - 4s 22ms/step - loss: 0.6944 - accuracy: 0.4960 - auc: 0.5763 - val_loss: 0.6934 - val_accuracy: 0.4990 - val_auc: 0.5000
# Epoch 2/7
# 141/141 [==============================] - 3s 20ms/step - loss: 0.6932 - accuracy: 0.5036 - auc: 0.5059 - val_loss: 0.6932 - val_accuracy: 0.4990 - val_auc: 0.5000
# Epoch 3/7
# 141/141 [==============================] - 3s 21ms/step - loss: 0.6934 - accuracy: 0.4940 - auc: 0.4941 - val_loss: 0.6931 - val_accuracy: 0.5010 - val_auc: 0.5000
# Epoch 4/7
# 141/141 [==============================] - 3s 22ms/step - loss: 0.6934 - accuracy: 0.4944 - auc: 0.4936 - val_loss: 0.6932 - val_accuracy: 0.4990 - val_auc: 0.5000
# Epoch 5/7
# 141/141 [==============================] - 3s 19ms/step - loss: 0.6932 - accuracy: 0.4957 - auc: 0.5031 - val_loss: 0.6932 - val_accuracy: 0.4990 - val_auc: 0.5000
# Epoch 1/7
# 141/141 [==============================] - 3s 18ms/step - loss: 0.6950 - accuracy: 0.4929 - auc: 0.4921 - val_loss: 0.6934 - val_accuracy: 0.4810 - val_auc: 0.5000
# Epoch 2/7
# 141/141 [==============================] - 2s 17ms/step - loss: 0.6933 - accuracy: 0.4979 - auc: 0.4960 - val_loss: 0.6943 - val_accuracy: 0.4810 - val_auc: 0.5000
# Epoch 3/7
# 141/141 [==============================] - 2s 17ms/step - loss: 0.6933 - accuracy: 0.4967 - auc: 0.4967 - val_loss: 0.6940 - val_accuracy: 0.4810 - val_auc: 0.5000
# Epoch 4/7
# 141/141 [==============================] - 2s 17ms/step - loss: 0.6935 - accuracy: 0.4967 - auc: 0.4987 - val_loss: 0.6938 - val_accuracy: 0.4810 - val_auc: 0.5000
# Epoch 5/7
# 141/141 [==============================] - 2s 17ms/step - loss: 0.6931 - accuracy: 0.5048 - auc: 0.5031 - val_loss: 0.6939 - val_accuracy: 0.4810 - val_auc: 0.5000
# Epoch 6/7
# 141/141 [==============================] - 3s 19ms/step - loss: 0.6933 - accuracy: 0.4964 - auc: 0.4982 - val_loss: 0.6936 - val_accuracy: 0.4810 - val_auc: 0.5000
# Epoch 7/7
# 141/141 [==============================] - 3s 20ms/step - loss: 0.6934 - accuracy: 0.4941 - auc: 0.4932 - val_loss: 0.6933 - val_accuracy: 0.4810 - val_auc: 0.5000

# %%
# Get accuracy scores for each fold (train and validation)
loss = []
acc = []
val_loss = []
val_acc = []

for history in histories:
    loss.append(np.mean(history["loss"]))
    acc.append(np.mean(history["accuracy"]))
    val_loss.append(np.mean(history["val_loss"]))
    val_acc.append(np.mean(history["val_accuracy"]))

# %%
# Plot loss and validation loss per fold
import matplotlib.pyplot as plt
plt.title('Losses')
plt.plot(range(1, len(acc)+1), acc, label='Loss')
plt.plot(range(1, len(val_acc)+1), val_acc, label='Validation loss')
plt.ylim(0.0, 1.0)
plt.xlabel('Fold')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Plot accuracies and validation accuracies per fold
import matplotlib.pyplot as plt
plt.title('Accuracies')
plt.plot(range(1, len(acc)+1), acc, label='Accuracy')
plt.plot(range(1, len(val_acc)+1), val_acc, label='Validation accuracy')
plt.ylim(0.0, 1.0)
plt.xlabel('Fold')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Train a final model with same parameters and save it
train_generator = datagen.flow(x=X_train, y=y_train, batch_size=batch_size)
valid_generator = datagen.flow(x=X_val, y=y_val, batch_size=batch_size)
model = create_model()
history = model.fit(train_generator, validation_data=valid_generator, epochs=epochs, verbose=1, callbacks=[early_stop])
model.save('cnn.h5')
# Out:
# Epoch 1/7
# 157/157 [==============================] - 5s 26ms/step - loss: 0.6850 - accuracy: 0.5401 - auc: 0.5687 - val_loss: 0.6679 - val_accuracy: 0.6250 - val_auc: 0.6250
# Epoch 2/7
# 157/157 [==============================] - 3s 19ms/step - loss: 0.6339 - accuracy: 0.6732 - auc: 0.6997 - val_loss: 0.5838 - val_accuracy: 0.7500 - val_auc: 0.7344
# Epoch 3/7
# 157/157 [==============================] - 3s 19ms/step - loss: 0.5959 - accuracy: 0.6998 - auc: 0.7490 - val_loss: 0.6227 - val_accuracy: 0.5625 - val_auc: 0.8203
# Epoch 4/7
# 157/157 [==============================] - 3s 19ms/step - loss: 0.5758 - accuracy: 0.7210 - auc: 0.7703 - val_loss: 0.6728 - val_accuracy: 0.6250 - val_auc: 0.7188
# Epoch 5/7
# 157/157 [==============================] - 3s 19ms/step - loss: 0.5476 - accuracy: 0.7430 - auc: 0.7950 - val_loss: 0.6786 - val_accuracy: 0.5000 - val_auc: 0.6875
# Epoch 6/7
# 157/157 [==============================] - 3s 19ms/step - loss: 0.5101 - accuracy: 0.7682 - auc: 0.8289 - val_loss: 0.5489 - val_accuracy: 0.6875 - val_auc: 0.8047
# Epoch 7/7
# 157/157 [==============================] - 3s 19ms/step - loss: 0.4885 - accuracy: 0.7826 - auc: 0.8448 - val_loss: 0.6275 - val_accuracy: 0.6250 - val_auc: 0.7188

# %%
# Plot val accuracy and val loss of the trained model
import matplotlib.pyplot as plt
plt.title('Accuracy vs Loss per Epoch')
plt.plot(range(1, len(history.history["val_accuracy"])+1), history.history["val_accuracy"], label='Accuracy')
plt.plot(range(1, len(history.history["val_loss"])+1), history.history["val_loss"], label='Loss')
plt.ylim(0.0, 1.0)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Make predictions on the test set
y_pred_test = model.predict(X_test)
y_pred_test = np.where(y_pred_test >= 0.5, 1, 0)
# Out:
# 20/20 [==============================] - 1s 4ms/step

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Compute ROC curve and AUC score for the predictions
fpr, tpr, thresholds = roc_curve(y_test, y_pred_test)
roc_auc = auc(fpr, tpr)

# Plot ROC curve and show AUC score on the plot
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()

# %%
from sklearn.metrics import confusion_matrix
# Compute the confusion matrix for test set
cm = confusion_matrix(y_test, y_pred_test.flatten())
print(cm)
# Out:
# [[149  85]
#  [ 83 307]]

# %%
# Plot the confusion matrix
class_names = subfolders
import seaborn as sns
sns.heatmap(cm, annot=True, fmt='g', cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()

# %%
# Compute the classification report for test set
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred_test, target_names=class_names))
# Out:
#               precision    recall  f1-score   support
#
#       NORMAL       0.64      0.64      0.64       234
#    PNEUMONIA       0.78      0.79      0.79       390
#
#     accuracy                           0.73       624
#    macro avg       0.71      0.71      0.71       624
# weighted avg       0.73      0.73      0.73       624

# %%
# Heatmaps and Grad-CAM
from common.cam import get_img_array
import cv2
import matplotlib.pyplot as plt 

images = [
    {
        "path": "./val/NORMAL/NORMAL2-IM-1442-0001.jpeg"
    },
    {
        "path": "./val/PNEUMONIA/person1946_bacteria_4874.jpeg"
    }
]

for image in images:
    image_temp = cv2.imread(image["path"])
    image_temp = cv2.cvtColor(image_temp, cv2.COLOR_RGB2GRAY)
    image_temp = cv2.resize(image_temp, (img_width, img_height))

    plt.imshow(image_temp, cmap=plt.cm.gray)
    plt.show()
    
    image["array"] = get_img_array(image["path"], size=(img_width, img_height))
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\keras\utils\image_utils.py:409: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn(

# %%
# Remove last layer's softmax
model.layers[-1].activation = None

# import os
# os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
# Print model summary to get last max pooling layer name
print(model.summary())
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_40 (Conv2D)          (None, 97, 97, 32)        32800
#
#  max_pooling2d_40 (MaxPoolin  (None, 48, 48, 32)       0
#  g2D)
#
#  conv2d_41 (Conv2D)          (None, 47, 47, 64)        8256
#
#  max_pooling2d_41 (MaxPoolin  (None, 23, 23, 64)       0
#  g2D)
#
#  conv2d_42 (Conv2D)          (None, 22, 22, 128)       32896
#
#  max_pooling2d_42 (MaxPoolin  (None, 11, 11, 128)      0
#  g2D)
#
#  conv2d_43 (Conv2D)          (None, 10, 10, 256)       131328
#
#  max_pooling2d_43 (MaxPoolin  (None, 5, 5, 256)        0
#  g2D)
#
#  flatten_10 (Flatten)        (None, 6400)              0
#
#  dense_30 (Dense)            (None, 256)               1638656
#
#  dropout_20 (Dropout)        (None, 256)               0
#
#  dense_31 (Dense)            (None, 128)               32896
#
#  dropout_21 (Dropout)        (None, 128)               0
#
#  dense_32 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 1,876,961
# Trainable params: 1,876,961
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Select last conv layer
last_conv_layer_name = "max_pooling2d_43"

# %%
from common.cam import make_gradcam_heatmap, display_heatmaps

for image in images:
    heatmaps = []
    for layer in model.layers[:model.layers.index(model.get_layer(last_conv_layer_name)) + 1]:
        heatmap = make_gradcam_heatmap(image["array"], model, layer.name)
        heatmaps.append({
            "layer_name": layer.name,
            "image": heatmap
        })

    # Display heatmaps from all layers until the last max pooling layer
    display_heatmaps(image["path"], heatmaps)

    # Display the chosen image superimposed with heatmaps of each layer until the last max pooling layer
    display_heatmaps(image["path"], heatmaps, True)

# %%
# Predict
for image in images:
    pred = model.predict(image["array"].reshape(1, img_width, img_height, 1))
    print(pred)
    # Display predicted class
    print("Predicted class: {}".format(subfolders[int(pred[0][0])]))
# Out:
# 1/1 [==============================] - 1s 808ms/step
# [[0.]]
# Predicted class: NORMAL
# 1/1 [==============================] - 0s 20ms/step
# [[2.9009415e-14]]
# Predicted class: NORMAL
