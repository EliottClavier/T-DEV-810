# %% [markdown]
# # CNN Tuning - Nombre de filtres - Extrême haut, altération des couches cachées
#
# ## Objectif
# L'objectif de ce notebook est de tester notre CNN en augmentant la taille du pool_size pour chaque couche de pooling.
#
# ## Hypothèses
# Les hypothèses quant aux résultats attendus sont les suivantes :
# - Une précision plus faible que celle du CNN du template. Le pool size va plus rapidement réduire la taille de l'image, ce qui va faire perdre de l'information au modèle.
#
# ## Etapes de la démarche
# 1. Dans la méthode create_model(), changer le pool size de chaque couche de Max Pooling
# 2. Tester le modèle sur le jeu de données
# 3. Calculer les métriques de performance
# 4. Comparer les résultats avec les résultats du CNN
#
# ## Conclusion
# Les résultats obtenus sont les suivants :
# - Une précision légèrement plus faible que celle du CNN du template (0.90 contre 0.92). Le pool size va plus rapidement réduire la taille de l'image, ce qui va faire perdre de l'information au modèle.
# - Les heatmaps montre que pour une radio normale, le modèle ne se focalise sur rien qui concerne les poumons mais plutôt une lettre, ce qui biaise la précision.
# L'augmentation du pooling n'a pas permis d'améliorer les résultats du modèle et semble empêcher le CNN de se focaliser sur certaines zones d'intêret dans certains cas.

# %%
# Check that GPU is used
import tensorflow as tf
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
from PIL import Image
import os
import numpy as np

# Define the folders where your data is stored
train_folder = 'train'
test_folder = 'test'
val_folder = 'val'

# Define the subfolders within each folder where the images are stored
subfolders = ['NORMAL', 'PNEUMONIA']

# Define the size of the images you want to resize your images to
img_width, img_height = 128, 128

# %%
# Function to load and resize images from a folder
def load_images_from_folder(folder, limit_per_subfolder=None):
    X = []
    y = []
    for subfolder in subfolders:
        folder_path = os.path.join(folder, subfolder)
        if limit_per_subfolder:
            # Get amount of random filenames from the folder
            filenames = np.random.choice(os.listdir(folder_path), limit_per_subfolder, replace=False)
        else:
            filenames = os.listdir(folder_path)
        for filename in filenames:
            img_path = os.path.join(folder_path, filename)
            img = Image.open(img_path)

            # Resize the image to the desired size
            img = img.resize((img_width, img_height))

            # Convert RGB image to grayscale
            img = img.convert('L')

            # Convert the image to a NumPy array and append it to X
            img = np.array(img)
            X.append(img)

            # Append the corresponding label to y
            y.append(subfolders.index(subfolder))

    X = np.array(X)
    y = np.array(y)
    return X, y

# %%
# Generate augmented for the training set
from common.data_augmentation import generate_augmented_images
generate_augmented_images(train_folder, 'NORMAL', image_size=(img_width, img_height))
generate_augmented_images(train_folder, 'PNEUMONIA', image_size=(img_width, img_height))
# Out:
# Found 1341 images belonging to 1 classes.
# Additional count of images to generate: 0
# Given NORMAL count: 1341
# Augmented NORMAL count: 5000
# Found 3874 images belonging to 1 classes.
# Additional count of images to generate: 0
# Given PNEUMONIA count: 3874
# Augmented PNEUMONIA count: 5000

# %%
# Load the training data
# Get min value between the number of normal images and the number of pneumonia images
train_folder = f"{train_folder}_augmented"
min_images = min(len(os.listdir(os.path.join(train_folder, subfolders[0]))), len(os.listdir(os.path.join(train_folder, subfolders[1]))))
X_train, y_train = load_images_from_folder(train_folder, min_images)

# Load the test data
X_test, y_test = load_images_from_folder(test_folder)

# Load the validation data
X_val, y_val = load_images_from_folder(val_folder)

# %%
# Make a matplot figure to show how many images are in each subfolder of train
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))
plt.bar(subfolders, [len(os.listdir(os.path.join(train_folder, subfolder))) for subfolder in subfolders])
plt.title('Number of images in each subfolder of train')
plt.show()

# %%
# Make a matplot figure to show how many images if each class in the training set
plt.figure(figsize=(10, 5))
plt.bar(subfolders, [len(y_train[y_train == i]) for i in range(len(subfolders))])
plt.title('Number of images in each class in the training set')
plt.show()

# %%
# Normalize the pixel values to be between 0 and 1
X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255
X_val = X_val.astype('float32') / 255

X_train = X_train.reshape(len(X_train), img_width, img_height, 1)
X_test = X_test.reshape(len(X_test), img_width, img_height, 1)
X_val = X_val.reshape(len(X_val), img_width, img_height, 1)

# %%
single_image = X_train[np.random.randint(len(X_train))]
print(single_image.shape)
plt.imshow(single_image, cmap='Greys')
# Out:
# (128, 128, 1)

# %%
# Define model metrics
from keras.metrics import AUC

metrics = [
    "accuracy",
    AUC(name='auc')
]

# %% [markdown]
# On double le pool size de chaque couche de Max Pooling

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# Define the model architecture
def create_model():
    model = Sequential()

    model.add(Conv2D(filters=32, kernel_size=(3,3), input_shape=(img_width, img_height, 1), activation="relu"))
    model.add(Conv2D(filters=64, kernel_size=(3,3), activation="relu"))
    model.add(MaxPooling2D(pool_size=(8,8)))

    model.add(Conv2D(filters=128, kernel_size=(3,3), activation="relu"))
    model.add(Conv2D(filters=256, kernel_size=(3,3), activation="relu"))
    model.add(MaxPooling2D(pool_size=(8,8)))

    model.add(Flatten())

    model.add(Dense(256, activation="relu"))
    model.add(Dropout(0.5))

    model.add(Dense(128, activation="relu"))
    model.add(Dropout(0.5))

    model.add(Dense(1, activation="sigmoid"))

    # compile the model
    model.compile(loss="binary_crossentropy", optimizer="adam", metrics=metrics)

    return model

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='loss', patience=3, restore_best_weights=True)

# %%
# Cross validation
from sklearn.model_selection import KFold
from keras.preprocessing.image import ImageDataGenerator

# Define the number of folds for cross-validation
n_splits = 10
epochs = 7
batch_size = 64

# Initialize KFold with the number of folds
kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)

# Define lists to store the evaluation scores for each fold
accuracy_scores = []
histories = []
models = []

# Iterate through each fold and train/evaluate the model
for train_idx, val_idx in kf.split(X_train, y_train):
    # Split the data into training and validation sets for this fold
    X_train_fold, y_train_fold = X_train[train_idx], y_train[train_idx]
    X_val_fold, y_val_fold = X_train[val_idx], y_train[val_idx]

    # Create an instance of ImageDataGenerator to generate your image data
    datagen = ImageDataGenerator()

    # Create generators for training and validation data
    train_generator = datagen.flow(x=X_train_fold, y=y_train_fold, batch_size=batch_size)
    valid_generator = datagen.flow(x=X_val_fold, y=y_val_fold, batch_size=batch_size)

    # Create instance of the model for this fold and train it
    model = create_model()

    # Train your model on the training data for this fold
    history = model.fit(train_generator, validation_data=valid_generator, epochs=epochs, verbose=1, callbacks=[early_stop])
    histories.append(history.history)

    models.append(model)
# Out:
# Epoch 1/7
# 141/141 [==============================] - 10s 40ms/step - loss: 0.5880 - accuracy: 0.6731 - auc: 0.7510 - val_loss: 0.3834 - val_accuracy: 0.8210 - val_auc: 0.9584
# Epoch 2/7
# 141/141 [==============================] - 5s 34ms/step - loss: 0.3052 - accuracy: 0.8809 - auc: 0.9395 - val_loss: 0.2227 - val_accuracy: 0.9220 - val_auc: 0.9726
# Epoch 3/7
# 141/141 [==============================] - 5s 35ms/step - loss: 0.2516 - accuracy: 0.9090 - auc: 0.9582 - val_loss: 0.1870 - val_accuracy: 0.9360 - val_auc: 0.9806
# Epoch 4/7
# 141/141 [==============================] - 5s 35ms/step - loss: 0.2208 - accuracy: 0.9206 - auc: 0.9679 - val_loss: 0.1785 - val_accuracy: 0.9370 - val_auc: 0.9846
# Epoch 5/7
# 141/141 [==============================] - 5s 34ms/step - loss: 0.2152 - accuracy: 0.9201 - auc: 0.9700 - val_loss: 0.1641 - val_accuracy: 0.9490 - val_auc: 0.9851
# Epoch 6/7
# 141/141 [==============================] - 5s 35ms/step - loss: 0.2021 - accuracy: 0.9270 - auc: 0.9730 - val_loss: 0.2016 - val_accuracy: 0.9250 - val_auc: 0.9883
# Epoch 7/7
# 141/141 [==============================] - 5s 36ms/step - loss: 0.1800 - accuracy: 0.9339 - auc: 0.9784 - val_loss: 0.1486 - val_accuracy: 0.9480 - val_auc: 0.9887
# Epoch 1/7
# 141/141 [==============================] - 6s 39ms/step - loss: 0.5267 - accuracy: 0.7056 - auc: 0.8329 - val_loss: 0.3172 - val_accuracy: 0.8880 - val_auc: 0.9469
# Epoch 2/7
# 141/141 [==============================] - 6s 39ms/step - loss: 0.2849 - accuracy: 0.8930 - auc: 0.9476 - val_loss: 0.2533 - val_accuracy: 0.9010 - val_auc: 0.9589
# Epoch 3/7
# 141/141 [==============================] - 5s 37ms/step - loss: 0.2495 - accuracy: 0.9083 - auc: 0.9591 - val_loss: 0.3347 - val_accuracy: 0.8750 - val_auc: 0.9582
# Epoch 4/7
# 141/141 [==============================] - 5s 36ms/step - loss: 0.2264 - accuracy: 0.9182 - auc: 0.9667 - val_loss: 0.2393 - val_accuracy: 0.9090 - val_auc: 0.9683
# Epoch 5/7
# 141/141 [==============================] - 5s 35ms/step - loss: 0.2048 - accuracy: 0.9258 - auc: 0.9723 - val_loss: 0.2224 - val_accuracy: 0.9140 - val_auc: 0.9713
# Epoch 6/7
# 141/141 [==============================] - 5s 36ms/step - loss: 0.1859 - accuracy: 0.9327 - auc: 0.9770 - val_loss: 0.2014 - val_accuracy: 0.9220 - val_auc: 0.9768
# Epoch 7/7
# 141/141 [==============================] - 5s 37ms/step - loss: 0.1727 - accuracy: 0.9390 - auc: 0.9798 - val_loss: 0.2163 - val_accuracy: 0.9200 - val_auc: 0.9774
# Epoch 1/7
# 141/141 [==============================] - 6s 39ms/step - loss: 0.5742 - accuracy: 0.6752 - auc: 0.7929 - val_loss: 0.3868 - val_accuracy: 0.8350 - val_auc: 0.9285
# Epoch 2/7
# 141/141 [==============================] - 6s 38ms/step - loss: 0.3038 - accuracy: 0.8850 - auc: 0.9400 - val_loss: 0.3127 - val_accuracy: 0.8770 - val_auc: 0.9534
# Epoch 3/7
# 141/141 [==============================] - 5s 37ms/step - loss: 0.2548 - accuracy: 0.9071 - auc: 0.9571 - val_loss: 0.2531 - val_accuracy: 0.9070 - val_auc: 0.9686
# Epoch 4/7
# 141/141 [==============================] - 5s 37ms/step - loss: 0.2169 - accuracy: 0.9220 - auc: 0.9682 - val_loss: 0.2146 - val_accuracy: 0.9250 - val_auc: 0.9693
# Epoch 5/7
# 141/141 [==============================] - 5s 37ms/step - loss: 0.2003 - accuracy: 0.9282 - auc: 0.9726 - val_loss: 0.2253 - val_accuracy: 0.9140 - val_auc: 0.9727
# Epoch 6/7
# 141/141 [==============================] - 5s 35ms/step - loss: 0.1774 - accuracy: 0.9383 - auc: 0.9782 - val_loss: 0.1912 - val_accuracy: 0.9350 - val_auc: 0.9775
# Epoch 7/7
# 141/141 [==============================] - 5s 36ms/step - loss: 0.1717 - accuracy: 0.9386 - auc: 0.9802 - val_loss: 0.1997 - val_accuracy: 0.9290 - val_auc: 0.9744
# Epoch 1/7
# 141/141 [==============================] - 7s 40ms/step - loss: 0.5302 - accuracy: 0.7073 - auc: 0.8299 - val_loss: 0.4339 - val_accuracy: 0.8020 - val_auc: 0.9456
# Epoch 2/7
# 141/141 [==============================] - 5s 38ms/step - loss: 0.3071 - accuracy: 0.8812 - auc: 0.9389 - val_loss: 0.2373 - val_accuracy: 0.9090 - val_auc: 0.9664
# Epoch 3/7
# 141/141 [==============================] - 5s 38ms/step - loss: 0.2408 - accuracy: 0.9119 - auc: 0.9623 - val_loss: 0.1908 - val_accuracy: 0.9400 - val_auc: 0.9745
# Epoch 4/7
# 141/141 [==============================] - 5s 37ms/step - loss: 0.2179 - accuracy: 0.9203 - auc: 0.9687 - val_loss: 0.1789 - val_accuracy: 0.9330 - val_auc: 0.9784
# Epoch 5/7
# 141/141 [==============================] - 5s 38ms/step - loss: 0.1923 - accuracy: 0.9319 - auc: 0.9748 - val_loss: 0.1810 - val_accuracy: 0.9360 - val_auc: 0.9781
# Epoch 6/7
# 141/141 [==============================] - 5s 36ms/step - loss: 0.1767 - accuracy: 0.9370 - auc: 0.9788 - val_loss: 0.1600 - val_accuracy: 0.9470 - val_auc: 0.9836
# Epoch 7/7
# 141/141 [==============================] - 5s 36ms/step - loss: 0.1700 - accuracy: 0.9387 - auc: 0.9808 - val_loss: 0.1500 - val_accuracy: 0.9460 - val_auc: 0.9858
# Epoch 1/7
# 141/141 [==============================] - 5s 36ms/step - loss: 0.4981 - accuracy: 0.7449 - auc: 0.8593 - val_loss: 0.2672 - val_accuracy: 0.8960 - val_auc: 0.9537
# Epoch 2/7
# 141/141 [==============================] - 5s 35ms/step - loss: 0.3015 - accuracy: 0.8864 - auc: 0.9413 - val_loss: 0.3658 - val_accuracy: 0.8520 - val_auc: 0.9570
# Epoch 3/7
# 141/141 [==============================] - 5s 35ms/step - loss: 0.2549 - accuracy: 0.9099 - auc: 0.9569 - val_loss: 0.2248 - val_accuracy: 0.9140 - val_auc: 0.9694
# Epoch 4/7
# 141/141 [==============================] - 5s 35ms/step - loss: 0.2237 - accuracy: 0.9180 - auc: 0.9674 - val_loss: 0.2014 - val_accuracy: 0.9250 - val_auc: 0.9762
# Epoch 5/7
# 141/141 [==============================] - 5s 35ms/step - loss: 0.2094 - accuracy: 0.9228 - auc: 0.9716 - val_loss: 0.1842 - val_accuracy: 0.9340 - val_auc: 0.9791
# Epoch 6/7
# 141/141 [==============================] - 5s 35ms/step - loss: 0.1812 - accuracy: 0.9347 - auc: 0.9783 - val_loss: 0.1779 - val_accuracy: 0.9390 - val_auc: 0.9804
# Epoch 7/7
# 141/141 [==============================] - 5s 36ms/step - loss: 0.1847 - accuracy: 0.9304 - auc: 0.9774 - val_loss: 0.1961 - val_accuracy: 0.9230 - val_auc: 0.9796
# Epoch 1/7
# 141/141 [==============================] - 6s 38ms/step - loss: 0.5563 - accuracy: 0.6946 - auc: 0.8122 - val_loss: 0.4334 - val_accuracy: 0.7870 - val_auc: 0.9469
# Epoch 2/7
# 141/141 [==============================] - 5s 37ms/step - loss: 0.3245 - accuracy: 0.8708 - auc: 0.9333 - val_loss: 0.2254 - val_accuracy: 0.9200 - val_auc: 0.9672
# Epoch 3/7
# 141/141 [==============================] - 5s 38ms/step - loss: 0.2562 - accuracy: 0.9023 - auc: 0.9575 - val_loss: 0.2440 - val_accuracy: 0.9060 - val_auc: 0.9736
# Epoch 4/7
# 141/141 [==============================] - 5s 36ms/step - loss: 0.2221 - accuracy: 0.9180 - auc: 0.9677 - val_loss: 0.2461 - val_accuracy: 0.8970 - val_auc: 0.9775
# Epoch 5/7
# 141/141 [==============================] - 5s 36ms/step - loss: 0.2098 - accuracy: 0.9213 - auc: 0.9710 - val_loss: 0.2116 - val_accuracy: 0.9140 - val_auc: 0.9825
# Epoch 6/7
# 141/141 [==============================] - 5s 35ms/step - loss: 0.1887 - accuracy: 0.9280 - auc: 0.9763 - val_loss: 0.2153 - val_accuracy: 0.9080 - val_auc: 0.9826
# Epoch 7/7
# 141/141 [==============================] - 5s 37ms/step - loss: 0.1724 - accuracy: 0.9374 - auc: 0.9799 - val_loss: 0.1482 - val_accuracy: 0.9480 - val_auc: 0.9841
# Epoch 1/7
# 141/141 [==============================] - 6s 38ms/step - loss: 0.5825 - accuracy: 0.6670 - auc: 0.7880 - val_loss: 0.3333 - val_accuracy: 0.8670 - val_auc: 0.9534
# Epoch 2/7
# 141/141 [==============================] - 5s 38ms/step - loss: 0.3082 - accuracy: 0.8802 - auc: 0.9389 - val_loss: 0.2499 - val_accuracy: 0.9020 - val_auc: 0.9669
# Epoch 3/7
# 141/141 [==============================] - 5s 38ms/step - loss: 0.2509 - accuracy: 0.9124 - auc: 0.9585 - val_loss: 0.1899 - val_accuracy: 0.9340 - val_auc: 0.9784
# Epoch 4/7
# 141/141 [==============================] - 5s 37ms/step - loss: 0.2277 - accuracy: 0.9151 - auc: 0.9665 - val_loss: 0.1778 - val_accuracy: 0.9380 - val_auc: 0.9820
# Epoch 5/7
# 141/141 [==============================] - 5s 37ms/step - loss: 0.1978 - accuracy: 0.9282 - auc: 0.9735 - val_loss: 0.2120 - val_accuracy: 0.9100 - val_auc: 0.9833
# Epoch 6/7
# 141/141 [==============================] - 5s 35ms/step - loss: 0.1927 - accuracy: 0.9308 - auc: 0.9756 - val_loss: 0.1836 - val_accuracy: 0.9260 - val_auc: 0.9824
# Epoch 7/7
# 141/141 [==============================] - 5s 35ms/step - loss: 0.1720 - accuracy: 0.9378 - auc: 0.9803 - val_loss: 0.1636 - val_accuracy: 0.9370 - val_auc: 0.9853
# Epoch 1/7
# 141/141 [==============================] - 6s 36ms/step - loss: 0.5866 - accuracy: 0.6679 - auc: 0.7862 - val_loss: 0.4657 - val_accuracy: 0.7790 - val_auc: 0.9154
# Epoch 2/7
# 141/141 [==============================] - 5s 35ms/step - loss: 0.3071 - accuracy: 0.8814 - auc: 0.9400 - val_loss: 0.2592 - val_accuracy: 0.8980 - val_auc: 0.9593
# Epoch 3/7
# 141/141 [==============================] - 5s 35ms/step - loss: 0.2343 - accuracy: 0.9120 - auc: 0.9634 - val_loss: 0.2346 - val_accuracy: 0.9070 - val_auc: 0.9654
# Epoch 4/7
# 141/141 [==============================] - 5s 35ms/step - loss: 0.2159 - accuracy: 0.9194 - auc: 0.9693 - val_loss: 0.2239 - val_accuracy: 0.9080 - val_auc: 0.9684
# Epoch 5/7
# 141/141 [==============================] - 5s 35ms/step - loss: 0.2089 - accuracy: 0.9249 - auc: 0.9710 - val_loss: 0.2194 - val_accuracy: 0.9090 - val_auc: 0.9696
# Epoch 6/7
# 141/141 [==============================] - 5s 35ms/step - loss: 0.2030 - accuracy: 0.9224 - auc: 0.9733 - val_loss: 0.2441 - val_accuracy: 0.9080 - val_auc: 0.9689
# Epoch 7/7
# 141/141 [==============================] - 5s 35ms/step - loss: 0.1778 - accuracy: 0.9352 - auc: 0.9789 - val_loss: 0.2359 - val_accuracy: 0.9100 - val_auc: 0.9732
# Epoch 1/7
# 141/141 [==============================] - 5s 36ms/step - loss: 0.5219 - accuracy: 0.7163 - auc: 0.8370 - val_loss: 0.2866 - val_accuracy: 0.8870 - val_auc: 0.9550
# Epoch 2/7
# 141/141 [==============================] - 5s 35ms/step - loss: 0.3007 - accuracy: 0.8826 - auc: 0.9414 - val_loss: 0.2372 - val_accuracy: 0.9130 - val_auc: 0.9658
# Epoch 3/7
# 141/141 [==============================] - 5s 35ms/step - loss: 0.2458 - accuracy: 0.9080 - auc: 0.9602 - val_loss: 0.2230 - val_accuracy: 0.9210 - val_auc: 0.9724
# Epoch 4/7
# 141/141 [==============================] - 5s 35ms/step - loss: 0.2364 - accuracy: 0.9096 - auc: 0.9635 - val_loss: 0.2146 - val_accuracy: 0.9170 - val_auc: 0.9735
# Epoch 5/7
# 141/141 [==============================] - 5s 35ms/step - loss: 0.2108 - accuracy: 0.9219 - auc: 0.9703 - val_loss: 0.1953 - val_accuracy: 0.9280 - val_auc: 0.9763
# Epoch 6/7
# 141/141 [==============================] - 5s 35ms/step - loss: 0.2352 - accuracy: 0.9090 - auc: 0.9647 - val_loss: 0.2174 - val_accuracy: 0.9150 - val_auc: 0.9732
# Epoch 7/7
# 141/141 [==============================] - 5s 36ms/step - loss: 0.1950 - accuracy: 0.9289 - auc: 0.9748 - val_loss: 0.2212 - val_accuracy: 0.9170 - val_auc: 0.9766
# Epoch 1/7
# 141/141 [==============================] - 5s 36ms/step - loss: 0.5713 - accuracy: 0.6663 - auc: 0.7883 - val_loss: 0.3457 - val_accuracy: 0.8620 - val_auc: 0.9232
# Epoch 2/7
# 141/141 [==============================] - 5s 34ms/step - loss: 0.3112 - accuracy: 0.8793 - auc: 0.9368 - val_loss: 0.2745 - val_accuracy: 0.8970 - val_auc: 0.9495
# Epoch 3/7
# 141/141 [==============================] - 5s 35ms/step - loss: 0.2568 - accuracy: 0.9050 - auc: 0.9568 - val_loss: 0.2637 - val_accuracy: 0.8980 - val_auc: 0.9618
# Epoch 4/7
# 141/141 [==============================] - 5s 35ms/step - loss: 0.2232 - accuracy: 0.9180 - auc: 0.9673 - val_loss: 0.2208 - val_accuracy: 0.9210 - val_auc: 0.9697
# Epoch 5/7
# 141/141 [==============================] - 5s 35ms/step - loss: 0.2077 - accuracy: 0.9258 - auc: 0.9716 - val_loss: 0.1949 - val_accuracy: 0.9300 - val_auc: 0.9745
# Epoch 6/7
# 141/141 [==============================] - 5s 35ms/step - loss: 0.1930 - accuracy: 0.9310 - auc: 0.9752 - val_loss: 0.1878 - val_accuracy: 0.9370 - val_auc: 0.9771
# Epoch 7/7
# 141/141 [==============================] - 5s 36ms/step - loss: 0.1869 - accuracy: 0.9317 - auc: 0.9768 - val_loss: 0.1887 - val_accuracy: 0.9270 - val_auc: 0.9769

# %%
# Get accuracy scores for each fold (train and validation)
loss = []
acc = []
val_loss = []
val_acc = []

for history in histories:
    loss.append(np.mean(history["loss"]))
    acc.append(np.mean(history["accuracy"]))
    val_loss.append(np.mean(history["val_loss"]))
    val_acc.append(np.mean(history["val_accuracy"]))

# %%
# Plot loss and validation loss per fold
import matplotlib.pyplot as plt
plt.title('Losses')
plt.plot(range(1, len(loss)+1), loss, label='Loss')
plt.plot(range(1, len(val_loss)+1), val_loss, label='Validation loss')
plt.ylim(0.0, 1.0)
plt.xlabel('Fold')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Plot accuracies and validation accuracies per fold
import matplotlib.pyplot as plt
plt.title('Accuracies')
plt.plot(range(1, len(acc)+1), acc, label='Accuracy')
plt.plot(range(1, len(val_acc)+1), val_acc, label='Validation accuracy')
plt.ylim(0.0, 1.0)
plt.xlabel('Fold')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Train a final model with same parameters and save it
train_generator = datagen.flow(x=X_train, y=y_train, batch_size=batch_size)
valid_generator = datagen.flow(x=X_val, y=y_val, batch_size=batch_size)
model = create_model()
history = model.fit(train_generator, validation_data=valid_generator, epochs=epochs, verbose=1, callbacks=[early_stop])
model.save('cnn.h5')
# Out:
# Epoch 1/7
# 157/157 [==============================] - 7s 40ms/step - loss: 0.4928 - accuracy: 0.7609 - auc: 0.8648 - val_loss: 0.6033 - val_accuracy: 0.6250 - val_auc: 0.8047
# Epoch 2/7
# 157/157 [==============================] - 6s 38ms/step - loss: 0.2860 - accuracy: 0.8924 - auc: 0.9466 - val_loss: 0.6885 - val_accuracy: 0.6875 - val_auc: 0.8750
# Epoch 3/7
# 157/157 [==============================] - 6s 36ms/step - loss: 0.2370 - accuracy: 0.9131 - auc: 0.9627 - val_loss: 0.8528 - val_accuracy: 0.6250 - val_auc: 0.9609
# Epoch 4/7
# 157/157 [==============================] - 6s 36ms/step - loss: 0.2097 - accuracy: 0.9233 - auc: 0.9707 - val_loss: 0.8625 - val_accuracy: 0.6250 - val_auc: 0.9688
# Epoch 5/7
# 157/157 [==============================] - 6s 37ms/step - loss: 0.1891 - accuracy: 0.9327 - auc: 0.9758 - val_loss: 0.4627 - val_accuracy: 0.7500 - val_auc: 0.9531
# Epoch 6/7
# 157/157 [==============================] - 6s 37ms/step - loss: 0.1737 - accuracy: 0.9408 - auc: 0.9794 - val_loss: 0.9674 - val_accuracy: 0.6875 - val_auc: 0.9922
# Epoch 7/7
# 157/157 [==============================] - 6s 38ms/step - loss: 0.1609 - accuracy: 0.9402 - auc: 0.9827 - val_loss: 0.2775 - val_accuracy: 0.8750 - val_auc: 0.9844

# %%
# Plot val accuracy and val loss of the trained model
import matplotlib.pyplot as plt
plt.title('Accuracy vs Loss per Epoch')
plt.plot(range(1, len(history.history["val_accuracy"])+1), history.history["val_accuracy"], label='Accuracy')
plt.plot(range(1, len(history.history["val_loss"])+1), history.history["val_loss"], label='Loss')
plt.ylim(0.0, 1.0)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Make predictions on the test set
y_pred_test = model.predict(X_test)
y_pred_test = np.where(y_pred_test >= 0.5, 1, 0)
# Out:
# 20/20 [==============================] - 0s 6ms/step

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Compute ROC curve and AUC score for the predictions
fpr, tpr, thresholds = roc_curve(y_test, y_pred_test)
roc_auc = auc(fpr, tpr)

# Plot ROC curve and show AUC score on the plot
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()

# %%
from sklearn.metrics import confusion_matrix
# Compute the confusion matrix for test set
cm = confusion_matrix(y_test, y_pred_test.flatten())
print(cm)
# Out:
# [[206  28]
#  [ 24 366]]

# %%
# Plot the confusion matrix
class_names = subfolders
import seaborn as sns
sns.heatmap(cm, annot=True, fmt='g', cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()

# %%
# Compute the classification report for test set
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred_test, target_names=class_names))
# Out:
#               precision    recall  f1-score   support
#
#       NORMAL       0.90      0.88      0.89       234
#    PNEUMONIA       0.93      0.94      0.93       390
#
#     accuracy                           0.92       624
#    macro avg       0.91      0.91      0.91       624
# weighted avg       0.92      0.92      0.92       624

# %%
# Heatmaps and Grad-CAM
from common.cam import get_img_array
import cv2
import matplotlib.pyplot as plt 

images = [
    {
        "path": "./val/NORMAL/NORMAL2-IM-1442-0001.jpeg"
    },
    {
        "path": "./val/PNEUMONIA/person1946_bacteria_4874.jpeg"
    }
]

for image in images:
    image_temp = cv2.imread(image["path"])
    image_temp = cv2.cvtColor(image_temp, cv2.COLOR_RGB2GRAY)
    image_temp = cv2.resize(image_temp, (img_width, img_height))

    plt.imshow(image_temp, cmap=plt.cm.gray)
    plt.show()
    
    image["array"] = get_img_array(image["path"], size=(img_width, img_height))
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\keras\utils\image_utils.py:409: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn(

# %%
# Remove last layer's softmax
model.layers[-1].activation = None

# import os
# os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
# Print model summary to get last max pooling layer name
print(model.summary())
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_40 (Conv2D)          (None, 126, 126, 32)      320
#
#  conv2d_41 (Conv2D)          (None, 124, 124, 64)      18496
#
#  max_pooling2d_20 (MaxPoolin  (None, 15, 15, 64)       0
#  g2D)
#
#  conv2d_42 (Conv2D)          (None, 13, 13, 128)       73856
#
#  conv2d_43 (Conv2D)          (None, 11, 11, 256)       295168
#
#  max_pooling2d_21 (MaxPoolin  (None, 1, 1, 256)        0
#  g2D)
#
#  flatten_10 (Flatten)        (None, 256)               0
#
#  dense_30 (Dense)            (None, 256)               65792
#
#  dropout_20 (Dropout)        (None, 256)               0
#
#  dense_31 (Dense)            (None, 128)               32896
#
#  dropout_21 (Dropout)        (None, 128)               0
#
#  dense_32 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 486,657
# Trainable params: 486,657
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Select last conv layer
last_conv_layer_name = "conv2d_43"

# %%
from common.cam import make_gradcam_heatmap, display_heatmaps

for image in images:
    heatmaps = []
    for layer in model.layers[:model.layers.index(model.get_layer(last_conv_layer_name)) + 1]:
        heatmap = make_gradcam_heatmap(image["array"], model, layer.name)
        heatmaps.append({
            "layer_name": layer.name,
            "image": heatmap
        })

    # Display heatmaps from all layers until the last max pooling layer
    display_heatmaps(image["path"], heatmaps)

    # Display the chosen image superimposed with heatmaps of each layer until the last max pooling layer
    display_heatmaps(image["path"], heatmaps, True)

# %%
# Predict
for image in images:
    pred = model.predict(image["array"].reshape(1, img_width, img_height, 1))
    print(pred)
    # Display predicted class
    print("Predicted class: {}".format(subfolders[int(pred[0][0])]))
